# %% [markdown]
# ## Subtask A: Entity and Relationship Extraction

# %%
#pip install transformers
#pip install spacy
#pip install nltk
#pip install torch
#pip install requests beautifulsoup4
#pip install yahooquery
#pip install scikit-learn
#pip install gensim

# %%
#!python -m spacy download en_core_web_sm

# %%
import sqlite3
from transformers import AutoTokenizer, AutoModelForTokenClassification, pipeline
import spacy 
import nltk
import requests 
import torch
import pandas as pd
import re

from collections import Counter, defaultdict
from bs4 import BeautifulSoup
from sklearn.feature_extraction.text import TfidfVectorizer
from gensim import corpora
from gensim.models import LdaModel
pd.set_option("display.max_rows", 200)

# %%
dbpath = 'ecmdatabase.db'
con = sqlite3.connect(f"file:{dbpath}?mode=ro", uri=True)
with con:
    result = con.execute("SELECT * from companies WHERE stock_symbol = 'TSLA';")
    records = result.fetchall()
    company_name = records[0][1]
    tsla_item1 = records[0][2]

# %%
tsla_item1
# Out:
# " ITEM 1. BUSINESS \n\nOverview \n\nWe design, develop, manufacture, sell and lease high-performance fully electric vehicles and energy generation and storage systems, and offer services related to our products. We generally sell our products directly to customers, and continue to grow our customer-facing infrastructure through a global network of vehicle showrooms and service centers, Mobile Service, body shops, Supercharger stations and Destination Chargers to accelerate the widespread adoption of our products. We emphasize performance, attractive styling and the safety of our users and workforce in the design and manufacture of our products and are continuing to develop full self-driving technology for improved safety. We also strive to lower the cost of ownership for our customers through continuous efforts to reduce manufacturing costs and by offering financial and other services tailored to our products. \n\nOur mission is to accelerate the world&#8217;s transition to sustainable energy. We believe that this mission, along with our engineering expertise, vertically integrated business model and focus on user experience differentiate us from other companies. \n\nSegment Information \n\nWe operate as two reportable segments: (i) automotive and (ii) energy generation and storage. \n\nThe automotive segment includes the design, development, manufacturing, sales and leasing of high-performance fully electric vehicles as well as sales of automotive regulatory credits. Additionally, the automotive segment also includes services and other, which includes sales of used vehicles, non-warranty after-sales vehicle services, body shop and parts, paid Supercharging, vehicle insurance revenue and retail merchandise. The energy generation and storage segment includes the design, manufacture, installation, sales and leasing of solar energy generation and energy storage products and related services and sales of solar energy systems incentives. \n\nOur Products and Services \n\nAutomotive \n\nWe currently manufacture five different consumer vehicles &#8211; the Model 3, Y, S, X and Cybertruck. Model 3 is a four-door mid-size sedan that we designed for manufacturability with a base price for mass-market appeal. Model Y is a compact sport utility vehicle (&#8220;SUV&#8221;) built on the Model 3 platform with seating for up to seven adults. Model S is a four-door full-size sedan and Model X is a mid-size SUV with seating for up to seven adults. Model S and Model X feature the highest performance characteristics and longest ranges that we offer in a sedan and SUV, respectively. In November 2023, we entered the consumer pickup truck market with first deliveries of the Cybertruck, a full-size electric pickup truck with a stainless steel exterior that has the utility and strength of a truck while featuring the speed of a sports car. \n\nIn 2022, we also began early production and deliveries of a commercial electric vehicle, the Tesla Semi. We have planned electric vehicles to address additional vehicle markets, and to continue leveraging developments in our proprietary Full Self-Driving (&#8220;FSD&#8221;) Capability features, battery cell and other technologies. \n\nEnergy Generation and Storage \n\nEnergy Storage Products \n\nPowerwall and Megapack are our lithium-ion battery energy storage products. Powerwall, which we sell directly to customers, as well as through channel partners, is designed to store energy at a home or small commercial facility. Megapack is an energy storage solution for commercial, industrial, utility and energy generation customers, multiple of which may be grouped together to form larger installations of gigawatt hours (&#8220;GWh&#8221;) or greater capacity. \n\nWe also continue to develop software capabilities for remotely controlling and dispatching our energy storage systems across a wide range of markets and applications, including through our real-time energy control and optimization platforms. \n\nSolar Energy O ...

# %%
tsla_item1 = tsla_item1.replace('\n', '')
tsla_item1
# Out:
# " ITEM 1. BUSINESS Overview We design, develop, manufacture, sell and lease high-performance fully electric vehicles and energy generation and storage systems, and offer services related to our products. We generally sell our products directly to customers, and continue to grow our customer-facing infrastructure through a global network of vehicle showrooms and service centers, Mobile Service, body shops, Supercharger stations and Destination Chargers to accelerate the widespread adoption of our products. We emphasize performance, attractive styling and the safety of our users and workforce in the design and manufacture of our products and are continuing to develop full self-driving technology for improved safety. We also strive to lower the cost of ownership for our customers through continuous efforts to reduce manufacturing costs and by offering financial and other services tailored to our products. Our mission is to accelerate the world&#8217;s transition to sustainable energy. We believe that this mission, along with our engineering expertise, vertically integrated business model and focus on user experience differentiate us from other companies. Segment Information We operate as two reportable segments: (i) automotive and (ii) energy generation and storage. The automotive segment includes the design, development, manufacturing, sales and leasing of high-performance fully electric vehicles as well as sales of automotive regulatory credits. Additionally, the automotive segment also includes services and other, which includes sales of used vehicles, non-warranty after-sales vehicle services, body shop and parts, paid Supercharging, vehicle insurance revenue and retail merchandise. The energy generation and storage segment includes the design, manufacture, installation, sales and leasing of solar energy generation and energy storage products and related services and sales of solar energy systems incentives. Our Products and Services Automotive We currently manufacture five different consumer vehicles &#8211; the Model 3, Y, S, X and Cybertruck. Model 3 is a four-door mid-size sedan that we designed for manufacturability with a base price for mass-market appeal. Model Y is a compact sport utility vehicle (&#8220;SUV&#8221;) built on the Model 3 platform with seating for up to seven adults. Model S is a four-door full-size sedan and Model X is a mid-size SUV with seating for up to seven adults. Model S and Model X feature the highest performance characteristics and longest ranges that we offer in a sedan and SUV, respectively. In November 2023, we entered the consumer pickup truck market with first deliveries of the Cybertruck, a full-size electric pickup truck with a stainless steel exterior that has the utility and strength of a truck while featuring the speed of a sports car. In 2022, we also began early production and deliveries of a commercial electric vehicle, the Tesla Semi. We have planned electric vehicles to address additional vehicle markets, and to continue leveraging developments in our proprietary Full Self-Driving (&#8220;FSD&#8221;) Capability features, battery cell and other technologies. Energy Generation and Storage Energy Storage Products Powerwall and Megapack are our lithium-ion battery energy storage products. Powerwall, which we sell directly to customers, as well as through channel partners, is designed to store energy at a home or small commercial facility. Megapack is an energy storage solution for commercial, industrial, utility and energy generation customers, multiple of which may be grouped together to form larger installations of gigawatt hours (&#8220;GWh&#8221;) or greater capacity. We also continue to develop software capabilities for remotely controlling and dispatching our energy storage systems across a wide range of markets and applications, including through our real-time energy control and optimization platforms. Solar Energy Offerings We sell retrofit solar energy systems to customers  ...

# %% [markdown]
# ## Data Exploration - Text Analysis

# %% [markdown]
# ### Frequency Analysis

# %%
## FREQUENCY ANALYSIS
# load spacy model
nlp = spacy.load('en_core_web_sm')
nlp.disable_pipe("parser")
nlp.enable_pipe("senter")
# load data
doc = nlp(tsla_item1)
words = [token.text for token in doc if not token.is_stop and not token.is_punct]

print(Counter(words).most_common(20))
# Out:
# [('energy', 75), ('vehicles', 68), ('systems', 39), ('vehicle', 34), ('products', 33), ('solar', 33), ('storage', 32), ('customers', 32), ('Tesla', 32), ('U.S.', 25), ('electric', 24), ('including', 24), ('certain', 23), ('battery', 20), ('driving', 18), ('new', 17), ('offer', 16), ('self', 16), ('markets', 16), ('Energy', 16)]

# %% [markdown]
# From the frequency analysis, we see that Tesla was mentioned a total of 32 times.

# %% [markdown]
# ### TF-IDF

# %%
# Load spaCy model
nlp = spacy.load('en_core_web_sm')

# Step 1: Load and preprocess the text
text_data = [tsla_item1]

# Tokenization using nltk
nltk.download('punkt')
nltk.download('stopwords')
from nltk.corpus import stopwords
from nltk.tokenize import word_tokenize

stop_words = set(stopwords.words('english'))

def preprocess(text):
    # Tokenization and lowercasing
    tokens = word_tokenize(text.lower())
    # Remove stopwords and non-alphabetic characters
    tokens = [word for word in tokens if word.isalpha() and word not in stop_words]
    return ' '.join(tokens)

# Preprocess the data
processed_text = [preprocess(text) for text in text_data]
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\DELL\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\DELL\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!

# %%
# TF-IDF Vectorization
tfidf_vectorizer = TfidfVectorizer(max_features=10)  # Limit to top 10 features for brevity
tfidf_matrix = tfidf_vectorizer.fit_transform(processed_text)
tfidf_keywords = tfidf_vectorizer.get_feature_names_out()

print("Top TF-IDF Keywords:")
print(tfidf_keywords)
# Out:
# Top TF-IDF Keywords:
# ['also' 'customers' 'energy' 'products' 'solar' 'storage' 'systems'
#  'tesla' 'vehicle' 'vehicles']

# %% [markdown]
# ### LDA

# %%
# Prepare data for LDA
tokenized_texts = [preprocess(text).split() for text in text_data]
dictionary = corpora.Dictionary(tokenized_texts)
corpus = [dictionary.doc2bow(text) for text in tokenized_texts]

# Train LDA model
lda_model = LdaModel(corpus, num_topics=2, id2word=dictionary, passes=15)

# Display topics
print("LDA Topics:")
for idx, topic in lda_model.print_topics(-1):
    print(f"Topic {idx}: {topic}")
# Out:
# LDA Topics:
# Topic 0: 0.020*"energy" + 0.015*"vehicles" + 0.010*"solar" + 0.010*"also" + 0.009*"storage" + 0.009*"systems" + 0.008*"vehicle" + 0.008*"products" + 0.007*"customers" + 0.007*"tesla"
# Topic 1: 0.001*"vehicles" + 0.001*"energy" + 0.001*"storage" + 0.001*"also" + 0.001*"solar" + 0.001*"systems" + 0.001*"products" + 0.001*"vehicle" + 0.001*"customers" + 0.001*"certain"

# %% [markdown]
# ### Pos tagging

# %%
# POS Tagging using spaCy
doc = nlp(tsla_item1)

# Extract POS tags
pos_tags = [(token.text, token.pos_) for token in doc]

print("Part-of-Speech Tags:")
print(pos_tags)
# Out:
# Part-of-Speech Tags:
# [(' ', 'SPACE'), ('ITEM', 'PROPN'), ('1', 'NUM'), ('.', 'PUNCT'), ('BUSINESS', 'PROPN'), ('Overview', 'PROPN'), ('We', 'PRON'), ('design', 'VERB'), (',', 'PUNCT'), ('develop', 'VERB'), (',', 'PUNCT'), ('manufacture', 'NOUN'), (',', 'PUNCT'), ('sell', 'VERB'), ('and', 'CCONJ'), ('lease', 'VERB'), ('high', 'ADJ'), ('-', 'PUNCT'), ('performance', 'NOUN'), ('fully', 'ADV'), ('electric', 'ADJ'), ('vehicles', 'NOUN'), ('and', 'CCONJ'), ('energy', 'NOUN'), ('generation', 'NOUN'), ('and', 'CCONJ'), ('storage', 'NOUN'), ('systems', 'NOUN'), (',', 'PUNCT'), ('and', 'CCONJ'), ('offer', 'VERB'), ('services', 'NOUN'), ('related', 'VERB'), ('to', 'ADP'), ('our', 'PRON'), ('products', 'NOUN'), ('.', 'PUNCT'), ('We', 'PRON'), ('generally', 'ADV'), ('sell', 'VERB'), ('our', 'PRON'), ('products', 'NOUN'), ('directly', 'ADV'), ('to', 'ADP'), ('customers', 'NOUN'), (',', 'PUNCT'), ('and', 'CCONJ'), ('continue', 'VERB'), ('to', 'PART'), ('grow', 'VERB'), ('our', 'PRON'), ('customer', 'NOUN'), ('-', 'PUNCT'), ('facing', 'VERB'), ('infrastructure', 'NOUN'), ('through', 'ADP'), ('a', 'DET'), ('global', 'ADJ'), ('network', 'NOUN'), ('of', 'ADP'), ('vehicle', 'NOUN'), ('showrooms', 'NOUN'), ('and', 'CCONJ'), ('service', 'NOUN'), ('centers', 'NOUN'), (',', 'PUNCT'), ('Mobile', 'PROPN'), ('Service', 'PROPN'), (',', 'PUNCT'), ('body', 'NOUN'), ('shops', 'NOUN'), (',', 'PUNCT'), ('Supercharger', 'NOUN'), ('stations', 'NOUN'), ('and', 'CCONJ'), ('Destination', 'PROPN'), ('Chargers', 'PROPN'), ('to', 'PART'), ('accelerate', 'VERB'), ('the', 'DET'), ('widespread', 'ADJ'), ('adoption', 'NOUN'), ('of', 'ADP'), ('our', 'PRON'), ('products', 'NOUN'), ('.', 'PUNCT'), ('We', 'PRON'), ('emphasize', 'VERB'), ('performance', 'NOUN'), (',', 'PUNCT'), ('attractive', 'ADJ'), ('styling', 'NOUN'), ('and', 'CCONJ'), ('the', 'DET'), ('safety', 'NOUN'), ('of', 'ADP'), ('our', 'PRON'), ('users', 'NOUN'), ('and', 'CCONJ'), ('workforce', 'NOUN'), ('in', 'ADP'), ('the', 'DET'), ('design', 'NOUN'), ('and', 'CCONJ'), ('manufacture', 'NOUN'), ('of', 'ADP'), ('our', 'PRON'), ('products', 'NOUN'), ('and', 'CCONJ'), ('are', 'AUX'), ('continuing', 'VERB'), ('to', 'PART'), ('develop', 'VERB'), ('full', 'ADJ'), ('self', 'NOUN'), ('-', 'PUNCT'), ('driving', 'VERB'), ('technology', 'NOUN'), ('for', 'ADP'), ('improved', 'ADJ'), ('safety', 'NOUN'), ('.', 'PUNCT'), ('We', 'PRON'), ('also', 'ADV'), ('strive', 'VERB'), ('to', 'PART'), ('lower', 'VERB'), ('the', 'DET'), ('cost', 'NOUN'), ('of', 'ADP'), ('ownership', 'NOUN'), ('for', 'ADP'), ('our', 'PRON'), ('customers', 'NOUN'), ('through', 'ADP'), ('continuous', 'ADJ'), ('efforts', 'NOUN'), ('to', 'PART'), ('reduce', 'VERB'), ('manufacturing', 'NOUN'), ('costs', 'NOUN'), ('and', 'CCONJ'), ('by', 'ADP'), ('offering', 'VERB'), ('financial', 'ADJ'), ('and', 'CCONJ'), ('other', 'ADJ'), ('services', 'NOUN'), ('tailored', 'VERB'), ('to', 'ADP'), ('our', 'PRON'), ('products', 'NOUN'), ('.', 'PUNCT'), ('Our', 'PRON'), ('mission', 'NOUN'), ('is', 'AUX'), ('to', 'PART'), ('accelerate', 'VERB'), ('the', 'DET'), ('world&#8217;s', 'NOUN'), ('transition', 'NOUN'), ('to', 'ADP'), ('sustainable', 'ADJ'), ('energy', 'NOUN'), ('.', 'PUNCT'), ('We', 'PRON'), ('believe', 'VERB'), ('that', 'SCONJ'), ('this', 'DET'), ('mission', 'NOUN'), (',', 'PUNCT'), ('along', 'ADP'), ('with', 'ADP'), ('our', 'PRON'), ('engineering', 'NOUN'), ('expertise', 'NOUN'), (',', 'PUNCT'), ('vertically', 'ADV'), ('integrated', 'VERB'), ('business', 'NOUN'), ('model', 'NOUN'), ('and', 'CCONJ'), ('focus', 'VERB'), ('on', 'ADP'), ('user', 'NOUN'), ('experience', 'NOUN'), ('differentiate', 'VERB'), ('us', 'PRON'), ('from', 'ADP'), ('other', 'ADJ'), ('companies', 'NOUN'), ('.', 'PUNCT'), ('Segment', 'NOUN'), ('Information', 'PROPN'), ('We', 'PRON'), ('operate', 'VERB'), ('as', 'ADP'), ('two', 'NUM'), ('reportable', 'ADJ'), ('segments', 'NOUN'), (':', 'PUNCT'), ('(', 'PUNCT'), ('i', 'NOUN'), (')', 'PUNCT'), ('automotive', 'ADJ'), ('and', 'CCONJ'), ('(', 'PUNCT'), ('ii', 'PROPN'), (')', 'PUNCT') ...

# %% [markdown]
# ## Named Entity Recognition

# %% [markdown]
# ### NLTK

# %%
## using nltk to identify mentions of Tesla
'''
nltk.download('punkt')
nltk.download('punkt_tab')
nltk.download('averaged_perceptron_tagger_eng')
nltk.download('maxent_ne_chunker_tab')
nltk.download('words')
''' 
nltk_name=[]
nltk_label=[]
for sent in nltk.sent_tokenize(tsla_item1):
  for chunk in nltk.ne_chunk(nltk.pos_tag(nltk.word_tokenize(sent))):
     if hasattr(chunk, 'label'):
      entity_name = ' '.join(c[0] for c in chunk)
      entity_label = chunk.label()
      nltk_name.append(entity_name)
      nltk_label.append(entity_label)
      if entity_name == 'Tesla':
        print(entity_label, entity_name)
# Out:
# GPE Tesla
# PERSON Tesla
# PERSON Tesla
# ORGANIZATION Tesla
# GPE Tesla
# GPE Tesla
# GPE Tesla
# PERSON Tesla
# PERSON Tesla
# PERSON Tesla
# GPE Tesla
# GPE Tesla
# GPE Tesla
# ORGANIZATION Tesla
# ORGANIZATION Tesla
# PERSON Tesla
# PERSON Tesla
# ORGANIZATION Tesla
# ORGANIZATION Tesla

# %% [markdown]
# We see that the word Tesla was recognised as an entity 19 times. However, it was only correctly tagged as an organisation 5 times, resulting in a precision of only 26.3% and a recall of 59%. In fact, NLTK more frequently classifies Tesla as a geographical location (GPE)! We wish to find a NER model that can perform better at accurately linking entities. We try SpaCy next.

# %% [markdown]
# ### Spacy

# %% [markdown]
# SpaCy recognises 26 high-level entity classes, including:
# - PERSON:      People, including fictional.
# - NORP:        Nationalities or religious or political groups.
# - FAC:         Buildings, airports, highways, bridges, etc.
# - ORG:         Companies, agencies, institutions, etc.
# - GPE:         Countries, cities, states.
# - LOC:         Non-GPE locations, mountain ranges, bodies of water.
# - PRODUCT:     Objects, vehicles, foods, etc. (Not services.)
# - DATE:        Absolute or relative dates or periods.
# - TIME:        Times smaller than a day.

# %%
## Using spacy

# load spacy model
nlp = spacy.load('en_core_web_sm')
nlp.disable_pipe("parser")
nlp.enable_pipe("senter")
# load data
doc = nlp(tsla_item1)
Spacy_name=[]
Spacy_label=[]
# collect unique labels
unique_labels = {}
for ent in doc.ents:
    if ent.label_ not in unique_labels.keys():
        unique_labels[ent.label_] = []
    unique_labels[ent.label_].append((ent.text, ent.start_char, ent.end_char))
    Spacy_name.append(ent.text)
    Spacy_label.append(ent.label_)
    if ent.text == 'Tesla':
        print(ent.text, ent.label_)
# Out:
# Tesla ORG
# Tesla ORG
# Tesla ORG
# Tesla NORP
# Tesla ORG
# Tesla ORG
# Tesla NORP
# Tesla ORG
# Tesla ORG
# Tesla ORG
# Tesla ORG
# Tesla ORG
# Tesla ORG
# Tesla ORG
# Tesla ORG
# Tesla ORG
# Tesla ORG
# Tesla ORG
# Tesla ORG
# Tesla ORG

# %% [markdown]
# SpaCy performs much better than NLTK, recognising Tesla as an entity 20 times, and correctly identifying it as an organisation 18 times, for a precision of 90% and recall of 62.5%.

# %% [markdown]
# ## NER Evaluation

# %% [markdown]
# We generalise the process of identifying the most frequently assigned label for a given entity below.

# %%
def count(name, label):
    name_counts = {}
    for n, l in zip(name, label):
        if n in name_counts:
            name_counts[n] += 1
        else:
            name_counts[n] = 1
    return name_counts

def transfer_dic(name, label):
    name_label_counts = {}
    for n, l in zip(name, label):
        key = (n, l) 
        if key in name_label_counts:
            name_label_counts[key] += 1
        else:
            name_label_counts[key] = 1
    return name_label_counts

# output first the total appearing counts and the respective counts of each label
def check_name(name, label, target_name):
    if target_name not in name:
        return "no target_name"
    name_counts=count(name, label)
    name_label_counts=transfer_dic(name, label)
    print("total counts "+ str(name_counts[target_name]))
    for i in name_label_counts:
        if i[0]==target_name:
            print((i[1],name_label_counts[i]))

# output a dictionary containg the key of name and the label with highest appearing ratio. {name:(label,ratio)}
def get_NER(name, label,entity = None):
    res={}
    name_counts=count(name, label)
    name_label_counts=transfer_dic(name, label)
    for i in list(set(name)):
        for j in name_label_counts:
            if j[0]==i:
                ratio=name_label_counts[j]/name_counts[i]
                if j[0] in res:
                    if ratio>res[j[0]][1]:
                        res[j[0]]=(j[1],ratio)
                else:
                    res[j[0]]=(j[1],ratio)
    if entity != None:
        return res.get(entity,'not found')
    
    return res

def highest_label(name, label):
    res={}
    NER=get_NER(name, label)
    for i in NER:
        if NER[i][0] in res:
            res[NER[i][0]].append(i)
        else:
            res[NER[i][0]]=[i,]
    return res



print(get_NER(Spacy_name,Spacy_label,'Tesla'))
print(get_NER(nltk_name,nltk_label,'Tesla'))
# Out:
# ('ORG', 0.9)
# ('GPE', 0.3684210526315789)

# %%
unique_labels.keys()
# Out:
# dict_keys(['ORG', 'PERSON', 'CARDINAL', 'MONEY', 'PRODUCT', 'NORP', 'DATE', 'ORDINAL', 'TIME', 'LOC', 'GPE', 'FAC', 'EVENT', 'LAW', 'PERCENT', 'WORK_OF_ART'])

# %%
unique_labels['ORG']
# Out:
# [('Mobile Service', 380, 394),
#  ('Our Products and Services Automotive', 1942, 1978),
#  ('Full Self-Driving (&', 3066, 3086),
#  ('Energy Generation and Storage Energy Storage Products Powerwall',
#   3162,
#   3225),
#  ('Solar Energy Offerings', 3925, 3947),
#  ('Powertrain Our', 4680, 4694),
#  ('Model S', 5321, 5328),
#  ('Vehicle Control', 5785, 5800),
#  ('Control systems', 5942, 5957),
#  ('Self-Driving Development and Artificial Intelligence We', 6250, 6305),
#  ('FSD Computer', 6449, 6461),
#  ('Autopilot', 6804, 6813),
#  ('Tesla', 7312, 7317),
#  ('AI', 7652, 7654),
#  ('Energy Generation and Storage Energy Storage Products', 7663, 7716),
#  ('Solar Energy Systems', 8235, 8255),
#  ('Energy Generation and Storage', 9642, 9671),
#  ('Megapack', 9945, 9953),
#  ('Automotive Direct Sales Our', 10536, 10563),
#  ('Tesla', 11052, 11057),
#  ('Tesla', 11508, 11513),
#  ('Tesla', 11585, 11590),
#  ('Tesla', 11737, 11742),
#  ('Tesla Superchargers', 11857, 11876),
#  ('the North American Charging Standard', 12677, 12713),
#  ('NACS', 12715, 12719),
#  ('NACS', 13037, 13041),
#  ('NACS', 13141, 13145),
#  ('SAE International', 13201, 13218),
#  ('NACS', 13229, 13233),
#  ('Tesla Superchargers', 13327, 13346),
#  ('Energy Generation and Storage', 14018, 14047),
#  ('Warranty Automotive Service', 14569, 14596),
#  ('Tesla Mobile Service', 14693, 14713),
#  ('Vehicle Limited Warranties and Extended Service', 15090, 15137),
#  ('Tesla', 15215, 15220),
#  ('Energy Generation and Storage', 15538, 15567),
#  ('Financial Services', 16552, 16570),
#  ('Automotive Purchase Financing and Leases', 16571, 16611),
#  ('Energy Generation and Storage', 17434, 17463),
#  ('Governmental Programs', 20292, 20313),
#  ('Significant Accounting Policies', 20717, 20748),
#  ('Incentives Inflation Reduction Act', 20880, 20914),
#  ('Tesla', 21342, 21347),
#  ('Automotive Regulatory Credits', 21480, 21509),
#  ('The Federal Energy Regulatory Commission', 22458, 22498),
#  ('the California Self Generation Incentive Program', 22792, 22840),
#  ('the Internal Revenue Code', 23251, 23276),
#  ('Solar Energy System Incentives', 23703, 23733),
#  ('IRC', 24090, 24093),
#  ('Regulations Vehicle Safety and Testing In', 24518, 24559),
#  ('the National Highway Traffic Safety Administration', 24612, 24662),
#  ('Federal Motor Vehicle Safety Standards (&#8220;FMVSS&#8221', 24711, 24769),
#  ('NHTSA', 24780, 24785),
#  ('NHTSA', 25207, 25212),
#  ('NHTSA', 25382, 25387),
#  ('Theft Prevention Act', 25445, 25465),
#  ('Standing General Order', 25685, 25707),
#  ('The U.S. Automobile Information and Disclosure Act', 25921, 25971),
#  ('the U.S. Department of Transportation', 26227, 26264),
#  ('the Environmental Protection Agency', 26269, 26304),
#  ('the &#8220;EPA&#8221', 26306, 26326),
#  ('New Car Assessment Program', 26334, 26360),
#  ('NHTSA', 26386, 26391),
#  ('Self-Driving Vehicles Generally', 26731, 26762),
#  ('NHTSA', 27048, 27053),
#  ('FMVSS', 27132, 27137),
#  ('the United Nations Economic Commission for Europe', 27643, 27692),
#  ('ECE markets &#8221;)', 27702, 27722),
#  ('ECE', 28190, 28193),
#  ('Automobile Manufacturer', 28315, 28338),
#  ('Battery Safety and Testing Our', 29692, 29722),
#  ('Model S', 31962, 31969),
#  ('Autopilot', 33331, 33340),
#  ('FSD', 33342, 33345),
#  ('Energy Generation and Storage Energy Storage Systems', 33432, 33484),
#  ('Solar Energy Systems', 33993, 34013),
#  ('Human Capital Resources', 36044, 36067),
#  ('Tesla', 36092, 36097),
#  ('the Organization for Economic Co-operation and', 37222, 37268),
#  ('ESG Sustainability Council', 38044, 38070),
#  ('Board of Directors', 38148, 38166),
#  ('ESG', 38187, 38190),
#  ('Human Capital Resources A', 38228, 38253),
#  ('Tesla', 38275, 38280),
#  ('Tesla', 38364, 38369),
#  ('Tesla', 38824, 38829),
#  ('Tesla', 39143, 39148),
#  ('Tesla', 39644, 39649),
#  (': &#8226', 39756, 39764),
#  ('Technician Trainee (Service) &', 39766, 39796),
#  ('Technician Trainee Program', 39821, 39847),
#  ('Tesla', 39903, 39908),
#  ('Technician Trainees', 40132, 40151),
#  ('START', 40196, 40201),
#  ('Technician Trainee', 40304, 40322),
#  ('Tesla', 40413, 40418),
#  ('Internships &#8211', 40708, 40726),
#  ('Tesla', 40738, 40743),
#  ('European Defence Ministries', 41345, 41372),
#  ('the U.S.', 41407, 41415),
#  ('Apprenticeships &#8211', 41584, 41606),
#  ('Manufacturing Development Program &', 41929, 41964),
#  ('Tesla', 42181, 42186),
#  ('Gigafactory Nevada', 42341, 42359),
#  ('Engineering Development Program &', 42413, 42446),
#  ('Austin Community College', 42604, 42628),
#  ('Tesla', 43187, 43192),
#  ('Take Charge', 44528, 44539),
#  ('Human Resource Partners', 44839, 44862),
#  ('SEC', 45251, 45254),
#  ('SEC', 45273, 45276),
#  ('ir.tesla.com', 45632, 45644),
#  ('SEC', 45745, 45748)]

# %%
unique_labels['PRODUCT'] #products
# Out:
# [('the Model 3', 2045, 2056),
#  ('Model 3', 2082, 2089),
#  ('Model 3', 2277, 2284),
#  ('Model S', 2437, 2444),
#  ('Solar Roof', 4355, 4365),
#  ('Solar Roof', 8275, 8285),
#  ('Solar Roof', 10158, 10168),
#  ('Solar Roof', 16095, 16105),
#  ('Solar Roof', 17592, 17602),
#  ('Model 3', 32041, 32048),
#  ('Model Y', 32053, 32060)]

# %%
unique_labels['LOC'] # locations
# Out:
# [('North America', 16709, 16722),
#  ('Europe', 16724, 16730),
#  ('Asia', 16735, 16739),
#  ('Northern California', 17880, 17899),
#  ('Europe', 32867, 32873),
#  ('Europe', 41224, 41230)]

# %%
unique_labels['FAC'] # facilities / factories
# Out:
# [('Gigafactory Texas', 17963, 17980),
#  ('Fremont Factory', 42324, 42339),
#  ('Gigafactory Texas', 42361, 42378)]

# %%
unique_labels['EVENT'] # events
# Out:
# [('this Annual Report on Form 10-K', 20814, 20845),
#  ('this Annual Report on Form 10-K. Energy Storage System Incentives',
#   21988,
#   22053),
#  ('this Annual Report on Form 10-K. Pursuant', 23163, 23204),
#  ('this Annual Report on Form 10-K.', 45826, 45858)]

# %%
from spacy import displacy
#displacy.render(doc, style="ent")

# %% [markdown]
# ### ReFinED transformer

# %% [markdown]
# <a href = "https://github.com/amazon-science/ReFinED"> ReFinED </a> uses a Transformer model to perform mention detection, entity typing, and entity disambiguation for all mentions in a document in a single forward pass. The model is trained on a dataset we generated dataset using Wikipedia hyperlinks, which consists of over 150M entity mentions. The model uses entity descriptions and fine-grained entity types to perform linking. Therefore, new entities can be added to the system without retraining.

# %%
pip install git+https://github.com/ardentaegis17/ReFinED.git
# Out:
# Collecting git+https://github.com/ardentaegis17/ReFinED.git
#   Cloning https://github.com/ardentaegis17/ReFinED.git to c:\users\dell\appdata\local\temp\pip-req-build-88ver3lc
#   Resolved https://github.com/ardentaegis17/ReFinED.git to commit 46d70155e6042d69fad5869f38a195f335fab9c1
#   Preparing metadata (setup.py): started
#   Preparing metadata (setup.py): finished with status 'done'
# Requirement already satisfied: requests in c:\users\dell\appdata\local\programs\python\python312\lib\site-packages (from ReFinED==1.0) (2.32.3)
# Requirement already satisfied: torch>=1.12.1 in c:\users\dell\appdata\local\programs\python\python312\lib\site-packages (from ReFinED==1.0) (2.4.1)
# Requirement already satisfied: numpy>=1.15.4 in c:\users\dell\appdata\local\programs\python\python312\lib\site-packages (from ReFinED==1.0) (1.26.4)
# Requirement already satisfied: nltk>=3.5 in c:\users\dell\appdata\local\programs\python\python312\lib\site-packages (from ReFinED==1.0) (3.9.1)
# Requirement already satisfied: urllib3>=1.25.8 in c:\users\dell\appdata\local\programs\python\python312\lib\site-packages (from ReFinED==1.0) (2.2.2)
# Requirement already satisfied: Unidecode>=1.1.1 in c:\users\dell\appdata\local\programs\python\python312\lib\site-packages (from ReFinED==1.0) (1.3.8)
# Requirement already satisfied: ujson in c:\users\dell\appdata\local\programs\python\python312\lib\site-packages (from ReFinED==1.0) (5.10.0)
# Requirement already satisfied: tqdm in c:\users\dell\appdata\local\programs\python\python312\lib\site-packages (from ReFinED==1.0) (4.66.5)
# Requirement already satisfied: transformers>=4.2.2 in c:\users\dell\appdata\local\programs\python\python312\lib\site-packages (from ReFinED==1.0) (4.44.2)
# Requirement already satisfied: tensorboard in c:\users\dell\appdata\local\programs\python\python312\lib\site-packages (from ReFinED==1.0) (2.18.0)
# Requirement already satisfied: Cython in c:\users\dell\appdata\local\programs\python\python312\lib\site-packages (from ReFinED==1.0) (3.0.11)
# Requirement already satisfied: lmdb>=1.0 in c:\users\dell\appdata\local\programs\python\python312\lib\site-packages (from ReFinED==1.0) (1.5.1)
# Requirement already satisfied: boto3 in c:\users\dell\appdata\local\programs\python\python312\lib\site-packages (from ReFinED==1.0) (1.35.35)
# Requirement already satisfied: prettyprint in c:\users\dell\appdata\local\programs\python\python312\lib\site-packages (from ReFinED==1.0) (0.1.5)
# Requirement already satisfied: botocore in c:\users\dell\appdata\local\programs\python\python312\lib\site-packages (from ReFinED==1.0) (1.35.35)
# Requirement already satisfied: click in c:\users\dell\appdata\local\programs\python\python312\lib\site-packages (from nltk>=3.5->ReFinED==1.0) (8.1.7)
# Requirement already satisfied: joblib in c:\users\dell\appdata\local\programs\python\python312\lib\site-packages (from nltk>=3.5->ReFinED==1.0) (1.4.2)
# Requirement already satisfied: regex>=2021.8.3 in c:\users\dell\appdata\local\programs\python\python312\lib\site-packages (from nltk>=3.5->ReFinED==1.0) (2024.7.24)
# Requirement already satisfied: filelock in c:\users\dell\appdata\local\programs\python\python312\lib\site-packages (from torch>=1.12.1->ReFinED==1.0) (3.16.0)
# Requirement already satisfied: typing-extensions>=4.8.0 in c:\users\dell\appdata\local\programs\python\python312\lib\site-packages (from torch>=1.12.1->ReFinED==1.0) (4.12.2)
# Requirement already satisfied: sympy in c:\users\dell\appdata\local\programs\python\python312\lib\site-packages (from torch>=1.12.1->ReFinED==1.0) (1.13.2)
# Requirement already satisfied: networkx in c:\users\dell\appdata\local\programs\python\python312\lib\site-packages (from torch>=1.12.1->ReFinED==1.0) (3.3)
# Requirement already satisfied: jinja2 in c:\users\dell\appdata\local\programs\python\python312\lib\site-packages (from torch>=1.12.1->ReFinED==1.0) (3.1.4)
# Requirement already satisfied: fsspec in c:\users\dell\appdata\local\programs\python\python312\lib\site-packages (from torch>=1.12.1->ReFinED==1.0) (2024.9.0)
# Requirement already satisfied: setuptools in c:\users\dell\appdata\local\programs\python\python312\lib\site-packages (from torch>=1.12.1->ReFinED==1.0) (74.1.2)
# Requirement already satisfied: huggingface-hub<1.0,>=0.23.2 in c:\users\dell\appdata\local\programs\python\python312\lib\site-packages (from transformers>=4.2.2->ReFinED==1.0) (0.24.6)
# Requirement already satisfied: packaging>=20.0 in c:\users\dell\appdata\roaming\python\python312\site-packages (from transformers>=4.2.2->ReFinED==1.0) (24.1)
# Requirement already satisfied: pyyaml>=5.1 in c:\users\dell\appdata\local\programs\python\python312\lib\site-packages (from transformers>=4.2.2->ReFinED==1.0) (6.0.2)
# Requirement already satisfied: safetensors>=0.4.1 in c:\users\dell\appdata\local\programs\python\python312\lib\site-packages (from transformers>=4.2.2->ReFinED==1.0) (0.4.5)
# Requirement already satisfied: tokenizers<0.20,>=0.19 in c:\users\dell\appdata\local\programs\python\python312\lib\site-packages (from transformers>=4.2.2->ReFinED==1.0) (0.19.1)
# Requirement already satisfied: colorama in c:\users\dell\appdata\roaming\python\python312\site-packages (from tqdm->ReFinED==1.0) (0.4.6)
# Requirement already satisfied: jmespath<2.0.0,>=0.7.1 in c:\users\dell\appdata\local\programs\python\python312\lib\site-packages (from boto3->ReFinED==1.0) (1.0.1)
# Requirement already satisfied: s3transfer<0.11.0,>=0.10.0 in c:\users\dell\appdata\local\programs\python\python312\lib\site-packages (from boto3->ReFinED==1.0) (0.10.2)
# Requirement already satisfied: python-dateutil<3.0.0,>=2.1 in c:\users\dell\appdata\roaming\python\python312\site-packages (from botocore->ReFinED==1.0) (2.9.0.post0)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\dell\appdata\local\programs\python\python312\lib\site-packages (from requests->ReFinED==1.0) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\dell\appdata\local\programs\python\python312\lib\site-packages (from requests->ReFinED==1.0) (3.8)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\dell\appdata\local\programs\python\python312\lib\site-packages (from requests->ReFinED==1.0) (2024.8.30)
# Requirement already satisfied: absl-py>=0.4 in c:\users\dell\appdata\local\programs\python\python312\lib\site-packages (from tensorboard->ReFinED==1.0) (2.1.0)
# Requirement already satisfied: grpcio>=1.48.2 in c:\users\dell\appdata\local\programs\python\python312\lib\site-packages (from tensorboard->ReFinED==1.0) (1.66.2)
# Requirement already satisfied: markdown>=2.6.8 in c:\users\dell\appdata\local\programs\python\python312\lib\site-packages (from tensorboard->ReFinED==1.0) (3.7)
# Requirement already satisfied: protobuf!=4.24.0,>=3.19.6 in c:\users\dell\appdata\local\programs\python\python312\lib\site-packages (from tensorboard->ReFinED==1.0) (5.28.2)
# Requirement already satisfied: six>1.9 in c:\users\dell\appdata\roaming\python\python312\site-packages (from tensorboard->ReFinED==1.0) (1.16.0)
# Requirement already satisfied: tensorboard-data-server<0.8.0,>=0.7.0 in c:\users\dell\appdata\local\programs\python\python312\lib\site-packages (from tensorboard->ReFinED==1.0) (0.7.2)
# Requirement already satisfied: werkzeug>=1.0.1 in c:\users\dell\appdata\local\programs\python\python312\lib\site-packages (from tensorboard->ReFinED==1.0) (3.0.4)
# Requirement already satisfied: MarkupSafe>=2.1.1 in c:\users\dell\appdata\local\programs\python\python312\lib\site-packages (from werkzeug>=1.0.1->tensorboard->ReFinED==1.0) (2.1.5)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in c:\users\dell\appdata\local\programs\python\python312\lib\site-packages (from sympy->torch>=1.12.1->ReFinED==1.0) (1.3.0)
# Note: you may need to restart the kernel to use updated packages.
#   Running command git clone --filter=blob:none --quiet https://github.com/ardentaegis17/ReFinED.git 'C:\Users\DELL\AppData\Local\Temp\pip-req-build-88ver3lc'

# %%
from refined.inference.processor import Refined


refined = Refined.from_pretrained(model_name='wikipedia_model_with_numbers',
                                  entity_set="wikipedia")

spans = refined.process_text(tsla_item1)

print(spans)
print(len(spans))

i = 0 

for span in spans:
    if isinstance(span.predicted_entity,type(spans[3].predicted_entity)): #the fourth entity identified is 'Model 3', which is correctly linked to the Wikipedia article for Tesla Model 3.
        i += 1

print(i)
# Out:
# c:\Users\DELL\AppData\Local\Programs\Python\Python312\Lib\site-packages\transformers\tokenization_utils_base.py:1601: FutureWarning: `clean_up_tokenization_spaces` was not set. It will be set to `True` by default. This behavior will be depracted in transformers v4.45, and will be then set to `False` by default. For more details check this issue: https://github.com/huggingface/transformers/issues/31884
#   warnings.warn(
# c:\Users\DELL\AppData\Local\Programs\Python\Python312\Lib\site-packages\refined\model_components\refined_model.py:626: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   checkpoint = torch.load(io.BytesIO(f.read()), map_location="cpu")
# c:\Users\DELL\AppData\Local\Programs\Python\Python312\Lib\site-packages\refined\inference\processor.py:293: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with autocast():
# c:\Users\DELL\AppData\Local\Programs\Python\Python312\Lib\site-packages\torch\amp\autocast_mode.py:265: UserWarning: User provided device_type of 'cuda', but CUDA is not available. Disabling
#   warnings.warn(
# [['ITEM 1', Entity not linked to a knowledge base, None], ['two', None, 'CARDINAL'], ['five', None, 'CARDINAL'], ['Model 3', Entity(wikidata_entity_id=Q23663332, wikipedia_entity_title=Tesla Model 3), None], ['Cybertruck', Entity(wikidata_entity_id=Q66311587, wikipedia_entity_title=Tesla Cybertruck), None], ['Model 3', Entity(wikidata_entity_id=Q23663332, wikipedia_entity_title=Tesla Model 3), None], ['four-door', None, 'CARDINAL'], ['Model', Entity(wikidata_entity_id=Q4610556, wikipedia_entity_title=Model (person)), None], ['Model 3', Entity(wikidata_entity_id=Q23663332, wikipedia_entity_title=Tesla Model 3), None], ['seven', None, 'CARDINAL'], ['Model S', Entity(wikidata_entity_id=Q1463050, wikipedia_entity_title=Tesla Model S), None], ['four-door', None, 'CARDINAL'], ['Model X', Entity(wikidata_entity_id=Q1634161, wikipedia_entity_title=Tesla Model X), None], ['seven', None, 'CARDINAL'], ['Model S', Entity(wikidata_entity_id=Q1463050, wikipedia_entity_title=Tesla Model S), None], ['Model X', Entity(wikidata_entity_id=Q1634161, wikipedia_entity_title=Tesla Model X), None], ['November 2023', Entity(parsed_string=[timepoint: ["2023/11"]]), 'DATE'], ['first', None, 'ORDINAL'], ['Cybertruck', Entity(wikidata_entity_id=Q66311587, wikipedia_entity_title=Tesla Cybertruck), None], ['2022', Entity(parsed_string=[timepoint: ["2022"]]), 'DATE'], ['Tesla Semi', Entity(wikidata_entity_id=Q40008974, wikipedia_entity_title=Tesla Semi), None], ['Powerwall', Entity(wikidata_entity_id=Q19845823, wikipedia_entity_title=Tesla Powerwall), None], ['Megapack', Entity(wikidata_entity_id=Q85806042, wikipedia_entity_title=Tesla Megapack), None], ['Power', Entity(wikidata_entity_id=Q27137, wikipedia_entity_title=Electric power), None], ['Megapack', Entity(wikidata_entity_id=Q85806042, wikipedia_entity_title=Tesla Megapack), None], ['gigawatt hours', None, 'QUANTITY'], ['two', None, 'CARDINAL'], ['three', None, 'CARDINAL'], ['Model S', Entity(wikidata_entity_id=Q1463050, wikipedia_entity_title=Tesla Model S), None], ['Model X', Entity(wikidata_entity_id=Q1634161, wikipedia_entity_title=Tesla Model X), None], ['Cybertruck', Entity(wikidata_entity_id=Q66311587, wikipedia_entity_title=Tesla Cybertruck), None], ['Tesla Semi', Entity(wikidata_entity_id=Q40008974, wikipedia_entity_title=Tesla Semi), None], ['Tesla', Entity(wikidata_entity_id=Q478214, wikipedia_entity_title=Tesla, Inc.), 'ORG'], ['Optimus', Entity not linked to a knowledge base, None], ['Solar Energy Systems', Entity not linked to a knowledge base, 'ORG'], ['Solar', Entity not linked to a knowledge base, None], ['Powerwall', Entity(wikidata_entity_id=Q19845823, wikipedia_entity_title=Tesla Powerwall), None], ['Megapack', Entity(wikidata_entity_id=Q85806042, wikipedia_entity_title=Tesla Megapack), None], ['Autom', Entity not linked to a knowledge base, 'ORG'], ['Tesla', Entity(wikidata_entity_id=Q478214, wikipedia_entity_title=Tesla, Inc.), 'ORG'], ['Tesla', Entity(wikidata_entity_id=Q478214, wikipedia_entity_title=Tesla, Inc.), 'ORG'], ['non-Tesla', Entity not linked to a knowledge base, None], ['Tesla', Entity(wikidata_entity_id=Q478214, wikipedia_entity_title=Tesla, Inc.), 'ORG'], ['Tesla', Entity(wikidata_entity_id=Q478214, wikipedia_entity_title=Tesla, Inc.), 'ORG'], ['non-Tesla', Entity not linked to a knowledge base, None], ['third', None, 'ORDINAL'], ['Tesla', Entity(wikidata_entity_id=Q478214, wikipedia_entity_title=Tesla, Inc.), 'ORG'], ['Tesla', Entity(wikidata_entity_id=Q478214, wikipedia_entity_title=Tesla, Inc.), 'ORG'], ['November 2021', Entity(parsed_string=[timepoint: ["2021/11"]]), 'DATE'], ['non-Tesla', Entity not linked to a knowledge base, None], ['November 2022', Entity(parsed_string=[timepoint: ["2022/11"]]), 'DATE'], ['the North American Charging Standard', Entity not linked to a knowledge base, None], ['2024', Entity(parsed_string=[timepoint: ["2024"]]), 'DATE'], ['no later than 2025', None, 'DATE'], ['SAE International', Entity(wikidata_entity_id=Q1427072, wikipedia_e ...
# 252
# 197

# %% [markdown]
# We see that the ReFinED transformer does an excellent job at entity resolution and disambiguation, successfully linking 197 of 252 entities to Wikipedia articles. We explore its capabilities further in the ERD.ipynb notebook. However, it lacks the ability to differentiate between important entities. Relationship extraction is also challenging, as it requires querying the Wikidata API using the entity id and parsing through voluminious JSON output. We thus turn to our final NER model.

# %% [markdown]
# ## Diffbot API
# <a href = "https://www.diffbot.com/"> Diffbot </a> is a developer of machine learning and computer vision algorithms and public APIs for extracting data from web pages / web scraping to create a knowledge base. In September 2020 the company released a Natural Language Processing API for automatically building Knowledge Graphs from text.
#
# Because entities can be of different types and not all are equally important in the
# context of the natural language text being analyzed, it is quite common for NER
# processors to return the following in addition to a list of entities:
#
#  **type**
# - Is it a person? Is it a location? Is it an organization? The set of categories will
# depend on the specific model used.
# - Diffbot API distinguishes between <a href= https://demo.nl.diffbot.com/schema/#types> 69 different entity types. </a>
#
# **salience**
# - The relative importance in the text analyzed or, in other words, the entity’s
# relevance.
# - Is the entity central to the text (higher score/salience), or is it just
# mentioned tangentially (lower score/salience)?

# %%
from getpass import getpass

TOKEN = getpass('Enter token: ')

# %%
FIELDS = "entities,facts"
HOST = "nl.diffbot.com"

# %%
import json

def get_request(payload):
  res = requests.post("https://{}/v1/?fields={}&token={}".format(HOST, FIELDS, TOKEN), json=payload)
  ret = None
  try:
    ret = res.json()
  except:
    print("Bad response: " + res.text)
    print(res.status_code)
    print(res.headers)
  return ret

# %%
res = get_request({
    "content": tsla_item1,
    "lang": "en",
    "format": "plain text with title",
})

print (res)
# Out:
# {'entities': [{'name': 'Tesla Semi', 'diffbotUri': 'https://diffbot.com/entity/EF4g4ohJUPUeLKh-N-rvUyA', 'confidence': 0.9569246, 'salience': 0.8978014, 'isCustom': False, 'allUris': ['http://www.wikidata.org/entity/Q40008974'], 'allTypes': [{'name': 'skill', 'diffbotUri': 'https://diffbot.com/entity/EvfbHngnSNVOh7ZBM5XTywQ'}, {'name': 'product', 'diffbotUri': 'https://diffbot.com/entity/EgSPUye7QPcyQoPylO8biMQ'}, {'name': 'tool', 'diffbotUri': 'https://diffbot.com/entity/EKvoYuTx4P9WT35YUouc0ug'}, {'name': 'vehicle', 'diffbotUri': 'https://diffbot.com/entity/E4vBDPVu3OTq90vd1GhX5mw', 'dbpediaUri': 'http://dbpedia.org/ontology/MeanOfTransportation'}], 'mentions': [{'text': 'Tesla', 'beginOffset': 2922, 'endOffset': 2927, 'confidence': 0.9569246}, {'text': 'Tesla', 'beginOffset': 5361, 'endOffset': 5366, 'confidence': 0.9569246}]}, {'name': 'automotive battery', 'diffbotUri': 'https://diffbot.com/entity/EF6RvyvRnNsW6oAQQjtPb7g', 'confidence': 0.97791916, 'salience': 0.77393895, 'isCustom': False, 'allUris': ['http://www.wikidata.org/entity/Q902054'], 'allTypes': [{'name': 'skill', 'diffbotUri': 'https://diffbot.com/entity/EvfbHngnSNVOh7ZBM5XTywQ'}, {'name': 'product', 'diffbotUri': 'https://diffbot.com/entity/EgSPUye7QPcyQoPylO8biMQ'}, {'name': 'tool', 'diffbotUri': 'https://diffbot.com/entity/EKvoYuTx4P9WT35YUouc0ug'}], 'mentions': [{'text': 'Automotive', 'beginOffset': 4657, 'endOffset': 4667, 'confidence': 0.97791916}]}, {'name': 'Tesla Model X', 'diffbotUri': 'https://diffbot.com/entity/ETr-Ee8SIMyW2qgYQ352vQA', 'confidence': 0.9138682, 'salience': 0.6964315, 'isCustom': False, 'allUris': ['http://www.wikidata.org/entity/Q1634161'], 'allTypes': [{'name': 'skill', 'diffbotUri': 'https://diffbot.com/entity/EvfbHngnSNVOh7ZBM5XTywQ'}, {'name': 'product', 'diffbotUri': 'https://diffbot.com/entity/EgSPUye7QPcyQoPylO8biMQ'}, {'name': 'tool', 'diffbotUri': 'https://diffbot.com/entity/EKvoYuTx4P9WT35YUouc0ug'}, {'name': 'vehicle', 'diffbotUri': 'https://diffbot.com/entity/E4vBDPVu3OTq90vd1GhX5mw', 'dbpediaUri': 'http://dbpedia.org/ontology/MeanOfTransportation'}], 'mentions': [{'text': 'Model', 'beginOffset': 2374, 'endOffset': 2379, 'confidence': 0.9138682}, {'text': 'Model', 'beginOffset': 2449, 'endOffset': 2454, 'confidence': 0.9138682}, {'text': 'Model', 'beginOffset': 5321, 'endOffset': 5326, 'confidence': 0.9104794}, {'text': 'Model', 'beginOffset': 5333, 'endOffset': 5338, 'confidence': 0.9138682}]}, {'name': 'solar energy', 'diffbotUri': 'https://diffbot.com/entity/EPOEH5adkND6DrYMaSXAARQ', 'confidence': 0.97090673, 'salience': 0.6094218, 'isCustom': False, 'allUris': ['http://www.wikidata.org/entity/Q40015'], 'allTypes': [], 'mentions': [{'text': 'solar', 'beginOffset': 1823, 'endOffset': 1828, 'confidence': 0.97090673}]}, {'name': 'Tesla Autopilot', 'diffbotUri': 'https://diffbot.com/entity/EduXdFbV7Mtm7CyoRE7BNsg', 'confidence': 0.6537608, 'salience': 0.5553389, 'isCustom': False, 'allUris': ['http://www.wikidata.org/entity/Q27150149'], 'allTypes': [{'name': 'skill', 'diffbotUri': 'https://diffbot.com/entity/EvfbHngnSNVOh7ZBM5XTywQ'}, {'name': 'field of work', 'diffbotUri': 'https://diffbot.com/entity/EjGOLMsQZOGSg549SwYfFyQ'}, {'name': 'technology', 'diffbotUri': 'https://diffbot.com/entity/E-5jnlQEGOt2x8rdkkht1NQ'}], 'mentions': [{'text': 'full self-', 'beginOffset': 673, 'endOffset': 683, 'confidence': 0.6537608}, {'text': 'Full Self-', 'beginOffset': 3066, 'endOffset': 3076, 'confidence': 0.6537608}]}, {'name': 'artificial intelligence', 'diffbotUri': 'https://diffbot.com/entity/E_lYDrjmAMlKKwXaDf958zg', 'confidence': 0.94689095, 'salience': 0.5336387, 'isCustom': False, 'allUris': ['http://www.wikidata.org/entity/Q11660'], 'allTypes': [{'name': 'skill', 'diffbotUri': 'https://diffbot.com/entity/EvfbHngnSNVOh7ZBM5XTywQ'}, {'name': 'field of work', 'diffbotUri': 'https://diffbot.com/entity/EjGOLMsQZOGSg549SwYfFyQ'}, {'name': 'technology', 'diffbotUri': 'https://diffbot.com/entity/E-5jnlQEGOt2x8rdkkht1NQ'}], 'mentions' ...

# %% [markdown]
# ### View Entities and Entity Types

# %%
for ent in res["entities"]:
    if ent["salience"] > 0.5:
        print("Entity Name: " + ent['name'])
        print("Salience: " + str(ent['salience']))
        print("Entity Types:")
        print([ent_type["name"] for ent_type in ent['allTypes']])
        print()
# Out:
# Entity Name: Tesla Semi
# Salience: 0.8978014
# Entity Types:
# ['skill', 'product', 'tool', 'vehicle']
#
# Entity Name: automotive battery
# Salience: 0.77393895
# Entity Types:
# ['skill', 'product', 'tool']
#
# Entity Name: Tesla Model X
# Salience: 0.6964315
# Entity Types:
# ['skill', 'product', 'tool', 'vehicle']
#
# Entity Name: solar energy
# Salience: 0.6094218
# Entity Types:
# []
#
# Entity Name: Tesla Autopilot
# Salience: 0.5553389
# Entity Types:
# ['skill', 'field of work', 'technology']
#
# Entity Name: artificial intelligence
# Salience: 0.5336387
# Entity Types:
# ['skill', 'field of work', 'technology']
#
# Entity Name: electric vehicle
# Salience: 0.5048789
# Entity Types:
# ['skill', 'product', 'tool', 'vehicle']

# %% [markdown]
# Filtering the output to retain only significant entities with a salience score greater than 0.5, we see that 7 entities were extracted from the SEC 10-K filing data. All entities are indeed relevant to Tesla as an automobile electric vehicle company with significant investments in solar energy and artificial intelligence.
#
# We also see that each entity is linked to a variety of entity types. For our knowledge graph, we are primarily interested in **company**, **product**, **industry / field of work**, and **location / country** entities.

# %%
def extract_entites(res):
    ents = pd.DataFrame.from_dict(res["entities"])
    if not ents.empty:
        salient_ents = ents[ents["salience"] > 0.5]
        salient_ents["Labels"] = None
        for i, row in salient_ents.iterrows():
            if len(row['allTypes']) != 0:
                names = [ent_type["name"] for ent_type in row['allTypes']]
                if "organization" in names:
                    salient_ents.loc[i,"Labels"] = 'company'
                elif ("field of work" in names)  or ("industry" in names) or ("industry" in row['name']):
                    salient_ents.loc[i,'Labels'] = 'industry'
                elif "country" in names:
                    salient_ents.loc[i,'Labels'] = 'country'
                elif "location" in names:
                    salient_ents.loc[i,'Labels'] = 'location'
                elif "product" in names:
                    salient_ents.loc[i,'Labels'] = 'product'
                else:
                    salient_ents.loc[i,'Labels'] = row['allTypes'][0]['name']
                

        fin_ents = salient_ents[['name','salience','Labels']]
        return fin_ents
    return ents

# %%
tsla_entities = extract_entites(res)
tsla_entities.head()
# Out:
# C:\Users\DELL\AppData\Local\Temp\ipykernel_34176\2575082870.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   salient_ents["Labels"] = None
#                  name  salience    Labels
# 0          Tesla Semi  0.897801   product
# 1  automotive battery  0.773939   product
# 2       Tesla Model X  0.696431   product
# 3        solar energy  0.609422      None
# 4     Tesla Autopilot  0.555339  industry

# %% [markdown]
# ## View Relationships and Relationship Types

# %%
def extract_relationships(res):
    rels =  pd.DataFrame.from_dict(res["facts"])
    if not rels.empty:
        for i, row in rels.iterrows():
            rels.loc[i,"entity"] = row["entity"]["name"]
            rels.loc[i,"property"] = row["property"]["name"]
            rels.loc[i,"value"] = row["value"]["name"]
            if row["evidence"] != []:
                rels.loc[i,"evidence"] = row["evidence"][0].get("passage",None)
        fin_rels = rels[['entity','property','value','evidence']]
        return fin_rels
    return rels

# %%
extract_relationships(res)
# Out:
# Empty DataFrame
# Columns: []
# Index: []

# %% [markdown]
# Diffbot's NLP API is unable to extract any relationships from Tesla's SEC 10-K filing data. We turn to Tesla's wikipedia article as a supplementary data source.

# %% [markdown]
# ### Supplementary Source: Wikipedia Article

# %%
tesla_wiki = "Tesla, Inc. (/ˈtɛslə/ TESS-lə or /ˈtɛzlə/ TEZ-lə[a]) is an American multinational automotive and clean energy company. Headquartered in Austin, Texas, it designs, manufactures and sells battery electric vehicles (BEVs), stationary battery energy storage devices from home to grid-scale, solar panels and solar shingles, and related products and services. \
    Tesla was incorporated in July 2003 by Martin Eberhard and Marc Tarpenning as Tesla Motors. Its name is a tribute to inventor and electrical engineer Nikola Tesla. In February 2004, Elon Musk joined as Tesla's largest shareholder; in 2008, he was named chief executive officer. In 2008, the company began production of its first car model, the Roadster sports car, followed by the Model S sedan in 2012, the Model X SUV in 2015, the Model 3 sedan in 2017, the Model Y crossover in 2020, the Tesla Semi truck in 2022 and the Cybertruck pickup truck in 2023. The Model 3 is the all-time best-selling plug-in electric car worldwide, and in June 2021 became the first electric car to sell 1 million units globally.[6] In 2023, the Model Y was the best-selling vehicle, of any kind, globally.[7][8][3] \
        Tesla is one of the world's most valuable companies in terms of market capitalization. In October 2021, Tesla temporarily became a trillion-dollar company, the seventh U.S. company to do so. In 2023, the company led the battery electric vehicle market, with 19.9% share. Also in 2023, the company was ranked 69th in the Forbes Global 2000.[9] As of March 2024, it is the world's most valuable automaker. Tesla has been the subject of lawsuits, government scrutiny, and journalistic criticism, stemming from allegations of multiple cases of whistleblower retaliation, worker rights violations such as sexual harassment and anti-union activities, safety defects leadings to dozens of recalls, the lack of a public relations department, and controversial statements from Musk including overpromising on the company's driving assist technology and product release timelines."

# %%
res = get_request({
    "content": tesla_wiki,
    "lang": "en",
    "format": "plain text with title",
})

# %%
tsla_wiki_entities = extract_entites(res)
tsla_wiki_entities.head()
# Out:
# C:\Users\DELL\AppData\Local\Temp\ipykernel_34176\2575082870.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   salient_ents["Labels"] = None
#                        name  salience   Labels
# 0           Marc Tarpenning  0.988777   person
# 1           Martin Eberhard  0.988030   person
# 2                     Tesla  0.975387  company
# 3  battery electric vehicle  0.834153  product
# 4                 Elon Musk  0.758810   person

# %%
tsla_wiki_entities[tsla_wiki_entities['Labels'] == 'company'] #Tesla correctly identified as the most salient company entity.
# Out:
#                                                  name  salience   Labels
# 2                                               Tesla  0.975387  company
# 22  NASA's Transiting Exoplanet Survey Satellite -...  0.559259  company
# 51                                               BEVs  0.529361  company
# 62                                         Cybertruck  0.733953  company

# %%
tsla_wiki_entities[tsla_wiki_entities['Labels'] == 'industry']
# Out:
#                       name  salience    Labels
# 14     automotive industry  0.669135  industry
# 16      sustainable energy  0.624084  industry
# 19  electrical engineering  0.606833  industry

# %%
tsla_wiki_entities[tsla_wiki_entities['Labels'] == 'product']
# Out:
#                                  name  salience   Labels
# 3            battery electric vehicle  0.834153  product
# 5            plug-in electric vehicle  0.742809  product
# 6                       Tesla Model Y  0.742138  product
# 7                        pickup truck  0.741191  product
# 8                       Tesla Model X  0.720437  product
# 11                      Tesla Model S  0.707837  product
# 13                       electric car  0.684443  product
# 15              sport utility vehicle  0.655946  product
# 17                         sports car  0.618520  product
# 18                     energy storage  0.607389  product
# 20  Tesla Roadster (first generation)  0.580403  product
# 21                      Tesla Model 3  0.564537  product
# 23                          crossover  0.545244  product

# %%
extract_relationships(res).head()
# Out:
#             entity                property                          value  \
# 0            Tesla            product type  related products and services
# 1  Martin Eberhard   employee or member of                          Tesla
# 2  Marc Tarpenning   employee or member of                          Tesla
# 3            Tesla  organization locations                          Texas
# 4            Tesla            headquarters                          Texas
#
#                                             evidence
# 0  Headquartered in Austin, Texas, it designs, ma...
# 1  Tesla was incorporated in July 2003 by Martin ...
# 2  Tesla was incorporated in July 2003 by Martin ...
# 3  Headquartered in Austin, Texas, it designs, ma...
# 4  Headquartered in Austin, Texas, it designs, ma...

# %% [markdown]
# Diffbot can successfully extract entity relationships from Tesla's Wikipedia article!

# %% [markdown]
# ### Creating Entity-Relationship Extraction Pipelines

# %% [markdown]
# We now construct E-R extraction pipelines, and run them to gain insights into Apple Inc, with stock ticker code AAPL.

# %%
from googlesearch import search
from yahooquery import Ticker

def get_company_ticker(self):

    searchval = 'yahoo finance '+ self
    link = []
    #limits to the first link
    for url in search(searchval, stop = 1):
        link.append(url)

    link = str(link[0])
    link=link.split("/")
    if link[-1]=='':
        ticker=link[-2]
    else:
        x=link[-1].split('=')
        ticker=x[-1]
    print(ticker)
    return(ticker)

get_company_ticker("Booking Holdings Inc.")

def get_company_name(ticker):
    try:
        ticker_info = Ticker(ticker)
        company_name = ticker_info.quote_type[ticker]['longName']
        print(f"Found Company: {company_name}")
        return company_name
    except Exception as e:
        print(f"Error fetching company name for ticker {ticker}: {e}")
        return ticker

# get_company_name("AAPL")
# Out:
# BKNG

# %%
import requests
from bs4 import BeautifulSoup

def get_wikipedia_article(company_name_or_ticker):
    search_url = f"https://en.wikipedia.org/wiki/{company_name_or_ticker}"
    
    try:
        response = requests.get(search_url)
        response.raise_for_status()

        soup = BeautifulSoup(response.text, 'html.parser')

        title = soup.find('h1', {'id': 'firstHeading'}).text

        content_div = soup.find('div', {'id': 'mw-content-text'})

        paragraphs = content_div.find_all('p')

        full_article_text = '\n\n'.join([p.text.strip() for p in paragraphs if p.text.strip()])

        #print(f"Title: {title}")
        #print(f"Full Article:\n{full_article_text}")
        return f"{title}" + " " + f"{full_article_text}"

    except requests.exceptions.RequestException as e:
        print(f"Error fetching the Wikipedia article: {e}")
        return None

# company_name_or_ticker = input("Enter the company name or ticker code: ").replace(' ', '_')
# get_wikipedia_article(company_name_or_ticker)

# %%
def wikipedia_ner_rel_pipeline(ticker):
    company_name = get_company_name(ticker)
    article = get_wikipedia_article(company_name)
    if article is None:
        return (None,None)
    res = get_request({
    "content": article,
    "lang": "en",
    "format": "plain text with title",
    })
    ents, rels = None, None
    try:
        ents = extract_entites(res)
        rels = extract_relationships(res)
    except:
        print("Rate Limit Exceeded. Natural Language API allows only 500 calls a month.")
        print(res)
        return (None, None)
    
    pd.options.display.max_columns = None
    pd.set_option('display.width', 3000)
    
    return (ents, rels)

def sec_10k_ner_rel_pipeline(ticker):
    dbpath = 'data/ecmdatabase.db'
    con = sqlite3.connect(f"file:{dbpath}?mode=ro", uri=True)
    with con:
        result = con.execute(f"SELECT * from companies WHERE stock_symbol = '{ticker}';")
        records = result.fetchall()
        if records == []:
            print(f"no records of company ticker {ticker} found in database.")
            return (None,None)
        company_name = records[0][1]
        item1 = records[0][2].replace('\n', '')
        item7 = records[0][3].replace('\n', '')
    item1_res = get_request({
    "content": item1,
    "lang": "en",
    "format": "plain text",
    })
    item7_res = get_request({
    "content": item7,
    "lang": "en",
    "format": "plain text",
    })

    try:
        item1_ents, item1_rels = extract_entites(item1_res), extract_relationships(item1_res)
        item7_ents, item7_rels = extract_entites(item7_res), extract_relationships(item7_res)
    except:
        print("Rate Limit Exceeded. Natural Language API allows only 500 calls a month.")
        print(item1_res)
        return (None, None)

    ents = pd.concat([item1_ents,item7_ents],axis = 0)
    rels = pd.concat([item1_rels,item7_rels],axis = 0)

    return (ents,rels)

# %%
(aapl_sec_ents, aapl_sec_rels) = sec_10k_ner_rel_pipeline('AAPL')
# Out:
# C:\Users\DELL\AppData\Local\Temp\ipykernel_34176\2575082870.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   salient_ents["Labels"] = None
# C:\Users\DELL\AppData\Local\Temp\ipykernel_34176\2575082870.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   salient_ents["Labels"] = None

# %%
aapl_sec_ents.head() # more entities extracted compared to wikipedia articles.
# Out:
#           name  salience   Labels
# 0        Apple  0.902315  company
# 1  MacBook Air  0.895517  product
# 2  MacBook Pro  0.867708  product
# 3     Apple TV  0.840443  product
# 4  AirPods Max  0.831631     None

# %%
aapl_sec_rels #can't extract relationships from 10-K forms.
# Out:
# Empty DataFrame
# Columns: []
# Index: []

# %%
(aapl_wiki_ents, aapl_wiki_rels) = wikipedia_ner_rel_pipeline("AAPL")
# Out:
# Found Company: Apple Inc.
# C:\Users\DELL\AppData\Local\Temp\ipykernel_34176\2575082870.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   salient_ents["Labels"] = None

# %%
aapl_wiki_ents.head() # fewer entities extracted
# Out:
#                 name  salience   Labels
# 0         Jef Raskin  0.954252   person
# 1       Ronald Wayne  0.946990   person
# 2              Apple  0.918116  company
# 3  Jean-Louis Gassée  0.881677   person
# 4         Steve Jobs  0.864480   person

# %%
aapl_wiki_rels.head()
# Out:
#              entity               property                       value                                           evidence
# 0     Jeff Williams          position held     chief operating officer  [369] The following December, Apple's chief op...
# 1        Steve Jobs          date of death                  2011-10-05  On October 5, 2011, Steve Jobs died, marking t...
# 2              Jobs  employee or member of                       Apple  [102] When Apple surpassed Dell's market cap i...
# 3  Charlie Elphicke  employee or member of  British Conservative Party  British Conservative Party Member of Parliamen...
# 4  Charlie Elphicke  political affiliation  British Conservative Party  British Conservative Party Member of Parliamen...

# %%
aapl_wiki_rels["property"].unique()
# Out:
# array(['position held', 'date of death', 'employee or member of',
#        'political affiliation', 'work relationship', 'founded by',
#        'chief executive officer', 'product type', 'acquired by',
#        'suppliers', 'organization locations', 'headquarters',
#        'partnership', 'founding date', 'yearly revenue', 'customers',
#        'competitors', 'number of employees', 'cause of death',
#        'skilled at', 'interested in', 'parent organization', 'subsidiary',
#        'brands', 'industry', 'contributed to', 'all names', 'gender'],
#       dtype=object)

# %%
aapl_wiki_rels[aapl_wiki_rels["property"] == "product type"]
# Out:
#                 entity      property             value                                           evidence
# 16               Apple  product type  iPad accessories  [1] Apple sells several iPad accessories, incl...
# 98               Apple  product type    mobile handset  [115] By October 2008, Apple was the third-lar...
# 101             Emagic  product type          computer  The purchase of Emagic made Apple the first co...
# 119         Apple Inc.  product type      solar energy  Apple Energy, LLC is a wholly-owned subsidiary...
# 125  Apple Energy, LLC  product type      solar energy  Apple Energy, LLC is a wholly-owned subsidiary...

# %%
aapl_wiki_rels[aapl_wiki_rels["property"] == "organization locations"]
# Out:
#                         entity                property       value                                           evidence
# 22                       Apple  organization locations  California  Apple Computer, Inc. was incorporated in Cuper...
# 39                       Apple  organization locations        Cork  Apple's headquarters for Europe, the Middle Ea...
# 78                       Apple  organization locations        Cork  [274] Apple's international sales and distribu...
# 81                       Apple  organization locations     Ireland  Apple's headquarters for Europe, the Middle Ea...
# 109                      Apple  organization locations      Austin  Apple has two campuses near Austin, Texas: a 2...
# 110                      Apple  organization locations       Texas  Apple has two campuses near Austin, Texas: a 2...
# 146                      Apple  organization locations   Cupertino  Apple Inc. is an American multinational corpor...
# 156  Zhengzhou Technology Park  organization locations   Zhengzhou  [386] Zhengzhou Technology Park alone employs ...

# %%
aapl_wiki_rels[aapl_wiki_rels["property"] == "headquarters"]
# Out:
#                         entity      property       value                                           evidence
# 23                       Apple  headquarters  California  Apple Inc. is an American multinational corpor...
# 147                      Apple  headquarters   Cupertino  Apple Inc. is an American multinational corpor...
# 157  Zhengzhou Technology Park  headquarters   Zhengzhou  [386] Zhengzhou Technology Park alone employs ...

# %%
aapl_wiki_rels[aapl_wiki_rels["property"] == "industry"]
# Out:
#     entity  property                   value                                           evidence
# 140  Apple  industry              accounting  In the late 1980s, Apple was a pioneer of an a...
# 154  Apple  industry  information technology  Apple is one of the Big Five American informat...
# 164  Apple  industry              technology  Apple Inc. is an American multinational corpor...

# %%
aapl_wiki_rels[aapl_wiki_rels["property"] == "subsidiary"]
# Out:
#          entity    property              value                                           evidence
# 94      Verizon  subsidiary   Flurry Analytics  A study by Verizon subsidiary Flurry Analytics...
# 120  Apple Inc.  subsidiary  Apple Energy, LLC  Apple Energy, LLC is a wholly-owned subsidiary...

# %%
aapl_wiki_rels[aapl_wiki_rels["property"] == "suppliers"]
# Out:
#     entity   property            value                                           evidence
# 19   Apple  suppliers  Lens Technology  Apple announced on August 16, 2016, that Lens ...
# 102  Apple  suppliers         NeXTSTEP  [69] Only weeks away from bankruptcy,[70] Appl...
# 167  Apple  suppliers  Lens Technology  Apple announced on August 16, 2016, that Lens ...

# %%
aapl_wiki_rels[aapl_wiki_rels["property"] == "competitors"]
# Out:
#         entity     property      value                                           evidence
# 43         CBM  competitors   VisiCalc  [26] VisiCalc created a business market for th...
# 53       Atari  competitors   VisiCalc  [26] VisiCalc created a business market for th...
# 85    VisiCalc  competitors        CBM  [26] VisiCalc created a business market for th...
# 95    VisiCalc  competitors      Atari  [26] VisiCalc created a business market for th...
# 115  Microsoft  competitors      Apple  [119] In May 2010, Apple's market cap exceeded...
# 130      Apple  competitors  Microsoft  [119] In May 2010, Apple's market cap exceeded...

# %% [markdown]
# ## Create JSON Node and Relationship Objects

# %% [markdown]
# To faciliate knowledge graph construction, we collate the entities and relationships extracted for all 40 companies into a JSON object.

# %%
def create_json_schema():
    json_schema = {
        "nodes":{
            "Company":[
                # company nodes here
            ],
            "Country":[
                # country nodes here
            ],
            "Industry":[
                # industry nodes here
            ],
            "Region":[
                # region nodes here
            ],

            "Product":[
                # product nodes here
            ]
        },
        
        "relationships":{
            "PARTNERS_WITH":[
                # (COMPANY cid1)-[:PARTNERS_WITH]->(COMPANY cid2)
            ],
            "COMPETES_WITH":[
                # (COMPANY cid1)-[:COMPETES_WITH]->(COMPANY cid2)
            ],
            "SUBSIDIARY_OF":[
                # (COMPANY cid1)-[:SUBSIDIARY_OF]->(COMPANY cid2)
            ],

            "HEADQUARTERS_IN":[
                # (COMPANY cid)-[:HEADQUARTERS_IN]->(COUNTRY ctyid)
            ],

            "OPERATES_IN_COUNTRY":[
                # (COMPANY cid)-[:OPERATES_IN_COUNTRY]->(COUNTRY ctyid)
            ],

            "IS_INVOLVED_IN":[
                # (COMPANY cid)-[:IS_INVOLVED_IN]->(INDUSTRY iid)
            ],

            "IS_IN":[
                # (COUNTRY ctyid)-[:IS_IN]->(REGION rid)
            ],

            "OPERATES_IN_REGION":[
                # (COMPANY cid)-[:OPERATES_IN_REGION]->(REGION rid)
            ],

            "PRODUCES":[
                # (COMPANY cid)-[:PRODUCES]->(PRODUCT)
            ]
    }}


    return json_schema

# %%
def create_company_node(name,ticker_code = None,founded_year = None):
    c_node = {}

    c_node["name"] = name

    if ticker_code is None:
        c_node["ticker_code"] = get_company_ticker(name)
    else:
        c_node["ticker_code"] = ticker_code
    c_node["founded_year"] = founded_year

    return c_node

# %%
#pip install pycountry
#pip install pycountry-convert
#pip install locationtagger

# %%
import pycountry_convert as pc
import random

def city_to_country(city):
    response = requests.request("GET", f"https://www.geonames.org/search.html?q={city}&country=")
    country_raw = re.findall("/countries.*\\.html", response.text)
    if len(country_raw) != 0:
        country_pred = country_raw[0].strip(".html").split("/")[-1]
        country = country_pred.replace('-',' ').title()
        return country
    else:
        return "Not Found"

def country_to_continent(country_name):
    country_alpha2 = pc.country_name_to_country_alpha2(country_name)
    country_continent_code = pc.country_alpha2_to_continent_code(country_alpha2)
    country_continent_name = pc.convert_continent_code_to_continent_name(country_continent_code)
    return country_continent_name

def create_country_node(name,iso3=None,iso2=None, population = None, gdp = None, corporate_tax_rate = None, is_city = False):
    cnty_node = {}
    
    if is_city:
        cnty_node["source_city"] = name
        name = city_to_country(name)
    cnty_node["name"] = name
    try:
        cnty_node["iso2"] = pc.country_name_to_country_alpha2(name)
        cnty_node["iso3"] = pc.country_name_to_country_alpha3(name)
    except KeyError:
        print(f"{cnty_node["name"]} could not be mapped to iso code")
    
    cnty_node["population"] = random.randint(5,1400) #in millions
    cnty_node["gdp"] = random.randint(1,20000) #in billions
    cnty_node["corporate_tax_rate"] = random.randint(10,50)

    return cnty_node

def create_region_node(cnty_node):
    reg_node = {}
    if cnty_node.get("iso2",None) is None:
        reg_node["name"] = "Not Found"
    else:
        reg_node["name"] = pc.country_alpha2_to_continent_code(cnty_node["iso2"])

    reg_node["m49"] = None
    return reg_node

# %%
def create_industry_node(name,SIC_code = None, industry_group = None, subindustry_desc = None, primary_activity= None):
    ind_node = {}
    ind_node["name"] = name
    ind_node["SIC_code"] = SIC_code
    ind_node["industry_group"] = industry_group
    ind_node["subindustry_desc"] = subindustry_desc
    ind_node["primary_activity"] = primary_activity
    return ind_node

def create_product_node(name):
    pdt_node = {}
    pdt_node["name"] = name
    return pdt_node

# %%
def create_hq_rel(c_node, cnty_node):
    hq_rel = {}
    hq_rel["company_name"] = c_node["name"]
    hq_rel["country_name"] = cnty_node["name"]

    return hq_rel

def create_operates_in_country_rel(c_node, cnty_node):
    oic_rel = {}
    oic_rel["company_name"] = c_node["name"]
    oic_rel["country_name"] = cnty_node["name"]
    oic_rel["net sales"] = random.randint(-30000000,30000000)
    oic_rel["headcount"] = random.randint(1,10000)

    return oic_rel

def create_operates_in_region_rel(c_node, reg_node):
    oir_rel = {}
    oir_rel["company_name"] = c_node["name"]
    oir_rel["region_name"] = reg_node["name"]
    oir_rel["net sales"] = random.randint(-30000000,30000000)
    oir_rel["headcount"] = random.randint(100,1000000)

    return oir_rel

def create_is_in_rel(cnty_node, reg_node):
    is_in_rel = {}
    is_in_rel["country_name"] = cnty_node["name"]
    is_in_rel["region_name"] = reg_node["name"]

    return is_in_rel


#partners, competitors, subsidiaries 
def create_company_company_rel(c_node1, c_node2, type = None):
    c_c_rel = {}
    c_c_rel["company_name_1"] = c_node1["name"]
    c_c_rel["company_name_2"] = c_node2["name"]
    c_c_rel["type"] = type

    return c_c_rel

def create_in_industry_rel(c_node, ind_node):
    c_ind_rel = {}
    c_ind_rel["company_name"] = c_node["name"]
    c_ind_rel["industry_name"] = ind_node["name"]
    return c_ind_rel

def create_produces_rel(c_node, pdt_node):
    c_pdt_rel = {}
    c_pdt_rel["company_name"] = c_node["name"]
    c_pdt_rel["product_name"] = pdt_node["name"]

    return c_pdt_rel

# %%
def generate_json_schema(json, offset = 0):
    dbpath = 'data/ecmdatabase.db'
    con = sqlite3.connect(f"file:{dbpath}?mode=ro", uri=True)

    def fill_entities(ents, c_name):
        if ents is None:
            return None
        
        for _,ent in ents.iterrows():
            if ent["Labels"] =='company' and ent["name"] != c_name:
                ticker = get_company_ticker(ent["name"])
                json["nodes"]["Company"].append(create_company_node(ent["name"],ticker))
            elif ent["Labels"] == 'industry':
                json["nodes"]["Industry"].append(create_industry_node(ent["name"]))
            elif ent["Labels"] == 'country':
                json["nodes"]["Country"].append(create_country_node(ent["name"]))
            elif ent["Labels"] == 'location':
                json["nodes"]["Country"].append(create_country_node(ent["name"], is_city = True))
            elif ent["Labels"] == 'product':
                json["nodes"]["Product"].append(create_product_node(ent["name"]))

        for cnty_node in json["nodes"]["Country"]:
            reg_node = create_region_node(cnty_node)
            json["nodes"]["Region"].append(reg_node)
            json["relationships"]["IS_IN"].append(create_is_in_rel(cnty_node,reg_node))
    
    def fill_relationships(rels):
        if rels is None:
            return None
        
        for _, rel in rels.iterrows():
            if rel["property"] == "headquarters":
                c_node = create_company_node(rel["entity"])
                hq_node = create_country_node(rel["value"], is_city = True)
                hq_rel = create_hq_rel(c_node, hq_node)
                json["relationships"]["HEADQUARTERS_IN"].append(hq_rel)
            elif rel["property"] == "organization locations":
                c_node = create_company_node(rel["entity"])
                loc_node = create_country_node(rel["value"],is_city = True)
                loc_rel = create_operates_in_country_rel(c_node, loc_node)
                json["relationships"]["OPERATES_IN_COUNTRY"].append(loc_rel)
            elif rel["property"] == "industry":
                c_node = create_company_node(rel["entity"])
                ind_node = create_industry_node(rel["value"])
                works_rel = create_in_industry_rel(c_node, ind_node)
                json["relationships"]["IS_INVOLVED_IN"].append(works_rel)
            elif rel["property"] == "product type":
                c_node = create_company_node(rel["entity"])
                pdt_node = create_product_node(rel["value"])
                produces_rel = create_produces_rel(c_node,pdt_node)
                json["relationships"]["PRODUCES"].append(produces_rel)

            elif rel["property"] == "competitors":
                c_node_1 = create_company_node(rel["entity"])
                c_node_2 = create_company_node(rel["value"])
                cc_rel = create_company_company_rel(c_node_1,c_node_2)
                json["relationships"]["COMPETES_WITH"].append(cc_rel)
            elif rel["property"] == "suppliers":
                c_node_1 = create_company_node(rel["entity"])
                c_node_2 = create_company_node(rel["value"])
                cc_rel = create_company_company_rel(c_node_1,c_node_2, "suppliers")
                json["relationships"]["PARTNERS_WITH"].append(cc_rel)
            elif rel["property"] == "subsidiary":
                c_node_1 = create_company_node(rel["entity"])
                c_node_2 = create_company_node(rel["value"])
                cc_rel = create_company_company_rel(c_node_2, c_node_1, "subsidiary")
                json["relationships"]["SUBSIDIARY_OF"].append(cc_rel)
    with con:
        result = con.execute(f"SELECT name, stock_symbol from companies ORDER BY name LIMIT 40 OFFSET {offset};")
        records = result.fetchall()
        for record in records:
            company_name = record[0]
            stock_code = record[1]

            print(f'Processing {company_name} with stock code {stock_code}')
            
            c_node = create_company_node(company_name,stock_code)
            json["nodes"]["Company"].append(c_node)

            sec_10k_ents, sec_10k_rels = sec_10k_ner_rel_pipeline(stock_code)
            wiki_ents, wiki_rels = wikipedia_ner_rel_pipeline(stock_code)

            fill_entities(sec_10k_ents,company_name)
            fill_entities(wiki_ents,company_name)
            fill_relationships(sec_10k_rels)
            fill_relationships(wiki_rels)
    
    return json

# %%
empty_schema = create_json_schema()
print(empty_schema)
# Out:
# {'nodes': {'Company': [], 'Country': [], 'Industry': [], 'Region': [], 'Product': []}, 'relationships': {'PARTNERS_WITH': [], 'COMPETES_WITH': [], 'SUBSIDIARY_OF': [], 'HEADQUARTERS_IN': [], 'OPERATES_IN_COUNTRY': [], 'IS_INVOLVED_IN': [], 'IS_IN': [], 'OPERATES_IN_REGION': [], 'PRODUCES': []}}

# %%
import warnings
warnings.filterwarnings('ignore')

kg_json = generate_json_schema(empty_schema, offset = 32) # change offset to index of last generated company
# Out:
# Processing Booking Holdings Inc. with stock code BKNG
# Rate Limit Exceeded. Natural Language API allows only 500 calls a month.
# {'entities': [{'name': 'Booking Holdings', 'diffbotUri': 'https://diffbot.com/entity/EfyZKNKILOy6FOhU-apo2uQ', 'confidence': 0.99997425, 'salience': 0.97308975, 'isCustom': False, 'allUris': ['http://www.wikidata.org/entity/Q18674747'], 'allTypes': [{'name': 'organization', 'diffbotUri': 'https://diffbot.com/entity/EN1ClYEdMMQCxB6AWTkT3mA', 'dbpediaUri': 'http://dbpedia.org/ontology/Organisation'}], 'mentions': [{'text': 'Our', 'beginOffset': 18, 'endOffset': 21, 'isPronoun': True, 'confidence': 0.9999145}, {'text': 'We', 'beginOffset': 89, 'endOffset': 91, 'isPronoun': True, 'confidence': 0.9998443}, {'text': 'We', 'beginOffset': 310, 'endOffset': 312, 'isPronoun': True, 'confidence': 0.99980754}, {'text': 'Priceline', 'beginOffset': 392, 'endOffset': 401, 'confidence': 0.999236}, {'text': 'We', 'beginOffset': 432, 'endOffset': 434, 'isPronoun': True, 'confidence': 0.99985516}, {'text': 'our', 'beginOffset': 473, 'endOffset': 476, 'isPronoun': True, 'confidence': 0.9997482}, {'text': 'our', 'beginOffset': 584, 'endOffset': 587, 'isPronoun': True, 'confidence': 0.99986875}, {'text': 'our', 'beginOffset': 870, 'endOffset': 873, 'isPronoun': True, 'confidence': 0.9996183}, {'text': 'our', 'beginOffset': 929, 'endOffset': 932, 'isPronoun': True, 'confidence': 0.9997813}, {'text': 'our', 'beginOffset': 1014, 'endOffset': 1017, 'isPronoun': True, 'confidence': 0.99997425}, {'text': 'our', 'beginOffset': 1037, 'endOffset': 1040, 'isPronoun': True, 'confidence': 0.9997962}, {'text': 'our', 'beginOffset': 1172, 'endOffset': 1175, 'isPronoun': True, 'confidence': 0.99966395}, {'text': 'our', 'beginOffset': 1221, 'endOffset': 1224, 'isPronoun': True, 'confidence': 0.99994123}, {'text': 'Our', 'beginOffset': 1355, 'endOffset': 1358, 'isPronoun': True, 'confidence': 0.9998447}, {'text': 'BKNG', 'beginOffset': 1434, 'endOffset': 1438, 'confidence': 0.97701454}, {'text': 'We', 'beginOffset': 1440, 'endOffset': 1442, 'isPronoun': True, 'confidence': 0.99986327}, {'text': 'our', 'beginOffset': 1452, 'endOffset': 1455, 'isPronoun': True, 'confidence': 0.999863}, {'text': 'our', 'beginOffset': 1475, 'endOffset': 1478, 'isPronoun': True, 'confidence': 0.9998306}, {'text': 'Booking Holdings', 'beginOffset': 1519, 'endOffset': 1535, 'confidence': 0.9978549}, {'text': 'we', 'beginOffset': 1550, 'endOffset': 1552, 'isPronoun': True, 'confidence': 0.9997265}, {'text': 'our', 'beginOffset': 1554, 'endOffset': 1557, 'isPronoun': True, 'confidence': 0.99952567}, {'text': 'Our', 'beginOffset': 1566, 'endOffset': 1569, 'isPronoun': True, 'confidence': 0.9999081}, {'text': 'We', 'beginOffset': 1592, 'endOffset': 1594, 'isPronoun': True, 'confidence': 0.9997454}, {'text': 'our', 'beginOffset': 1623, 'endOffset': 1626, 'isPronoun': True, 'confidence': 0.99990344}, {'text': 'we', 'beginOffset': 1782, 'endOffset': 1784, 'isPronoun': True, 'confidence': 0.9997826}, {'text': 'We', 'beginOffset': 1846, 'endOffset': 1848, 'isPronoun': True, 'confidence': 0.99956554}, {'text': 'we', 'beginOffset': 2095, 'endOffset': 2097, 'isPronoun': True, 'confidence': 0.99977535}, {'text': 'we', 'beginOffset': 2244, 'endOffset': 2246, 'isPronoun': True, 'confidence': 0.99994254}, {'text': 'Priceline', 'beginOffset': 9656, 'endOffset': 9665, 'confidence': 0.8062597}, {'text': 'Priceline', 'beginOffset': 9667, 'endOffset': 9676, 'confidence': 0.9965653}, {'text': 'Priceline', 'beginOffset': 9849, 'endOffset': 9858, 'confidence': 0.99353504}], 'location': {'latitude': 41.093143, 'longitude': -73.45418, 'precision': 0.1}}, {'name': 'Booking.com', 'diffbotUri': 'https://diffbot.com/entity/EX4bUvUmLPo65Bbp8TscmHg', 'confidence': 0.9986626, 'salience': 0.9510528, 'isCustom': False, 'allUris': ['http://www.wikidata.org/entity/Q4035313'], 'allTypes': [{'name': 'organization', 'diffbotUri': 'https://diffbot.com/entity/EN1ClYEdMMQCxB6AWTkT3mA', 'dbpediaUri': 'http://dbpedia.org/ontology/Organisation'}, {'name': 'skill', 'diffbotUri': 'https://diffbot.com/entity/EvfbHngnSNVOh7ZBM5XTywQ'}, { ...
# Found Company: Booking Holdings Inc.
# Error fetching the Wikipedia article: 404 Client Error: Not Found for url: https://en.wikipedia.org/wiki/Booking_Holdings_Inc.
# Processing Broadcom Inc. with stock code AVGO
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[38], line 4
#       1 import warnings
#       2 warnings.filterwarnings('ignore')
# ----> 4 kg_json = generate_json_schema(empty_schema,offset = 10) # change offset to index of last generated company
#
# Cell In[27], line 80, in generate_json_schema(json, offset)
#      77 c_node = create_company_node(company_name,stock_code)
#      78 json["nodes"]["Company"].append(c_node)
# ---> 80 sec_10k_ents, sec_10k_rels = sec_10k_ner_rel_pipeline(stock_code)
#      81 wiki_ents, wiki_rels = wikipedia_ner_rel_pipeline(stock_code)
#      83 fill_entities(sec_10k_ents,company_name)
#
# Cell In[21], line 42, in sec_10k_ner_rel_pipeline(ticker)
#      36     item7 = records[0][3].replace('\n', '')
#      37 item1_res = get_request({
#      38 "content": item1,
#      39 "lang": "en",
#      40 "format": "plain text",
#      41 })
# ---> 42 item7_res = get_request({
#      43 "content": item7,
#      44 "lang": "en",
#      45 "format": "plain text",
#      46 })
#      48 try:
#      49     item1_ents, item1_rels = extract_entites(item1_res), extract_relationships(item1_res)
#
# Cell In[15], line 4, in get_request(payload)
#       3 def get_request(payload):
# ----> 4   res = requests.post("https://{}/v1/?fields={}&token={}".format(HOST, FIELDS, TOKEN), json=payload)
#       5   ret = None
#       6   try:
#
# File c:\Users\DELL\AppData\Local\Programs\Python\Python312\Lib\site-packages\requests\api.py:115, in post(url, data, json, **kwargs)
#     103 def post(url, data=None, json=None, **kwargs):
#     104     r"""Sends a POST request.
#     105
#     106     :param url: URL for the new :class:`Request` object.
#    (...)
#     112     :rtype: requests.Response
#     113     """
# --> 115     return request("post", url, data=data, json=json, **kwargs)
#
# File c:\Users\DELL\AppData\Local\Programs\Python\Python312\Lib\site-packages\requests\api.py:59, in request(method, url, **kwargs)
#      55 # By using the 'with' statement we are sure the session is closed, thus we
#      56 # avoid leaving sockets open which can trigger a ResourceWarning in some
#      57 # cases, and look like a memory leak in others.
#      58 with sessions.Session() as session:
# ---> 59     return session.request(method=method, url=url, **kwargs)
#
# File c:\Users\DELL\AppData\Local\Programs\Python\Python312\Lib\site-packages\requests\sessions.py:589, in Session.request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     584 send_kwargs = {
#     585     "timeout": timeout,
#     586     "allow_redirects": allow_redirects,
#     587 }
#     588 send_kwargs.update(settings)
# --> 589 resp = self.send(prep, **send_kwargs)
#     591 return resp
#
# File c:\Users\DELL\AppData\Local\Programs\Python\Python312\Lib\site-packages\requests\sessions.py:703, in Session.send(self, request, **kwargs)
#     700 start = preferred_clock()
#     702 # Send the request
# --> 703 r = adapter.send(request, **kwargs)
#     705 # Total elapsed time of the request (approximately)
#     706 elapsed = preferred_clock() - start
#
# File c:\Users\DELL\AppData\Local\Programs\Python\Python312\Lib\site-packages\requests\adapters.py:667, in HTTPAdapter.send(self, request, stream, timeout, verify, cert, proxies)
#     664     timeout = TimeoutSauce(connect=timeout, read=timeout)
#     666 try:
# --> 667     resp = conn.urlopen(
#     668         method=request.method,
#     669         url=url,
#     670         body=request.body,
#     671         headers=request.headers,
#     672         redirect=False,
#     673         assert_same_host=False,
#     674         preload_content=False,
#     675         decode_content=False,
#     676         retries=self.max_retries,
#     677         timeout=timeout,
#     678         chunked=chunked,
#     679     )
#     681 except (ProtocolError, OSError) as err:
#     682     raise ConnectionError(err, request=request)
#
# File c:\Users\DELL\AppData\Local\Programs\Python\Python312\Lib\site-packages\urllib3\connectionpool.py:789, in HTTPConnectionPool.urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, preload_content, decode_content, **response_kw)
#     786 response_conn = conn if not release_conn else None
#     788 # Make the request on the HTTPConnection object
# --> 789 response = self._make_request(
#     790     conn,
#     791     method,
#     792     url,
#     793     timeout=timeout_obj,
#     794     body=body,
#     795     headers=headers,
#     796     chunked=chunked,
#     797     retries=retries,
#     798     response_conn=response_conn,
#     799     preload_content=preload_content,
#     800     decode_content=decode_content,
#     801     **response_kw,
#     802 )
#     804 # Everything went great!
#     805 clean_exit = True
#
# File c:\Users\DELL\AppData\Local\Programs\Python\Python312\Lib\site-packages\urllib3\connectionpool.py:536, in HTTPConnectionPool._make_request(self, conn, method, url, body, headers, retries, timeout, chunked, response_conn, preload_content, decode_content, enforce_content_length)
#     534 # Receive the response from the server
#     535 try:
# --> 536     response = conn.getresponse()
#     537 except (BaseSSLError, OSError) as e:
#     538     self._raise_timeout(err=e, url=url, timeout_value=read_timeout)
#
# File c:\Users\DELL\AppData\Local\Programs\Python\Python312\Lib\site-packages\urllib3\connection.py:464, in HTTPConnection.getresponse(self)
#     461 from .response import HTTPResponse
#     463 # Get the response from http.client.HTTPConnection
# --> 464 httplib_response = super().getresponse()
#     466 try:
#     467     assert_header_parsing(httplib_response.msg)
#
# File c:\Users\DELL\AppData\Local\Programs\Python\Python312\Lib\http\client.py:1428, in HTTPConnection.getresponse(self)
#    1426 try:
#    1427     try:
# -> 1428         response.begin()
#    1429     except ConnectionError:
#    1430         self.close()
#
# File c:\Users\DELL\AppData\Local\Programs\Python\Python312\Lib\http\client.py:331, in HTTPResponse.begin(self)
#     329 # read until we get a non-100 response
#     330 while True:
# --> 331     version, status, reason = self._read_status()
#     332     if status != CONTINUE:
#     333         break
#
# File c:\Users\DELL\AppData\Local\Programs\Python\Python312\Lib\http\client.py:292, in HTTPResponse._read_status(self)
#     291 def _read_status(self):
# --> 292     line = str(self.fp.readline(_MAXLINE + 1), "iso-8859-1")
#     293     if len(line) > _MAXLINE:
#     294         raise LineTooLong("status line")
#
# File c:\Users\DELL\AppData\Local\Programs\Python\Python312\Lib\socket.py:720, in SocketIO.readinto(self, b)
#     718 while True:
#     719     try:
# --> 720         return self._sock.recv_into(b)
#     721     except timeout:
#     722         self._timeout_occurred = True
#
# File c:\Users\DELL\AppData\Local\Programs\Python\Python312\Lib\ssl.py:1251, in SSLSocket.recv_into(self, buffer, nbytes, flags)
#    1247     if flags != 0:
#    1248         raise ValueError(
#    1249           "non-zero flags not allowed in calls to recv_into() on %s" %
#    1250           self.__class__)
# -> 1251     return self.read(nbytes, buffer)
#    1252 else:
#    1253     return super().recv_into(buffer, nbytes, flags)
#
# File c:\Users\DELL\AppData\Local\Programs\Python\Python312\Lib\ssl.py:1103, in SSLSocket.read(self, len, buffer)
#    1101 try:
#    1102     if buffer is not None:
# -> 1103         return self._sslobj.read(len, buffer)
#    1104     else:
#    1105         return self._sslobj.read(len)
#
# KeyboardInterrupt:

# %%
empty_schema
# Out:
# {'nodes': {'Company': [{'name': 'Booking Holdings Inc.',
#     'ticker_code': 'BKNG',
#     'founded_year': None},
#    {'name': 'Booking Holdings', 'ticker_code': 'BKNG', 'founded_year': None},
#    {'name': 'Booking.com', 'ticker_code': 'BKNG', 'founded_year': None},
#    {'name': 'OpenTable',
#     'ticker_code': 'opentable-225400154.html',
#     'founded_year': None},
#    {'name': 'Agoda', 'ticker_code': 'BKNG', 'founded_year': None},
#    {'name': 'Nasdaq', 'ticker_code': '%5EIXIC', 'founded_year': None},
#    {'name': 'Agoda', 'ticker_code': 'BKNG', 'founded_year': None},
#    {'name': 'Booking.com', 'ticker_code': 'BKNG', 'founded_year': None},
#    {'name': 'OpenTable',
#     'ticker_code': 'opentable-225400154.html',
#     'founded_year': None},
#    {'name': 'Booking Holdings', 'ticker_code': 'BKNG', 'founded_year': None},
#    {'name': 'Broadcom Inc.', 'ticker_code': 'AVGO', 'founded_year': None},
#    {'name': 'Brocade Communications Systems',
#     'ticker_code': 'BCSA.DE',
#     'founded_year': None},
#    {'name': 'VMware', 'ticker_code': 'vmw', 'founded_year': None},
#    {'name': 'Broadcom', 'ticker_code': 'AVGO', 'founded_year': None},
#    {'name': 'LSI', 'ticker_code': 'LYTS', 'founded_year': None},
#    {'name': 'VMware Merger',
#     'ticker_code': 'broadcom-completes-acquisition-vmware-133000964.html',
#     'founded_year': None},
#    {'name': 'VMware Merger',
#     'ticker_code': 'broadcom-completes-acquisition-vmware-133000964.html',
#     'founded_year': None},
#    {'name': 'Symantec Enterprise Security',
#     'ticker_code': 'symantec-cybersecurity-solutions-assessed-combat-220000232.html',
#     'founded_year': None},
#    {'name': 'VMware Merger',
#     'ticker_code': 'broadcom-completes-acquisition-vmware-133000964.html',
#     'founded_year': None},
#    {'name': 'Broadcom', 'ticker_code': 'AVGO', 'founded_year': None},
#    {'name': 'VMware', 'ticker_code': 'vmw', 'founded_year': None},
#    {'name': 'AND Analysis',
#     'ticker_code': 'sg.finance.yahoo.com',
#     'founded_year': None},
#    {'name': 'Securities and Exchange Commission',
#     'ticker_code': 'd293630d10k.htm',
#     'founded_year': None},
#    {'name': 'Broadcom', 'ticker_code': 'AVGO', 'founded_year': None},
#    {'name': 'CINTAS CORP', 'ticker_code': 'CTAS', 'founded_year': None},
#    {'name': 'Cintas', 'ticker_code': 'CTAS', 'founded_year': None},
#    {'name': 'Workday', 'ticker_code': 'WDAY', 'founded_year': None},
#    {'name': 'Cintas', 'ticker_code': 'CTAS', 'founded_year': None},
#    {'name': 'Workday', 'ticker_code': 'WDAY', 'founded_year': None},
#    {'name': 'Cintas', 'ticker_code': 'CTAS', 'founded_year': None},
#    {'name': 'CISCO SYSTEMS, INC.',
#     'ticker_code': 'CSCO',
#     'founded_year': None},
#    {'name': 'Cisco Systems', 'ticker_code': 'CSCO', 'founded_year': None},
#    {'name': 'APJC', 'ticker_code': 'APJCX', 'founded_year': None},
#    {'name': 'Securities and Exchange Commission',
#     'ticker_code': 'd293630d10k.htm',
#     'founded_year': None},
#    {'name': 'Splunk', 'ticker_code': 'SPLK', 'founded_year': None},
#    {'name': 'Modernize', 'ticker_code': 'select-plan', 'founded_year': None},
#    {'name': 'APJC', 'ticker_code': 'APJCX', 'founded_year': None},
#    {'name': 'Cisco Systems', 'ticker_code': 'CSCO', 'founded_year': None},
#    {'name': 'Splunk', 'ticker_code': 'SPLK', 'founded_year': None},
#    {'name': 'Key Financial',
#     'ticker_code': 'sg.finance.yahoo.com',
#     'founded_year': None},
#    {'name': 'Cisco Systems', 'ticker_code': 'CSCO', 'founded_year': None},
#    {'name': 'COMCAST CORP', 'ticker_code': 'CMCSA', 'founded_year': None},
#    {'name': 'Sky Stream',
#     'ticker_code': 'youll-soon-able-sky-stream-230100403.html',
#     'founded_year': None},
#    {'name': 'Sky Sports', 'ticker_code': 'SKT.NZ', 'founded_year': None},
#    {'name': 'Internet Essentials',
#     'ticker_code': 'comcast-remains-dedicated-closing-digital-144500207.html',
#     'founded_year': None},
#    {'name': 'Virgin Media O2',
#     'ticker_code': 'virgin-media-o2-offload-stake-071957969.html',
#     'founded_year': None},
#    {'name': 'Comcast Business', 'ticker_code': 'CMCSA', 'founded_year': None},
#    {'name': 'Comcast', 'ticker_code': 'CMCSA', 'founded_year': None},
#    {'name': 'Xumo',
#     'ticker_code': 'xumo-2024-fast-report-reveals-140000471.html',
#     'founded_year': None},
#    {'name': 'NOW', 'ticker_code': 'NOW', 'founded_year': None},
#    {'name': 'Universal Pictures', 'ticker_code': 'UVV', 'founded_year': None},
#    {'name': 'Comcast', 'ticker_code': 'CMCSA', 'founded_year': None},
#    {'name': 'Comcast Corporation',
#     'ticker_code': 'CMCSA',
#     'founded_year': None},
#    {'name': 'Comcast', 'ticker_code': 'CMCSA', 'founded_year': None},
#    {'name': 'COSTCO WHOLESALE CORP /NEW',
#     'ticker_code': 'COST',
#     'founded_year': None},
#    {'name': 'Costco Wholesale', 'ticker_code': 'COST', 'founded_year': None},
#    {'name': 'Securities and Exchange Commission',
#     'ticker_code': 'd293630d10k.htm',
#     'founded_year': None},
#    {'name': 'Costco Wholesale', 'ticker_code': 'COST', 'founded_year': None},
#    {'name': 'GILEAD SCIENCES, INC.',
#     'ticker_code': 'GILD',
#     'founded_year': None},
#    {'name': 'Janssen Pharmaceutica',
#     'ticker_code': 'JNJ',
#     'founded_year': None},
#    {'name': 'Asegua Therapeutics',
#     'ticker_code': 'gilead-sciences-announces-second-quarter-200200721.html',
#     'founded_year': None},
#    {'name': 'Food and Drug Administration',
#     'ticker_code': 'u-food-drug-administration-gives-111600724.html',
#     'founded_year': None},
#    {'name': 'Federal Trade Commission',
#     'ticker_code': 'ftc-finalizes-merger-filing-requirements-214331138.html',
#     'founded_year': None},
#    {'name': 'Janssen Sciences Ireland Unlimited Company',
#     'ticker_code': 'GILD',
#     'founded_year': None},
#    {'name': 'Shanghai Fosun Pharmaceutical (Group) Co.',
#     'ticker_code': '2196.HK',
#     'founded_year': None},
#    {'name': 'XinThera',
#     'ticker_code': 'mbrace-therapeutics-raises-85-million-133000731.html',
#     'founded_year': None},
#    {'name': 'Tentarix Biotherapeutics',
#     'ticker_code': 'tentarix-biotherapeutics-announces-appointment-andrew-120000907.html',
#     'founded_year': None},
#    {'name': 'Tmunity Therapeutics',
#     'ticker_code': 'CTNM',
#     'founded_year': None},
#    {'name': 'Compugen', 'ticker_code': 'CGEN', 'founded_year': None},
#    {'name': 'Arcus Biosciences', 'ticker_code': 'RCUS', 'founded_year': None},
#    {'name': 'Arcellx', 'ticker_code': 'ACLX', 'founded_year': None},
#    {'name': 'European Commission',
#     'ticker_code': 'european-union',
#     'founded_year': None},
#    {'name': 'Metabolex', 'ticker_code': 'META', 'founded_year': None},
#    {'name': 'Assembly Biosciences',
#     'ticker_code': 'ASMB',
#     'founded_year': None},
#    {'name': 'Daiichi Sankyo', 'ticker_code': 'DSNKY', 'founded_year': None},
#    {'name': 'Food and Drug Administration',
#     'ticker_code': 'u-food-drug-administration-gives-111600724.html',
#     'founded_year': None},
#    {'name': 'Nurix', 'ticker_code': 'NRIX', 'founded_year': None},
#    {'name': 'AND Analysis',
#     'ticker_code': 'sg.finance.yahoo.com',
#     'founded_year': None},
#    {'name': 'Securities and Exchange Commission',
#     'ticker_code': 'd293630d10k.htm',
#     'founded_year': None},
#    {'name': 'Gilead Sciences', 'ticker_code': 'GILD', 'founded_year': None},
#    {'name': 'European Union',
#     'ticker_code': 'european-union',
#     'founded_year': None},
#    {'name': 'Oaktree', 'ticker_code': 'OAK-PB', 'founded_year': None},
#    {'name': 'Gilead Sciences K.K.',
#     'ticker_code': 'GILD',
#     'founded_year': None},
#    {'name': 'Gilead Sciences', 'ticker_code': 'GILD', 'founded_year': None},
#    {'name': 'HONEYWELL INTERNATIONAL INC',
#     'ticker_code': 'HON',
#     'founded_year': None},
#    {'name': 'Aerospace Technologies Group',
#     'ticker_code': '1725.HK',
#     'founded_year': None},
#    {'name': 'Honeywell Building Technologies',
#     'ticker_code': 'HON',
#     'founded_year': None},
#    {'name': 'Honeywell International',
#     'ticker_code': 'HON',
#     'founded_year': None},
#    {'name': 'Quantinuum',
#     'ticker_code': 'quantinuum-unveils-accelerated-roadmap-achieve-141700991.html',
#     'founded_year': None},
#    {'name': 'Honeywell International Inc.',
#     'ticker_code': 'HON',
#     'founded_year': None},
#    {'name': 'Performance Materials and Technologies',
#     'ticker_code': 'technology',
#     'founded_year': None},
#    {'name': 'AEROSPACE',
#     'ticker_code': 'aerospace-defense',
#     'founded_year': None},
#    {'name': 'Commercial Aviation Original Equipment',
#     'ticker_code': 'commercial-aviation-iot-integration-growth-224500494.html',
#     'founded_year': None},
#    {'name': 'Energy and Sustainability Solutions',
#     'ticker_code': 'energy-industry-trends-report-2023-152900468.html',
#     'founded_year': None},
#    {'name': 'Honeywell International',
#     'ticker_code': 'HON',
#     'founded_year': None},
#    {'name': 'Butz', 'ticker_code': 'BULZ', 'founded_year': None},
#    {'name': 'INTEL CORP', 'ticker_code': 'INTC', 'founded_year': None},
#    {'name': 'Intel', 'ticker_code': 'INTC', 'founded_year': None},
#    {'name': 'Silicon Integrated Systems',
#     'ticker_code': '2363.TW',
#     'founded_year': None},
#    {'name': 'United Microelectronics',
#     'ticker_code': 'UMC',
#     'founded_year': None},
#    {'name': 'Applied Micro Circuits',
#     'ticker_code': 'lawsuit-investors-held-shares-applied-132000786.html',
#     'founded_year': None},
#    {'name': 'INTUIT INC.', 'ticker_code': 'INTU', 'founded_year': None},
#    {'name': 'Credit Karma',
#     'ticker_code': 'intuit-ceo-credit-karma-ceo-153916360.html',
#     'founded_year': None},
#    {'name': 'Intuit', 'ticker_code': 'INTU', 'founded_year': None},
#    {'name': 'Growth Strategy',
#     'ticker_code': 'why-clearbridge-growth-strategy-increased-125509019.html',
#     'founded_year': None},
#    {'name': 'Humanise.AI', 'ticker_code': 'HEART-USD', 'founded_year': None},
#    {'name': 'Mailchimp',
#     'ticker_code': 'intuit-mailchimp-wix-enter-strategic-130000364.html',
#     'founded_year': None},
#    {'name': 'ProTax', 'ticker_code': 'INTU', 'founded_year': None},
#    {'name': 'ProTax', 'ticker_code': 'INTU', 'founded_year': None},
#    {'name': 'AND Analysis',
#     'ticker_code': 'sg.finance.yahoo.com',
#     'founded_year': None},
#    {'name': 'Mailchimp',
#     'ticker_code': 'intuit-mailchimp-wix-enter-strategic-130000364.html',
#     'founded_year': None},
#    {'name': 'The Rocket Science Group LLC',
#     'ticker_code': 'RKT',
#     'founded_year': None},
#    {'name': 'Intuit', 'ticker_code': 'INTU', 'founded_year': None},
#    {'name': 'INTUITIVE SURGICAL INC',
#     'ticker_code': 'ISRG',
#     'founded_year': None},
#    {'name': 'Intuitive Surgical', 'ticker_code': 'ISRG', 'founded_year': None},
#    {'name': 'KLA CORP', 'ticker_code': 'KLAC', 'founded_year': None},
#    {'name': 'KLA Corporation', 'ticker_code': 'KLAC', 'founded_year': None},
#    {'name': 'Current Reports',
#     'ticker_code': 'sg.finance.yahoo.com',
#     'founded_year': None},
#    {'name': 'KLA-Tencor Corporation',
#     'ticker_code': 'KLAC',
#     'founded_year': None},
#    {'name': 'Tencor Instruments', 'ticker_code': 'KLAC', 'founded_year': None},
#    {'name': 'KLA Instruments Corporation',
#     'ticker_code': 'KLAC',
#     'founded_year': None},
#    {'name': 'AND Analysis',
#     'ticker_code': 'sg.finance.yahoo.com',
#     'founded_year': None},
#    {'name': 'KLA Corporation', 'ticker_code': 'KLAC', 'founded_year': None},
#    {'name': 'SensArray Corporation',
#     'ticker_code': 'KLAC',
#     'founded_year': None},
#    {'name': 'LAM RESEARCH CORP', 'ticker_code': 'LRCX', 'founded_year': None},
#    {'name': 'Lam Research', 'ticker_code': 'LRCX', 'founded_year': None},
#    {'name': 'Current Reports',
#     'ticker_code': 'sg.finance.yahoo.com',
#     'founded_year': None},
#    {'name': 'Customer Support Business Group',
#     'ticker_code': 'sg.finance.yahoo.com',
#     'founded_year': None},
#    {'name': 'Customer Support Business Group',
#     'ticker_code': 'sg.finance.yahoo.com',
#     'founded_year': None},
#    {'name': 'Customer Support Business Group',
#     'ticker_code': 'sg.finance.yahoo.com',
#     'founded_year': None},
#    {'name': 'Lam Research', 'ticker_code': 'LRCX', 'founded_year': None},
#    {'name': 'Lam Research', 'ticker_code': 'LRCX', 'founded_year': None},
#    {'name': 'LINDE PLC', 'ticker_code': 'LIN', 'founded_year': None},
#    {'name': 'AND Analysis',
#     'ticker_code': 'sg.finance.yahoo.com',
#     'founded_year': None},
#    {'name': 'The Linde Group', 'ticker_code': 'LIN', 'founded_year': None},
#    {'name': 'MERCADOLIBRE INC', 'ticker_code': 'MELI', 'founded_year': None},
#    {'name': 'Mercado Pago', 'ticker_code': 'MELI', 'founded_year': None},
#    {'name': 'MercadoLibre', 'ticker_code': 'MELI', 'founded_year': None},
#    {'name': 'IN-STORE',
#     'ticker_code': 'sg.finance.yahoo.com',
#     'founded_year': None},
#    {'name': 'Marketplaces',
#     'ticker_code': 'sg.finance.yahoo.com',
#     'founded_year': None},
#    {'name': 'BUSINESS MercadoLibre, Inc.',
#     'ticker_code': 'MELI',
#     'founded_year': None},
#    {'name': 'Mercado Envios', 'ticker_code': 'MELI', 'founded_year': None},
#    {'name': 'MercadoLibre', 'ticker_code': 'MELI', 'founded_year': None},
#    {'name': 'Mercado Pago', 'ticker_code': 'MELI', 'founded_year': None},
#    {'name': 'AND Analysis',
#     'ticker_code': 'sg.finance.yahoo.com',
#     'founded_year': None},
#    {'name': 'Marketplaces',
#     'ticker_code': 'sg.finance.yahoo.com',
#     'founded_year': None},
#    {'name': 'Mercado Envios', 'ticker_code': 'MELI', 'founded_year': None},
#    {'name': 'Mercado Libre Classifieds',
#     'ticker_code': 'MELI',
#     'founded_year': None},
#    {'name': 'Mercado Libre Classifieds',
#     'ticker_code': 'MELI',
#     'founded_year': None},
#    {'name': 'MercadoLibre', 'ticker_code': 'MELI', 'founded_year': None},
#    {'name': 'Classified Media Group',
#     'ticker_code': 'news',
#     'founded_year': None},
#    {'name': 'MercadoLibre.com', 'ticker_code': 'MELI', 'founded_year': None},
#    {'name': 'MICRON TECHNOLOGY INC',
#     'ticker_code': 'MU',
#     'founded_year': None},
#    {'name': 'Micron Technology', 'ticker_code': 'MU', 'founded_year': None},
#    {'name': 'Mobile Business Unit',
#     'ticker_code': 'ic-group-announces-successful-transition-150800300.html',
#     'founded_year': None},
#    {'name': 'Mobile Business Unit',
#     'ticker_code': 'ic-group-announces-successful-transition-150800300.html',
#     'founded_year': None},
#    {'name': 'Mobile Business Unit',
#     'ticker_code': 'ic-group-announces-successful-transition-150800300.html',
#     'founded_year': None},
#    {'name': 'Mobile Business Unit',
#     'ticker_code': 'ic-group-announces-successful-transition-150800300.html',
#     'founded_year': None},
#    {'name': 'Mobile Business Unit',
#     'ticker_code': 'ic-group-announces-successful-transition-150800300.html',
#     'founded_year': None},
#    {'name': 'Mobile Business Unit',
#     'ticker_code': 'ic-group-announces-successful-transition-150800300.html',
#     'founded_year': None},
#    {'name': 'AND Analysis',
#     'ticker_code': 'sg.finance.yahoo.com',
#     'founded_year': None},
#    {'name': 'Cyberspace Administration of China',
#     'ticker_code': 'chinas-cyberspace-administration-conducting-review-034809137.html',
#     'founded_year': None},
#    {'name': 'CAC', 'ticker_code': '%5EFCHI', 'founded_year': None},
#    {'name': 'CAC', 'ticker_code': '%5EFCHI', 'founded_year': None},
#    {'name': 'Micron Technology', 'ticker_code': 'MU', 'founded_year': None},
#    {'name': 'MICROSOFT CORP', 'ticker_code': 'MSFT', 'founded_year': None},
#    {'name': 'Intelligent Cloud',
#     'ticker_code': 'microsoft-cuts-first-quarter-intelligent-203547916.html',
#     'founded_year': None},
#    {'name': 'Microsoft', 'ticker_code': 'MSFT', 'founded_year': None},
#    {'name': 'Nuance Communications',
#     'ticker_code': 'NUAN',
#     'founded_year': None},
#    {'name': 'Humanise.AI', 'ticker_code': 'HEART-USD', 'founded_year': None},
#    {'name': 'OpenAI', 'ticker_code': 'openai', 'founded_year': None},
#    {'name': 'REinvent', 'ticker_code': 'RTPZU', 'founded_year': None},
#    {'name': 'Intelligent Cloud',
#     'ticker_code': 'microsoft-cuts-first-quarter-intelligent-203547916.html',
#     'founded_year': None},
#    {'name': 'Activision Blizzard',
#     'ticker_code': 'AIY.DE',
#     'founded_year': None},
#    {'name': 'AND Analysis',
#     'ticker_code': 'sg.finance.yahoo.com',
#     'founded_year': None},
#    {'name': 'Reportable', 'ticker_code': 'earnings', 'founded_year': None},
#    {'name': 'Microsoft', 'ticker_code': 'MSFT', 'founded_year': None},
#    {'name': 'Additional',
#     'ticker_code': 'sg.finance.yahoo.com',
#     'founded_year': None},
#    {'name': 'LinkedIn', 'ticker_code': 'yahoo-finance', 'founded_year': None},
#    {'name': 'Microsoft', 'ticker_code': 'MSFT', 'founded_year': None},
#    {'name': 'Micro Instrumentation and Telemetry Systems (MITS)',
#     'ticker_code': 'happy-birthday-microsoft-5-fun-180906925.html',
#     'founded_year': None},
#    {'name': 'Meta Platforms, Inc.',
#     'ticker_code': 'META',
#     'founded_year': None},
#    {'name': 'Reality Labs',
#     'ticker_code': 'metas-reality-check-inside-the-45-billion-cash-burn-at-reality-labs-125717347.html',
#     'founded_year': None},
#    {'name': 'Meta Platforms', 'ticker_code': 'META', 'founded_year': None},
#    {'name': 'Instagram', 'ticker_code': 'en', 'founded_year': None},
#    {'name': 'Meta Horizon Worlds',
#     'ticker_code': 'meta-horizon-worlds-focused-user-094623638.html',
#     'founded_year': None},
#    {'name': 'Securities and Exchange Commission',
#     'ticker_code': 'd293630d10k.htm',
#     'founded_year': None},
#    {'name': 'Instagram', 'ticker_code': 'en', 'founded_year': None},
#    {'name': 'Reality Labs',
#     'ticker_code': 'metas-reality-check-inside-the-45-billion-cash-burn-at-reality-labs-125717347.html',
#     'founded_year': None},
#    {'name': 'Court of Justice of the European Union',
#     'ticker_code': 'eu-court-upholds-googles-2-075723454.html',
#     'founded_year': None},
#    {'name': 'European Union',
#     'ticker_code': 'european-union',
#     'founded_year': None},
#    {'name': 'Switzerland', 'ticker_code': '%5ESSMI', 'founded_year': None},
#    {'name': 'Meta Platforms', 'ticker_code': 'META', 'founded_year': None},
#    {'name': 'Mondelez International, Inc.',
#     'ticker_code': 'MDLZ',
#     'founded_year': None},
#    {'name': 'NETFLIX INC', 'ticker_code': 'NFLX', 'founded_year': None},
#    {'name': 'Netflix', 'ticker_code': 'NFLX', 'founded_year': None},
#    {'name': 'Red Envelope Entertainment',
#     'ticker_code': 'netflix-subscription-red-envelope-last-dvd-service-015046050.html',
#     'founded_year': None},
#    {'name': 'Netflix', 'ticker_code': 'NFLX', 'founded_year': None},
#    {'name': 'Pure Software',
#     'ticker_code': 'puresoftware-wins-best-banking-platform-000000478.html',
#     'founded_year': None},
#    {'name': 'Hastings', 'ticker_code': 'HAS.AX', 'founded_year': None},
#    {'name': 'NVIDIA CORP', 'ticker_code': 'NVDA', 'founded_year': None},
#    {'name': 'Nvidia', 'ticker_code': 'NVDA', 'founded_year': None},
#    {'name': 'Mellanox Technologies',
#     'ticker_code': 'history',
#     'founded_year': None},
#    {'name': 'NVIDIA Data Center', 'ticker_code': 'NVDA', 'founded_year': None},
#    {'name': 'USG', 'ticker_code': 'USG', 'founded_year': None},
#    {'name': 'Nvidia', 'ticker_code': 'NVDA', 'founded_year': None},
#    {'name': 'Nvidia', 'ticker_code': 'NVDA', 'founded_year': None},
#    {'name': 'Exluna', 'ticker_code': 'LUNA', 'founded_year': None},
#    {'name': 'PEPSICO INC', 'ticker_code': 'PEP', 'founded_year': None}],
#   'Country': [{'source_city': 'North America',
#     'name': 'United States',
#     'iso2': 'US',
#     'iso3': 'USA',
#     'population': 433,
#     'gdp': 3203,
#     'corporate_tax_rate': 14},
#    {'name': 'Belarus',
#     'iso2': 'BY',
#     'iso3': 'BLR',
#     'population': 957,
#     'gdp': 2980,
#     'corporate_tax_rate': 39},
#    {'name': 'Israel',
#     'iso2': 'IL',
#     'iso3': 'ISR',
#     'population': 920,
#     'gdp': 11702,
#     'corporate_tax_rate': 45},
#    {'name': 'Ukraine',
#     'iso2': 'UA',
#     'iso3': 'UKR',
#     'population': 101,
#     'gdp': 6666,
#     'corporate_tax_rate': 13},
#    {'name': 'United States of America',
#     'iso2': 'US',
#     'iso3': 'USA',
#     'population': 378,
#     'gdp': 12471,
#     'corporate_tax_rate': 48},
#    {'name': 'Israel',
#     'iso2': 'IL',
#     'iso3': 'ISR',
#     'population': 941,
#     'gdp': 8776,
#     'corporate_tax_rate': 17},
#    {'name': 'United States of America',
#     'iso2': 'US',
#     'iso3': 'USA',
#     'population': 1360,
#     'gdp': 14490,
#     'corporate_tax_rate': 42},
#    {'source_city': 'Ohio River',
#     'name': 'United States',
#     'iso2': 'US',
#     'iso3': 'USA',
#     'population': 492,
#     'gdp': 14060,
#     'corporate_tax_rate': 40},
#    {'source_city': 'North America',
#     'name': 'United States',
#     'iso2': 'US',
#     'iso3': 'USA',
#     'population': 561,
#     'gdp': 1970,
#     'corporate_tax_rate': 13},
#    {'source_city': 'California',
#     'name': 'United States',
#     'iso2': 'US',
#     'iso3': 'USA',
#     'population': 579,
#     'gdp': 3284,
#     'corporate_tax_rate': 22},
#    {'source_city': 'San Jose',
#     'name': 'Costa Rica',
#     'iso2': 'CR',
#     'iso3': 'CRI',
#     'population': 422,
#     'gdp': 15254,
#     'corporate_tax_rate': 44},
#    {'name': "People's Republic of China",
#     'iso2': 'CN',
#     'iso3': 'CHN',
#     'population': 1371,
#     'gdp': 13981,
#     'corporate_tax_rate': 23},
#    {'name': 'United Kingdom',
#     'iso2': 'GB',
#     'iso3': 'GBR',
#     'population': 604,
#     'gdp': 4876,
#     'corporate_tax_rate': 14},
#    {'name': 'United States of America',
#     'iso2': 'US',
#     'iso3': 'USA',
#     'population': 508,
#     'gdp': 566,
#     'corporate_tax_rate': 46},
#    {'name': 'Italy',
#     'iso2': 'IT',
#     'iso3': 'ITA',
#     'population': 549,
#     'gdp': 296,
#     'corporate_tax_rate': 49},
#    {'source_city': 'Orlando',
#     'name': 'United States',
#     'iso2': 'US',
#     'iso3': 'USA',
#     'population': 241,
#     'gdp': 17886,
#     'corporate_tax_rate': 44},
#    {'name': 'United States of America',
#     'iso2': 'US',
#     'iso3': 'USA',
#     'population': 402,
#     'gdp': 13369,
#     'corporate_tax_rate': 34},
#    {'name': 'United States of America',
#     'iso2': 'US',
#     'iso3': 'USA',
#     'population': 719,
#     'gdp': 12609,
#     'corporate_tax_rate': 45},
#    {'name': 'United Kingdom',
#     'iso2': 'GB',
#     'iso3': 'GBR',
#     'population': 836,
#     'gdp': 17415,
#     'corporate_tax_rate': 28},
#    {'name': 'Korea',
#     'population': 125,
#     'gdp': 15808,
#     'corporate_tax_rate': 44},
#    {'name': 'Australia',
#     'iso2': 'AU',
#     'iso3': 'AUS',
#     'population': 940,
#     'gdp': 17737,
#     'corporate_tax_rate': 31},
#    {'name': 'Canada',
#     'iso2': 'CA',
#     'iso3': 'CAN',
#     'population': 741,
#     'gdp': 19104,
#     'corporate_tax_rate': 35},
#    {'name': 'Japan',
#     'iso2': 'JP',
#     'iso3': 'JPN',
#     'population': 538,
#     'gdp': 13695,
#     'corporate_tax_rate': 45},
#    {'source_city': 'Seattle',
#     'name': 'United States',
#     'iso2': 'US',
#     'iso3': 'USA',
#     'population': 126,
#     'gdp': 6785,
#     'corporate_tax_rate': 32},
#    {'name': 'New Zealand',
#     'iso2': 'NZ',
#     'iso3': 'NZL',
#     'population': 914,
#     'gdp': 15761,
#     'corporate_tax_rate': 20},
#    {'source_city': 'Puerto Rico',
#     'name': 'Puerto Rico',
#     'iso2': 'PR',
#     'iso3': 'PRI',
#     'population': 1235,
#     'gdp': 1658,
#     'corporate_tax_rate': 36},
#    {'name': 'Mexico',
#     'iso2': 'MX',
#     'iso3': 'MEX',
#     'population': 991,
#     'gdp': 9714,
#     'corporate_tax_rate': 12},
#    {'name': 'Spain',
#     'iso2': 'ES',
#     'iso3': 'ESP',
#     'population': 1356,
#     'gdp': 5240,
#     'corporate_tax_rate': 25},
#    {'name': 'Taiwan',
#     'iso2': 'TW',
#     'iso3': 'TWN',
#     'population': 791,
#     'gdp': 13575,
#     'corporate_tax_rate': 37},
#    {'name': 'Sweden',
#     'iso2': 'SE',
#     'iso3': 'SWE',
#     'population': 316,
#     'gdp': 15108,
#     'corporate_tax_rate': 31},
#    {'name': "People's Republic of China",
#     'iso2': 'CN',
#     'iso3': 'CHN',
#     'population': 266,
#     'gdp': 67,
#     'corporate_tax_rate': 16},
#    {'name': 'France',
#     'iso2': 'FR',
#     'iso3': 'FRA',
#     'population': 53,
#     'gdp': 11567,
#     'corporate_tax_rate': 38},
#    {'source_city': 'Washington',
#     'name': 'United States',
#     'iso2': 'US',
#     'iso3': 'USA',
#     'population': 911,
#     'gdp': 15617,
#     'corporate_tax_rate': 42},
#    {'name': 'Iceland',
#     'iso2': 'IS',
#     'iso3': 'ISL',
#     'population': 625,
#     'gdp': 1168,
#     'corporate_tax_rate': 33},
#    {'source_city': 'Foster City',
#     'name': 'United States',
#     'iso2': 'US',
#     'iso3': 'USA',
#     'population': 1138,
#     'gdp': 13944,
#     'corporate_tax_rate': 21},
#    {'source_city': 'Foster City',
#     'name': 'United States',
#     'iso2': 'US',
#     'iso3': 'USA',
#     'population': 902,
#     'gdp': 4879,
#     'corporate_tax_rate': 35},
#    {'name': 'Japan',
#     'iso2': 'JP',
#     'iso3': 'JPN',
#     'population': 459,
#     'gdp': 1798,
#     'corporate_tax_rate': 34},
#    {'source_city': 'Foster City',
#     'name': 'United States',
#     'iso2': 'US',
#     'iso3': 'USA',
#     'population': 1334,
#     'gdp': 17644,
#     'corporate_tax_rate': 21},
#    {'source_city': 'California',
#     'name': 'United States',
#     'iso2': 'US',
#     'iso3': 'USA',
#     'population': 526,
#     'gdp': 6694,
#     'corporate_tax_rate': 37},
#    {'source_city': 'Mountain View',
#     'name': 'United States',
#     'iso2': 'US',
#     'iso3': 'USA',
#     'population': 834,
#     'gdp': 7501,
#     'corporate_tax_rate': 31},
#    {'source_city': 'Delaware',
#     'name': 'United States',
#     'iso2': 'US',
#     'iso3': 'USA',
#     'population': 317,
#     'gdp': 6185,
#     'corporate_tax_rate': 11},
#    {'name': 'Taiwan',
#     'iso2': 'TW',
#     'iso3': 'TWN',
#     'population': 148,
#     'gdp': 947,
#     'corporate_tax_rate': 10},
#    {'name': "People's Republic of China",
#     'iso2': 'CN',
#     'iso3': 'CHN',
#     'population': 89,
#     'gdp': 16868,
#     'corporate_tax_rate': 45},
#    {'name': 'Japan',
#     'iso2': 'JP',
#     'iso3': 'JPN',
#     'population': 71,
#     'gdp': 4032,
#     'corporate_tax_rate': 11},
#    {'name': 'Korea', 'population': 881, 'gdp': 4226, 'corporate_tax_rate': 29},
#    {'name': 'United States of America',
#     'iso2': 'US',
#     'iso3': 'USA',
#     'population': 1005,
#     'gdp': 9541,
#     'corporate_tax_rate': 50},
#    {'name': 'United Kingdom',
#     'iso2': 'GB',
#     'iso3': 'GBR',
#     'population': 1244,
#     'gdp': 10011,
#     'corporate_tax_rate': 29},
#    {'source_city': 'Americas',
#     'name': 'Dominican Republic',
#     'iso2': 'DO',
#     'iso3': 'DOM',
#     'population': 310,
#     'gdp': 11531,
#     'corporate_tax_rate': 48},
#    {'source_city': 'Asia-Pacific',
#     'name': 'Indonesia',
#     'iso2': 'ID',
#     'iso3': 'IDN',
#     'population': 1228,
#     'gdp': 937,
#     'corporate_tax_rate': 37},
#    {'name': 'South Korea',
#     'iso2': 'KR',
#     'iso3': 'KOR',
#     'population': 646,
#     'gdp': 5416,
#     'corporate_tax_rate': 23},
#    {'name': 'United Kingdom',
#     'iso2': 'GB',
#     'iso3': 'GBR',
#     'population': 293,
#     'gdp': 9092,
#     'corporate_tax_rate': 34},
#    {'name': 'Australia',
#     'iso2': 'AU',
#     'iso3': 'AUS',
#     'population': 1247,
#     'gdp': 19831,
#     'corporate_tax_rate': 25},
#    {'source_city': 'United States Germany',
#     'name': 'Isle Of Man',
#     'population': 1072,
#     'gdp': 6008,
#     'corporate_tax_rate': 26},
#    {'source_city': 'Latin America',
#     'name': 'Brazi',
#     'population': 655,
#     'gdp': 4076,
#     'corporate_tax_rate': 35},
#    {'name': 'Argentina',
#     'iso2': 'AR',
#     'iso3': 'ARG',
#     'population': 180,
#     'gdp': 10545,
#     'corporate_tax_rate': 35},
#    {'name': 'Mexico',
#     'iso2': 'MX',
#     'iso3': 'MEX',
#     'population': 1260,
#     'gdp': 2025,
#     'corporate_tax_rate': 26},
#    {'name': 'El Salvador',
#     'iso2': 'SV',
#     'iso3': 'SLV',
#     'population': 617,
#     'gdp': 10631,
#     'corporate_tax_rate': 48},
#    {'name': 'Chile',
#     'iso2': 'CL',
#     'iso3': 'CHL',
#     'population': 837,
#     'gdp': 17408,
#     'corporate_tax_rate': 34},
#    {'name': 'Colombia',
#     'iso2': 'CO',
#     'iso3': 'COL',
#     'population': 52,
#     'gdp': 1256,
#     'corporate_tax_rate': 47},
#    {'name': 'Peru',
#     'iso2': 'PE',
#     'iso3': 'PER',
#     'population': 52,
#     'gdp': 3810,
#     'corporate_tax_rate': 33},
#    {'name': 'Costa Rica',
#     'iso2': 'CR',
#     'iso3': 'CRI',
#     'population': 850,
#     'gdp': 5808,
#     'corporate_tax_rate': 46},
#    {'name': 'Dominican Republic',
#     'iso2': 'DO',
#     'iso3': 'DOM',
#     'population': 299,
#     'gdp': 9500,
#     'corporate_tax_rate': 16},
#    {'name': 'Nicaragua',
#     'iso2': 'NI',
#     'iso3': 'NIC',
#     'population': 403,
#     'gdp': 10985,
#     'corporate_tax_rate': 32},
#    {'name': 'Chile',
#     'iso2': 'CL',
#     'iso3': 'CHL',
#     'population': 947,
#     'gdp': 9291,
#     'corporate_tax_rate': 48},
#    {'name': 'Argentina',
#     'iso2': 'AR',
#     'iso3': 'ARG',
#     'population': 349,
#     'gdp': 18772,
#     'corporate_tax_rate': 17},
#    {'source_city': 'Latin America',
#     'name': 'Brazi',
#     'population': 263,
#     'gdp': 10637,
#     'corporate_tax_rate': 31},
#    {'name': 'Uruguay',
#     'iso2': 'UY',
#     'iso3': 'URY',
#     'population': 1343,
#     'gdp': 2508,
#     'corporate_tax_rate': 33},
#    {'name': 'Colombia',
#     'iso2': 'CO',
#     'iso3': 'COL',
#     'population': 1359,
#     'gdp': 11054,
#     'corporate_tax_rate': 38},
#    {'name': 'Peru',
#     'iso2': 'PE',
#     'iso3': 'PER',
#     'population': 172,
#     'gdp': 19947,
#     'corporate_tax_rate': 36},
#    {'name': 'Mexico',
#     'iso2': 'MX',
#     'iso3': 'MEX',
#     'population': 216,
#     'gdp': 5749,
#     'corporate_tax_rate': 24},
#    {'name': 'El Salvador',
#     'iso2': 'SV',
#     'iso3': 'SLV',
#     'population': 1338,
#     'gdp': 1860,
#     'corporate_tax_rate': 49},
#    {'name': 'Dominican Republic',
#     'iso2': 'DO',
#     'iso3': 'DOM',
#     'population': 318,
#     'gdp': 15881,
#     'corporate_tax_rate': 27},
#    {'name': 'Nicaragua',
#     'iso2': 'NI',
#     'iso3': 'NIC',
#     'population': 1276,
#     'gdp': 19607,
#     'corporate_tax_rate': 23},
#    {'name': 'Paraguay',
#     'iso2': 'PY',
#     'iso3': 'PRY',
#     'population': 1381,
#     'gdp': 13087,
#     'corporate_tax_rate': 46},
#    {'name': 'Brazil',
#     'iso2': 'BR',
#     'iso3': 'BRA',
#     'population': 669,
#     'gdp': 12750,
#     'corporate_tax_rate': 12},
#    {'name': 'Honduras',
#     'iso2': 'HN',
#     'iso3': 'HND',
#     'population': 1239,
#     'gdp': 5959,
#     'corporate_tax_rate': 45},
#    {'name': 'Costa Rica',
#     'iso2': 'CR',
#     'iso3': 'CRI',
#     'population': 120,
#     'gdp': 4518,
#     'corporate_tax_rate': 14},
#    {'name': 'Ecuador',
#     'iso2': 'EC',
#     'iso3': 'ECU',
#     'population': 1095,
#     'gdp': 19565,
#     'corporate_tax_rate': 18},
#    {'name': 'Bolivia',
#     'iso2': 'BO',
#     'iso3': 'BOL',
#     'population': 944,
#     'gdp': 3841,
#     'corporate_tax_rate': 10},
#    {'source_city': 'Utah',
#     'name': 'United States',
#     'iso2': 'US',
#     'iso3': 'USA',
#     'population': 226,
#     'gdp': 17110,
#     'corporate_tax_rate': 27},
#    {'source_city': 'Lehi',
#     'name': 'United States',
#     'iso2': 'US',
#     'iso3': 'USA',
#     'population': 594,
#     'gdp': 8652,
#     'corporate_tax_rate': 32},
#    {'name': 'United States of America',
#     'iso2': 'US',
#     'iso3': 'USA',
#     'population': 562,
#     'gdp': 4216,
#     'corporate_tax_rate': 17},
#    {'source_city': 'Scotts Valley',
#     'name': 'United States',
#     'iso2': 'US',
#     'iso3': 'USA',
#     'population': 1058,
#     'gdp': 881,
#     'corporate_tax_rate': 15},
#    {'source_city': 'Santa Clara',
#     'name': 'Cuba',
#     'iso2': 'CU',
#     'iso3': 'CUB',
#     'population': 715,
#     'gdp': 2599,
#     'corporate_tax_rate': 33},
#    {'source_city': 'California',
#     'name': 'United States',
#     'iso2': 'US',
#     'iso3': 'USA',
#     'population': 552,
#     'gdp': 13266,
#     'corporate_tax_rate': 16},
#    {'source_city': 'California',
#     'name': 'United States',
#     'iso2': 'US',
#     'iso3': 'USA',
#     'population': 455,
#     'gdp': 15893,
#     'corporate_tax_rate': 28},
#    {'source_city': 'Middle East',
#     'name': 'Iran',
#     'iso2': 'IR',
#     'iso3': 'IRN',
#     'population': 1342,
#     'gdp': 16678,
#     'corporate_tax_rate': 46},
#    {'source_city': 'Santa Clara',
#     'name': 'Cuba',
#     'iso2': 'CU',
#     'iso3': 'CUB',
#     'population': 54,
#     'gdp': 5697,
#     'corporate_tax_rate': 14},
#    {'name': "People's Republic of China",
#     'iso2': 'CN',
#     'iso3': 'CHN',
#     'population': 818,
#     'gdp': 16145,
#     'corporate_tax_rate': 17},
#    {'name': 'Saudi Arabia',
#     'iso2': 'SA',
#     'iso3': 'SAU',
#     'population': 465,
#     'gdp': 6591,
#     'corporate_tax_rate': 46},
#    {'name': 'Russia',
#     'iso2': 'RU',
#     'iso3': 'RUS',
#     'population': 50,
#     'gdp': 13899,
#     'corporate_tax_rate': 20},
#    {'name': 'Israel',
#     'iso2': 'IL',
#     'iso3': 'ISR',
#     'population': 260,
#     'gdp': 1410,
#     'corporate_tax_rate': 23}],
#   'Industry': [{'name': 'CMOS',
#     'SIC_code': None,
#     'industry_group': None,
#     'subindustry_desc': None,
#     'primary_activity': None},
#    {'name': 'artificial intelligence',
#     'SIC_code': None,
#     'industry_group': None,
#     'subindustry_desc': None,
#     'primary_activity': None},
#    {'name': 'computer security',
#     'SIC_code': None,
#     'industry_group': None,
#     'subindustry_desc': None,
#     'primary_activity': None},
#    {'name': 'wireless communication',
#     'SIC_code': None,
#     'industry_group': None,
#     'subindustry_desc': None,
#     'primary_activity': None},
#    {'name': 'operations management',
#     'SIC_code': None,
#     'industry_group': None,
#     'subindustry_desc': None,
#     'primary_activity': None},
#    {'name': 'analysis',
#     'SIC_code': None,
#     'industry_group': None,
#     'subindustry_desc': None,
#     'primary_activity': None},
#    {'name': 'management',
#     'SIC_code': None,
#     'industry_group': None,
#     'subindustry_desc': None,
#     'primary_activity': None},
#    {'name': 'management',
#     'SIC_code': None,
#     'industry_group': None,
#     'subindustry_desc': None,
#     'primary_activity': None},
#    {'name': 'oncology',
#     'SIC_code': None,
#     'industry_group': None,
#     'subindustry_desc': None,
#     'primary_activity': None},
#    {'name': 'automation',
#     'SIC_code': None,
#     'industry_group': None,
#     'subindustry_desc': None,
#     'primary_activity': None},
#    {'name': 'sensor',
#     'SIC_code': None,
#     'industry_group': None,
#     'subindustry_desc': None,
#     'primary_activity': None},
#    {'name': 'building automation',
#     'SIC_code': None,
#     'industry_group': None,
#     'subindustry_desc': None,
#     'primary_activity': None},
#    {'name': 'management',
#     'SIC_code': None,
#     'industry_group': None,
#     'subindustry_desc': None,
#     'primary_activity': None},
#    {'name': 'finance',
#     'SIC_code': None,
#     'industry_group': None,
#     'subindustry_desc': None,
#     'primary_activity': None},
#    {'name': 'self-employment',
#     'SIC_code': None,
#     'industry_group': None,
#     'subindustry_desc': None,
#     'primary_activity': None},
#    {'name': 'artificial intelligence',
#     'SIC_code': None,
#     'industry_group': None,
#     'subindustry_desc': None,
#     'primary_activity': None},
#    {'name': 'accounting',
#     'SIC_code': None,
#     'industry_group': None,
#     'subindustry_desc': None,
#     'primary_activity': None},
#    {'name': 'self-employment',
#     'SIC_code': None,
#     'industry_group': None,
#     'subindustry_desc': None,
#     'primary_activity': None},
#    {'name': 'management',
#     'SIC_code': None,
#     'industry_group': None,
#     'subindustry_desc': None,
#     'primary_activity': None},
#    {'name': 'dynamic random-access memory',
#     'SIC_code': None,
#     'industry_group': None,
#     'subindustry_desc': None,
#     'primary_activity': None},
#    {'name': 'flash memory',
#     'SIC_code': None,
#     'industry_group': None,
#     'subindustry_desc': None,
#     'primary_activity': None},
#    {'name': 'dynamic random-access memory',
#     'SIC_code': None,
#     'industry_group': None,
#     'subindustry_desc': None,
#     'primary_activity': None},
#    {'name': 'High Bandwidth Memory',
#     'SIC_code': None,
#     'industry_group': None,
#     'subindustry_desc': None,
#     'primary_activity': None},
#    {'name': 'flash memory',
#     'SIC_code': None,
#     'industry_group': None,
#     'subindustry_desc': None,
#     'primary_activity': None},
#    {'name': 'dynamic random-access memory',
#     'SIC_code': None,
#     'industry_group': None,
#     'subindustry_desc': None,
#     'primary_activity': None},
#    {'name': 'artificial intelligence',
#     'SIC_code': None,
#     'industry_group': None,
#     'subindustry_desc': None,
#     'primary_activity': None},
#    {'name': 'artificial intelligence',
#     'SIC_code': None,
#     'industry_group': None,
#     'subindustry_desc': None,
#     'primary_activity': None},
#    {'name': 'Xbox',
#     'SIC_code': None,
#     'industry_group': None,
#     'subindustry_desc': None,
#     'primary_activity': None},
#    {'name': 'Microsoft Windows',
#     'SIC_code': None,
#     'industry_group': None,
#     'subindustry_desc': None,
#     'primary_activity': None},
#    {'name': 'virtual reality',
#     'SIC_code': None,
#     'industry_group': None,
#     'subindustry_desc': None,
#     'primary_activity': None},
#    {'name': 'mixed reality',
#     'SIC_code': None,
#     'industry_group': None,
#     'subindustry_desc': None,
#     'primary_activity': None},
#    {'name': 'artificial intelligence',
#     'SIC_code': None,
#     'industry_group': None,
#     'subindustry_desc': None,
#     'primary_activity': None},
#    {'name': 'research',
#     'SIC_code': None,
#     'industry_group': None,
#     'subindustry_desc': None,
#     'primary_activity': None},
#    {'name': 'application programming interface',
#     'SIC_code': None,
#     'industry_group': None,
#     'subindustry_desc': None,
#     'primary_activity': None},
#    {'name': 'deep learning super sampling',
#     'SIC_code': None,
#     'industry_group': None,
#     'subindustry_desc': None,
#     'primary_activity': None},
#    {'name': 'artificial intelligence',
#     'SIC_code': None,
#     'industry_group': None,
#     'subindustry_desc': None,
#     'primary_activity': None}],
#   'Region': [{'name': 'NA', 'm49': None},
#    {'name': 'EU', 'm49': None},
#    {'name': 'AS', 'm49': None},
#    {'name': 'EU', 'm49': None},
#    {'name': 'NA', 'm49': None},
#    {'name': 'EU', 'm49': None},
#    {'name': 'AS', 'm49': None},
#    {'name': 'EU', 'm49': None},
#    {'name': 'NA', 'm49': None},
#    {'name': 'AS', 'm49': None},
#    {'name': 'NA', 'm49': None},
#    {'name': 'EU', 'm49': None},
#    {'name': 'AS', 'm49': None},
#    {'name': 'EU', 'm49': None},
#    {'name': 'NA', 'm49': None},
#    {'name': 'AS', 'm49': None},
#    {'name': 'NA', 'm49': None},
#    {'name': 'EU', 'm49': None},
#    {'name': 'AS', 'm49': None},
#    {'name': 'EU', 'm49': None},
#    {'name': 'NA', 'm49': None},
#    {'name': 'AS', 'm49': None},
#    {'name': 'NA', 'm49': None},
#    {'name': 'NA', 'm49': None},
#    {'name': 'NA', 'm49': None},
#    {'name': 'NA', 'm49': None},
#    {'name': 'EU', 'm49': None},
#    {'name': 'AS', 'm49': None},
#    {'name': 'EU', 'm49': None},
#    {'name': 'NA', 'm49': None},
#    {'name': 'AS', 'm49': None},
#    {'name': 'NA', 'm49': None},
#    {'name': 'NA', 'm49': None},
#    {'name': 'NA', 'm49': None},
#    {'name': 'NA', 'm49': None},
#    {'name': 'EU', 'm49': None},
#    {'name': 'AS', 'm49': None},
#    {'name': 'EU', 'm49': None},
#    {'name': 'NA', 'm49': None},
#    {'name': 'AS', 'm49': None},
#    {'name': 'NA', 'm49': None},
#    {'name': 'NA', 'm49': None},
#    {'name': 'NA', 'm49': None},
#    {'name': 'NA', 'm49': None},
#    {'name': 'NA', 'm49': None},
#    {'name': 'AS', 'm49': None},
#    {'name': 'NA', 'm49': None},
#    {'name': 'EU', 'm49': None},
#    {'name': 'AS', 'm49': None},
#    {'name': 'EU', 'm49': None},
#    {'name': 'NA', 'm49': None},
#    {'name': 'AS', 'm49': None},
#    {'name': 'NA', 'm49': None},
#    {'name': 'NA', 'm49': None},
#    {'name': 'NA', 'm49': None},
#    {'name': 'NA', 'm49': None},
#    {'name': 'NA', 'm49': None},
#    {'name': 'AS', 'm49': None},
#    {'name': 'NA', 'm49': None},
#    {'name': 'EU', 'm49': None},
#    {'name': 'AS', 'm49': None},
#    {'name': 'EU', 'm49': None},
#    {'name': 'NA', 'm49': None},
#    {'name': 'AS', 'm49': None},
#    {'name': 'NA', 'm49': None},
#    {'name': 'NA', 'm49': None},
#    {'name': 'NA', 'm49': None},
#    {'name': 'NA', 'm49': None},
#    {'name': 'NA', 'm49': None},
#    {'name': 'AS', 'm49': None},
#    {'name': 'EU', 'm49': None},
#    {'name': 'NA', 'm49': None},
#    {'name': 'EU', 'm49': None},
#    {'name': 'NA', 'm49': None},
#    {'name': 'NA', 'm49': None},
#    {'name': 'NA', 'm49': None},
#    {'name': 'EU', 'm49': None},
#    {'name': 'AS', 'm49': None},
#    {'name': 'EU', 'm49': None},
#    {'name': 'NA', 'm49': None},
#    {'name': 'AS', 'm49': None},
#    {'name': 'NA', 'm49': None},
#    {'name': 'NA', 'm49': None},
#    {'name': 'NA', 'm49': None},
#    {'name': 'NA', 'm49': None},
#    {'name': 'NA', 'm49': None},
#    {'name': 'AS', 'm49': None},
#    {'name': 'EU', 'm49': None},
#    {'name': 'NA', 'm49': None},
#    {'name': 'EU', 'm49': None},
#    {'name': 'NA', 'm49': None},
#    {'name': 'NA', 'm49': None},
#    {'name': 'NA', 'm49': None},
#    {'name': 'EU', 'm49': None},
#    {'name': 'AS', 'm49': None},
#    {'name': 'EU', 'm49': None},
#    {'name': 'NA', 'm49': None},
#    {'name': 'AS', 'm49': None},
#    {'name': 'NA', 'm49': None},
#    {'name': 'NA', 'm49': None},
#    {'name': 'NA', 'm49': None},
#    {'name': 'NA', 'm49': None},
#    {'name': 'NA', 'm49': None},
#    {'name': 'AS', 'm49': None},
#    {'name': 'EU', 'm49': None},
#    {'name': 'NA', 'm49': None},
#    {'name': 'EU', 'm49': None},
#    {'name': 'NA', 'm49': None},
#    {'name': 'NA', 'm49': None},
#    {'name': 'NA', 'm49': None},
#    {'name': 'EU', 'm49': None},
#    {'name': 'Not Found', 'm49': None},
#    {'name': 'OC', 'm49': None},
#    {'name': 'NA', 'm49': None},
#    {'name': 'AS', 'm49': None},
#    {'name': 'NA', 'm49': None},
#    {'name': 'OC', 'm49': None},
#    {'name': 'NA', 'm49': None},
#    {'name': 'NA', 'm49': None},
#    {'name': 'EU', 'm49': None},
#    {'name': 'AS', 'm49': None},
#    {'name': 'EU', 'm49': None},
#    {'name': 'AS', 'm49': None},
#    {'name': 'EU', 'm49': None},
#    {'name': 'NA', 'm49': None},
#    {'name': 'EU', 'm49': None},
#    {'name': 'NA', 'm49': None},
#    {'name': 'EU', 'm49': None},
#    {'name': 'AS', 'm49': None},
#    {'name': 'EU', 'm49': None},
#    {'name': 'NA', 'm49': None},
#    {'name': 'AS', 'm49': None},
#    {'name': 'NA', 'm49': None},
#    {'name': 'NA', 'm49': None},
#    {'name': 'NA', 'm49': None},
#    {'name': 'NA', 'm49': None},
#    {'name': 'NA', 'm49': None},
#    {'name': 'AS', 'm49': None},
#    {'name': 'EU', 'm49': None},
#    {'name': 'NA', 'm49': None},
#    {'name': 'EU', 'm49': None},
#    {'name': 'NA', 'm49': None},
#    {'name': 'NA', 'm49': None},
#    {'name': 'NA', 'm49': None},
#    {'name': 'EU', 'm49': None},
#    {'name': 'Not Found', 'm49': None},
#    {'name': 'OC', 'm49': None},
#    {'name': 'NA', 'm49': None},
#    {'name': 'AS', 'm49': None},
#    {'name': 'NA', 'm49': None},
#    {'name': 'OC', 'm49': None},
#    {'name': 'NA', 'm49': None},
#    {'name': 'NA', 'm49': None},
#    {'name': 'EU', 'm49': None},
#    {'name': 'AS', 'm49': None},
#    {'name': 'EU', 'm49': None},
#    {'name': 'AS', 'm49': None},
#    {'name': 'EU', 'm49': None},
#    {'name': 'NA', 'm49': None},
#    {'name': 'EU', 'm49': None},
#    {'name': 'NA', 'm49': None},
#    {'name': 'EU', 'm49': None},
#    {'name': 'AS', 'm49': None},
#    {'name': 'EU', 'm49': None},
#    {'name': 'NA', 'm49': None},
#    {'name': 'AS', 'm49': None},
#    {'name': 'NA', 'm49': None},
#    {'name': 'NA', 'm49': None},
#    {'name': 'NA', 'm49': None},
#    {'name': 'NA', 'm49': None},
#    {'name': 'NA', 'm49': None},
#    {'name': 'AS', 'm49': None},
#    {'name': 'EU', 'm49': None},
#    {'name': 'NA', 'm49': None},
#    {'name': 'EU', 'm49': None},
#    {'name': 'NA', 'm49': None},
#    {'name': 'NA', 'm49': None},
#    {'name': 'NA', 'm49': None},
#    {'name': 'EU', 'm49': None},
#    {'name': 'Not Found', 'm49': None},
#    {'name': 'OC', 'm49': None},
#    {'name': 'NA', 'm49': None},
#    {'name': 'AS', 'm49': None},
#    {'name': 'NA', 'm49': None},
#    {'name': 'OC', 'm49': None},
#    {'name': 'NA', 'm49': None},
#    {'name': 'NA', 'm49': None},
#    {'name': 'EU', 'm49': None},
#    {'name': 'AS', 'm49': None},
#    {'name': 'EU', 'm49': None},
#    {'name': 'AS', 'm49': None},
#    {'name': 'EU', 'm49': None},
#    {'name': 'NA', 'm49': None},
#    {'name': 'EU', 'm49': None},
#    {'name': 'NA', 'm49': None},
#    {'name': 'NA', 'm49': None},
#    {'name': 'AS', 'm49': None},
#    {'name': 'NA', 'm49': None},
#    {'name': 'EU', 'm49': None},
#    {'name': 'AS', 'm49': None},
#    {'name': 'EU', 'm49': None},
#    {'name': 'NA', 'm49': None},
#    {'name': 'AS', 'm49': None},
#    {'name': 'NA', 'm49': None},
#    {'name': 'NA', 'm49': None},
#    {'name': 'NA', 'm49': None},
#    {'name': 'NA', 'm49': None},
#    {'name': 'NA', 'm49': None},
#    {'name': 'AS', 'm49': None},
#    {'name': 'EU', 'm49': None},
#    {'name': 'NA', 'm49': None},
#    {'name': 'EU', 'm49': None},
#    {'name': 'NA', 'm49': None},
#    {'name': 'NA', 'm49': None},
#    {'name': 'NA', 'm49': None},
#    {'name': 'EU', 'm49': None},
#    {'name': 'Not Found', 'm49': None},
#    {'name': 'OC', 'm49': None},
#    {'name': 'NA', 'm49': None},
#    {'name': 'AS', 'm49': None},
#    {'name': 'NA', 'm49': None},
#    {'name': 'OC', 'm49': None},
#    {'name': 'NA', 'm49': None},
#    {'name': 'NA', 'm49': None},
#    {'name': 'EU', 'm49': None},
#    {'name': 'AS', 'm49': None},
#    {'name': 'EU', 'm49': None},
#    {'name': 'AS', 'm49': None},
#    {'name': 'EU', 'm49': None},
#    {'name': 'NA', 'm49': None},
#    {'name': 'EU', 'm49': None},
#    {'name': 'NA', 'm49': None},
#    {'name': 'NA', 'm49': None},
#    {'name': 'AS', 'm49': None},
#    {'name': 'NA', 'm49': None},
#    {'name': 'NA', 'm49': None},
#    {'name': 'EU', 'm49': None},
#    {'name': 'AS', 'm49': None},
#    {'name': 'EU', 'm49': None},
#    {'name': 'NA', 'm49': None},
#    {'name': 'AS', 'm49': None},
#    {'name': 'NA', 'm49': None},
#    {'name': 'NA', 'm49': None},
#    {'name': 'NA', 'm49': None},
#    {'name': 'NA', 'm49': None},
#    {'name': 'NA', 'm49': None},
#    {'name': 'AS', 'm49': None},
#    {'name': 'EU', 'm49': None},
#    {'name': 'NA', 'm49': None},
#    {'name': 'EU', 'm49': None},
#    {'name': 'NA', 'm49': None},
#    {'name': 'NA', 'm49': None},
#    {'name': 'NA', 'm49': None},
#    {'name': 'EU', 'm49': None},
#    {'name': 'Not Found', 'm49': None},
#    {'name': 'OC', 'm49': None},
#    {'name': 'NA', 'm49': None},
#    {'name': 'AS', 'm49': None},
#    {'name': 'NA', 'm49': None},
#    {'name': 'OC', 'm49': None},
#    {'name': 'NA', 'm49': None},
#    {'name': 'NA', 'm49': None},
#    {'name': 'EU', 'm49': None},
#    {'name': 'AS', 'm49': None},
#    {'name': 'EU', 'm49': None},
#    {'name': 'AS', 'm49': None},
#    {'name': 'EU', 'm49': None},
#    {'name': 'NA', 'm49': None},
#    {'name': 'EU', 'm49': None},
#    {'name': 'NA', 'm49': None},
#    {'name': 'NA', 'm49': None},
#    {'name': 'AS', 'm49': None},
#    {'name': 'NA', 'm49': None},
#    {'name': 'NA', 'm49': None},
#    {'name': 'EU', 'm49': None},
#    {'name': 'AS', 'm49': None},
#    {'name': 'EU', 'm49': None},
#    {'name': 'NA', 'm49': None},
#    {'name': 'AS', 'm49': None},
#    {'name': 'NA', 'm49': None},
#    {'name': 'NA', 'm49': None},
#    {'name': 'NA', 'm49': None},
#    {'name': 'NA', 'm49': None},
#    {'name': 'NA', 'm49': None},
#    {'name': 'AS', 'm49': None},
#    {'name': 'EU', 'm49': None},
#    {'name': 'NA', 'm49': None},
#    {'name': 'EU', 'm49': None},
#    {'name': 'NA', 'm49': None},
#    {'name': 'NA', 'm49': None},
#    {'name': 'NA', 'm49': None},
#    {'name': 'EU', 'm49': None},
#    {'name': 'Not Found', 'm49': None},
#    {'name': 'OC', 'm49': None},
#    {'name': 'NA', 'm49': None},
#    {'name': 'AS', 'm49': None},
#    {'name': 'NA', 'm49': None},
#    {'name': 'OC', 'm49': None},
#    {'name': 'NA', 'm49': None},
#    {'name': 'NA', 'm49': None},
#    {'name': 'EU', 'm49': None},
#    {'name': 'AS', 'm49': None},
#    {'name': 'EU', 'm49': None},
#    {'name': 'AS', 'm49': None},
#    {'name': 'EU', 'm49': None},
#    {'name': 'NA', 'm49': None},
#    {'name': 'EU', 'm49': None},
#    {'name': 'NA', 'm49': None},
#    {'name': 'NA', 'm49': None},
#    {'name': 'AS', 'm49': None},
#    {'name': 'NA', 'm49': None},
#    {'name': 'NA', 'm49': None},
#    {'name': 'EU', 'm49': None},
#    {'name': 'AS', 'm49': None},
#    {'name': 'EU', 'm49': None},
#    {'name': 'NA', 'm49': None},
# ...
#    {'country_name': 'United States', 'region_name': 'NA'},
#    {'country_name': 'Japan', 'region_name': 'AS'},
#    {'country_name': 'United States', 'region_name': 'NA'},
#    {'country_name': 'United States', 'region_name': 'NA'},
#    {'country_name': 'United States', 'region_name': 'NA'},
#    {'country_name': 'United States', 'region_name': 'NA'},
#    {'country_name': 'Taiwan', 'region_name': 'AS'},
#    {'country_name': "People's Republic of China", 'region_name': 'AS'},
#    {'country_name': 'Japan', 'region_name': 'AS'},
#    {'country_name': 'Korea', 'region_name': 'Not Found'},
#    {'country_name': 'United States of America', 'region_name': 'NA'},
#    {'country_name': 'United Kingdom', 'region_name': 'EU'},
#    {'country_name': 'Dominican Republic', 'region_name': 'NA'},
#    {'country_name': 'Indonesia', 'region_name': 'AS'},
#    {'country_name': 'South Korea', 'region_name': 'AS'},
#    {'country_name': 'United Kingdom', 'region_name': 'EU'},
#    {'country_name': 'Australia', 'region_name': 'OC'},
#    {'country_name': 'Isle Of Man', 'region_name': 'Not Found'},
#    {'country_name': 'Brazi', 'region_name': 'Not Found'},
#    {'country_name': 'Argentina', 'region_name': 'SA'},
#    {'country_name': 'Mexico', 'region_name': 'NA'},
#    {'country_name': 'El Salvador', 'region_name': 'NA'},
#    {'country_name': 'Chile', 'region_name': 'SA'},
#    {'country_name': 'Colombia', 'region_name': 'SA'},
#    {'country_name': 'Peru', 'region_name': 'SA'},
#    {'country_name': 'Costa Rica', 'region_name': 'NA'},
#    {'country_name': 'Dominican Republic', 'region_name': 'NA'},
#    {'country_name': 'Nicaragua', 'region_name': 'NA'},
#    {'country_name': 'Chile', 'region_name': 'SA'},
#    {'country_name': 'Argentina', 'region_name': 'SA'},
#    {'country_name': 'Brazi', 'region_name': 'Not Found'},
#    {'country_name': 'Uruguay', 'region_name': 'SA'},
#    {'country_name': 'Colombia', 'region_name': 'SA'},
#    {'country_name': 'Peru', 'region_name': 'SA'},
#    {'country_name': 'Mexico', 'region_name': 'NA'},
#    {'country_name': 'El Salvador', 'region_name': 'NA'},
#    {'country_name': 'Dominican Republic', 'region_name': 'NA'},
#    {'country_name': 'Nicaragua', 'region_name': 'NA'},
#    {'country_name': 'Paraguay', 'region_name': 'SA'},
#    {'country_name': 'Brazil', 'region_name': 'SA'},
#    {'country_name': 'Honduras', 'region_name': 'NA'},
#    {'country_name': 'Costa Rica', 'region_name': 'NA'},
#    {'country_name': 'Ecuador', 'region_name': 'SA'},
#    {'country_name': 'Bolivia', 'region_name': 'SA'},
#    {'country_name': 'United States', 'region_name': 'NA'},
#    {'country_name': 'Belarus', 'region_name': 'EU'},
#    {'country_name': 'Israel', 'region_name': 'AS'},
#    {'country_name': 'Ukraine', 'region_name': 'EU'},
#    {'country_name': 'United States of America', 'region_name': 'NA'},
#    {'country_name': 'Israel', 'region_name': 'AS'},
#    {'country_name': 'United States of America', 'region_name': 'NA'},
#    {'country_name': 'United States', 'region_name': 'NA'},
#    {'country_name': 'United States', 'region_name': 'NA'},
#    {'country_name': 'United States', 'region_name': 'NA'},
#    {'country_name': 'Costa Rica', 'region_name': 'NA'},
#    {'country_name': "People's Republic of China", 'region_name': 'AS'},
#    {'country_name': 'United Kingdom', 'region_name': 'EU'},
#    {'country_name': 'United States of America', 'region_name': 'NA'},
#    {'country_name': 'Italy', 'region_name': 'EU'},
#    {'country_name': 'United States', 'region_name': 'NA'},
#    {'country_name': 'United States of America', 'region_name': 'NA'},
#    {'country_name': 'United States of America', 'region_name': 'NA'},
#    {'country_name': 'United Kingdom', 'region_name': 'EU'},
#    {'country_name': 'Korea', 'region_name': 'Not Found'},
#    {'country_name': 'Australia', 'region_name': 'OC'},
#    {'country_name': 'Canada', 'region_name': 'NA'},
#    {'country_name': 'Japan', 'region_name': 'AS'},
#    {'country_name': 'United States', 'region_name': 'NA'},
#    {'country_name': 'New Zealand', 'region_name': 'OC'},
#    {'country_name': 'Puerto Rico', 'region_name': 'NA'},
#    {'country_name': 'Mexico', 'region_name': 'NA'},
#    {'country_name': 'Spain', 'region_name': 'EU'},
#    {'country_name': 'Taiwan', 'region_name': 'AS'},
#    {'country_name': 'Sweden', 'region_name': 'EU'},
#    {'country_name': "People's Republic of China", 'region_name': 'AS'},
#    {'country_name': 'France', 'region_name': 'EU'},
#    {'country_name': 'United States', 'region_name': 'NA'},
#    {'country_name': 'Iceland', 'region_name': 'EU'},
#    {'country_name': 'United States', 'region_name': 'NA'},
#    {'country_name': 'United States', 'region_name': 'NA'},
#    {'country_name': 'Japan', 'region_name': 'AS'},
#    {'country_name': 'United States', 'region_name': 'NA'},
#    {'country_name': 'United States', 'region_name': 'NA'},
#    {'country_name': 'United States', 'region_name': 'NA'},
#    {'country_name': 'United States', 'region_name': 'NA'},
#    {'country_name': 'Taiwan', 'region_name': 'AS'},
#    {'country_name': "People's Republic of China", 'region_name': 'AS'},
#    {'country_name': 'Japan', 'region_name': 'AS'},
#    {'country_name': 'Korea', 'region_name': 'Not Found'},
#    {'country_name': 'United States of America', 'region_name': 'NA'},
#    {'country_name': 'United Kingdom', 'region_name': 'EU'},
#    {'country_name': 'Dominican Republic', 'region_name': 'NA'},
#    {'country_name': 'Indonesia', 'region_name': 'AS'},
#    {'country_name': 'South Korea', 'region_name': 'AS'},
#    {'country_name': 'United Kingdom', 'region_name': 'EU'},
#    {'country_name': 'Australia', 'region_name': 'OC'},
#    {'country_name': 'Isle Of Man', 'region_name': 'Not Found'},
#    {'country_name': 'Brazi', 'region_name': 'Not Found'},
#    {'country_name': 'Argentina', 'region_name': 'SA'},
#    {'country_name': 'Mexico', 'region_name': 'NA'},
#    {'country_name': 'El Salvador', 'region_name': 'NA'},
#    {'country_name': 'Chile', 'region_name': 'SA'},
#    {'country_name': 'Colombia', 'region_name': 'SA'},
#    {'country_name': 'Peru', 'region_name': 'SA'},
#    {'country_name': 'Costa Rica', 'region_name': 'NA'},
#    {'country_name': 'Dominican Republic', 'region_name': 'NA'},
#    {'country_name': 'Nicaragua', 'region_name': 'NA'},
#    {'country_name': 'Chile', 'region_name': 'SA'},
#    {'country_name': 'Argentina', 'region_name': 'SA'},
#    {'country_name': 'Brazi', 'region_name': 'Not Found'},
#    {'country_name': 'Uruguay', 'region_name': 'SA'},
#    {'country_name': 'Colombia', 'region_name': 'SA'},
#    {'country_name': 'Peru', 'region_name': 'SA'},
#    {'country_name': 'Mexico', 'region_name': 'NA'},
#    {'country_name': 'El Salvador', 'region_name': 'NA'},
#    {'country_name': 'Dominican Republic', 'region_name': 'NA'},
#    {'country_name': 'Nicaragua', 'region_name': 'NA'},
#    {'country_name': 'Paraguay', 'region_name': 'SA'},
#    {'country_name': 'Brazil', 'region_name': 'SA'},
#    {'country_name': 'Honduras', 'region_name': 'NA'},
#    {'country_name': 'Costa Rica', 'region_name': 'NA'},
#    {'country_name': 'Ecuador', 'region_name': 'SA'},
#    {'country_name': 'Bolivia', 'region_name': 'SA'},
#    {'country_name': 'United States', 'region_name': 'NA'},
#    {'country_name': 'United States', 'region_name': 'NA'},
#    {'country_name': 'United States', 'region_name': 'NA'},
#    {'country_name': 'Belarus', 'region_name': 'EU'},
#    {'country_name': 'Israel', 'region_name': 'AS'},
#    ...],
#   'OPERATES_IN_REGION': [],
#   'PRODUCES': [{'company_name': 'Booking.com',
#     'product_name': 'accommodation reservation services'},
#    {'company_name': 'Booking Holdings',
#     'product_name': 'hotel distribution services'},
#    {'company_name': 'Agoda',
#     'product_name': 'activities reservation services'},
#    {'company_name': 'Agoda', 'product_name': 'ground transportation'},
#    {'company_name': 'Agoda', 'product_name': 'flight'},
#    {'company_name': 'Booking Holdings',
#     'product_name': 'rental car reservation services'},
#    {'company_name': 'Booking.com', 'product_name': 'Connected Trip'},
#    {'company_name': 'Broadcom',
#     'product_name': 'semiconductor and infrastructure software products'},
#    {'company_name': 'Broadcom', 'product_name': 'SSD controller'},
#    {'company_name': 'Broadcom', 'product_name': 'enterprise security'},
#    {'company_name': 'Cintas', 'product_name': 'shop towels'},
#    {'company_name': 'Cintas', 'product_name': 'corporate identity uniforms'},
#    {'company_name': 'Cintas', 'product_name': 'mats'},
#    {'company_name': 'Cintas', 'product_name': 'products and services'},
#    {'company_name': 'Cintas', 'product_name': 'mops'},
#    {'company_name': 'Cintas', 'product_name': 'safety courses'},
#    {'company_name': 'Cintas',
#     'product_name': 'cleaning and restroom supplies'},
#    {'company_name': 'Cintas', 'product_name': 'first aid and safety products'},
#    {'company_name': 'Kamp Fire Equipment',
#     'product_name': 'fire safety products and services'},
#    {'company_name': 'Cintas',
#     'product_name': 'fire safety products and services'},
#    {'company_name': 'Cintas', 'product_name': 'fire protection'},
#    {'company_name': 'Cisco Systems', 'product_name': 'equipment'},
#    {'company_name': 'Cisco Systems',
#     'product_name': 'mobile network management'},
#    {'company_name': 'Cisco', 'product_name': 'IP phones'},
#    {'company_name': 'Cisco Systems',
#     'product_name': 'high-technology services'},
#    {'company_name': 'Cisco Systems', 'product_name': 'networking hardware'},
#    {'company_name': 'Cisco Systems', 'product_name': 'software'},
#    {'company_name': 'Cisco Systems',
#     'product_name': 'telecommunications equipment'},
#    {'company_name': 'Cisco Systems', 'product_name': 'computer boards'},
#    {'company_name': 'Cisco Systems',
#     'product_name': 'IT products and services'},
#    {'company_name': 'Comcast', 'product_name': 'first-party content'},
#    {'company_name': 'Comcast',
#     'product_name': 'television programming content'},
#    {'company_name': 'Comcast', 'product_name': 'cable'},
#    {'company_name': 'Comcast', 'product_name': 'commercial services'},
#    {'company_name': 'Comcast', 'product_name': 'broadband services'},
#    {'company_name': 'Comcast', 'product_name': 'home telephone service'},
#    {'company_name': 'Greater Philadelphia Cablevision',
#     'product_name': 'cable'},
#    {'company_name': 'Comcast', 'product_name': 'wireless devices'},
#    {'company_name': 'Costco Wholesale', 'product_name': 'vacation packages'},
#    {'company_name': 'Costco Wholesale', 'product_name': 'cruises'},
#    {'company_name': 'Costco Wholesale', 'product_name': 'car rentals'},
#    {'company_name': 'Costco Wholesale', 'product_name': 'hot dogs'},
#    {'company_name': 'Costco Home', 'product_name': 'furniture'},
#    {'company_name': 'Pepsi', 'product_name': 'drinks'},
#    {'company_name': 'Gilead Sciences',
#     'product_name': 'intellectual property'},
#    {'company_name': 'Gilead Sciences', 'product_name': 'hepatitis C.'},
#    {'company_name': 'Raylo Chemicals',
#     'product_name': 'pharmaceutical ingredients'},
#    {'company_name': 'Raylo Chemicals',
#     'product_name': 'advanced intermediates'},
#    {'company_name': 'Honeywell', 'product_name': 'deadly and maiming weapons'},
#    {'company_name': 'Honeywell International',
#     'product_name': 'deadly and maiming weapons'},
#    {'company_name': 'Honeywell', 'product_name': 'cluster bombs'},
#    {'company_name': 'Honeywell International',
#     'product_name': 'cluster bombs'},
#    {'company_name': 'Honeywell International',
#     'product_name': 'photographic equipment'},
#    {'company_name': 'Honeywell International',
#     'product_name': 'personal protective equipment'},
#    {'company_name': 'Honeywell International',
#     'product_name': 'Pentax cameras'},
#    {'company_name': 'Pentax', 'product_name': 'photographic equipment'},
#    {'company_name': 'Honeywell International',
#     'product_name': 'electronic guidance systems'},
#    {'company_name': 'Honeywell International',
#     'product_name': 'secondary power turbine engines'},
#    {'company_name': 'Intel', 'product_name': 'computer components'},
#    {'company_name': 'Intel Israel', 'product_name': 'communications products'},
#    {'company_name': 'Intel', 'product_name': 'semiconductor chip'},
#    {'company_name': 'Intel', 'product_name': 'PC microprocessors'},
#    {'company_name': 'Intel', 'product_name': 'hardware'},
#    {'company_name': 'Compaq', 'product_name': 'PC-compatible systems'},
#    {'company_name': 'ProConnect', 'product_name': 'form updates'},
#    {'company_name': 'Intuit', 'product_name': 'e-commerce tools'},
#    {'company_name': 'Intuit', 'product_name': 'credit cards'},
#    {'company_name': 'Intuitive Surgical Devices',
#     'product_name': 'robotic products'},
#    {'company_name': 'Intuitive Surgical', 'product_name': 'spare part'},
#    {'company_name': 'KLA Corporation',
#     'product_name': 'surface inspection system'},
#    {'company_name': 'ADE', 'product_name': 'silicon wafer metrology'},
#    {'company_name': 'ADE', 'product_name': 'related gear'},
#    {'company_name': 'KLA Corporation KLA Corporation',
#     'product_name': 'yield management'},
#    {'company_name': 'KLA Corporation', 'product_name': 'plasma etch products'},
#    {'company_name': 'Lam Research', 'product_name': 'and services'},
#    {'company_name': 'Lam Research',
#     'product_name': 'innovative wafer fabrication equipment'},
#    {'company_name': 'Lam Research', 'product_name': 'chip equipment'},
#    {'company_name': 'Ontrak', 'product_name': 'chip equipment'},
#    {'company_name': 'Lam Research', 'product_name': 'semiconductor wafer'},
#    {'company_name': 'Lam Research', 'product_name': 'related services'},
#    {'company_name': 'The Linde Group',
#     'product_name': 'merchant and cylinder gases'},
#    {'company_name': 'The Linde Group', 'product_name': 'plant components'},
#    {'company_name': 'The Linde Group', 'product_name': 'synthesis gases'},
#    {'company_name': 'The Linde Group', 'product_name': 'argon'},
#    {'company_name': 'Linde plc', 'product_name': 'debt securities'},
#    {'company_name': 'The Linde Group',
#     'product_name': 'industrial gas products'},
#    {'company_name': 'The Linde Group', 'product_name': 'pipeline complexes'},
#    {'company_name': 'The Linde Group', 'product_name': 'delivery vehicles'},
#    {'company_name': 'Lansing Bagnall', 'product_name': 'forklift'},
#    {'company_name': 'Lincare Holdings', 'product_name': 'home care gas'},
#    {'company_name': 'HiQ Tyres & Autocare',
#     'product_name': 'industrial gases'},
#    {'company_name': 'HiQ Tyres & Autocare', 'product_name': 'specialty gases'},
#    {'company_name': 'HiQ Tyres & Autocare', 'product_name': 'medical gases'},
#    {'company_name': 'Mercado Pago Servicios de Procesamiento S.R.L.',
#     'product_name': 'electronic money transfers'},
#    {'company_name': 'Netlist', 'product_name': 'memory'},
#    {'company_name': 'Lexar Media', 'product_name': 'digital media products'},
#    {'company_name': 'Microsoft', 'product_name': 'BASIC interpreters'},
#    {'company_name': 'Netflix', 'product_name': 'DVD'},
#    {'company_name': 'LSI Logic Corporation', 'product_name': 'computer chip'},
#    {'company_name': 'Nvidia', 'product_name': 'AI) hardware'},
#    {'company_name': 'ATI Technologies', 'product_name': 'southbridge parts'},
#    {'company_name': 'Nvidia', 'product_name': 'graphics hardware'},
#    {'company_name': 'Nvidia', 'product_name': 'southbridge parts'},
#    {'company_name': 'ULI Electronics', 'product_name': 'southbridge parts'},
#    {'company_name': 'Nvidia', 'product_name': 'mobile processors'},
#    {'company_name': 'Nvidia',
#     'product_name': 'vehicle navigation and entertainment systems'},
#    {'company_name': 'Nvidia', 'product_name': 'graphics adapters'},
#    {'company_name': 'Pearl Milling Company', 'product_name': 'syrups'},
#    {'company_name': 'Wimm Bill Dann Foods', 'product_name': 'fruit juices'},
#    {'company_name': 'Wimm Bill Dann Foods', 'product_name': 'yogurt'},
#    {'company_name': 'PepsiCo', 'product_name': 'Frito-Lay snacks'},
#    {'company_name': 'PepsiCo', 'product_name': 'Tropicana juices'},
#    {'company_name': 'LOFT', 'product_name': 'candy'}]}}

# %%
len(empty_schema["nodes"]["Company"])
# Out:
# 209

# %%
with open('nasdaq_kg_schema_rank_11-40.json', 'w') as f:
    json.dump(empty_schema, f)

# %% [markdown]
# ## Spacy Node and Relationship Objects

# %%
# Load spaCy English language model
nlp = spacy.load("en_core_web_sm")

doc = nlp(tsla_item1)

# Extract entities and relations
nodes = defaultdict(set)  # Use a set to avoid duplicates
edges = []

# Define a function to identify non-company keywords
def is_non_company(entity_text):
    # Keywords or patterns that indicate the entity is not a company
    non_company_keywords = [
        'program', 'act', 'regulation', 'department', 'agency', 'council',
        'commission', 'service', 'policy', 'initiative', 'standard', 
        'incentive', 'college', 'school', 'university', 'authority', 'board',
        'order', 'capital', 'vehicle', 'development', 'internship', 'apprenticeship',
        'system', 'training', 'product', 'directive', 'committee', 'resource',
        'partnership', 'technology', 'platform'
    ]
    
    # If the entity contains any of these keywords, it is not a company
    return any(re.search(r'\b' + keyword + r'\b', entity_text.lower()) for keyword in non_company_keywords)

# Improved function to categorize and extract entities
def categorize_entities(entity):
    if entity.label_ == 'ORG':
        # Check if it's not a company
        if is_non_company(entity.text):
            return  # Exclude if it's not a company
        nodes['Company'].add(entity.text)
    elif entity.label_ == 'PRODUCT':
        nodes['Product'].add(entity.text)
    elif entity.label_ == 'GPE':
        nodes['Country'].add(entity.text)
    elif entity.label_ in ['NORP', 'INDUSTRY']:
        nodes['Industry'].add(entity.text)

# Extract named entities
for ent in doc.ents:
    categorize_entities(ent)

# Synonyms to match different verbs for edge detection
target_phrases = {
    'SUPPLIES': ["provide products", "manufactures products", "delivers goods", "offers items", "distributes products"],
    'LOCATED_IN': ["headquartered in", "based in", "located in", "situated in"],
    'RIVALS_WITH': ["competes with", "is a competitor of", "challenges", "rivals"],
    'ALLIES_WITH': ["partners with", "collaborates with", "is allied with", "cooperates with"]
}

# Extract relationships using semantic similarity
for sent in doc.sents:
    sent_vector = sent.vector  # Get the vector of the current sentence
    for relationship, phrases in target_phrases.items():
        for phrase in phrases:
            phrase_vector = nlp(phrase).vector  # Get the vector for the target phrase
            similarity = sent.similarity(nlp(phrase))  # Compute similarity
            if similarity > 0.7:  # Threshold for determining a match
                # Check if entities in the sentence can be matched to the known nodes
                for entity in sent.ents:
                    if entity.label_ == "ORG" and entity.text in nodes["Company"]:
                        target_entity = None
                        if relationship == "SUPPLIES":
                            target_entity = [ent.text for ent in sent.ents if ent.label_ == "PRODUCT"]
                        elif relationship == "LOCATED_IN":
                            target_entity = [ent.text for ent in sent.ents if ent.label_ == "GPE"]
                        elif relationship in ["RIVALS_WITH", "ALLIES_WITH"]:
                            target_entity = [ent.text for ent in sent.ents if ent.label_ == "ORG" and ent.text != entity.text]
                        
                        if target_entity:
                            for target in target_entity:
                                edges.append((entity.text, relationship, target))



# Convert nodes to list to remove duplicates and maintain order
nodes = {k: list(v) for k, v in nodes.items()}

# Output nodes and edges
print("Nodes:")
for node_type, node_list in nodes.items():
    print(f"{node_type}: {node_list}")

print("\nEdges:")
for edge in edges:
    print(f"{edge[0]} -[{edge[1]}]-> {edge[2]}")
# Out:
# C:\Users\ongai\AppData\Local\Temp\ipykernel_28788\1123930051.py:57: UserWarning: [W007] The model you're using has no word vectors loaded, so the result of the Span.similarity method will be based on the tagger, parser and NER, which may not give useful similarity judgements. This may happen if you're using one of the small models, e.g. `en_core_web_sm`, which don't ship with word vectors and only use context-sensitive tensors. You can always add your own word vectors, or use one of the larger models instead if available.
#   similarity = sent.similarity(nlp(phrase))  # Compute similarity
# Nodes:
# Company: ['FSD Computer', 'Gigafactory Nevada', 'Automotive Purchase Financing and Leases', 'Powertrain Our', 'Model S', 'Energy Generation and Storage Energy Storage Systems', 'NHTSA', 'Megapack', 'AI', 'the Organization for Economic Co-operation and', 'Tesla Superchargers', 'Autopilot', 'Internships &#8211', 'the National Highway Traffic Safety Administration', 'ECE', 'ESG', 'Tesla', 'SAE International', 'Solar Energy Offerings', 'the Internal Revenue Code', 'Energy Generation and Storage Energy Storage Products', 'Control systems', 'FMVSS', 'Automobile Manufacturer', 'Energy Generation and Storage Energy Storage Products Powerwall', 'European Defence Ministries', 'ECE markets &#8221;)', 'Our Products and Services Automotive', 'FSD', 'ir.tesla.com', 'NACS', 'Technician Trainee', 'the &#8220;EPA&#8221', 'Battery Safety and Testing Our', ': &#8226', 'IRC', 'SEC', 'Full Self-Driving (&', 'Take Charge', 'START', 'Significant Accounting Policies', 'Solar Energy Systems', 'Financial Services', 'Technician Trainees', 'the U.S.', 'Energy Generation and Storage', 'Automotive Direct Sales Our', 'Automotive Regulatory Credits', 'Governmental Programs', 'Self-Driving Vehicles', 'Apprenticeships &#8211']
# Product: ['the Model 3', 'Model Y', 'Model S', 'Solar Roof', 'Model 3']
# Industry: ['non-Tesla', 'Model X', 'Tesla', 'Optimus', 'Superchargers']
# Country: ['Nevada', 'Gigafactory Nevada', 'Texas', 'Germany', 'Buffalo', 'China', 'Korea', 'Gigafactory Berlin-Brandenburg', 'New York', 'United Kingdom', 'Shanghai', 'Monterrey', 'Reno', 'California', 'Hong Kong', 'Mexico', 'Gigafactory', 'Australia', 'Austin', 'Heroes', 'U.S.']
#
# Edges:
