# %%
import dotenv
import os
from neo4j import GraphDatabase
import pandas as pd
import json 
from operator import itemgetter
import numpy as np
import re
import glob

# %% [markdown]
# ### Neo4j AuraDB Connection

# %%
load_status = dotenv.load_dotenv("Neo4j-fccfe306-Created-2024-09-24.txt")
if load_status is False:
    raise RuntimeError('Environment variables not loaded.')

URI = os.getenv("NEO4J_URI")
AUTH = (os.getenv("NEO4J_USERNAME"), os.getenv("NEO4J_PASSWORD"))

with GraphDatabase.driver(URI, auth=AUTH) as driver:
    driver.verify_connectivity()
    print("Connection established.")
# Out:
# Connection established.

# %% [markdown]
# ### Import Json file
# In this part, import all the json files, `nasdaq_kg_schema.json`, `nasdaq_kg_schema_rank_1-10.json` and `nasdaq_kg_schema_rank_11-32.json`.

# %%
json_files = glob.glob('**/*.json', recursive=True)
print(json_files)

def merge_json_files(json_list):

    merged_json = {
        "nodes": {},
        "relationships": {}
    }

    for file_path in json_list:
        with open(file_path, 'r') as file:
            try:
                data = json.load(file)

                
                if "nodes" in data:
                    for node_type, nodes in data["nodes"].items():
                        if node_type not in merged_json["nodes"]:
                            merged_json["nodes"][node_type] = []
                        merged_json["nodes"][node_type].extend(nodes)

               
                if "relationships" in data:
                    for relationship_type, relationships in data["relationships"].items():
                        if relationship_type not in merged_json["relationships"]:
                            merged_json["relationships"][relationship_type] = []
                        merged_json["relationships"][relationship_type].extend(relationships)

            except json.JSONDecodeError as e:
                print(f"Error decoding {file_path}: {e}")
                
            except FileNotFoundError:
                print("Error: The file was not found.")

    # Write the merged data to a JSON file
    return merged_json

merged_json = merge_json_files(json_files)
# Out:
# ['merged_output.json', 'nasdaq_kg_schema.json', 'nasdaq_kg_schema_rank_1-10.json', 'nasdaq_kg_schema_rank_11-32.json']

# %%
def extract_nodes_from_json(data):
    """Extracts nodes from the specified JSON file and returns them in a structured format."""
    extracted_nodes = {
        'Company': set(),
        'Product': set(),
        'Country': set(),
        'Industry': set()
    }

    for company in data['nodes'].get('Company', []):
        extracted_nodes['Company'].add(company['name'])
    
    for product in data['nodes'].get('Product', []):
        extracted_nodes['Product'].add(product['name'])
    
    for country in data['nodes'].get('Country', []):
        extracted_nodes['Country'].add(country['name'])
    
    for industry in data['nodes'].get('Industry', []):
        extracted_nodes['Industry'].add(industry['name'])

    extracted_nodes = {key: list(value) for key, value in extracted_nodes.items()}
    
    data = {"nodes": extracted_nodes}
    return data

nodes_json = extract_nodes_from_json(merged_json)
nodes_json = json.dumps(merged_json, indent=4) 
print(nodes_json)
# Out:
# {
#     "nodes": {
#         "Company": [
#             {
#                 "name": "Apple Inc.",
#                 "ticker_code": "AAPL",
#                 "founded_year": null
#             },
#             {
#                 "name": "Apple",
#                 "ticker_code": "AAPL",
#                 "founded_year": null
#             },
#             {
#                 "name": "App Store",
#                 "ticker_code": "id328412701",
#                 "founded_year": null
#             },
#             {
#                 "name": "Apple Arcade",
#                 "ticker_code": "apple-launches-game-subscription-apple-arcade-181647109--finance.html",
#                 "founded_year": null
#             },
#             {
#                 "name": "AirPods",
#                 "ticker_code": "AAPL",
#                 "founded_year": null
#             },
#             {
#                 "name": "Apple",
#                 "ticker_code": "AAPL",
#                 "founded_year": null
#             },
#             {
#                 "name": "MLS Season Pass",
#                 "ticker_code": "apple-tv-cuts-price-mls-161110203.html",
#                 "founded_year": null
#             },
#             {
#                 "name": "Major League Soccer (MLS)",
#                 "ticker_code": "MLFB",
#                 "founded_year": null
#             },
#             {
#                 "name": "Apple",
#                 "ticker_code": "AAPL",
#                 "founded_year": null
#             },
#             {
#                 "name": "Sculley",
#                 "ticker_code": "SRL",
#                 "founded_year": null
#             },
#             {
#                 "name": "Sculley",
#                 "ticker_code": "SRL",
#                 "founded_year": null
#             },
#             {
#                 "name": "ADOBE INC.",
#                 "ticker_code": "ADBE",
#                 "founded_year": null
#             },
#             {
#                 "name": "Frame.io",
#                 "ticker_code": "adobe-buying-frame-io-1-203840757.html",
#                 "founded_year": null
#             },
#             {
#                 "name": "Adobe Express",
#                 "ticker_code": "ADBE",
#                 "founded_year": null
#             },
#             {
#                 "name": "Humanise.AI",
#                 "ticker_code": "ai-generated-text-human-touch-040000477.html",
#                 "founded_year": null
#             },
#             {
#                 "name": "Adobe",
#                 "ticker_code": "ADBE",
#                 "founded_year": null
#             },
#             {
#                 "name": "Adobe GenStudio",
#                 "ticker_code": "adobes-genstudio-brings-brand-safe-160445659.html",
#                 "founded_year": null
#             },
#             {
#                 "name": "Adobe Express",
#                 "ticker_code": "ADBE",
#                 "founded_year": null
#             },
#             {
#                 "name": "EchoSign",
#                 "ticker_code": "2011-12-22-adobe-releases-echosign-app-for-ios-enables-legally-binding-con.html",
#                 "founded_year": null
#             },
#             {
#                 "name": "Adobe",
#                 "ticker_code": "ADBE",
#                 "founded_year": null
#             },
#             {
#                 "name": "AGREEMENTS",
#                 "ticker_code": "en-US",
#                 "founded_year": null
#             },
#             {
#                 "name": "AND Analysis",
#                 "ticker_code": "sg.finance.yahoo.com",
#                 "founded_year": null
#             },
#             {
#                 "name": "Creative Cloud",
#                 "ticker_code": "ADBE",
#                 "founded_year": null
#             },
#             {
#                 "name": "Document Cloud",
#                 "ticker_code": "tap-high-growth-document-cloud-121454230.html",
#                 "founded_year": null
#             },
#             {
#                 "name": "Creative Cloud",
#                 "ticker_code": "ADBE",
#                 "founded_year": null
#             },
#             {
#                 "name": "Creative Cloud",
#                 "ticker_code": "ADBE",
#                 "founded_year": null
#             },
#             {
#                 "name": "Creative Cloud",
#                 "ticker_code": "ADBE",
#                 "founded_year": null
#             },
#             {
#                 "name": "Document Cloud",
#                 "ticker_code": "tap-high-growth-document-cloud-121454230.html",
#                 "founded_year": null
#             },
#             {
#                 "name": "Creative Cloud",
#                 "ticker_code": "ADBE",
#                 "founded_year": null
#             },
#             {
#                 "name": "Document Cloud",
#                 "ticker_code": "tap-high-growth-document-cloud-121454230.html",
#                 "founded_year": null
#             },
#             {
#                 "name": "Document Cloud",
#                 "ticker_code": "tap-high-growth-document-cloud-121454230.html",
#                 "founded_year": null
#             },
#             {
#                 "name": "Creative Cloud",
#                 "ticker_code": "ADBE",
#                 "founded_year": null
#             },
#             {
#                 "name": "Creative Cloud",
#                 "ticker_code": "ADBE",
#                 "founded_year": null
#             },
#             {
#                 "name": "Creative Cloud",
#                 "ticker_code": "ADBE",
#                 "founded_year": null
#             },
#             {
#                 "name": "Document Cloud",
#                 "ticker_code": "tap-high-growth-document-cloud-121454230.html",
#                 "founded_year": null
#             },
#             {
#                 "name": "Creative Cloud",
#                 "ticker_code": "ADBE",
#                 "founded_year": null
#             },
#             {
#                 "name": "Document Cloud",
#                 "ticker_code": "tap-high-growth-document-cloud-121454230.html",
#                 "founded_year": null
#             },
#             {
#                 "name": "Adobe",
#                 "ticker_code": "ADBE",
#                 "founded_year": null
#             },
#             {
#                 "name": "Geschke",
#                 "ticker_code": "adobe-co-founder-developer-pdfs-152857768.html",
#                 "founded_year": null
#             },
#             {
#                 "name": "ANALOG DEVICES INC",
#                 "ticker_code": "ADI",
#                 "founded_year": null
#             },
#             {
#                 "name": "Maxim Integrated Products",
#                 "ticker_code": "MXIM",
#                 "founded_year": null
#             },
#             {
#                 "name": "Analog Devices",
#                 "ticker_code": "ADI",
#                 "founded_year": null
#             },
#             {
#                 "name": "Securities and Exchange Commission",
#                 "ticker_code": "d293630d10k.htm",
#                 "founded_year": null
#             },
#             {
#                 "name": "board of directors",
#                 "ticker_code": "List_of_corporate_directors_of_Yahoo",
#                 "founded_year": null
#             },
#             {
#                 "name": "Current Reports",
#                 "ticker_code": "news",
#                 "founded_year": null
#             },
#             {
#                 "name": "AND Analysis",
#                 "ticker_code": "sg.finance.yahoo.com",
#                 "founded_year": null
#             },
#             {
#                 "name": "Analog Devices",
#                 "ticker_code": "ADI",
#                 "founded_year": null
#             },
#             {
#                 "name": "AUTOMATIC DATA PROCESSING INC",
#                 "ticker_code": "ADP",
#                 "founded_year": null
#             },
#             {
#                 "name": "Automatic Data Processing",
#                 "ticker_code": "ADP",
#                 "founded_year": null
#             },
#             {
#                 "name": "Humanise.AI",
#                 "ticker_code": "ai-generated-text-human-touch-040000477.html",
#                 "founded_year": null
#             },
#             {
#                 "name": "AI Breakthrough",
#                 "ticker_code": "top-13-artificial-intelligence-ai-222907215.html",
#                 "founded_year": null
#             },
#             {
#                 "name": "ADP Assist",
#                 "ticker_code": "ADP",
#                 "founded_year": null
#             },
#             {
#                 "name": "Automatic Data Processing",
#                 "ticker_code": "ADP",
#                 "founded_year": null
#             },
#             {
#                 "name": "Reportable",
#                 "ticker_code": "earnings",
#                 "founded_year": null
#             },
#             {
#                 "name": "GAAP",
#                 "ticker_code": "gaap-203500605.html",
#                 "founded_year": null
#             },
#             {
#                 "name": "Automatic Data Processing",
#                 "ticker_code": "ADP",
#                 "founded_year": null
#             },
#             {
#                 "name": "APPLIED MATERIALS INC /DE",
#                 "ticker_code": "AMAT",
#                 "founded_year": null
#             },
#             {
#                 "name": "Applied Materials",
#                 "ticker_code": "AMAT",
#                 "founded_year": null
#             },
#             {
#                 "name": "SmartFactory",
#                 "ticker_code": "smart-factory-market-set-grow-120000901.html",
#                 "founded_year": null
#             },
#             {
#                 "name": "UVision Air",
#                 "ticker_code": "AIR",
#                 "founded_year": null
#             },
#             {
#                 "name": "Prime Vision - Kinston PA",
#                 "ticker_code": "EYE",
#                 "founded_year": null
#             },
#             {
#                 "name": "Applied",
#                 "ticker_code": "AMAT",
#                 "founded_year": null
#             },
#             {
#                 "name": "Vantage Systems",
#                 "ticker_code": "VTAGY",
#                 "founded_year": null
#             },
#             {
#                 "name": "Semiconductor Systems",
#                 "ticker_code": "semiconductors",
#                 "founded_year": null
#             },
#             {
#                 "name": "Semiconductor Systems",
#                 "ticker_code": "semiconductors",
#                 "founded_year": null
#             },
#             {
#                 "name": "Applied Global Services",
#                 "ticker_code": "AMAT",
#                 "founded_year": null
#             },
#             {
#                 "name": "Applied Global Services",
#                 "ticker_code": "AMAT",
#                 "founded_year": null
#             },
#             {
#                 "name": "Semiconductor Systems",
#                 "ticker_code": "semiconductors",
#                 "founded_year": null
#             },
#             {
#                 "name": "Applied Materials",
#                 "ticker_code": "AMAT",
#                 "founded_year": null
#             },
#             {
#                 "name": "ADVANCED MICRO DEVICES INC",
#                 "ticker_code": "AMD",
#                 "founded_year": null
#             },
#             {
#                 "name": "Microsoft",
#                 "ticker_code": "MSFT",
#                 "founded_year": null
#             },
#             {
#                 "name": "CoolRunner",
#                 "ticker_code": "amd-axes-xilinx-cpld-chips-134217470.html",
#                 "founded_year": null
#             },
#             {
#                 "name": "Advanced Micro Devices",
#                 "ticker_code": "AMD",
#                 "founded_year": null
#             },
#             {
#                 "name": "board of directors",
#                 "ticker_code": "List_of_corporate_directors_of_Yahoo",
#                 "founded_year": null
#             },
#             {
#                 "name": "Securities and Exchange Commission",
#                 "ticker_code": "d293630d10k.htm",
#                 "founded_year": null
#             },
#             {
#                 "name": "Arm Holdings",
#                 "ticker_code": "ARM",
#                 "founded_year": null
#             },
#             {
#                 "name": "Nasdaq",
#                 "ticker_code": "%5EIXIC",
#                 "founded_year": null
#             },
#             {
#                 "name": "The Khronos Group",
#                 "ticker_code": "KRO",
#                 "founded_year": null
#             },
#             {
#                 "name": "Pensando Systems",
#                 "ticker_code": "amd-buys-networking-technology-maker-134636085.html",
#                 "founded_year": null
#             },
#             {
#                 "name": "Infinity Fabric",
#                 "ticker_code": "chinese-chipmaker-samples-128-core-120022116.html",
#                 "founded_year": null
#             },
#             {
#                 "name": "ADOBE INC.",
#                 "ticker_code": "ADBE",
#                 "founded_year": null
#             },
#             {
#                 "name": "Frame.io",
#                 "ticker_code": "adobe-buying-frame-io-1-203840757.html",
#                 "founded_year": null
#             },
#             {
#                 "name": "Adobe Express",
#                 "ticker_code": "ADBE",
#                 "founded_year": null
#             },
#             {
#                 "name": "Humanise.AI",
#                 "ticker_code": "HEART-USD",
#                 "founded_year": null
#             },
#             {
#                 "name": "Adobe",
#                 "ticker_code": "ADBE",
#                 "founded_year": null
#             },
#             {
#                 "name": "Adobe GenStudio",
#                 "ticker_code": "adobes-genstudio-brings-brand-safe-160445659.html",
#                 "founded_year": null
#             },
#             {
#                 "name": "Adobe Express",
#                 "ticker_code": "ADBE",
#                 "founded_year": null
#             },
#             {
#                 "name": "EchoSign",
#                 "ticker_code": "2011-12-22-adobe-releases-echosign-app-for-ios-enables-legally-binding-con.html",
#                 "founded_year": null
#             },
#             {
#                 "name": "Adobe",
#                 "ticker_code": "ADBE",
#                 "founded_year": null
#             },
#             {
#                 "name": "AGREEMENTS",
#                 "ticker_code": "index.html",
#                 "founded_year": null
#             },
#             {
#                 "name": "AND Analysis",
#                 "ticker_code": "sg.finance.yahoo.com",
#                 "founded_year": null
#             },
#             {
#                 "name": "Creative Cloud",
#                 "ticker_code": "ADBE",
#                 "founded_year": null
#             },
#             {
#                 "name": "Creative Cloud",
#                 "ticker_code": "ADBE",
#                 "founded_year": null
#             },
#             {
#                 "name": "Creative Cloud",
#                 "ticker_code": "ADBE",
#                 "founded_year": null
#             },
#             {
#                 "name": "Document Cloud",
#                 "ticker_code": "tap-high-growth-document-cloud-121454230.html",
#                 "founded_year": null
#             },
#             {
#                 "name": "Creative Cloud",
#                 "ticker_code": "ADBE",
#                 "founded_year": null
#             },
#             {
#                 "name": "Document Cloud",
#                 "ticker_code": "tap-high-growth-document-cloud-121454230.html",
#                 "founded_year": null
#             },
#             {
#                 "name": "Creative Cloud",
#                 "ticker_code": "ADBE",
#                 "founded_year": null
#             },
#             {
#                 "name": "Document Cloud",
#                 "ticker_code": "tap-high-growth-document-cloud-121454230.html",
#                 "founded_year": null
#             },
#             {
#                 "name": "Creative Cloud",
#                 "ticker_code": "ADBE",
#                 "founded_year": null
#             },
#             {
#                 "name": "Document Cloud",
#                 "ticker_code": "tap-high-growth-document-cloud-121454230.html",
#                 "founded_year": null
#             },
#             {
#                 "name": "Document Cloud",
#                 "ticker_code": "tap-high-growth-document-cloud-121454230.html",
#                 "founded_year": null
#             },
#             {
#                 "name": "Creative Cloud",
#                 "ticker_code": "ADBE",
#                 "founded_year": null
#             },
#             {
#                 "name": "Document Cloud",
#                 "ticker_code": "tap-high-growth-document-cloud-121454230.html",
#                 "founded_year": null
#             },
#             {
#                 "name": "Creative Cloud",
#                 "ticker_code": "ADBE",
#                 "founded_year": null
#             },
#             {
#                 "name": "Creative Cloud",
#                 "ticker_code": "ADBE",
#                 "founded_year": null
#             },
#             {
#                 "name": "Adobe",
#                 "ticker_code": "ADBE",
#                 "founded_year": null
#             },
#             {
#                 "name": "Geschke",
#                 "ticker_code": "adobe-co-founder-developer-pdfs-152857768.html",
#                 "founded_year": null
#             },
#             {
#                 "name": "ADVANCED MICRO DEVICES INC",
#                 "ticker_code": "AMD",
#                 "founded_year": null
#             },
#             {
#                 "name": "Microsoft",
#                 "ticker_code": "MSFT",
#                 "founded_year": null
#             },
#             {
#                 "name": "CoolRunner",
#                 "ticker_code": "CLCO",
#                 "founded_year": null
#             },
#             {
#                 "name": "Advanced Micro Devices",
#                 "ticker_code": "AMD",
#                 "founded_year": null
#             },
#             {
#                 "name": "board of directors",
#                 "ticker_code": "List_of_corporate_directors_of_Yahoo",
#                 "founded_year": null
#             },
#             {
#                 "name": "Securities and Exchange Commission",
#                 "ticker_code": "sg.finance.yahoo.com",
#                 "founded_year": null
#             },
#             {
#                 "name": "Arm Holdings",
#                 "ticker_code": "ARM",
#                 "founded_year": null
#             },
#             {
#                 "name": "Nasdaq",
#                 "ticker_code": "%5EIXIC",
#                 "founded_year": null
#             },
#             {
#                 "name": "The Khronos Group",
#                 "ticker_code": "KRO",
#                 "founded_year": null
#             },
#             {
#                 "name": "Pensando Systems",
#                 "ticker_code": "amd-buys-networking-technology-maker-134636085.html",
#                 "founded_year": null
#             },
#             {
#                 "name": "Infinity Fabric",
#                 "ticker_code": "chinese-chipmaker-samples-128-core-120022116.html",
#                 "founded_year": null
#             },
#             {
#                 "name": "Mipsology",
#                 "ticker_code": "avnet-distribute-mipsology-breakthrough-fpga-020000886.html",
#                 "founded_year": null
#             },
#             {
#                 "name": "Advanced Micro Devices",
#                 "ticker_code": "AMD",
#                 "founded_year": null
#             },
#             {
#                 "name": "AND Analysis",
#                 "ticker_code": "sg.finance.yahoo.com",
#                 "founded_year": null
#             },
#             {
#                 "name": "Nod",
#                 "ticker_code": "NOD.OL",
#                 "founded_year": null
#             },
#             {
#                 "name": "Xilinx",
#                 "ticker_code": "xilinx-stock-holders-now-amd-162514748.html",
#                 "founded_year": null
#             },
#             {
#                 "name": "Advanced Micro Devices",
#                 "ticker_code": "AMD",
#                 "founded_year": null
#             },
#             {
#                 "name": "AMAZON COM INC",
#                 "ticker_code": "AMZN",
#                 "founded_year": null
#             },
#             {
#                 "name": "Amazon",
#                 "ticker_code": "AMZN",
#                 "founded_year": null
#             },
#             {
#                 "name": "Executive Officers",
#                 "ticker_code": "about",
#                 "founded_year": null
#             },
#             {
#                 "name": "Career Choice",
#                 "ticker_code": "u-news-world-report-announces-131300118.html",
#                 "founded_year": null
#             },
#             {
#                 "name": "Amazon Web Services (AWS)",
#                 "ticker_code": "AMZN",
#                 "founded_year": null
#             },
#             {
#                 "name": "Securities and Exchange Commission",
#                 "ticker_code": "sg.finance.yahoo.com",
#                 "founded_year": null
#             },
#             {
#                 "name": "Amazon",
#                 "ticker_code": "AMZN",
#                 "founded_year": null
#             },
#             {
#                 "name": "AMGEN INC",
#                 "ticker_code": "AMGN",
#                 "founded_year": null
#             },
#             {
#                 "name": "Amgen",
#                 "ticker_code": "AMGN",
#                 "founded_year": null
#             },
#             {
#                 "name": "ANALOG DEVICES INC",
#                 "ticker_code": "ADI",
#                 "founded_year": null
#             },
#             {
#                 "name": "Maxim Integrated Products",
#                 "ticker_code": "maxim-integrated-products-nasdaq-mxim-074910474.html",
#                 "founded_year": null
#             },
#             {
#                 "name": "Analog Devices",
#                 "ticker_code": "ADI",
#                 "founded_year": null
#             },
#             {
#                 "name": "Securities and Exchange Commission",
#                 "ticker_code": "sg.finance.yahoo.com",
#                 "founded_year": null
#             },
#             {
#                 "name": "board of directors",
#                 "ticker_code": "List_of_corporate_directors_of_Yahoo",
#                 "founded_year": null
#             },
#             {
#                 "name": "Current Reports",
#                 "ticker_code": "news",
#                 "founded_year": null
#             },
#             {
#                 "name": "AND Analysis",
#                 "ticker_code": "sg.finance.yahoo.com",
#                 "founded_year": null
#             },
#             {
#                 "name": "Analog Devices",
#                 "ticker_code": "ADI",
#                 "founded_year": null
#             },
#             {
#                 "name": "APPLIED MATERIALS INC /DE",
#                 "ticker_code": "AMAT",
#                 "founded_year": null
#             },
#             {
#                 "name": "Applied Materials",
#                 "ticker_code": "AMAT",
#                 "founded_year": null
#             },
#             {
#                 "name": "SmartFactory",
#                 "ticker_code": "global-smart-factory-strategic-analysis-172300561.html",
#                 "founded_year": null
#             },
#             {
#                 "name": "UVision Air",
#                 "ticker_code": "AIR",
#                 "founded_year": null
#             },
#             {
#                 "name": "Prime Vision - Kinston PA",
#                 "ticker_code": "TTE.PA",
#                 "founded_year": null
#             },
#             {
#                 "name": "Applied",
#                 "ticker_code": "AMAT",
#                 "founded_year": null
#             },
#             {
#                 "name": "Vantage Systems",
#                 "ticker_code": "VTAGY",
#                 "founded_year": null
#             },
#             {
#                 "name": "Semiconductor Systems",
#                 "ticker_code": "semiconductors",
#                 "founded_year": null
#             },
#             {
#                 "name": "Applied Global Services",
#                 "ticker_code": "AMAT",
#                 "founded_year": null
#             },
#             {
#                 "name": "Semiconductor Systems",
#                 "ticker_code": "semiconductors",
#                 "founded_year": null
#             },
#             {
#                 "name": "Semiconductor Systems",
#                 "ticker_code": "semiconductors",
#                 "founded_year": null
#             },
#             {
#                 "name": "Applied Global Services",
#                 "ticker_code": "AMAT",
#                 "founded_year": null
#             },
#             {
#                 "name": "Applied Materials",
#                 "ticker_code": "AMAT",
#                 "founded_year": null
#             },
#             {
#                 "name": "AUTOMATIC DATA PROCESSING INC",
#                 "ticker_code": "ADP",
#                 "founded_year": null
#             },
#             {
#                 "name": "Automatic Data Processing",
#                 "ticker_code": "ADP",
#                 "founded_year": null
#             },
#             {
#                 "name": "Humanise.AI",
#                 "ticker_code": "HEART-USD",
#                 "founded_year": null
#             },
#             {
#                 "name": "AI Breakthrough",
#                 "ticker_code": "top-13-artificial-intelligence-ai-222907215.html",
#                 "founded_year": null
#             },
#             {
#                 "name": "ADP Assist",
#                 "ticker_code": "adp-assist-generative-ai-features-144500728.html",
#                 "founded_year": null
#             },
#             {
#                 "name": "Automatic Data Processing",
#                 "ticker_code": "ADP",
#                 "founded_year": null
#             },
#             {
#                 "name": "Reportable",
#                 "ticker_code": "SLN28397.html",
#                 "founded_year": null
#             },
#             {
#                 "name": "GAAP",
#                 "ticker_code": "gaap-203500605.html",
#                 "founded_year": null
#             },
#             {
#                 "name": "Automatic Data Processing",
#                 "ticker_code": "ADP",
#                 "founded_year": null
#             },
#             {
#                 "name": "Alphabet Inc.",
#                 "ticker_code": "GOOG",
#                 "founded_year": null
#             },
#             {
#                 "name": "Google",
#                 "ticker_code": "GOOG",
#                 "founded_year": null
#             },
#             {
#                 "name": "Humanise.AI",
#                 "ticker_code": "HEART-USD",
#                 "founded_year": null
#             },
#             {
#                 "name": "Audio Magic",
#                 "ticker_code": "MGIC",
#                 "founded_year": null
#             },
#             {
#                 "name": "Google Workspace",
#                 "ticker_code": "GOOG",
#                 "founded_year": null
#             },
#             {
#                 "name": "Globally",
#                 "ticker_code": "world-indices",
#                 "founded_year": null
#             },
#             {
#                 "name": "Product Studio",
#                 "ticker_code": "yahoo-finance-unveils-new-programming-initiatives-ahead-of-new-studio-launch",
#                 "founded_year": null
#             },
#             {
#                 "name": "DeepMind Technologies",
#                 "ticker_code": "google-deepmind-ceo-next-100-201256604.html",
#                 "founded_year": null
#             },
#             {
#                 "name": "Gemini",
#                 "ticker_code": "GMNI",
#                 "founded_year": null
#             },
#             {
#                 "name": "Improve Knowledge",
#                 "ticker_code": "improving-financial-literacy-help-build-110014080.html",
#                 "founded_year": null
#             },
#             {
#                 "name": "Performance Max",
#                 "ticker_code": "media-challengers-integrates-performance-max-132000307.html",
#                 "founded_year": null
#             },
#             {
#                 "name": "AlphaFold",
#                 "ticker_code": "deepminds-demis-hassabis-john-jumper-110448454.html",
#                 "founded_year": null
#             },
#             {
#                 "name": "Alphabet",
#                 "ticker_code": "GOOG",
#                 "founded_year": null
#             },
#             {
#                 "name": "Google",
#                 "ticker_code": "GOOG",
#                 "founded_year": null
#             },
#             {
#                 "name": "AND Analysis",
#                 "ticker_code": "sg.finance.yahoo.com",
#                 "founded_year": null
#             },
#             {
#                 "name": "Alphabet",
#                 "ticker_code": "GOOG",
#                 "founded_year": null
#             },
#             {
#                 "name": "Google",
#                 "ticker_code": "GOOG",
#                 "founded_year": null
#             },
#             {
#                 "name": "Alphabet Inc.",
#                 "ticker_code": "GOOGL",
#                 "founded_year": null
#             },
#             {
#                 "name": "Google",
#                 "ticker_code": "GOOG",
#                 "founded_year": null
#             },
#             {
#                 "name": "Humanise.AI",
#                 "ticker_code": "HEART-USD",
#                 "founded_year": null
#             },
#             {
#                 "name": "Audio Magic",
#                 "ticker_code": "MGIC",
#                 "founded_year": null
#             },
#             {
#                 "name": "Google Workspace",
#                 "ticker_code": "GOOG",
#                 "founded_year": null
#             },
#             {
#                 "name": "Globally",
#                 "ticker_code": "world-indices",
#                 "founded_year": null
#             },
#             {
#                 "name": "Product Studio",
#                 "ticker_code": "yahoo-finance-unveils-new-programming-initiatives-ahead-of-new-studio-launch",
#                 "founded_year": null
#             },
#             {
#                 "name": "DeepMind Technologies",
#                 "ticker_code": "google-deepmind-ceo-next-100-201256604.html",
#                 "founded_year": null
#             },
#             {
#                 "name": "Gemini",
#                 "ticker_code": "GMNI",
#                 "founded_year": null
#             },
#             {
#                 "name": "Improve Knowledge",
#                 "ticker_code": "improving-financial-literacy-help-build-110014080.html",
#                 "founded_year": null
#             },
#             {
#                 "name": "Performance Max",
#                 "ticker_code": "media-challengers-integrates-performance-max-132000307.html",
#                 "founded_year": null
#             },
#             {
#                 "name": "AlphaFold",
#                 "ticker_code": "deepminds-demis-hassabis-john-jumper-110448454.html",
#                 "founded_year": null
#             },
#             {
#                 "name": "Alphabet",
#                 "ticker_code": "GOOG",
#                 "founded_year": null
#             },
#             {
#                 "name": "Google",
#                 "ticker_code": "GOOG",
#                 "founded_year": null
#             },
#             {
#                 "name": "AND Analysis",
#                 "ticker_code": "sg.finance.yahoo.com",
#                 "founded_year": null
#             },
#             {
#                 "name": "Alphabet",
#                 "ticker_code": "GOOG",
#                 "founded_year": null
#             },
#             {
#                 "name": "Google",
#                 "ticker_code": "GOOG",
#                 "founded_year": null
#             },
#             {
#                 "name": "Apple Inc.",
#                 "ticker_code": "AAPL",
#                 "founded_year": null
#             },
#             {
#                 "name": "Apple",
#                 "ticker_code": "AAPL",
#                 "founded_year": null
#             },
#             {
#                 "name": "App Store",
#                 "ticker_code": "id328412701",
#                 "founded_year": null
#             },
#             {
#                 "name": "Apple Arcade",
#                 "ticker_code": "apple-launches-game-subscription-apple-arcade-181647109--finance.html",
#                 "founded_year": null
#             },
#             {
#                 "name": "AirPods",
#                 "ticker_code": "AAPL",
#                 "founded_year": null
#             },
#             {
#                 "name": "Apple",
#                 "ticker_code": "AAPL",
#                 "founded_year": null
#             },
#             {
#                 "name": "MLS Season Pass",
#                 "ticker_code": "apple-tv-cuts-price-mls-161110203.html",
#                 "founded_year": null
#             },
#             {
#                 "name": "Major League Soccer (MLS)",
#                 "ticker_code": "MLFB",
#                 "founded_year": null
#             },
#             {
#                 "name": "Apple",
#                 "ticker_code": "AAPL",
#                 "founded_year": null
#             },
#             {
#                 "name": "Sculley",
#                 "ticker_code": "SRL",
#                 "founded_year": null
#             },
#             {
#                 "name": "Booking Holdings Inc.",
#                 "ticker_code": "BKNG",
#                 "founded_year": null
#             },
#             {
#                 "name": "Booking Holdings Inc.",
#                 "ticker_code": "BKNG",
#                 "founded_year": null
#             },
#             {
#                 "name": "Booking Holdings",
#                 "ticker_code": "BKNG",
#                 "founded_year": null
#             },
#             {
#                 "name": "Booking.com",
#                 "ticker_code": "BKNG",
#                 "founded_year": null
#             },
#             {
#                 "name": "OpenTable",
#                 "ticker_code": "opentable-225400154.html",
#                 "founded_year": null
#             },
#             {
#                 "name": "Agoda",
#                 "ticker_code": "BKNG",
#                 "founded_year": null
#             },
#             {
#                 "name": "Nasdaq",
#                 "ticker_code": "%5EIXIC",
#                 "founded_year": null
#             },
#             {
#                 "name": "Agoda",
#                 "ticker_code": "BKNG",
#                 "founded_year": null
#             },
#             {
#                 "name": "Booking.com",
#                 "ticker_code": "BKNG",
#                 "founded_year": null
#             },
#             {
#                 "name": "OpenTable",
#                 "ticker_code": "opentable-225400154.html",
#                 "founded_year": null
#             },
#             {
#                 "name": "Booking Holdings",
#                 "ticker_code": "BKNG",
#                 "founded_year": null
#             },
#             {
#                 "name": "Broadcom Inc.",
#                 "ticker_code": "AVGO",
#                 "founded_year": null
#             },
#             {
#                 "name": "Brocade Communications Systems",
#                 "ticker_code": "BCSA.DE",
#                 "founded_year": null
#             },
#             {
#                 "name": "VMware",
#                 "ticker_code": "vmw",
#                 "founded_year": null
#             },
#             {
#                 "name": "Broadcom",
#                 "ticker_code": "AVGO",
#                 "founded_year": null
#             },
#             {
#                 "name": "LSI",
#                 "ticker_code": "LYTS",
#                 "founded_year": null
#             },
#             {
#                 "name": "VMware Merger",
#                 "ticker_code": "broadcom-completes-acquisition-vmware-133000964.html",
#                 "founded_year": null
#             },
#             {
#                 "name": "VMware Merger",
#                 "ticker_code": "broadcom-completes-acquisition-vmware-133000964.html",
#                 "founded_year": null
#             },
#             {
#                 "name": "Symantec Enterprise Security",
#                 "ticker_code": "symantec-cybersecurity-solutions-assessed-combat-220000232.html",
#                 "founded_year": null
#             },
#             {
#                 "name": "VMware Merger",
#                 "ticker_code": "broadcom-completes-acquisition-vmware-133000964.html",
#                 "founded_year": null
#             },
#             {
#                 "name": "Broadcom",
#                 "ticker_code": "AVGO",
#                 "founded_year": null
#             },
#             {
#                 "name": "VMware",
#                 "ticker_code": "vmw",
#                 "founded_year": null
#             },
#             {
#                 "name": "AND Analysis",
#                 "ticker_code": "sg.finance.yahoo.com",
#                 "founded_year": null
#             },
#             {
#                 "name": "Securities and Exchange Commission",
#                 "ticker_code": "d293630d10k.htm",
#                 "founded_year": null
#             },
#             {
#                 "name": "Broadcom",
#                 "ticker_code": "AVGO",
#                 "founded_year": null
#             },
#             {
#                 "name": "CINTAS CORP",
#                 "ticker_code": "CTAS",
#                 "founded_year": null
#             },
#             {
#                 "name": "Cintas",
#                 "ticker_code": "CTAS",
#                 "founded_year": null
#             },
#             {
#                 "name": "Workday",
#                 "ticker_code": "WDAY",
#                 "founded_year": null
#             },
#             {
#                 "name": "Cintas",
#                 "ticker_code": "CTAS",
#                 "founded_year": null
#             },
#             {
#                 "name": "Workday",
#                 "ticker_code": "WDAY",
#                 "founded_year": null
#             },
#             {
#                 "name": "Cintas",
#                 "ticker_code": "CTAS",
#                 "founded_year": null
#             },
#             {
#                 "name": "CISCO SYSTEMS, INC.",
#                 "ticker_code": "CSCO",
#                 "founded_year": null
#             },
#             {
#                 "name": "Cisco Systems",
#                 "ticker_code": "CSCO",
#                 "founded_year": null
#             },
#             {
#                 "name": "APJC",
#                 "ticker_code": "APJCX",
#                 "founded_year": null
#             },
#             {
#                 "name": "Securities and Exchange Commission",
#                 "ticker_code": "d293630d10k.htm",
#                 "founded_year": null
#             },
#             {
#                 "name": "Splunk",
#                 "ticker_code": "SPLK",
#                 "founded_year": null
#             },
#             {
#                 "name": "Modernize",
#                 "ticker_code": "select-plan",
#                 "founded_year": null
#             },
#             {
#                 "name": "APJC",
#                 "ticker_code": "APJCX",
#                 "founded_year": null
#             },
#             {
#                 "name": "Cisco Systems",
#                 "ticker_code": "CSCO",
#                 "founded_year": null
#             },
#             {
#                 "name": "Splunk",
#                 "ticker_code": "SPLK",
#                 "founded_year": null
#             },
#             {
#                 "name": "Key Financial",
#                 "ticker_code": "sg.finance.yahoo.com",
#                 "founded_year": null
#             },
#             {
#                 "name": "Cisco Systems",
#                 "ticker_code": "CSCO",
#                 "founded_year": null
#             },
#             {
#                 "name": "COMCAST CORP",
#                 "ticker_code": "CMCSA",
#                 "founded_year": null
#             },
#             {
#                 "name": "Sky Stream",
#                 "ticker_code": "youll-soon-able-sky-stream-230100403.html",
#                 "founded_year": null
#             },
#             {
#                 "name": "Sky Sports",
#                 "ticker_code": "SKT.NZ",
#                 "founded_year": null
#             },
#             {
#                 "name": "Internet Essentials",
#                 "ticker_code": "comcast-remains-dedicated-closing-digital-144500207.html",
#                 "founded_year": null
#             },
#             {
#                 "name": "Virgin Media O2",
#                 "ticker_code": "virgin-media-o2-offload-stake-071957969.html",
#                 "founded_year": null
#             },
#             {
#                 "name": "Comcast Business",
#                 "ticker_code": "CMCSA",
#                 "founded_year": null
#             },
#             {
#                 "name": "Comcast",
#                 "ticker_code": "CMCSA",
#                 "founded_year": null
#             },
#             {
#                 "name": "Xumo",
#                 "ticker_code": "xumo-2024-fast-report-reveals-140000471.html",
#                 "founded_year": null
#             },
#             {
#                 "name": "NOW",
#                 "ticker_code": "NOW",
#                 "founded_year": null
#             },
#             {
#                 "name": "Universal Pictures",
#                 "ticker_code": "UVV",
#                 "founded_year": null
#             },
#             {
#                 "name": "Comcast",
#                 "ticker_code": "CMCSA",
#                 "founded_year": null
#             },
#             {
#                 "name": "Comcast Corporation",
#                 "ticker_code": "CMCSA",
#                 "founded_year": null
#             },
#             {
#                 "name": "Comcast",
#                 "ticker_code": "CMCSA",
#                 "founded_year": null
#             },
#             {
#                 "name": "COSTCO WHOLESALE CORP /NEW",
#                 "ticker_code": "COST",
#                 "founded_year": null
#             },
#             {
#                 "name": "Costco Wholesale",
#                 "ticker_code": "COST",
#                 "founded_year": null
#             },
#             {
#                 "name": "Securities and Exchange Commission",
#                 "ticker_code": "d293630d10k.htm",
#                 "founded_year": null
#             },
#             {
#                 "name": "Costco Wholesale",
#                 "ticker_code": "COST",
#                 "founded_year": null
#             },
#             {
#                 "name": "GILEAD SCIENCES, INC.",
#                 "ticker_code": "GILD",
#                 "founded_year": null
#             },
#             {
#                 "name": "Janssen Pharmaceutica",
#                 "ticker_code": "JNJ",
#                 "founded_year": null
#             },
#             {
#                 "name": "Asegua Therapeutics",
#                 "ticker_code": "gilead-sciences-announces-second-quarter-200200721.html",
#                 "founded_year": null
#             },
#             {
#                 "name": "Food and Drug Administration",
#                 "ticker_code": "u-food-drug-administration-gives-111600724.html",
#                 "founded_year": null
#             },
#             {
#                 "name": "Federal Trade Commission",
#                 "ticker_code": "ftc-finalizes-merger-filing-requirements-214331138.html",
#                 "founded_year": null
#             },
#             {
#                 "name": "Janssen Sciences Ireland Unlimited Company",
#                 "ticker_code": "GILD",
#                 "founded_year": null
#             },
#             {
#                 "name": "Shanghai Fosun Pharmaceutical (Group) Co.",
#                 "ticker_code": "2196.HK",
#                 "founded_year": null
#             },
#             {
#                 "name": "XinThera",
#                 "ticker_code": "mbrace-therapeutics-raises-85-million-133000731.html",
#                 "founded_year": null
#             },
#             {
#                 "name": "Tentarix Biotherapeutics",
#                 "ticker_code": "tentarix-biotherapeutics-announces-appointment-andrew-120000907.html",
#                 "founded_year": null
#             },
#             {
#                 "name": "Tmunity Therapeutics",
#                 "ticker_code": "CTNM",
#                 "founded_year": null
#             },
#             {
#                 "name": "Compugen",
#                 "ticker_code": "CGEN",
#                 "founded_year": null
#             },
#             {
#                 "name": "Arcus Biosciences",
#                 "ticker_code": "RCUS",
#                 "founded_year": null
#             },
#             {
#                 "name": "Arcellx",
#                 "ticker_code": "ACLX",
#                 "founded_year": null
#             },
#             {
#                 "name": "European Commission",
#                 "ticker_code": "european-union",
#                 "founded_year": null
#             },
#             {
#                 "name": "Metabolex",
#                 "ticker_code": "META",
#                 "founded_year": null
#             },
#             {
#                 "name": "Assembly Biosciences",
#                 "ticker_code": "ASMB",
#                 "founded_year": null
#             },
#             {
#                 "name": "Daiichi Sankyo",
#                 "ticker_code": "DSNKY",
#                 "founded_year": null
#             },
#             {
#                 "name": "Food and Drug Administration",
#                 "ticker_code": "u-food-drug-administration-gives-111600724.html",
#                 "founded_year": null
#             },
#             {
#                 "name": "Nurix",
#                 "ticker_code": "NRIX",
#                 "founded_year": null
#             },
#             {
#                 "name": "AND Analysis",
#                 "ticker_code": "sg.finance.yahoo.com",
#                 "founded_year": null
#             },
#             {
#                 "name": "Securities and Exchange Commission",
#                 "ticker_code": "d293630d10k.htm",
#                 "founded_year": null
#             },
#             {
#                 "name": "Gilead Sciences",
#                 "ticker_code": "GILD",
#                 "founded_year": null
#             },
#             {
#                 "name": "European Union",
#                 "ticker_code": "european-union",
#                 "founded_year": null
#             },
#             {
#                 "name": "Oaktree",
#                 "ticker_code": "OAK-PB",
#                 "founded_year": null
#             },
#             {
#                 "name": "Gilead Sciences K.K.",
#                 "ticker_code": "GILD",
#                 "founded_year": null
#             },
#             {
#                 "name": "Gilead Sciences",
#                 "ticker_code": "GILD",
#                 "founded_year": null
#             },
#             {
#                 "name": "HONEYWELL INTERNATIONAL INC",
#                 "ticker_code": "HON",
#                 "founded_year": null
#             },
#             {
#                 "name": "Aerospace Technologies Group",
#                 "ticker_code": "1725.HK",
#                 "founded_year": null
#             },
#             {
#                 "name": "Honeywell Building Technologies",
#                 "ticker_code": "HON",
#                 "founded_year": null
#             },
#             {
#                 "name": "Honeywell International",
#                 "ticker_code": "HON",
#                 "founded_year": null
#             },
#             {
#                 "name": "Quantinuum",
#                 "ticker_code": "quantinuum-unveils-accelerated-roadmap-achieve-141700991.html",
#                 "founded_year": null
#             },
#             {
#                 "name": "Honeywell International Inc.",
#                 "ticker_code": "HON",
#                 "founded_year": null
#             },
#             {
#                 "name": "Performance Materials and Technologies",
#                 "ticker_code": "technology",
#                 "founded_year": null
#             },
#             {
#                 "name": "AEROSPACE",
# ...
#                 "product_name": "laser cleaning technologies"
#             },
#             {
#                 "company_name": "Applied Materials",
#                 "product_name": "solar manufacturing equipment"
#             },
#             {
#                 "company_name": "Applied Materials",
#                 "product_name": "semiconductor equipment"
#             },
#             {
#                 "company_name": "Tokyo Electron",
#                 "product_name": "semiconductor equipment"
#             },
#             {
#                 "company_name": "Applied Materials",
#                 "product_name": "manufacture of semiconductor (integrated circuit) chips"
#             },
#             {
#                 "company_name": "Apple",
#                 "product_name": "iPad accessories"
#             },
#             {
#                 "company_name": "Apple",
#                 "product_name": "mobile handset"
#             },
#             {
#                 "company_name": "Emagic",
#                 "product_name": "computer"
#             },
#             {
#                 "company_name": "Apple Inc.",
#                 "product_name": "solar energy"
#             },
#             {
#                 "company_name": "Apple Energy, LLC",
#                 "product_name": "solar energy"
#             },
#             {
#                 "company_name": "Booking.com",
#                 "product_name": "accommodation reservation services"
#             },
#             {
#                 "company_name": "Booking Holdings",
#                 "product_name": "hotel distribution services"
#             },
#             {
#                 "company_name": "Agoda",
#                 "product_name": "activities reservation services"
#             },
#             {
#                 "company_name": "Agoda",
#                 "product_name": "ground transportation"
#             },
#             {
#                 "company_name": "Agoda",
#                 "product_name": "flight"
#             },
#             {
#                 "company_name": "Booking Holdings",
#                 "product_name": "rental car reservation services"
#             },
#             {
#                 "company_name": "Booking.com",
#                 "product_name": "Connected Trip"
#             },
#             {
#                 "company_name": "Broadcom",
#                 "product_name": "semiconductor and infrastructure software products"
#             },
#             {
#                 "company_name": "Broadcom",
#                 "product_name": "SSD controller"
#             },
#             {
#                 "company_name": "Broadcom",
#                 "product_name": "enterprise security"
#             },
#             {
#                 "company_name": "Cintas",
#                 "product_name": "shop towels"
#             },
#             {
#                 "company_name": "Cintas",
#                 "product_name": "corporate identity uniforms"
#             },
#             {
#                 "company_name": "Cintas",
#                 "product_name": "mats"
#             },
#             {
#                 "company_name": "Cintas",
#                 "product_name": "products and services"
#             },
#             {
#                 "company_name": "Cintas",
#                 "product_name": "mops"
#             },
#             {
#                 "company_name": "Cintas",
#                 "product_name": "safety courses"
#             },
#             {
#                 "company_name": "Cintas",
#                 "product_name": "cleaning and restroom supplies"
#             },
#             {
#                 "company_name": "Cintas",
#                 "product_name": "first aid and safety products"
#             },
#             {
#                 "company_name": "Kamp Fire Equipment",
#                 "product_name": "fire safety products and services"
#             },
#             {
#                 "company_name": "Cintas",
#                 "product_name": "fire safety products and services"
#             },
#             {
#                 "company_name": "Cintas",
#                 "product_name": "fire protection"
#             },
#             {
#                 "company_name": "Cisco Systems",
#                 "product_name": "equipment"
#             },
#             {
#                 "company_name": "Cisco Systems",
#                 "product_name": "mobile network management"
#             },
#             {
#                 "company_name": "Cisco",
#                 "product_name": "IP phones"
#             },
#             {
#                 "company_name": "Cisco Systems",
#                 "product_name": "high-technology services"
#             },
#             {
#                 "company_name": "Cisco Systems",
#                 "product_name": "networking hardware"
#             },
#             {
#                 "company_name": "Cisco Systems",
#                 "product_name": "software"
#             },
#             {
#                 "company_name": "Cisco Systems",
#                 "product_name": "telecommunications equipment"
#             },
#             {
#                 "company_name": "Cisco Systems",
#                 "product_name": "computer boards"
#             },
#             {
#                 "company_name": "Cisco Systems",
#                 "product_name": "IT products and services"
#             },
#             {
#                 "company_name": "Comcast",
#                 "product_name": "first-party content"
#             },
#             {
#                 "company_name": "Comcast",
#                 "product_name": "television programming content"
#             },
#             {
#                 "company_name": "Comcast",
#                 "product_name": "cable"
#             },
#             {
#                 "company_name": "Comcast",
#                 "product_name": "commercial services"
#             },
#             {
#                 "company_name": "Comcast",
#                 "product_name": "broadband services"
#             },
#             {
#                 "company_name": "Comcast",
#                 "product_name": "home telephone service"
#             },
#             {
#                 "company_name": "Greater Philadelphia Cablevision",
#                 "product_name": "cable"
#             },
#             {
#                 "company_name": "Comcast",
#                 "product_name": "wireless devices"
#             },
#             {
#                 "company_name": "Costco Wholesale",
#                 "product_name": "vacation packages"
#             },
#             {
#                 "company_name": "Costco Wholesale",
#                 "product_name": "cruises"
#             },
#             {
#                 "company_name": "Costco Wholesale",
#                 "product_name": "car rentals"
#             },
#             {
#                 "company_name": "Costco Wholesale",
#                 "product_name": "hot dogs"
#             },
#             {
#                 "company_name": "Costco Home",
#                 "product_name": "furniture"
#             },
#             {
#                 "company_name": "Pepsi",
#                 "product_name": "drinks"
#             },
#             {
#                 "company_name": "Gilead Sciences",
#                 "product_name": "intellectual property"
#             },
#             {
#                 "company_name": "Gilead Sciences",
#                 "product_name": "hepatitis C."
#             },
#             {
#                 "company_name": "Raylo Chemicals",
#                 "product_name": "pharmaceutical ingredients"
#             },
#             {
#                 "company_name": "Raylo Chemicals",
#                 "product_name": "advanced intermediates"
#             },
#             {
#                 "company_name": "Honeywell",
#                 "product_name": "deadly and maiming weapons"
#             },
#             {
#                 "company_name": "Honeywell International",
#                 "product_name": "deadly and maiming weapons"
#             },
#             {
#                 "company_name": "Honeywell",
#                 "product_name": "cluster bombs"
#             },
#             {
#                 "company_name": "Honeywell International",
#                 "product_name": "cluster bombs"
#             },
#             {
#                 "company_name": "Honeywell International",
#                 "product_name": "photographic equipment"
#             },
#             {
#                 "company_name": "Honeywell International",
#                 "product_name": "personal protective equipment"
#             },
#             {
#                 "company_name": "Honeywell International",
#                 "product_name": "Pentax cameras"
#             },
#             {
#                 "company_name": "Pentax",
#                 "product_name": "photographic equipment"
#             },
#             {
#                 "company_name": "Honeywell International",
#                 "product_name": "electronic guidance systems"
#             },
#             {
#                 "company_name": "Honeywell International",
#                 "product_name": "secondary power turbine engines"
#             },
#             {
#                 "company_name": "Intel",
#                 "product_name": "computer components"
#             },
#             {
#                 "company_name": "Intel Israel",
#                 "product_name": "communications products"
#             },
#             {
#                 "company_name": "Intel",
#                 "product_name": "semiconductor chip"
#             },
#             {
#                 "company_name": "Intel",
#                 "product_name": "PC microprocessors"
#             },
#             {
#                 "company_name": "Intel",
#                 "product_name": "hardware"
#             },
#             {
#                 "company_name": "Compaq",
#                 "product_name": "PC-compatible systems"
#             },
#             {
#                 "company_name": "ProConnect",
#                 "product_name": "form updates"
#             },
#             {
#                 "company_name": "Intuit",
#                 "product_name": "e-commerce tools"
#             },
#             {
#                 "company_name": "Intuit",
#                 "product_name": "credit cards"
#             },
#             {
#                 "company_name": "Intuitive Surgical Devices",
#                 "product_name": "robotic products"
#             },
#             {
#                 "company_name": "Intuitive Surgical",
#                 "product_name": "spare part"
#             },
#             {
#                 "company_name": "KLA Corporation",
#                 "product_name": "surface inspection system"
#             },
#             {
#                 "company_name": "ADE",
#                 "product_name": "silicon wafer metrology"
#             },
#             {
#                 "company_name": "ADE",
#                 "product_name": "related gear"
#             },
#             {
#                 "company_name": "KLA Corporation KLA Corporation",
#                 "product_name": "yield management"
#             },
#             {
#                 "company_name": "KLA Corporation",
#                 "product_name": "plasma etch products"
#             },
#             {
#                 "company_name": "Lam Research",
#                 "product_name": "and services"
#             },
#             {
#                 "company_name": "Lam Research",
#                 "product_name": "innovative wafer fabrication equipment"
#             },
#             {
#                 "company_name": "Lam Research",
#                 "product_name": "chip equipment"
#             },
#             {
#                 "company_name": "Ontrak",
#                 "product_name": "chip equipment"
#             },
#             {
#                 "company_name": "Lam Research",
#                 "product_name": "semiconductor wafer"
#             },
#             {
#                 "company_name": "Lam Research",
#                 "product_name": "related services"
#             },
#             {
#                 "company_name": "The Linde Group",
#                 "product_name": "merchant and cylinder gases"
#             },
#             {
#                 "company_name": "The Linde Group",
#                 "product_name": "plant components"
#             },
#             {
#                 "company_name": "The Linde Group",
#                 "product_name": "synthesis gases"
#             },
#             {
#                 "company_name": "The Linde Group",
#                 "product_name": "argon"
#             },
#             {
#                 "company_name": "Linde plc",
#                 "product_name": "debt securities"
#             },
#             {
#                 "company_name": "The Linde Group",
#                 "product_name": "industrial gas products"
#             },
#             {
#                 "company_name": "The Linde Group",
#                 "product_name": "pipeline complexes"
#             },
#             {
#                 "company_name": "The Linde Group",
#                 "product_name": "delivery vehicles"
#             },
#             {
#                 "company_name": "Lansing Bagnall",
#                 "product_name": "forklift"
#             },
#             {
#                 "company_name": "Lincare Holdings",
#                 "product_name": "home care gas"
#             },
#             {
#                 "company_name": "HiQ Tyres & Autocare",
#                 "product_name": "industrial gases"
#             },
#             {
#                 "company_name": "HiQ Tyres & Autocare",
#                 "product_name": "specialty gases"
#             },
#             {
#                 "company_name": "HiQ Tyres & Autocare",
#                 "product_name": "medical gases"
#             },
#             {
#                 "company_name": "Mercado Pago Servicios de Procesamiento S.R.L.",
#                 "product_name": "electronic money transfers"
#             },
#             {
#                 "company_name": "Netlist",
#                 "product_name": "memory"
#             },
#             {
#                 "company_name": "Lexar Media",
#                 "product_name": "digital media products"
#             },
#             {
#                 "company_name": "Microsoft",
#                 "product_name": "BASIC interpreters"
#             },
#             {
#                 "company_name": "Netflix",
#                 "product_name": "DVD"
#             },
#             {
#                 "company_name": "LSI Logic Corporation",
#                 "product_name": "computer chip"
#             },
#             {
#                 "company_name": "Nvidia",
#                 "product_name": "AI) hardware"
#             },
#             {
#                 "company_name": "ATI Technologies",
#                 "product_name": "southbridge parts"
#             },
#             {
#                 "company_name": "Nvidia",
#                 "product_name": "graphics hardware"
#             },
#             {
#                 "company_name": "Nvidia",
#                 "product_name": "southbridge parts"
#             },
#             {
#                 "company_name": "ULI Electronics",
#                 "product_name": "southbridge parts"
#             },
#             {
#                 "company_name": "Nvidia",
#                 "product_name": "mobile processors"
#             },
#             {
#                 "company_name": "Nvidia",
#                 "product_name": "vehicle navigation and entertainment systems"
#             },
#             {
#                 "company_name": "Nvidia",
#                 "product_name": "graphics adapters"
#             },
#             {
#                 "company_name": "Pearl Milling Company",
#                 "product_name": "syrups"
#             },
#             {
#                 "company_name": "Wimm Bill Dann Foods",
#                 "product_name": "fruit juices"
#             },
#             {
#                 "company_name": "Wimm Bill Dann Foods",
#                 "product_name": "yogurt"
#             },
#             {
#                 "company_name": "PepsiCo",
#                 "product_name": "Frito-Lay snacks"
#             },
#             {
#                 "company_name": "PepsiCo",
#                 "product_name": "Tropicana juices"
#             },
#             {
#                 "company_name": "LOFT",
#                 "product_name": "candy"
#             }
#         ]
#     }
# }

# %% [markdown]
# ### Data Wrangling

# %% [markdown]
# * This part is only for company nodes, where we want to ensure data integrity by checking the primary key ticker_code and ensuring other fields like company name adhere to specific formatting rules and constraints.
# * Validating ticker_code as a valid string consisting of 4 to 5 uppercase letters, is for accurate indexing in financial markets.
# * The process identifies duplicates and keeps the more-info version of an entry over the other duplicates.
# * Standardizing company names into title case and eliminating special symbols maintains consistency in representation and usability.
# * All data entry whose ticker_code and company_name does not meet these criteria will be removed to maintain a clean dataset for the reporting of company information.

# %%
def is_valid_ticker(ticker_code):
    """Helper function to check if the ticker code is valid (str, 4 to 5 letters, all upper case)."""
    return isinstance(ticker_code, str) and 4 <= len(ticker_code) <= 5 and ticker_code.isupper()

def remove_invalid_ticker_companies(data):
    """Remove companies whose ticker_code doesn't meet the 3, 4, or 5 letter criteria."""
    if isinstance(data, str):
        print("Warning: data is a string, attempting to load as JSON.")
        data = json.loads(data)  
    
    if "nodes" in data and "Company" in data["nodes"]:
        companies = data["nodes"]["Company"]
        filtered_companies = [company for company in companies if is_valid_ticker(company.get("ticker_code"))]
        data["nodes"]["Company"] = filtered_companies
    else:
        print("Warning: The expected structure is not found in the data.")

    return data

def is_more_comprehensive(entry1, entry2):
    """Helper function to determine which duplicate has more comprehensive details."""
    return sum(1 for v in entry1.values() if v) > sum(1 for v in entry2.values() if v)

def remove_duplicates(data):
    seen_tickers = {}
    for company in data["nodes"]["Company"]:   
        ticker = company.get("ticker_code", "")
        if ticker in seen_tickers:
            if is_more_comprehensive(company, seen_tickers[ticker]):
                seen_tickers[ticker] = company
        else:
            seen_tickers[ticker] = company 
    data["nodes"]["Company"] = list(seen_tickers.values())
    return data

def standarize_case(data):
    """function to standardize title case and no other special."""
    for company in data["nodes"]["Company"]:
        company["name"] = company["name"].title() 
        company["name"] = re.sub(r'[^a-zA-Z0-9\s&.-]', '',company["name"]) 
    return data

# Example jsondata to test with
input_data = {
    "nodes": {
        "Company": [
            {"name": "Apple Inc.", "ticker_code": "AAPL", "founded_year": None},
            {"name": "APPLIED MATERIALS INC /DE", "ticker_code": "AMAT", "founded_year": None},
            {"name": "APP STORE", "ticker_code": "id328412701", "founded_year": None}, 
            {"name": "Apple Arcade", "ticker_code": "apple-launches-game-subscription-apple-arcade-181647109--finance.html", "founded_year": None},  # Invalid
            {"name": "AirPods", "ticker_code": ".&nbsp", "founded_year": None}, 
            {"name": "COMCAST CORP", "ticker_code": "CMCSA", "founded_year": 1986},
            {"name": "Key Financial","ticker_code": "sg.finance.yahoo.com","founded_year": None},
            {"name": "Apple Inc.", "ticker_code": "AAPL", "founded_year": 1976},
            {"name": "Executive Officers","ticker_code": "about","founded_year": None},
        ]
    }
}
# remove_invalid_ticker_companies(input_data)
# remove_duplicates(input_data)
# standarize_case(input_data)

# %%
def wrangling(data): 
    data = remove_invalid_ticker_companies(data)
    data = remove_duplicates(data)
    data = standarize_case(data)
    print("Completed.")
    return data

wrangling(merged_json)
# Out:
# Completed.
# {'nodes': {'Company': [{'name': 'Apple Inc.',
#     'ticker_code': 'AAPL',
#     'founded_year': None},
#    {'name': 'Major League Soccer Mls',
#     'ticker_code': 'MLFB',
#     'founded_year': None},
#    {'name': 'Adobe Inc.', 'ticker_code': 'ADBE', 'founded_year': None},
#    {'name': 'Maxim Integrated Products',
#     'ticker_code': 'MXIM',
#     'founded_year': None},
#    {'name': 'Applied Materials Inc De',
#     'ticker_code': 'AMAT',
#     'founded_year': None},
#    {'name': 'Vantage Systems', 'ticker_code': 'VTAGY', 'founded_year': None},
#    {'name': 'Microsoft', 'ticker_code': 'MSFT', 'founded_year': None},
#    {'name': 'Coolrunner', 'ticker_code': 'CLCO', 'founded_year': None},
#    {'name': 'Amazon Com Inc', 'ticker_code': 'AMZN', 'founded_year': None},
#    {'name': 'Amgen Inc', 'ticker_code': 'AMGN', 'founded_year': None},
#    {'name': 'Alphabet Inc.', 'ticker_code': 'GOOG', 'founded_year': None},
#    {'name': 'Audio Magic', 'ticker_code': 'MGIC', 'founded_year': None},
#    {'name': 'Gemini', 'ticker_code': 'GMNI', 'founded_year': None},
#    {'name': 'Alphabet Inc.', 'ticker_code': 'GOOGL', 'founded_year': None},
#    {'name': 'Booking Holdings Inc.',
#     'ticker_code': 'BKNG',
#     'founded_year': None},
#    {'name': 'Broadcom Inc.', 'ticker_code': 'AVGO', 'founded_year': None},
#    {'name': 'Lsi', 'ticker_code': 'LYTS', 'founded_year': None},
#    {'name': 'Cintas Corp', 'ticker_code': 'CTAS', 'founded_year': None},
#    {'name': 'Workday', 'ticker_code': 'WDAY', 'founded_year': None},
#    {'name': 'Cisco Systems Inc.', 'ticker_code': 'CSCO', 'founded_year': None},
#    {'name': 'Apjc', 'ticker_code': 'APJCX', 'founded_year': None},
#    {'name': 'Splunk', 'ticker_code': 'SPLK', 'founded_year': None},
#    {'name': 'Comcast Corp', 'ticker_code': 'CMCSA', 'founded_year': None},
#    {'name': 'Costco Wholesale Corp New',
#     'ticker_code': 'COST',
#     'founded_year': None},
#    {'name': 'Gilead Sciences Inc.',
#     'ticker_code': 'GILD',
#     'founded_year': None},
#    {'name': 'Tmunity Therapeutics',
#     'ticker_code': 'CTNM',
#     'founded_year': None},
#    {'name': 'Compugen', 'ticker_code': 'CGEN', 'founded_year': None},
#    {'name': 'Arcus Biosciences', 'ticker_code': 'RCUS', 'founded_year': None},
#    {'name': 'Arcellx', 'ticker_code': 'ACLX', 'founded_year': None},
#    {'name': 'Metabolex', 'ticker_code': 'META', 'founded_year': None},
#    {'name': 'Assembly Biosciences',
#     'ticker_code': 'ASMB',
#     'founded_year': None},
#    {'name': 'Daiichi Sankyo', 'ticker_code': 'DSNKY', 'founded_year': None},
#    {'name': 'Nurix', 'ticker_code': 'NRIX', 'founded_year': None},
#    {'name': 'Butz', 'ticker_code': 'BULZ', 'founded_year': None},
#    {'name': 'Intel Corp', 'ticker_code': 'INTC', 'founded_year': None},
#    {'name': 'Intuit Inc.', 'ticker_code': 'INTU', 'founded_year': None},
#    {'name': 'Intuitive Surgical Inc',
#     'ticker_code': 'ISRG',
#     'founded_year': None},
#    {'name': 'Kla Corp', 'ticker_code': 'KLAC', 'founded_year': None},
#    {'name': 'Lam Research Corp', 'ticker_code': 'LRCX', 'founded_year': None},
#    {'name': 'Mercadolibre Inc', 'ticker_code': 'MELI', 'founded_year': None},
#    {'name': 'Nuance Communications',
#     'ticker_code': 'NUAN',
#     'founded_year': None},
#    {'name': 'Reinvent', 'ticker_code': 'RTPZU', 'founded_year': None},
#    {'name': 'Mondelez International Inc.',
#     'ticker_code': 'MDLZ',
#     'founded_year': None},
#    {'name': 'Netflix Inc', 'ticker_code': 'NFLX', 'founded_year': None},
#    {'name': 'Nvidia Corp', 'ticker_code': 'NVDA', 'founded_year': None},
#    {'name': 'Exluna', 'ticker_code': 'LUNA', 'founded_year': None}],
#   'Country': [{'source_city': 'Greater China',
#     'name': 'Jamaica',
#     'iso2': 'JM',
#     'iso3': 'JAM',
#     'population': 129,
#     'gdp': 3841,
#     'corporate_tax_rate': 20},
#    {'name': 'Australia',
#     'iso2': 'AU',
#     'iso3': 'AUS',
#     'population': 281,
#     'gdp': 17148,
#     'corporate_tax_rate': 41},
#    {'source_city': 'Americas',
#     'name': 'Dominican Republic',
#     'iso2': 'DO',
#     'iso3': 'DOM',
#     'population': 1066,
#     'gdp': 5935,
#     'corporate_tax_rate': 49},
#    {'name': 'Japan',
#     'iso2': 'JP',
#     'iso3': 'JPN',
#     'population': 777,
#     'gdp': 5707,
#     'corporate_tax_rate': 37},
#    {'source_city': 'Cupertino',
#     'name': 'United States',
#     'iso2': 'US',
#     'iso3': 'USA',
#     'population': 256,
#     'gdp': 10831,
#     'corporate_tax_rate': 29},
#    {'source_city': 'Wilmington',
#     'name': 'United States',
#     'iso2': 'US',
#     'iso3': 'USA',
#     'population': 274,
#     'gdp': 6562,
#     'corporate_tax_rate': 13},
#    {'source_city': 'Massachusetts',
#     'name': 'United States',
#     'iso2': 'US',
#     'iso3': 'USA',
#     'population': 1026,
#     'gdp': 15906,
#     'corporate_tax_rate': 18},
#    {'source_city': 'Boston',
#     'name': 'United States',
#     'iso2': 'US',
#     'iso3': 'USA',
#     'population': 83,
#     'gdp': 5503,
#     'corporate_tax_rate': 13},
#    {'name': 'South Korea',
#     'iso2': 'KR',
#     'iso3': 'KOR',
#     'population': 795,
#     'gdp': 12661,
#     'corporate_tax_rate': 18},
#    {'name': 'Germany',
#     'iso2': 'DE',
#     'iso3': 'DEU',
#     'population': 387,
#     'gdp': 2098,
#     'corporate_tax_rate': 37},
#    {'name': 'Netherlands',
#     'iso2': 'NL',
#     'iso3': 'NLD',
#     'population': 394,
#     'gdp': 4616,
#     'corporate_tax_rate': 43},
#    {'name': 'United States of America',
#     'iso2': 'US',
#     'iso3': 'USA',
#     'population': 37,
#     'gdp': 5369,
#     'corporate_tax_rate': 30},
#    {'name': 'United States of America',
#     'iso2': 'US',
#     'iso3': 'USA',
#     'population': 796,
#     'gdp': 6619,
#     'corporate_tax_rate': 21},
#    {'source_city': 'Santa Clara',
#     'name': 'Cuba',
#     'iso2': 'CU',
#     'iso3': 'CUB',
#     'population': 939,
#     'gdp': 16737,
#     'corporate_tax_rate': 40},
#    {'source_city': 'California',
#     'name': 'United States',
#     'iso2': 'US',
#     'iso3': 'USA',
#     'population': 1081,
#     'gdp': 17738,
#     'corporate_tax_rate': 28},
#    {'name': 'United States of America',
#     'iso2': 'US',
#     'iso3': 'USA',
#     'population': 1029,
#     'gdp': 1698,
#     'corporate_tax_rate': 21},
#    {'source_city': 'Delaware',
#     'name': 'United States',
#     'iso2': 'US',
#     'iso3': 'USA',
#     'population': 128,
#     'gdp': 10874,
#     'corporate_tax_rate': 18},
#    {'source_city': 'Santa Clara',
#     'name': 'Cuba',
#     'iso2': 'CU',
#     'iso3': 'CUB',
#     'population': 1270,
#     'gdp': 17601,
#     'corporate_tax_rate': 33},
#    {'source_city': 'California',
#     'name': 'United States',
#     'iso2': 'US',
#     'iso3': 'USA',
#     'population': 572,
#     'gdp': 14189,
#     'corporate_tax_rate': 42},
#    {'name': 'United States of America',
#     'iso2': 'US',
#     'iso3': 'USA',
#     'population': 1075,
#     'gdp': 2172,
#     'corporate_tax_rate': 16},
#    {'source_city': 'Delaware',
#     'name': 'United States',
#     'iso2': 'US',
#     'iso3': 'USA',
#     'population': 1147,
#     'gdp': 19340,
#     'corporate_tax_rate': 27},
#    {'source_city': 'UltraScale',
#     'name': 'Not Found',
#     'population': 215,
#     'gdp': 11634,
#     'corporate_tax_rate': 41},
#    {'source_city': 'UltraScale',
#     'name': 'Not Found',
#     'population': 1162,
#     'gdp': 7452,
#     'corporate_tax_rate': 40},
#    {'source_city': 'Earth',
#     'name': 'United States',
#     'iso2': 'US',
#     'iso3': 'USA',
#     'population': 470,
#     'gdp': 14450,
#     'corporate_tax_rate': 47},
#    {'source_city': 'Wilmington',
#     'name': 'United States',
#     'iso2': 'US',
#     'iso3': 'USA',
#     'population': 950,
#     'gdp': 11204,
#     'corporate_tax_rate': 18},
#    {'source_city': 'Massachusetts',
#     'name': 'United States',
#     'iso2': 'US',
#     'iso3': 'USA',
#     'population': 1384,
#     'gdp': 17387,
#     'corporate_tax_rate': 27},
#    {'source_city': 'Boston',
#     'name': 'United States',
#     'iso2': 'US',
#     'iso3': 'USA',
#     'population': 150,
#     'gdp': 11983,
#     'corporate_tax_rate': 23},
#    {'name': 'South Korea',
#     'iso2': 'KR',
#     'iso3': 'KOR',
#     'population': 1257,
#     'gdp': 4703,
#     'corporate_tax_rate': 30},
#    {'name': 'Germany',
#     'iso2': 'DE',
#     'iso3': 'DEU',
#     'population': 360,
#     'gdp': 12947,
#     'corporate_tax_rate': 48},
#    {'name': 'Netherlands',
#     'iso2': 'NL',
#     'iso3': 'NLD',
#     'population': 1103,
#     'gdp': 15007,
#     'corporate_tax_rate': 40},
#    {'name': 'United States of America',
#     'iso2': 'US',
#     'iso3': 'USA',
#     'population': 426,
#     'gdp': 1269,
#     'corporate_tax_rate': 14},
#    {'name': 'United States of America',
#     'iso2': 'US',
#     'iso3': 'USA',
#     'population': 291,
#     'gdp': 17181,
#     'corporate_tax_rate': 28},
#    {'source_city': 'Greater China',
#     'name': 'Jamaica',
#     'iso2': 'JM',
#     'iso3': 'JAM',
#     'population': 869,
#     'gdp': 17845,
#     'corporate_tax_rate': 43},
#    {'name': 'Australia',
#     'iso2': 'AU',
#     'iso3': 'AUS',
#     'population': 339,
#     'gdp': 13042,
#     'corporate_tax_rate': 27},
#    {'source_city': 'Americas',
#     'name': 'Dominican Republic',
#     'iso2': 'DO',
#     'iso3': 'DOM',
#     'population': 1194,
#     'gdp': 7624,
#     'corporate_tax_rate': 28},
#    {'name': 'Japan',
#     'iso2': 'JP',
#     'iso3': 'JPN',
#     'population': 306,
#     'gdp': 893,
#     'corporate_tax_rate': 42},
#    {'source_city': 'Cupertino',
#     'name': 'United States',
#     'iso2': 'US',
#     'iso3': 'USA',
#     'population': 936,
#     'gdp': 7456,
#     'corporate_tax_rate': 13},
#    {'source_city': 'North America',
#     'name': 'United States',
#     'iso2': 'US',
#     'iso3': 'USA',
#     'population': 433,
#     'gdp': 3203,
#     'corporate_tax_rate': 14},
#    {'name': 'Belarus',
#     'iso2': 'BY',
#     'iso3': 'BLR',
#     'population': 957,
#     'gdp': 2980,
#     'corporate_tax_rate': 39},
#    {'name': 'Israel',
#     'iso2': 'IL',
#     'iso3': 'ISR',
#     'population': 920,
#     'gdp': 11702,
#     'corporate_tax_rate': 45},
#    {'name': 'Ukraine',
#     'iso2': 'UA',
#     'iso3': 'UKR',
#     'population': 101,
#     'gdp': 6666,
#     'corporate_tax_rate': 13},
#    {'name': 'United States of America',
#     'iso2': 'US',
#     'iso3': 'USA',
#     'population': 378,
#     'gdp': 12471,
#     'corporate_tax_rate': 48},
#    {'name': 'Israel',
#     'iso2': 'IL',
#     'iso3': 'ISR',
#     'population': 941,
#     'gdp': 8776,
#     'corporate_tax_rate': 17},
#    {'name': 'United States of America',
#     'iso2': 'US',
#     'iso3': 'USA',
#     'population': 1360,
#     'gdp': 14490,
#     'corporate_tax_rate': 42},
#    {'source_city': 'Ohio River',
#     'name': 'United States',
#     'iso2': 'US',
#     'iso3': 'USA',
#     'population': 492,
#     'gdp': 14060,
#     'corporate_tax_rate': 40},
#    {'source_city': 'North America',
#     'name': 'United States',
#     'iso2': 'US',
#     'iso3': 'USA',
#     'population': 561,
#     'gdp': 1970,
#     'corporate_tax_rate': 13},
#    {'source_city': 'California',
#     'name': 'United States',
#     'iso2': 'US',
#     'iso3': 'USA',
#     'population': 579,
#     'gdp': 3284,
#     'corporate_tax_rate': 22},
#    {'source_city': 'San Jose',
#     'name': 'Costa Rica',
#     'iso2': 'CR',
#     'iso3': 'CRI',
#     'population': 422,
#     'gdp': 15254,
#     'corporate_tax_rate': 44},
#    {'name': "People's Republic of China",
#     'iso2': 'CN',
#     'iso3': 'CHN',
#     'population': 1371,
#     'gdp': 13981,
#     'corporate_tax_rate': 23},
#    {'name': 'United Kingdom',
#     'iso2': 'GB',
#     'iso3': 'GBR',
#     'population': 604,
#     'gdp': 4876,
#     'corporate_tax_rate': 14},
#    {'name': 'United States of America',
#     'iso2': 'US',
#     'iso3': 'USA',
#     'population': 508,
#     'gdp': 566,
#     'corporate_tax_rate': 46},
#    {'name': 'Italy',
#     'iso2': 'IT',
#     'iso3': 'ITA',
#     'population': 549,
#     'gdp': 296,
#     'corporate_tax_rate': 49},
#    {'source_city': 'Orlando',
#     'name': 'United States',
#     'iso2': 'US',
#     'iso3': 'USA',
#     'population': 241,
#     'gdp': 17886,
#     'corporate_tax_rate': 44},
#    {'name': 'United States of America',
#     'iso2': 'US',
#     'iso3': 'USA',
#     'population': 402,
#     'gdp': 13369,
#     'corporate_tax_rate': 34},
#    {'name': 'United States of America',
#     'iso2': 'US',
#     'iso3': 'USA',
#     'population': 719,
#     'gdp': 12609,
#     'corporate_tax_rate': 45},
#    {'name': 'United Kingdom',
#     'iso2': 'GB',
#     'iso3': 'GBR',
#     'population': 836,
#     'gdp': 17415,
#     'corporate_tax_rate': 28},
#    {'name': 'Korea',
#     'population': 125,
#     'gdp': 15808,
#     'corporate_tax_rate': 44},
#    {'name': 'Australia',
#     'iso2': 'AU',
#     'iso3': 'AUS',
#     'population': 940,
#     'gdp': 17737,
#     'corporate_tax_rate': 31},
#    {'name': 'Canada',
#     'iso2': 'CA',
#     'iso3': 'CAN',
#     'population': 741,
#     'gdp': 19104,
#     'corporate_tax_rate': 35},
#    {'name': 'Japan',
#     'iso2': 'JP',
#     'iso3': 'JPN',
#     'population': 538,
#     'gdp': 13695,
#     'corporate_tax_rate': 45},
#    {'source_city': 'Seattle',
#     'name': 'United States',
#     'iso2': 'US',
#     'iso3': 'USA',
#     'population': 126,
#     'gdp': 6785,
#     'corporate_tax_rate': 32},
#    {'name': 'New Zealand',
#     'iso2': 'NZ',
#     'iso3': 'NZL',
#     'population': 914,
#     'gdp': 15761,
#     'corporate_tax_rate': 20},
#    {'source_city': 'Puerto Rico',
#     'name': 'Puerto Rico',
#     'iso2': 'PR',
#     'iso3': 'PRI',
#     'population': 1235,
#     'gdp': 1658,
#     'corporate_tax_rate': 36},
#    {'name': 'Mexico',
#     'iso2': 'MX',
#     'iso3': 'MEX',
#     'population': 991,
#     'gdp': 9714,
#     'corporate_tax_rate': 12},
#    {'name': 'Spain',
#     'iso2': 'ES',
#     'iso3': 'ESP',
#     'population': 1356,
#     'gdp': 5240,
#     'corporate_tax_rate': 25},
#    {'name': 'Taiwan',
#     'iso2': 'TW',
#     'iso3': 'TWN',
#     'population': 791,
#     'gdp': 13575,
#     'corporate_tax_rate': 37},
#    {'name': 'Sweden',
#     'iso2': 'SE',
#     'iso3': 'SWE',
#     'population': 316,
#     'gdp': 15108,
#     'corporate_tax_rate': 31},
#    {'name': "People's Republic of China",
#     'iso2': 'CN',
#     'iso3': 'CHN',
#     'population': 266,
#     'gdp': 67,
#     'corporate_tax_rate': 16},
#    {'name': 'France',
#     'iso2': 'FR',
#     'iso3': 'FRA',
#     'population': 53,
#     'gdp': 11567,
#     'corporate_tax_rate': 38},
#    {'source_city': 'Washington',
#     'name': 'United States',
#     'iso2': 'US',
#     'iso3': 'USA',
#     'population': 911,
#     'gdp': 15617,
#     'corporate_tax_rate': 42},
#    {'name': 'Iceland',
#     'iso2': 'IS',
#     'iso3': 'ISL',
#     'population': 625,
#     'gdp': 1168,
#     'corporate_tax_rate': 33},
#    {'source_city': 'Foster City',
#     'name': 'United States',
#     'iso2': 'US',
#     'iso3': 'USA',
#     'population': 1138,
#     'gdp': 13944,
#     'corporate_tax_rate': 21},
#    {'source_city': 'Foster City',
#     'name': 'United States',
#     'iso2': 'US',
#     'iso3': 'USA',
#     'population': 902,
#     'gdp': 4879,
#     'corporate_tax_rate': 35},
#    {'name': 'Japan',
#     'iso2': 'JP',
#     'iso3': 'JPN',
#     'population': 459,
#     'gdp': 1798,
#     'corporate_tax_rate': 34},
#    {'source_city': 'Foster City',
#     'name': 'United States',
#     'iso2': 'US',
#     'iso3': 'USA',
#     'population': 1334,
#     'gdp': 17644,
#     'corporate_tax_rate': 21},
#    {'source_city': 'California',
#     'name': 'United States',
#     'iso2': 'US',
#     'iso3': 'USA',
#     'population': 526,
#     'gdp': 6694,
#     'corporate_tax_rate': 37},
#    {'source_city': 'Mountain View',
#     'name': 'United States',
#     'iso2': 'US',
#     'iso3': 'USA',
#     'population': 834,
#     'gdp': 7501,
#     'corporate_tax_rate': 31},
#    {'source_city': 'Delaware',
#     'name': 'United States',
#     'iso2': 'US',
#     'iso3': 'USA',
#     'population': 317,
#     'gdp': 6185,
#     'corporate_tax_rate': 11},
#    {'name': 'Taiwan',
#     'iso2': 'TW',
#     'iso3': 'TWN',
#     'population': 148,
#     'gdp': 947,
#     'corporate_tax_rate': 10},
#    {'name': "People's Republic of China",
#     'iso2': 'CN',
#     'iso3': 'CHN',
#     'population': 89,
#     'gdp': 16868,
#     'corporate_tax_rate': 45},
#    {'name': 'Japan',
#     'iso2': 'JP',
#     'iso3': 'JPN',
#     'population': 71,
#     'gdp': 4032,
#     'corporate_tax_rate': 11},
#    {'name': 'Korea', 'population': 881, 'gdp': 4226, 'corporate_tax_rate': 29},
#    {'name': 'United States of America',
#     'iso2': 'US',
#     'iso3': 'USA',
#     'population': 1005,
#     'gdp': 9541,
#     'corporate_tax_rate': 50},
#    {'name': 'United Kingdom',
#     'iso2': 'GB',
#     'iso3': 'GBR',
#     'population': 1244,
#     'gdp': 10011,
#     'corporate_tax_rate': 29},
#    {'source_city': 'Americas',
#     'name': 'Dominican Republic',
#     'iso2': 'DO',
#     'iso3': 'DOM',
#     'population': 310,
#     'gdp': 11531,
#     'corporate_tax_rate': 48},
#    {'source_city': 'Asia-Pacific',
#     'name': 'Indonesia',
#     'iso2': 'ID',
#     'iso3': 'IDN',
#     'population': 1228,
#     'gdp': 937,
#     'corporate_tax_rate': 37},
#    {'name': 'South Korea',
#     'iso2': 'KR',
#     'iso3': 'KOR',
#     'population': 646,
#     'gdp': 5416,
#     'corporate_tax_rate': 23},
#    {'name': 'United Kingdom',
#     'iso2': 'GB',
#     'iso3': 'GBR',
#     'population': 293,
#     'gdp': 9092,
#     'corporate_tax_rate': 34},
#    {'name': 'Australia',
#     'iso2': 'AU',
#     'iso3': 'AUS',
#     'population': 1247,
#     'gdp': 19831,
#     'corporate_tax_rate': 25},
#    {'source_city': 'United States Germany',
#     'name': 'Isle Of Man',
#     'population': 1072,
#     'gdp': 6008,
#     'corporate_tax_rate': 26},
#    {'source_city': 'Latin America',
#     'name': 'Brazi',
#     'population': 655,
#     'gdp': 4076,
#     'corporate_tax_rate': 35},
#    {'name': 'Argentina',
#     'iso2': 'AR',
#     'iso3': 'ARG',
#     'population': 180,
#     'gdp': 10545,
#     'corporate_tax_rate': 35},
#    {'name': 'Mexico',
#     'iso2': 'MX',
#     'iso3': 'MEX',
#     'population': 1260,
#     'gdp': 2025,
#     'corporate_tax_rate': 26},
#    {'name': 'El Salvador',
#     'iso2': 'SV',
#     'iso3': 'SLV',
#     'population': 617,
#     'gdp': 10631,
#     'corporate_tax_rate': 48},
#    {'name': 'Chile',
#     'iso2': 'CL',
#     'iso3': 'CHL',
#     'population': 837,
#     'gdp': 17408,
#     'corporate_tax_rate': 34},
#    {'name': 'Colombia',
#     'iso2': 'CO',
#     'iso3': 'COL',
#     'population': 52,
#     'gdp': 1256,
#     'corporate_tax_rate': 47},
#    {'name': 'Peru',
#     'iso2': 'PE',
#     'iso3': 'PER',
#     'population': 52,
#     'gdp': 3810,
#     'corporate_tax_rate': 33},
#    {'name': 'Costa Rica',
#     'iso2': 'CR',
#     'iso3': 'CRI',
#     'population': 850,
#     'gdp': 5808,
#     'corporate_tax_rate': 46},
#    {'name': 'Dominican Republic',
#     'iso2': 'DO',
#     'iso3': 'DOM',
#     'population': 299,
#     'gdp': 9500,
#     'corporate_tax_rate': 16},
#    {'name': 'Nicaragua',
#     'iso2': 'NI',
#     'iso3': 'NIC',
#     'population': 403,
#     'gdp': 10985,
#     'corporate_tax_rate': 32},
#    {'name': 'Chile',
#     'iso2': 'CL',
#     'iso3': 'CHL',
#     'population': 947,
#     'gdp': 9291,
#     'corporate_tax_rate': 48},
#    {'name': 'Argentina',
#     'iso2': 'AR',
#     'iso3': 'ARG',
#     'population': 349,
#     'gdp': 18772,
#     'corporate_tax_rate': 17},
#    {'source_city': 'Latin America',
#     'name': 'Brazi',
#     'population': 263,
#     'gdp': 10637,
#     'corporate_tax_rate': 31},
#    {'name': 'Uruguay',
#     'iso2': 'UY',
#     'iso3': 'URY',
#     'population': 1343,
#     'gdp': 2508,
#     'corporate_tax_rate': 33},
#    {'name': 'Colombia',
#     'iso2': 'CO',
#     'iso3': 'COL',
#     'population': 1359,
#     'gdp': 11054,
#     'corporate_tax_rate': 38},
#    {'name': 'Peru',
#     'iso2': 'PE',
#     'iso3': 'PER',
#     'population': 172,
#     'gdp': 19947,
#     'corporate_tax_rate': 36},
#    {'name': 'Mexico',
#     'iso2': 'MX',
#     'iso3': 'MEX',
#     'population': 216,
#     'gdp': 5749,
#     'corporate_tax_rate': 24},
#    {'name': 'El Salvador',
#     'iso2': 'SV',
#     'iso3': 'SLV',
#     'population': 1338,
#     'gdp': 1860,
#     'corporate_tax_rate': 49},
#    {'name': 'Dominican Republic',
#     'iso2': 'DO',
#     'iso3': 'DOM',
#     'population': 318,
#     'gdp': 15881,
#     'corporate_tax_rate': 27},
#    {'name': 'Nicaragua',
#     'iso2': 'NI',
#     'iso3': 'NIC',
#     'population': 1276,
#     'gdp': 19607,
#     'corporate_tax_rate': 23},
#    {'name': 'Paraguay',
#     'iso2': 'PY',
#     'iso3': 'PRY',
#     'population': 1381,
#     'gdp': 13087,
#     'corporate_tax_rate': 46},
#    {'name': 'Brazil',
#     'iso2': 'BR',
#     'iso3': 'BRA',
#     'population': 669,
#     'gdp': 12750,
#     'corporate_tax_rate': 12},
#    {'name': 'Honduras',
#     'iso2': 'HN',
#     'iso3': 'HND',
#     'population': 1239,
#     'gdp': 5959,
#     'corporate_tax_rate': 45},
#    {'name': 'Costa Rica',
#     'iso2': 'CR',
#     'iso3': 'CRI',
#     'population': 120,
#     'gdp': 4518,
#     'corporate_tax_rate': 14},
#    {'name': 'Ecuador',
#     'iso2': 'EC',
#     'iso3': 'ECU',
#     'population': 1095,
#     'gdp': 19565,
#     'corporate_tax_rate': 18},
#    {'name': 'Bolivia',
#     'iso2': 'BO',
#     'iso3': 'BOL',
#     'population': 944,
#     'gdp': 3841,
#     'corporate_tax_rate': 10},
#    {'source_city': 'Utah',
#     'name': 'United States',
#     'iso2': 'US',
#     'iso3': 'USA',
#     'population': 226,
#     'gdp': 17110,
#     'corporate_tax_rate': 27},
#    {'source_city': 'Lehi',
#     'name': 'United States',
#     'iso2': 'US',
#     'iso3': 'USA',
#     'population': 594,
#     'gdp': 8652,
#     'corporate_tax_rate': 32},
#    {'name': 'United States of America',
#     'iso2': 'US',
#     'iso3': 'USA',
#     'population': 562,
#     'gdp': 4216,
#     'corporate_tax_rate': 17},
#    {'source_city': 'Scotts Valley',
#     'name': 'United States',
#     'iso2': 'US',
#     'iso3': 'USA',
#     'population': 1058,
#     'gdp': 881,
#     'corporate_tax_rate': 15},
#    {'source_city': 'Santa Clara',
#     'name': 'Cuba',
#     'iso2': 'CU',
#     'iso3': 'CUB',
#     'population': 715,
#     'gdp': 2599,
#     'corporate_tax_rate': 33},
#    {'source_city': 'California',
#     'name': 'United States',
#     'iso2': 'US',
#     'iso3': 'USA',
#     'population': 552,
#     'gdp': 13266,
#     'corporate_tax_rate': 16},
#    {'source_city': 'California',
#     'name': 'United States',
#     'iso2': 'US',
#     'iso3': 'USA',
#     'population': 455,
#     'gdp': 15893,
#     'corporate_tax_rate': 28},
#    {'source_city': 'Middle East',
#     'name': 'Iran',
#     'iso2': 'IR',
#     'iso3': 'IRN',
#     'population': 1342,
#     'gdp': 16678,
#     'corporate_tax_rate': 46},
#    {'source_city': 'Santa Clara',
#     'name': 'Cuba',
#     'iso2': 'CU',
#     'iso3': 'CUB',
#     'population': 54,
#     'gdp': 5697,
#     'corporate_tax_rate': 14},
#    {'name': "People's Republic of China",
#     'iso2': 'CN',
#     'iso3': 'CHN',
#     'population': 818,
#     'gdp': 16145,
#     'corporate_tax_rate': 17},
#    {'name': 'Saudi Arabia',
#     'iso2': 'SA',
#     'iso3': 'SAU',
#     'population': 465,
#     'gdp': 6591,
#     'corporate_tax_rate': 46},
#    {'name': 'Russia',
#     'iso2': 'RU',
#     'iso3': 'RUS',
#     'population': 50,
#     'gdp': 13899,
#     'corporate_tax_rate': 20},
#    {'name': 'Israel',
#     'iso2': 'IL',
#     'iso3': 'ISR',
#     'population': 260,
#     'gdp': 1410,
#     'corporate_tax_rate': 23},
#    {'source_city': 'Greater China',
#     'name': 'Jamaica',
#     'iso2': 'JM',
#     'iso3': 'JAM',
#     'population': 129,
#     'gdp': 3841,
#     'corporate_tax_rate': 20},
#    {'name': 'Australia',
#     'iso2': 'AU',
#     'iso3': 'AUS',
#     'population': 281,
#     'gdp': 17148,
#     'corporate_tax_rate': 41},
#    {'source_city': 'Americas',
#     'name': 'Dominican Republic',
#     'iso2': 'DO',
#     'iso3': 'DOM',
#     'population': 1066,
#     'gdp': 5935,
#     'corporate_tax_rate': 49},
#    {'name': 'Japan',
#     'iso2': 'JP',
#     'iso3': 'JPN',
#     'population': 777,
#     'gdp': 5707,
#     'corporate_tax_rate': 37},
#    {'source_city': 'Cupertino',
#     'name': 'United States',
#     'iso2': 'US',
#     'iso3': 'USA',
#     'population': 256,
#     'gdp': 10831,
#     'corporate_tax_rate': 29},
#    {'source_city': 'Wilmington',
#     'name': 'United States',
#     'iso2': 'US',
#     'iso3': 'USA',
#     'population': 274,
#     'gdp': 6562,
#     'corporate_tax_rate': 13},
#    {'source_city': 'Massachusetts',
#     'name': 'United States',
#     'iso2': 'US',
#     'iso3': 'USA',
#     'population': 1026,
#     'gdp': 15906,
#     'corporate_tax_rate': 18},
#    {'source_city': 'Boston',
#     'name': 'United States',
#     'iso2': 'US',
#     'iso3': 'USA',
#     'population': 83,
#     'gdp': 5503,
#     'corporate_tax_rate': 13},
#    {'name': 'South Korea',
#     'iso2': 'KR',
#     'iso3': 'KOR',
#     'population': 795,
#     'gdp': 12661,
#     'corporate_tax_rate': 18},
#    {'name': 'Germany',
#     'iso2': 'DE',
#     'iso3': 'DEU',
#     'population': 387,
#     'gdp': 2098,
#     'corporate_tax_rate': 37},
#    {'name': 'Netherlands',
#     'iso2': 'NL',
#     'iso3': 'NLD',
#     'population': 394,
#     'gdp': 4616,
#     'corporate_tax_rate': 43},
#    {'name': 'United States of America',
#     'iso2': 'US',
#     'iso3': 'USA',
#     'population': 37,
#     'gdp': 5369,
#     'corporate_tax_rate': 30},
#    {'name': 'United States of America',
#     'iso2': 'US',
#     'iso3': 'USA',
#     'population': 796,
#     'gdp': 6619,
#     'corporate_tax_rate': 21},
#    {'source_city': 'Santa Clara',
#     'name': 'Cuba',
#     'iso2': 'CU',
#     'iso3': 'CUB',
#     'population': 939,
#     'gdp': 16737,
#     'corporate_tax_rate': 40},
#    {'source_city': 'California',
#     'name': 'United States',
#     'iso2': 'US',
#     'iso3': 'USA',
#     'population': 1081,
#     'gdp': 17738,
#     'corporate_tax_rate': 28},
#    {'name': 'United States of America',
#     'iso2': 'US',
#     'iso3': 'USA',
#     'population': 1029,
#     'gdp': 1698,
#     'corporate_tax_rate': 21},
#    {'source_city': 'Delaware',
#     'name': 'United States',
#     'iso2': 'US',
#     'iso3': 'USA',
#     'population': 128,
#     'gdp': 10874,
#     'corporate_tax_rate': 18},
#    {'source_city': 'Santa Clara',
#     'name': 'Cuba',
#     'iso2': 'CU',
#     'iso3': 'CUB',
#     'population': 1270,
#     'gdp': 17601,
#     'corporate_tax_rate': 33},
#    {'source_city': 'California',
#     'name': 'United States',
#     'iso2': 'US',
#     'iso3': 'USA',
#     'population': 572,
#     'gdp': 14189,
#     'corporate_tax_rate': 42},
#    {'name': 'United States of America',
#     'iso2': 'US',
#     'iso3': 'USA',
#     'population': 1075,
#     'gdp': 2172,
#     'corporate_tax_rate': 16},
#    {'source_city': 'Delaware',
#     'name': 'United States',
#     'iso2': 'US',
#     'iso3': 'USA',
#     'population': 1147,
#     'gdp': 19340,
#     'corporate_tax_rate': 27},
#    {'source_city': 'UltraScale',
#     'name': 'Not Found',
#     'population': 215,
#     'gdp': 11634,
#     'corporate_tax_rate': 41},
#    {'source_city': 'UltraScale',
#     'name': 'Not Found',
#     'population': 1162,
#     'gdp': 7452,
#     'corporate_tax_rate': 40},
#    {'source_city': 'Earth',
#     'name': 'United States',
#     'iso2': 'US',
#     'iso3': 'USA',
#     'population': 470,
#     'gdp': 14450,
#     'corporate_tax_rate': 47},
#    {'source_city': 'Wilmington',
#     'name': 'United States',
#     'iso2': 'US',
#     'iso3': 'USA',
#     'population': 950,
#     'gdp': 11204,
#     'corporate_tax_rate': 18},
#    {'source_city': 'Massachusetts',
#     'name': 'United States',
#     'iso2': 'US',
#     'iso3': 'USA',
#     'population': 1384,
#     'gdp': 17387,
#     'corporate_tax_rate': 27},
#    {'source_city': 'Boston',
#     'name': 'United States',
#     'iso2': 'US',
#     'iso3': 'USA',
#     'population': 150,
#     'gdp': 11983,
#     'corporate_tax_rate': 23},
#    {'name': 'South Korea',
#     'iso2': 'KR',
#     'iso3': 'KOR',
#     'population': 1257,
#     'gdp': 4703,
#     'corporate_tax_rate': 30},
#    {'name': 'Germany',
#     'iso2': 'DE',
#     'iso3': 'DEU',
#     'population': 360,
#     'gdp': 12947,
#     'corporate_tax_rate': 48},
#    {'name': 'Netherlands',
#     'iso2': 'NL',
#     'iso3': 'NLD',
#     'population': 1103,
#     'gdp': 15007,
#     'corporate_tax_rate': 40},
#    {'name': 'United States of America',
#     'iso2': 'US',
#     'iso3': 'USA',
#     'population': 426,
#     'gdp': 1269,
#     'corporate_tax_rate': 14},
#    {'name': 'United States of America',
#     'iso2': 'US',
#     'iso3': 'USA',
#     'population': 291,
#     'gdp': 17181,
#     'corporate_tax_rate': 28},
#    {'source_city': 'Greater China',
#     'name': 'Jamaica',
#     'iso2': 'JM',
#     'iso3': 'JAM',
#     'population': 869,
#     'gdp': 17845,
#     'corporate_tax_rate': 43},
#    {'name': 'Australia',
#     'iso2': 'AU',
#     'iso3': 'AUS',
#     'population': 339,
#     'gdp': 13042,
#     'corporate_tax_rate': 27},
#    {'source_city': 'Americas',
#     'name': 'Dominican Republic',
#     'iso2': 'DO',
#     'iso3': 'DOM',
#     'population': 1194,
#     'gdp': 7624,
#     'corporate_tax_rate': 28},
#    {'name': 'Japan',
#     'iso2': 'JP',
#     'iso3': 'JPN',
#     'population': 306,
#     'gdp': 893,
#     'corporate_tax_rate': 42},
#    {'source_city': 'Cupertino',
#     'name': 'United States',
#     'iso2': 'US',
#     'iso3': 'USA',
#     'population': 936,
#     'gdp': 7456,
#     'corporate_tax_rate': 13},
#    {'source_city': 'North America',
#     'name': 'United States',
#     'iso2': 'US',
#     'iso3': 'USA',
#     'population': 433,
#     'gdp': 3203,
#     'corporate_tax_rate': 14},
#    {'name': 'Belarus',
#     'iso2': 'BY',
#     'iso3': 'BLR',
#     'population': 957,
#     'gdp': 2980,
#     'corporate_tax_rate': 39},
#    {'name': 'Israel',
#     'iso2': 'IL',
#     'iso3': 'ISR',
#     'population': 920,
#     'gdp': 11702,
#     'corporate_tax_rate': 45},
#    {'name': 'Ukraine',
#     'iso2': 'UA',
#     'iso3': 'UKR',
#     'population': 101,
#     'gdp': 6666,
#     'corporate_tax_rate': 13},
#    {'name': 'United States of America',
#     'iso2': 'US',
#     'iso3': 'USA',
#     'population': 378,
#     'gdp': 12471,
#     'corporate_tax_rate': 48},
#    {'name': 'Israel',
#     'iso2': 'IL',
#     'iso3': 'ISR',
#     'population': 941,
#     'gdp': 8776,
#     'corporate_tax_rate': 17},
#    {'name': 'United States of America',
#     'iso2': 'US',
#     'iso3': 'USA',
#     'population': 1360,
#     'gdp': 14490,
#     'corporate_tax_rate': 42},
#    {'source_city': 'Ohio River',
#     'name': 'United States',
#     'iso2': 'US',
#     'iso3': 'USA',
#     'population': 492,
#     'gdp': 14060,
#     'corporate_tax_rate': 40},
#    {'source_city': 'North America',
#     'name': 'United States',
#     'iso2': 'US',
#     'iso3': 'USA',
#     'population': 561,
#     'gdp': 1970,
#     'corporate_tax_rate': 13},
#    {'source_city': 'California',
#     'name': 'United States',
#     'iso2': 'US',
#     'iso3': 'USA',
#     'population': 579,
#     'gdp': 3284,
#     'corporate_tax_rate': 22},
#    {'source_city': 'San Jose',
#     'name': 'Costa Rica',
#     'iso2': 'CR',
#     'iso3': 'CRI',
#     'population': 422,
#     'gdp': 15254,
#     'corporate_tax_rate': 44},
#    {'name': "People's Republic of China",
#     'iso2': 'CN',
#     'iso3': 'CHN',
#     'population': 1371,
#     'gdp': 13981,
#     'corporate_tax_rate': 23},
#    {'name': 'United Kingdom',
#     'iso2': 'GB',
#     'iso3': 'GBR',
#     'population': 604,
#     'gdp': 4876,
#     'corporate_tax_rate': 14},
#    {'name': 'United States of America',
#     'iso2': 'US',
#     'iso3': 'USA',
#     'population': 508,
#     'gdp': 566,
#     'corporate_tax_rate': 46},
#    {'name': 'Italy',
#     'iso2': 'IT',
#     'iso3': 'ITA',
#     'population': 549,
#     'gdp': 296,
#     'corporate_tax_rate': 49},
#    {'source_city': 'Orlando',
#     'name': 'United States',
#     'iso2': 'US',
#     'iso3': 'USA',
#     'population': 241,
#     'gdp': 17886,
#     'corporate_tax_rate': 44},
#    {'name': 'United States of America',
#     'iso2': 'US',
#     'iso3': 'USA',
#     'population': 402,
#     'gdp': 13369,
#     'corporate_tax_rate': 34},
#    {'name': 'United States of America',
#     'iso2': 'US',
#     'iso3': 'USA',
#     'population': 719,
#     'gdp': 12609,
#     'corporate_tax_rate': 45},
#    {'name': 'United Kingdom',
#     'iso2': 'GB',
#     'iso3': 'GBR',
#     'population': 836,
#     'gdp': 17415,
#     'corporate_tax_rate': 28},
#    {'name': 'Korea',
#     'population': 125,
#     'gdp': 15808,
#     'corporate_tax_rate': 44},
#    {'name': 'Australia',
#     'iso2': 'AU',
#     'iso3': 'AUS',
#     'population': 940,
#     'gdp': 17737,
#     'corporate_tax_rate': 31},
#    {'name': 'Canada',
#     'iso2': 'CA',
#     'iso3': 'CAN',
#     'population': 741,
#     'gdp': 19104,
#     'corporate_tax_rate': 35},
#    {'name': 'Japan',
#     'iso2': 'JP',
#     'iso3': 'JPN',
#     'population': 538,
#     'gdp': 13695,
#     'corporate_tax_rate': 45},
#    {'source_city': 'Seattle',
#     'name': 'United States',
#     'iso2': 'US',
#     'iso3': 'USA',
#     'population': 126,
#     'gdp': 6785,
#     'corporate_tax_rate': 32},
#    {'name': 'New Zealand',
#     'iso2': 'NZ',
#     'iso3': 'NZL',
#     'population': 914,
#     'gdp': 15761,
#     'corporate_tax_rate': 20},
#    {'source_city': 'Puerto Rico',
#     'name': 'Puerto Rico',
#     'iso2': 'PR',
#     'iso3': 'PRI',
#     'population': 1235,
#     'gdp': 1658,
#     'corporate_tax_rate': 36},
#    {'name': 'Mexico',
#     'iso2': 'MX',
#     'iso3': 'MEX',
#     'population': 991,
#     'gdp': 9714,
#     'corporate_tax_rate': 12},
#    {'name': 'Spain',
#     'iso2': 'ES',
#     'iso3': 'ESP',
#     'population': 1356,
#     'gdp': 5240,
#     'corporate_tax_rate': 25},
#    {'name': 'Taiwan',
#     'iso2': 'TW',
#     'iso3': 'TWN',
#     'population': 791,
#     'gdp': 13575,
#     'corporate_tax_rate': 37},
#    {'name': 'Sweden',
#     'iso2': 'SE',
#     'iso3': 'SWE',
#     'population': 316,
#     'gdp': 15108,
#     'corporate_tax_rate': 31},
#    {'name': "People's Republic of China",
#     'iso2': 'CN',
#     'iso3': 'CHN',
#     'population': 266,
#     'gdp': 67,
#     'corporate_tax_rate': 16},
#    {'name': 'France',
#     'iso2': 'FR',
#     'iso3': 'FRA',
#     'population': 53,
#     'gdp': 11567,
#     'corporate_tax_rate': 38},
#    {'source_city': 'Washington',
#     'name': 'United States',
#     'iso2': 'US',
#     'iso3': 'USA',
#     'population': 911,
#     'gdp': 15617,
#     'corporate_tax_rate': 42},
#    {'name': 'Iceland',
#     'iso2': 'IS',
#     'iso3': 'ISL',
#     'population': 625,
#     'gdp': 1168,
#     'corporate_tax_rate': 33},
#    {'source_city': 'Foster City',
#     'name': 'United States',
#     'iso2': 'US',
#     'iso3': 'USA',
#     'population': 1138,
#     'gdp': 13944,
#     'corporate_tax_rate': 21},
#    {'source_city': 'Foster City',
#     'name': 'United States',
#     'iso2': 'US',
#     'iso3': 'USA',
#     'population': 902,
#     'gdp': 4879,
#     'corporate_tax_rate': 35},
#    {'name': 'Japan',
#     'iso2': 'JP',
#     'iso3': 'JPN',
#     'population': 459,
#     'gdp': 1798,
#     'corporate_tax_rate': 34},
#    {'source_city': 'Foster City',
#     'name': 'United States',
#     'iso2': 'US',
#     'iso3': 'USA',
#     'population': 1334,
#     'gdp': 17644,
#     'corporate_tax_rate': 21},
#    {'source_city': 'California',
#     'name': 'United States',
#     'iso2': 'US',
#     'iso3': 'USA',
#     'population': 526,
#     'gdp': 6694,
#     'corporate_tax_rate': 37},
#    {'source_city': 'Mountain View',
#     'name': 'United States',
#     'iso2': 'US',
#     'iso3': 'USA',
#     'population': 834,
#     'gdp': 7501,
#     'corporate_tax_rate': 31},
#    {'source_city': 'Delaware',
#     'name': 'United States',
#     'iso2': 'US',
#     'iso3': 'USA',
#     'population': 317,
#     'gdp': 6185,
#     'corporate_tax_rate': 11},
#    {'name': 'Taiwan',
#     'iso2': 'TW',
#     'iso3': 'TWN',
#     'population': 148,
#     'gdp': 947,
#     'corporate_tax_rate': 10},
#    {'name': "People's Republic of China",
#     'iso2': 'CN',
#     'iso3': 'CHN',
#     'population': 89,
#     'gdp': 16868,
#     'corporate_tax_rate': 45},
#    {'name': 'Japan',
#     'iso2': 'JP',
#     'iso3': 'JPN',
#     'population': 71,
#     'gdp': 4032,
#     'corporate_tax_rate': 11},
#    {'name': 'Korea', 'population': 881, 'gdp': 4226, 'corporate_tax_rate': 29},
#    {'name': 'United States of America',
#     'iso2': 'US',
#     'iso3': 'USA',
#     'population': 1005,
#     'gdp': 9541,
#     'corporate_tax_rate': 50},
#    {'name': 'United Kingdom',
#     'iso2': 'GB',
#     'iso3': 'GBR',
#     'population': 1244,
#     'gdp': 10011,
#     'corporate_tax_rate': 29},
#    {'source_city': 'Americas',
#     'name': 'Dominican Republic',
#     'iso2': 'DO',
#     'iso3': 'DOM',
#     'population': 310,
#     'gdp': 11531,
#     'corporate_tax_rate': 48},
#    {'source_city': 'Asia-Pacific',
#     'name': 'Indonesia',
#     'iso2': 'ID',
#     'iso3': 'IDN',
#     'population': 1228,
#     'gdp': 937,
#     'corporate_tax_rate': 37},
#    {'name': 'South Korea',
#     'iso2': 'KR',
#     'iso3': 'KOR',
#     'population': 646,
#     'gdp': 5416,
#     'corporate_tax_rate': 23},
#    {'name': 'United Kingdom',
#     'iso2': 'GB',
#     'iso3': 'GBR',
#     'population': 293,
#     'gdp': 9092,
#     'corporate_tax_rate': 34},
#    {'name': 'Australia',
#     'iso2': 'AU',
#     'iso3': 'AUS',
#     'population': 1247,
#     'gdp': 19831,
#     'corporate_tax_rate': 25},
#    {'source_city': 'United States Germany',
#     'name': 'Isle Of Man',
#     'population': 1072,
#     'gdp': 6008,
#     'corporate_tax_rate': 26},
#    {'source_city': 'Latin America',
#     'name': 'Brazi',
#     'population': 655,
#     'gdp': 4076,
#     'corporate_tax_rate': 35},
#    {'name': 'Argentina',
#     'iso2': 'AR',
#     'iso3': 'ARG',
#     'population': 180,
#     'gdp': 10545,
#     'corporate_tax_rate': 35},
#    {'name': 'Mexico',
#     'iso2': 'MX',
#     'iso3': 'MEX',
#     'population': 1260,
#     'gdp': 2025,
#     'corporate_tax_rate': 26},
#    {'name': 'El Salvador',
#     'iso2': 'SV',
#     'iso3': 'SLV',
#     'population': 617,
#     'gdp': 10631,
#     'corporate_tax_rate': 48},
#    {'name': 'Chile',
#     'iso2': 'CL',
#     'iso3': 'CHL',
#     'population': 837,
#     'gdp': 17408,
#     'corporate_tax_rate': 34},
#    {'name': 'Colombia',
#     'iso2': 'CO',
#     'iso3': 'COL',
#     'population': 52,
#     'gdp': 1256,
#     'corporate_tax_rate': 47},
#    {'name': 'Peru',
#     'iso2': 'PE',
#     'iso3': 'PER',
#     'population': 52,
#     'gdp': 3810,
#     'corporate_tax_rate': 33},
#    {'name': 'Costa Rica',
#     'iso2': 'CR',
#     'iso3': 'CRI',
#     'population': 850,
#     'gdp': 5808,
#     'corporate_tax_rate': 46},
#    {'name': 'Dominican Republic',
#     'iso2': 'DO',
#     'iso3': 'DOM',
#     'population': 299,
#     'gdp': 9500,
#     'corporate_tax_rate': 16},
#    {'name': 'Nicaragua',
#     'iso2': 'NI',
#     'iso3': 'NIC',
#     'population': 403,
#     'gdp': 10985,
#     'corporate_tax_rate': 32},
#    {'name': 'Chile',
#     'iso2': 'CL',
#     'iso3': 'CHL',
#     'population': 947,
#     'gdp': 9291,
#     'corporate_tax_rate': 48},
#    {'name': 'Argentina',
#     'iso2': 'AR',
#     'iso3': 'ARG',
#     'population': 349,
#     'gdp': 18772,
#     'corporate_tax_rate': 17},
#    {'source_city': 'Latin America',
#     'name': 'Brazi',
#     'population': 263,
#     'gdp': 10637,
#     'corporate_tax_rate': 31},
#    {'name': 'Uruguay',
#     'iso2': 'UY',
#     'iso3': 'URY',
#     'population': 1343,
#     'gdp': 2508,
#     'corporate_tax_rate': 33},
#    {'name': 'Colombia',
#     'iso2': 'CO',
#     'iso3': 'COL',
#     'population': 1359,
#     'gdp': 11054,
#     'corporate_tax_rate': 38},
#    {'name': 'Peru',
#     'iso2': 'PE',
#     'iso3': 'PER',
#     'population': 172,
#     'gdp': 19947,
#     'corporate_tax_rate': 36},
#    {'name': 'Mexico',
#     'iso2': 'MX',
#     'iso3': 'MEX',
#     'population': 216,
#     'gdp': 5749,
#     'corporate_tax_rate': 24},
#    {'name': 'El Salvador',
#     'iso2': 'SV',
#     'iso3': 'SLV',
#     'population': 1338,
#     'gdp': 1860,
#     'corporate_tax_rate': 49},
#    {'name': 'Dominican Republic',
#     'iso2': 'DO',
#     'iso3': 'DOM',
#     'population': 318,
#     'gdp': 15881,
#     'corporate_tax_rate': 27},
#    {'name': 'Nicaragua',
#     'iso2': 'NI',
#     'iso3': 'NIC',
#     'population': 1276,
#     'gdp': 19607,
#     'corporate_tax_rate': 23},
#    {'name': 'Paraguay',
#     'iso2': 'PY',
#     'iso3': 'PRY',
#     'population': 1381,
#     'gdp': 13087,
#     'corporate_tax_rate': 46},
#    {'name': 'Brazil',
#     'iso2': 'BR',
#     'iso3': 'BRA',
#     'population': 669,
#     'gdp': 12750,
#     'corporate_tax_rate': 12},
#    {'name': 'Honduras',
#     'iso2': 'HN',
#     'iso3': 'HND',
#     'population': 1239,
#     'gdp': 5959,
#     'corporate_tax_rate': 45},
#    {'name': 'Costa Rica',
#     'iso2': 'CR',
#     'iso3': 'CRI',
#     'population': 120,
#     'gdp': 4518,
#     'corporate_tax_rate': 14},
#    {'name': 'Ecuador',
#     'iso2': 'EC',
#     'iso3': 'ECU',
#     'population': 1095,
#     'gdp': 19565,
#     'corporate_tax_rate': 18},
#    {'name': 'Bolivia',
#     'iso2': 'BO',
#     'iso3': 'BOL',
#     'population': 944,
#     'gdp': 3841,
#     'corporate_tax_rate': 10},
#    {'source_city': 'Utah',
#     'name': 'United States',
#     'iso2': 'US',
#     'iso3': 'USA',
#     'population': 226,
#     'gdp': 17110,
#     'corporate_tax_rate': 27},
#    {'source_city': 'Lehi',
#     'name': 'United States',
#     'iso2': 'US',
#     'iso3': 'USA',
#     'population': 594,
#     'gdp': 8652,
#     'corporate_tax_rate': 32},
#    {'name': 'United States of America',
#     'iso2': 'US',
#     'iso3': 'USA',
#     'population': 562,
#     'gdp': 4216,
#     'corporate_tax_rate': 17},
#    {'source_city': 'Scotts Valley',
#     'name': 'United States',
#     'iso2': 'US',
#     'iso3': 'USA',
#     'population': 1058,
#     'gdp': 881,
#     'corporate_tax_rate': 15},
#    {'source_city': 'Santa Clara',
#     'name': 'Cuba',
#     'iso2': 'CU',
#     'iso3': 'CUB',
#     'population': 715,
#     'gdp': 2599,
#     'corporate_tax_rate': 33},
#    {'source_city': 'California',
#     'name': 'United States',
#     'iso2': 'US',
#     'iso3': 'USA',
#     'population': 552,
#     'gdp': 13266,
#     'corporate_tax_rate': 16},
#    {'source_city': 'California',
#     'name': 'United States',
#     'iso2': 'US',
#     'iso3': 'USA',
#     'population': 455,
#     'gdp': 15893,
#     'corporate_tax_rate': 28},
#    {'source_city': 'Middle East',
#     'name': 'Iran',
#     'iso2': 'IR',
#     'iso3': 'IRN',
#     'population': 1342,
#     'gdp': 16678,
#     'corporate_tax_rate': 46},
#    {'source_city': 'Santa Clara',
#     'name': 'Cuba',
#     'iso2': 'CU',
#     'iso3': 'CUB',
#     'population': 54,
#     'gdp': 5697,
#     'corporate_tax_rate': 14},
#    {'name': "People's Republic of China",
#     'iso2': 'CN',
#     'iso3': 'CHN',
#     'population': 818,
#     'gdp': 16145,
#     'corporate_tax_rate': 17},
#    {'name': 'Saudi Arabia',
#     'iso2': 'SA',
#     'iso3': 'SAU',
#     'population': 465,
#     'gdp': 6591,
#     'corporate_tax_rate': 46},
#    {'name': 'Russia',
#     'iso2': 'RU',
#     'iso3': 'RUS',
#     'population': 50,
#     'gdp': 13899,
#     'corporate_tax_rate': 20},
#    {'name': 'Israel',
#     'iso2': 'IL',
#     'iso3': 'ISR',
#     'population': 260,
#     'gdp': 1410,
#     'corporate_tax_rate': 23}],
#   'Industry': [{'name': 'Apple Card',
#     'SIC_code': None,
#     'industry_group': None,
#     'subindustry_desc': None,
#     'primary_activity': None},
#    {'name': 'iPhone',
#     'SIC_code': None,
#     'industry_group': None,
#     'subindustry_desc': None,
#     'primary_activity': None},
#    {'name': 'artificial intelligence',
#     'SIC_code': None,
#     'industry_group': None,
#     'subindustry_desc': None,
#     'primary_activity': None},
#    {'name': 'accounting',
#     'SIC_code': None,
#     'industry_group': None,
#     'subindustry_desc': None,
#     'primary_activity': None},
#    {'name': 'automotive industry',
#     'SIC_code': None,
#     'industry_group': None,
#     'subindustry_desc': None,
#     'primary_activity': None},
#    {'name': 'etching',
#     'SIC_code': None,
#     'industry_group': None,
#     'subindustry_desc': None,
#     'primary_activity': None},
#    {'name': 'electrochemistry',
#     'SIC_code': None,
#     'industry_group': None,
#     'subindustry_desc': None,
#     'primary_activity': None},
#    {'name': 'AMD Instinct',
#     'SIC_code': None,
#     'industry_group': None,
#     'subindustry_desc': None,
#     'primary_activity': None},
#    {'name': 'artificial intelligence',
#     'SIC_code': None,
#     'industry_group': None,
#     'subindustry_desc': None,
#     'primary_activity': None},
#    {'name': 'accounting',
#     'SIC_code': None,
#     'industry_group': None,
#     'subindustry_desc': None,
#     'primary_activity': None},
#    {'name': 'AMD Instinct',
#     'SIC_code': None,
#     'industry_group': None,
#     'subindustry_desc': None,
#     'primary_activity': None},
#    {'name': 'AMD Instinct',
#     'SIC_code': None,
#     'industry_group': None,
#     'subindustry_desc': None,
#     'primary_activity': None},
#    {'name': 'Ryzen',
#     'SIC_code': None,
#     'industry_group': None,
#     'subindustry_desc': None,
#     'primary_activity': None},
#    {'name': 'AMD EPYC',
#     'SIC_code': None,
#     'industry_group': None,
#     'subindustry_desc': None,
#     'primary_activity': None},
#    {'name': 'artificial intelligence',
#     'SIC_code': None,
#     'industry_group': None,
#     'subindustry_desc': None,
#     'primary_activity': None},
#    {'name': 'automotive industry',
#     'SIC_code': None,
#     'industry_group': None,
#     'subindustry_desc': None,
#     'primary_activity': None},
#    {'name': 'etching',
#     'SIC_code': None,
#     'industry_group': None,
#     'subindustry_desc': None,
#     'primary_activity': None},
#    {'name': 'electrochemistry',
#     'SIC_code': None,
#     'industry_group': None,
#     'subindustry_desc': None,
#     'primary_activity': None},
#    {'name': 'ethics of artificial intelligence',
#     'SIC_code': None,
#     'industry_group': None,
#     'subindustry_desc': None,
#     'primary_activity': None},
#    {'name': 'ethics of artificial intelligence',
#     'SIC_code': None,
#     'industry_group': None,
#     'subindustry_desc': None,
#     'primary_activity': None},
#    {'name': 'Apple Card',
#     'SIC_code': None,
#     'industry_group': None,
#     'subindustry_desc': None,
#     'primary_activity': None},
#    {'name': 'iPhone',
#     'SIC_code': None,
#     'industry_group': None,
#     'subindustry_desc': None,
#     'primary_activity': None},
#    {'name': 'CMOS',
#     'SIC_code': None,
#     'industry_group': None,
#     'subindustry_desc': None,
#     'primary_activity': None},
#    {'name': 'artificial intelligence',
#     'SIC_code': None,
#     'industry_group': None,
#     'subindustry_desc': None,
#     'primary_activity': None},
#    {'name': 'computer security',
#     'SIC_code': None,
#     'industry_group': None,
#     'subindustry_desc': None,
#     'primary_activity': None},
#    {'name': 'wireless communication',
#     'SIC_code': None,
#     'industry_group': None,
#     'subindustry_desc': None,
#     'primary_activity': None},
#    {'name': 'operations management',
#     'SIC_code': None,
#     'industry_group': None,
#     'subindustry_desc': None,
#     'primary_activity': None},
#    {'name': 'analysis',
#     'SIC_code': None,
#     'industry_group': None,
#     'subindustry_desc': None,
#     'primary_activity': None},
#    {'name': 'management',
#     'SIC_code': None,
#     'industry_group': None,
#     'subindustry_desc': None,
#     'primary_activity': None},
#    {'name': 'management',
#     'SIC_code': None,
#     'industry_group': None,
#     'subindustry_desc': None,
#     'primary_activity': None},
#    {'name': 'oncology',
#     'SIC_code': None,
#     'industry_group': None,
#     'subindustry_desc': None,
#     'primary_activity': None},
#    {'name': 'automation',
#     'SIC_code': None,
#     'industry_group': None,
#     'subindustry_desc': None,
#     'primary_activity': None},
#    {'name': 'sensor',
#     'SIC_code': None,
#     'industry_group': None,
#     'subindustry_desc': None,
#     'primary_activity': None},
#    {'name': 'building automation',
#     'SIC_code': None,
#     'industry_group': None,
#     'subindustry_desc': None,
#     'primary_activity': None},
#    {'name': 'management',
#     'SIC_code': None,
#     'industry_group': None,
#     'subindustry_desc': None,
#     'primary_activity': None},
#    {'name': 'finance',
#     'SIC_code': None,
#     'industry_group': None,
#     'subindustry_desc': None,
#     'primary_activity': None},
#    {'name': 'self-employment',
#     'SIC_code': None,
#     'industry_group': None,
#     'subindustry_desc': None,
#     'primary_activity': None},
#    {'name': 'artificial intelligence',
#     'SIC_code': None,
#     'industry_group': None,
#     'subindustry_desc': None,
#     'primary_activity': None},
#    {'name': 'accounting',
#     'SIC_code': None,
#     'industry_group': None,
#     'subindustry_desc': None,
#     'primary_activity': None},
#    {'name': 'self-employment',
#     'SIC_code': None,
#     'industry_group': None,
#     'subindustry_desc': None,
#     'primary_activity': None},
#    {'name': 'management',
#     'SIC_code': None,
#     'industry_group': None,
#     'subindustry_desc': None,
#     'primary_activity': None},
#    {'name': 'dynamic random-access memory',
#     'SIC_code': None,
#     'industry_group': None,
#     'subindustry_desc': None,
#     'primary_activity': None},
#    {'name': 'flash memory',
#     'SIC_code': None,
#     'industry_group': None,
#     'subindustry_desc': None,
#     'primary_activity': None},
#    {'name': 'dynamic random-access memory',
#     'SIC_code': None,
#     'industry_group': None,
#     'subindustry_desc': None,
#     'primary_activity': None},
#    {'name': 'High Bandwidth Memory',
#     'SIC_code': None,
#     'industry_group': None,
#     'subindustry_desc': None,
#     'primary_activity': None},
#    {'name': 'flash memory',
#     'SIC_code': None,
#     'industry_group': None,
#     'subindustry_desc': None,
#     'primary_activity': None},
# ...
#     'product_name': 'industrial gases'},
#    {'company_name': 'HiQ Tyres & Autocare', 'product_name': 'specialty gases'},
#    {'company_name': 'HiQ Tyres & Autocare', 'product_name': 'medical gases'},
#    {'company_name': 'Mercado Pago Servicios de Procesamiento S.R.L.',
#     'product_name': 'electronic money transfers'},
#    {'company_name': 'Netlist', 'product_name': 'memory'},
#    {'company_name': 'Lexar Media', 'product_name': 'digital media products'},
#    {'company_name': 'Microsoft', 'product_name': 'BASIC interpreters'},
#    {'company_name': 'Netflix', 'product_name': 'DVD'},
#    {'company_name': 'LSI Logic Corporation', 'product_name': 'computer chip'},
#    {'company_name': 'Nvidia', 'product_name': 'AI) hardware'},
#    {'company_name': 'ATI Technologies', 'product_name': 'southbridge parts'},
#    {'company_name': 'Nvidia', 'product_name': 'graphics hardware'},
#    {'company_name': 'Nvidia', 'product_name': 'southbridge parts'},
#    {'company_name': 'ULI Electronics', 'product_name': 'southbridge parts'},
#    {'company_name': 'Nvidia', 'product_name': 'mobile processors'},
#    {'company_name': 'Nvidia',
#     'product_name': 'vehicle navigation and entertainment systems'},
#    {'company_name': 'Nvidia', 'product_name': 'graphics adapters'},
#    {'company_name': 'Pearl Milling Company', 'product_name': 'syrups'},
#    {'company_name': 'Wimm Bill Dann Foods', 'product_name': 'fruit juices'},
#    {'company_name': 'Wimm Bill Dann Foods', 'product_name': 'yogurt'},
#    {'company_name': 'PepsiCo', 'product_name': 'Frito-Lay snacks'},
#    {'company_name': 'PepsiCo', 'product_name': 'Tropicana juices'},
#    {'company_name': 'LOFT', 'product_name': 'candy'},
#    {'company_name': 'Emagic', 'product_name': 'music software'},
#    {'company_name': 'Emagic', 'product_name': 'computer'},
#    {'company_name': 'Apple Energy, LLC', 'product_name': 'solar energy'},
#    {'company_name': 'Apple Inc.', 'product_name': 'solar energy'},
#    {'company_name': 'Apple', 'product_name': 'mobile handset'},
#    {'company_name': 'Analog Devices',
#     'product_name': 'thick film semiconductors'},
#    {'company_name': 'Analog Devices', 'product_name': 'reference circuits'},
#    {'company_name': 'Analog Devices', 'product_name': 'linear, mixed-signal'},
#    {'company_name': 'KLA-Tencor Corporation',
#     'product_name': 'yield management solutions'},
#    {'company_name': 'Semiconductor Products Group',
#     'product_name': 'and associated technologies'},
#    {'company_name': 'Applied Materials',
#     'product_name': 'solar manufacturing equipment'},
#    {'company_name': 'Applied Materials',
#     'product_name': 'laser cleaning technologies'},
#    {'company_name': 'Applied Materials', 'product_name': 'software'},
#    {'company_name': 'Applied Materials', 'product_name': 'services'},
#    {'company_name': 'Applied Materials', 'product_name': 'equipment'},
#    {'company_name': 'Eteris',
#     'product_name': 'semiconductor processing equipment'},
#    {'company_name': 'Applied Materials',
#     'product_name': 'manufacture of semiconductor (integrated circuit) chips'},
#    {'company_name': 'Applied Materials',
#     'product_name': 'flat panel displays'},
#    {'company_name': 'Oramir', 'product_name': 'laser cleaning technologies'},
#    {'company_name': 'Applied Materials',
#     'product_name': 'semiconductor equipment'},
#    {'company_name': 'Tokyo Electron',
#     'product_name': 'semiconductor equipment'},
#    {'company_name': 'NVIDIA Corporation',
#     'product_name': 'integrated graphics processors'},
#    {'company_name': 'Gaming Products',
#     'product_name': 'portable gaming devices'},
#    {'company_name': 'Advanced Micro Devices',
#     'product_name': 'graphics processors'},
#    {'company_name': 'Advanced Micro Devices',
#     'product_name': 'motherboard chipsets'},
#    {'company_name': 'Advanced Micro Devices',
#     'product_name': 'embedded processors'},
#    {'company_name': 'Advanced Micro Devices',
#     'product_name': 'microchip implant'},
#    {'company_name': 'ATI', 'product_name': 'integrated graphics cards'},
#    {'company_name': 'Advanced Micro Devices',
#     'product_name': 'related technologies'},
#    {'company_name': 'Advanced Micro Devices',
#     'product_name': 'computer processors'},
#    {'company_name': 'Advanced Micro Devices', 'product_name': 'semiconductor'},
#    {'company_name': 'Advanced Micro Devices', 'product_name': 'bipolar chips'},
#    {'company_name': 'ATI Technologies Inc.', 'product_name': 'graphics-card'},
#    {'company_name': 'Audible', 'product_name': 'digital audiobooks'},
#    {'company_name': 'Audible', 'product_name': 'programs'},
#    {'company_name': 'Amazon', 'product_name': 'audiobooks'},
#    {'company_name': 'Amazon', 'product_name': 'groceries'},
#    {'company_name': 'Amazon', 'product_name': 'beauty products'},
#    {'company_name': 'Amazon',
#     'product_name': 'health and personal care products'},
#    {'company_name': 'Amazon', 'product_name': 'gourmet food'},
#    {'company_name': 'Amazon', 'product_name': 'product lining'},
#    {'company_name': 'Amazon', 'product_name': 'movies'},
#    {'company_name': 'Amazon', 'product_name': 'baby products'},
#    {'company_name': 'Amazon', 'product_name': 'Kindle e-readers'},
#    {'company_name': 'Amazon', 'product_name': 'Fire tablets'},
#    {'company_name': 'Amazon', 'product_name': 'Echo devices'},
#    {'company_name': 'Amazon', 'product_name': 'Fire TVs'},
#    {'company_name': 'Amazon', 'product_name': 'batteries'},
#    {'company_name': 'Amazon', 'product_name': 'phone chargers'},
#    {'company_name': 'Toys R Us', 'product_name': 'toys'},
#    {'company_name': 'Toys R Us', 'product_name': 'baby products'},
#    {'company_name': 'Amazon', 'product_name': 'diaper wipes'},
#    {'company_name': 'Analog Devices',
#     'product_name': 'thick film semiconductors'},
#    {'company_name': 'Analog Devices', 'product_name': 'reference circuits'},
#    {'company_name': 'Analog Devices', 'product_name': 'linear, mixed-signal'},
#    {'company_name': 'Semiconductor Products Group',
#     'product_name': 'and associated technologies'},
#    {'company_name': 'KLA-Tencor Corporation',
#     'product_name': 'yield management solutions'},
#    {'company_name': 'Applied Materials', 'product_name': 'services'},
#    {'company_name': 'Applied Materials', 'product_name': 'software'},
#    {'company_name': 'Applied Materials', 'product_name': 'equipment'},
#    {'company_name': 'Eteris',
#     'product_name': 'semiconductor processing equipment'},
#    {'company_name': 'Applied Materials',
#     'product_name': 'flat panel displays'},
#    {'company_name': 'Oramir', 'product_name': 'laser cleaning technologies'},
#    {'company_name': 'Applied Materials',
#     'product_name': 'laser cleaning technologies'},
#    {'company_name': 'Applied Materials',
#     'product_name': 'solar manufacturing equipment'},
#    {'company_name': 'Applied Materials',
#     'product_name': 'semiconductor equipment'},
#    {'company_name': 'Tokyo Electron',
#     'product_name': 'semiconductor equipment'},
#    {'company_name': 'Applied Materials',
#     'product_name': 'manufacture of semiconductor (integrated circuit) chips'},
#    {'company_name': 'Apple', 'product_name': 'iPad accessories'},
#    {'company_name': 'Apple', 'product_name': 'mobile handset'},
#    {'company_name': 'Emagic', 'product_name': 'computer'},
#    {'company_name': 'Apple Inc.', 'product_name': 'solar energy'},
#    {'company_name': 'Apple Energy, LLC', 'product_name': 'solar energy'},
#    {'company_name': 'Booking.com',
#     'product_name': 'accommodation reservation services'},
#    {'company_name': 'Booking Holdings',
#     'product_name': 'hotel distribution services'},
#    {'company_name': 'Agoda',
#     'product_name': 'activities reservation services'},
#    {'company_name': 'Agoda', 'product_name': 'ground transportation'},
#    {'company_name': 'Agoda', 'product_name': 'flight'},
#    {'company_name': 'Booking Holdings',
#     'product_name': 'rental car reservation services'},
#    {'company_name': 'Booking.com', 'product_name': 'Connected Trip'},
#    {'company_name': 'Broadcom',
#     'product_name': 'semiconductor and infrastructure software products'},
#    {'company_name': 'Broadcom', 'product_name': 'SSD controller'},
#    {'company_name': 'Broadcom', 'product_name': 'enterprise security'},
#    {'company_name': 'Cintas', 'product_name': 'shop towels'},
#    {'company_name': 'Cintas', 'product_name': 'corporate identity uniforms'},
#    {'company_name': 'Cintas', 'product_name': 'mats'},
#    {'company_name': 'Cintas', 'product_name': 'products and services'},
#    {'company_name': 'Cintas', 'product_name': 'mops'},
#    {'company_name': 'Cintas', 'product_name': 'safety courses'},
#    {'company_name': 'Cintas',
#     'product_name': 'cleaning and restroom supplies'},
#    {'company_name': 'Cintas', 'product_name': 'first aid and safety products'},
#    {'company_name': 'Kamp Fire Equipment',
#     'product_name': 'fire safety products and services'},
#    {'company_name': 'Cintas',
#     'product_name': 'fire safety products and services'},
#    {'company_name': 'Cintas', 'product_name': 'fire protection'},
#    {'company_name': 'Cisco Systems', 'product_name': 'equipment'},
#    {'company_name': 'Cisco Systems',
#     'product_name': 'mobile network management'},
#    {'company_name': 'Cisco', 'product_name': 'IP phones'},
#    {'company_name': 'Cisco Systems',
#     'product_name': 'high-technology services'},
#    {'company_name': 'Cisco Systems', 'product_name': 'networking hardware'},
#    {'company_name': 'Cisco Systems', 'product_name': 'software'},
#    {'company_name': 'Cisco Systems',
#     'product_name': 'telecommunications equipment'},
#    {'company_name': 'Cisco Systems', 'product_name': 'computer boards'},
#    {'company_name': 'Cisco Systems',
#     'product_name': 'IT products and services'},
#    {'company_name': 'Comcast', 'product_name': 'first-party content'},
#    {'company_name': 'Comcast',
#     'product_name': 'television programming content'},
#    {'company_name': 'Comcast', 'product_name': 'cable'},
#    {'company_name': 'Comcast', 'product_name': 'commercial services'},
#    {'company_name': 'Comcast', 'product_name': 'broadband services'},
#    {'company_name': 'Comcast', 'product_name': 'home telephone service'},
#    {'company_name': 'Greater Philadelphia Cablevision',
#     'product_name': 'cable'},
#    {'company_name': 'Comcast', 'product_name': 'wireless devices'},
#    {'company_name': 'Costco Wholesale', 'product_name': 'vacation packages'},
#    {'company_name': 'Costco Wholesale', 'product_name': 'cruises'},
#    {'company_name': 'Costco Wholesale', 'product_name': 'car rentals'},
#    {'company_name': 'Costco Wholesale', 'product_name': 'hot dogs'},
#    {'company_name': 'Costco Home', 'product_name': 'furniture'},
#    {'company_name': 'Pepsi', 'product_name': 'drinks'},
#    {'company_name': 'Gilead Sciences',
#     'product_name': 'intellectual property'},
#    {'company_name': 'Gilead Sciences', 'product_name': 'hepatitis C.'},
#    {'company_name': 'Raylo Chemicals',
#     'product_name': 'pharmaceutical ingredients'},
#    {'company_name': 'Raylo Chemicals',
#     'product_name': 'advanced intermediates'},
#    {'company_name': 'Honeywell', 'product_name': 'deadly and maiming weapons'},
#    {'company_name': 'Honeywell International',
#     'product_name': 'deadly and maiming weapons'},
#    {'company_name': 'Honeywell', 'product_name': 'cluster bombs'},
#    {'company_name': 'Honeywell International',
#     'product_name': 'cluster bombs'},
#    {'company_name': 'Honeywell International',
#     'product_name': 'photographic equipment'},
#    {'company_name': 'Honeywell International',
#     'product_name': 'personal protective equipment'},
#    {'company_name': 'Honeywell International',
#     'product_name': 'Pentax cameras'},
#    {'company_name': 'Pentax', 'product_name': 'photographic equipment'},
#    {'company_name': 'Honeywell International',
#     'product_name': 'electronic guidance systems'},
#    {'company_name': 'Honeywell International',
#     'product_name': 'secondary power turbine engines'},
#    {'company_name': 'Intel', 'product_name': 'computer components'},
#    {'company_name': 'Intel Israel', 'product_name': 'communications products'},
#    {'company_name': 'Intel', 'product_name': 'semiconductor chip'},
#    {'company_name': 'Intel', 'product_name': 'PC microprocessors'},
#    {'company_name': 'Intel', 'product_name': 'hardware'},
#    {'company_name': 'Compaq', 'product_name': 'PC-compatible systems'},
#    {'company_name': 'ProConnect', 'product_name': 'form updates'},
#    {'company_name': 'Intuit', 'product_name': 'e-commerce tools'},
#    {'company_name': 'Intuit', 'product_name': 'credit cards'},
#    {'company_name': 'Intuitive Surgical Devices',
#     'product_name': 'robotic products'},
#    {'company_name': 'Intuitive Surgical', 'product_name': 'spare part'},
#    {'company_name': 'KLA Corporation',
#     'product_name': 'surface inspection system'},
#    {'company_name': 'ADE', 'product_name': 'silicon wafer metrology'},
#    {'company_name': 'ADE', 'product_name': 'related gear'},
#    {'company_name': 'KLA Corporation KLA Corporation',
#     'product_name': 'yield management'},
#    {'company_name': 'KLA Corporation', 'product_name': 'plasma etch products'},
#    {'company_name': 'Lam Research', 'product_name': 'and services'},
#    {'company_name': 'Lam Research',
#     'product_name': 'innovative wafer fabrication equipment'},
#    {'company_name': 'Lam Research', 'product_name': 'chip equipment'},
#    {'company_name': 'Ontrak', 'product_name': 'chip equipment'},
#    {'company_name': 'Lam Research', 'product_name': 'semiconductor wafer'},
#    {'company_name': 'Lam Research', 'product_name': 'related services'},
#    {'company_name': 'The Linde Group',
#     'product_name': 'merchant and cylinder gases'},
#    {'company_name': 'The Linde Group', 'product_name': 'plant components'},
#    {'company_name': 'The Linde Group', 'product_name': 'synthesis gases'},
#    {'company_name': 'The Linde Group', 'product_name': 'argon'},
#    {'company_name': 'Linde plc', 'product_name': 'debt securities'},
#    {'company_name': 'The Linde Group',
#     'product_name': 'industrial gas products'},
#    {'company_name': 'The Linde Group', 'product_name': 'pipeline complexes'},
#    {'company_name': 'The Linde Group', 'product_name': 'delivery vehicles'},
#    {'company_name': 'Lansing Bagnall', 'product_name': 'forklift'},
#    {'company_name': 'Lincare Holdings', 'product_name': 'home care gas'},
#    {'company_name': 'HiQ Tyres & Autocare',
#     'product_name': 'industrial gases'},
#    {'company_name': 'HiQ Tyres & Autocare', 'product_name': 'specialty gases'},
#    {'company_name': 'HiQ Tyres & Autocare', 'product_name': 'medical gases'},
#    {'company_name': 'Mercado Pago Servicios de Procesamiento S.R.L.',
#     'product_name': 'electronic money transfers'},
#    {'company_name': 'Netlist', 'product_name': 'memory'},
#    {'company_name': 'Lexar Media', 'product_name': 'digital media products'},
#    {'company_name': 'Microsoft', 'product_name': 'BASIC interpreters'},
#    {'company_name': 'Netflix', 'product_name': 'DVD'},
#    {'company_name': 'LSI Logic Corporation', 'product_name': 'computer chip'},
#    {'company_name': 'Nvidia', 'product_name': 'AI) hardware'},
#    {'company_name': 'ATI Technologies', 'product_name': 'southbridge parts'},
#    {'company_name': 'Nvidia', 'product_name': 'graphics hardware'},
#    {'company_name': 'Nvidia', 'product_name': 'southbridge parts'},
#    {'company_name': 'ULI Electronics', 'product_name': 'southbridge parts'},
#    {'company_name': 'Nvidia', 'product_name': 'mobile processors'},
#    {'company_name': 'Nvidia',
#     'product_name': 'vehicle navigation and entertainment systems'},
#    {'company_name': 'Nvidia', 'product_name': 'graphics adapters'},
#    {'company_name': 'Pearl Milling Company', 'product_name': 'syrups'},
#    {'company_name': 'Wimm Bill Dann Foods', 'product_name': 'fruit juices'},
#    {'company_name': 'Wimm Bill Dann Foods', 'product_name': 'yogurt'},
#    {'company_name': 'PepsiCo', 'product_name': 'Frito-Lay snacks'},
#    {'company_name': 'PepsiCo', 'product_name': 'Tropicana juices'},
#    {'company_name': 'LOFT', 'product_name': 'candy'}]}}

# %% [markdown]
# Here we use B24S and modify the scraping script to create a mapping dictionary which maps the ISO-alpha2 Code to the corresponding M49 Code. After scraping the data, we fill in the missing m49 values for each region in the regions dictionary based on the name field.

# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd

url = "https://unstats.un.org/unsd/methodology/m49/overview/"

response = requests.get(url)
soup = BeautifulSoup(response.content, 'html.parser')

table = soup.find('table')

rows = table.find_all('tr')

data = []

for row in rows[1:]: 
    cols = row.find_all('td')
    if len(cols) >= 13:  
        entry = {
            "Global Code": cols[0].text.strip(),
            "Global Name": cols[1].text.strip(),
            "Region Code": cols[2].text.strip(),
            "Region Name": cols[3].text.strip(),
            "Sub-region Code": cols[4].text.strip(),
            "Sub-region Name": cols[5].text.strip(),
            "Intermediate Region Code": cols[6].text.strip(),
            "Intermediate Region Name": cols[7].text.strip(),
            "Country or Area": cols[8].text.strip(),
            "M49 Code": cols[9].text.strip(),
            "ISO-alpha2 Code": cols[10].text.strip(),
            "ISO-alpha3 Code": cols[11].text.strip()
        }
        data.append(entry)

df = pd.DataFrame(data)

print(df["Region Name"].unique())
# Out:
# ['Africa' 'Americas' '' 'Asia' 'Europe' 'Oceania']

# %%
def rename_m49_to_region_code(regions):
    for region in regions['nodes']['Region']:
        region_value = region.get('m49')
        region['region_code'] = region_value
        del region['m49']
    return regions

# Example jsondata to test with
regions = { 
    "nodes": {
        "Region": [
            {"name": "AF", "m49": None}, 
            {"name": "AN", "m49": None},
            {"name": "AS", "m49": None},
            {"name": "EU", "m49": None},
            {"name": "NA", "m49": None},
            {"name": "OC", "m49": None},
            {"name": "SA", "m49": None}
        ]
    }
}

regions = rename_m49_to_region_code(regions)

# Self create a dictionary mapping of region abbreviations to their full names
region_map = {
    "AF": "Africa",
    "AN": "Antarctica",
    "AS": "Asia",
    "EU": "Europe",
    "NA": "Americas",
    "OC": "Oceania",
    "SA": "Americas"
}
def mapping(region_map,regions):
    region_code_mapping = {entry['Region Name']: entry['Region Code'] for entry in data if entry['Region Name'] and entry['Region Code']}

    for region in regions['nodes']['Region']:
        full_region_name = region_map.get(region['name'])

        region['region_code'] = region_code_mapping.get(full_region_name,"") 

    return regions

mapping(region_map,regions)
# Out:
# {'nodes': {'Region': [{'name': 'AF', 'region_code': '002'},
#    {'name': 'AN', 'region_code': ''},
#    {'name': 'AS', 'region_code': '142'},
#    {'name': 'EU', 'region_code': '150'},
#    {'name': 'NA', 'region_code': '019'},
#    {'name': 'OC', 'region_code': '009'},
#    {'name': 'SA', 'region_code': '019'}]}}

# %%
def wrangling(regions):
    """
    Cleans, wrangles, and removes duplicates from the Region data.
    - Rename record m49 to region_code
    - Add values to region code by mapping to data
    - Delete record if both name and region code is null or none
    - Ensures consistent formatting for string fields.
    - Removes duplicates based on 'name' and 'm49'.
    """

    data = rename_m49_to_region_code(regions)
    data = mapping(region_map,data)

    for region in data['nodes']['Region']:
        cleaned_name = region['name'].strip() if region['name'] else ""
        cleaned_region_code = region['region_code'] if region['region_code'] is not None else ""

        key = (cleaned_name, cleaned_region_code)
        data[key] = {"name": cleaned_name,"region_code": cleaned_region_code}

    return list(data.values())

wrangling(merged_json)
# Out:
# [{'Company': [{'name': 'Apple Inc.',
#     'ticker_code': 'AAPL',
#     'founded_year': None},
#    {'name': 'Major League Soccer Mls',
#     'ticker_code': 'MLFB',
#     'founded_year': None},
#    {'name': 'Adobe Inc.', 'ticker_code': 'ADBE', 'founded_year': None},
#    {'name': 'Maxim Integrated Products',
#     'ticker_code': 'MXIM',
#     'founded_year': None},
#    {'name': 'Applied Materials Inc De',
#     'ticker_code': 'AMAT',
#     'founded_year': None},
#    {'name': 'Vantage Systems', 'ticker_code': 'VTAGY', 'founded_year': None},
#    {'name': 'Microsoft', 'ticker_code': 'MSFT', 'founded_year': None},
#    {'name': 'Coolrunner', 'ticker_code': 'CLCO', 'founded_year': None},
#    {'name': 'Amazon Com Inc', 'ticker_code': 'AMZN', 'founded_year': None},
#    {'name': 'Amgen Inc', 'ticker_code': 'AMGN', 'founded_year': None},
#    {'name': 'Alphabet Inc.', 'ticker_code': 'GOOG', 'founded_year': None},
#    {'name': 'Audio Magic', 'ticker_code': 'MGIC', 'founded_year': None},
#    {'name': 'Gemini', 'ticker_code': 'GMNI', 'founded_year': None},
#    {'name': 'Alphabet Inc.', 'ticker_code': 'GOOGL', 'founded_year': None},
#    {'name': 'Booking Holdings Inc.',
#     'ticker_code': 'BKNG',
#     'founded_year': None},
#    {'name': 'Broadcom Inc.', 'ticker_code': 'AVGO', 'founded_year': None},
#    {'name': 'Lsi', 'ticker_code': 'LYTS', 'founded_year': None},
#    {'name': 'Cintas Corp', 'ticker_code': 'CTAS', 'founded_year': None},
#    {'name': 'Workday', 'ticker_code': 'WDAY', 'founded_year': None},
#    {'name': 'Cisco Systems Inc.', 'ticker_code': 'CSCO', 'founded_year': None},
#    {'name': 'Apjc', 'ticker_code': 'APJCX', 'founded_year': None},
#    {'name': 'Splunk', 'ticker_code': 'SPLK', 'founded_year': None},
#    {'name': 'Comcast Corp', 'ticker_code': 'CMCSA', 'founded_year': None},
#    {'name': 'Costco Wholesale Corp New',
#     'ticker_code': 'COST',
#     'founded_year': None},
#    {'name': 'Gilead Sciences Inc.',
#     'ticker_code': 'GILD',
#     'founded_year': None},
#    {'name': 'Tmunity Therapeutics',
#     'ticker_code': 'CTNM',
#     'founded_year': None},
#    {'name': 'Compugen', 'ticker_code': 'CGEN', 'founded_year': None},
#    {'name': 'Arcus Biosciences', 'ticker_code': 'RCUS', 'founded_year': None},
#    {'name': 'Arcellx', 'ticker_code': 'ACLX', 'founded_year': None},
#    {'name': 'Metabolex', 'ticker_code': 'META', 'founded_year': None},
#    {'name': 'Assembly Biosciences',
#     'ticker_code': 'ASMB',
#     'founded_year': None},
#    {'name': 'Daiichi Sankyo', 'ticker_code': 'DSNKY', 'founded_year': None},
#    {'name': 'Nurix', 'ticker_code': 'NRIX', 'founded_year': None},
#    {'name': 'Butz', 'ticker_code': 'BULZ', 'founded_year': None},
#    {'name': 'Intel Corp', 'ticker_code': 'INTC', 'founded_year': None},
#    {'name': 'Intuit Inc.', 'ticker_code': 'INTU', 'founded_year': None},
#    {'name': 'Intuitive Surgical Inc',
#     'ticker_code': 'ISRG',
#     'founded_year': None},
#    {'name': 'Kla Corp', 'ticker_code': 'KLAC', 'founded_year': None},
#    {'name': 'Lam Research Corp', 'ticker_code': 'LRCX', 'founded_year': None},
#    {'name': 'Mercadolibre Inc', 'ticker_code': 'MELI', 'founded_year': None},
#    {'name': 'Nuance Communications',
#     'ticker_code': 'NUAN',
#     'founded_year': None},
#    {'name': 'Reinvent', 'ticker_code': 'RTPZU', 'founded_year': None},
#    {'name': 'Mondelez International Inc.',
#     'ticker_code': 'MDLZ',
#     'founded_year': None},
#    {'name': 'Netflix Inc', 'ticker_code': 'NFLX', 'founded_year': None},
#    {'name': 'Nvidia Corp', 'ticker_code': 'NVDA', 'founded_year': None},
#    {'name': 'Exluna', 'ticker_code': 'LUNA', 'founded_year': None}],
#   'Country': [{'source_city': 'Greater China',
#     'name': 'Jamaica',
#     'iso2': 'JM',
#     'iso3': 'JAM',
#     'population': 129,
#     'gdp': 3841,
#     'corporate_tax_rate': 20},
#    {'name': 'Australia',
#     'iso2': 'AU',
#     'iso3': 'AUS',
#     'population': 281,
#     'gdp': 17148,
#     'corporate_tax_rate': 41},
#    {'source_city': 'Americas',
#     'name': 'Dominican Republic',
#     'iso2': 'DO',
#     'iso3': 'DOM',
#     'population': 1066,
#     'gdp': 5935,
#     'corporate_tax_rate': 49},
#    {'name': 'Japan',
#     'iso2': 'JP',
#     'iso3': 'JPN',
#     'population': 777,
#     'gdp': 5707,
#     'corporate_tax_rate': 37},
#    {'source_city': 'Cupertino',
#     'name': 'United States',
#     'iso2': 'US',
#     'iso3': 'USA',
#     'population': 256,
#     'gdp': 10831,
#     'corporate_tax_rate': 29},
#    {'source_city': 'Wilmington',
#     'name': 'United States',
#     'iso2': 'US',
#     'iso3': 'USA',
#     'population': 274,
#     'gdp': 6562,
#     'corporate_tax_rate': 13},
#    {'source_city': 'Massachusetts',
#     'name': 'United States',
#     'iso2': 'US',
#     'iso3': 'USA',
#     'population': 1026,
#     'gdp': 15906,
#     'corporate_tax_rate': 18},
#    {'source_city': 'Boston',
#     'name': 'United States',
#     'iso2': 'US',
#     'iso3': 'USA',
#     'population': 83,
#     'gdp': 5503,
#     'corporate_tax_rate': 13},
#    {'name': 'South Korea',
#     'iso2': 'KR',
#     'iso3': 'KOR',
#     'population': 795,
#     'gdp': 12661,
#     'corporate_tax_rate': 18},
#    {'name': 'Germany',
#     'iso2': 'DE',
#     'iso3': 'DEU',
#     'population': 387,
#     'gdp': 2098,
#     'corporate_tax_rate': 37},
#    {'name': 'Netherlands',
#     'iso2': 'NL',
#     'iso3': 'NLD',
#     'population': 394,
#     'gdp': 4616,
#     'corporate_tax_rate': 43},
#    {'name': 'United States of America',
#     'iso2': 'US',
#     'iso3': 'USA',
#     'population': 37,
#     'gdp': 5369,
#     'corporate_tax_rate': 30},
#    {'name': 'United States of America',
#     'iso2': 'US',
#     'iso3': 'USA',
#     'population': 796,
#     'gdp': 6619,
#     'corporate_tax_rate': 21},
#    {'source_city': 'Santa Clara',
#     'name': 'Cuba',
#     'iso2': 'CU',
#     'iso3': 'CUB',
#     'population': 939,
#     'gdp': 16737,
#     'corporate_tax_rate': 40},
#    {'source_city': 'California',
#     'name': 'United States',
#     'iso2': 'US',
#     'iso3': 'USA',
#     'population': 1081,
#     'gdp': 17738,
#     'corporate_tax_rate': 28},
#    {'name': 'United States of America',
#     'iso2': 'US',
#     'iso3': 'USA',
#     'population': 1029,
#     'gdp': 1698,
#     'corporate_tax_rate': 21},
#    {'source_city': 'Delaware',
#     'name': 'United States',
#     'iso2': 'US',
#     'iso3': 'USA',
#     'population': 128,
#     'gdp': 10874,
#     'corporate_tax_rate': 18},
#    {'source_city': 'Santa Clara',
#     'name': 'Cuba',
#     'iso2': 'CU',
#     'iso3': 'CUB',
#     'population': 1270,
#     'gdp': 17601,
#     'corporate_tax_rate': 33},
#    {'source_city': 'California',
#     'name': 'United States',
#     'iso2': 'US',
#     'iso3': 'USA',
#     'population': 572,
#     'gdp': 14189,
#     'corporate_tax_rate': 42},
#    {'name': 'United States of America',
#     'iso2': 'US',
#     'iso3': 'USA',
#     'population': 1075,
#     'gdp': 2172,
#     'corporate_tax_rate': 16},
#    {'source_city': 'Delaware',
#     'name': 'United States',
#     'iso2': 'US',
#     'iso3': 'USA',
#     'population': 1147,
#     'gdp': 19340,
#     'corporate_tax_rate': 27},
#    {'source_city': 'UltraScale',
#     'name': 'Not Found',
#     'population': 215,
#     'gdp': 11634,
#     'corporate_tax_rate': 41},
#    {'source_city': 'UltraScale',
#     'name': 'Not Found',
#     'population': 1162,
#     'gdp': 7452,
#     'corporate_tax_rate': 40},
#    {'source_city': 'Earth',
#     'name': 'United States',
#     'iso2': 'US',
#     'iso3': 'USA',
#     'population': 470,
#     'gdp': 14450,
#     'corporate_tax_rate': 47},
#    {'source_city': 'Wilmington',
#     'name': 'United States',
#     'iso2': 'US',
#     'iso3': 'USA',
#     'population': 950,
#     'gdp': 11204,
#     'corporate_tax_rate': 18},
#    {'source_city': 'Massachusetts',
#     'name': 'United States',
#     'iso2': 'US',
#     'iso3': 'USA',
#     'population': 1384,
#     'gdp': 17387,
#     'corporate_tax_rate': 27},
#    {'source_city': 'Boston',
#     'name': 'United States',
#     'iso2': 'US',
#     'iso3': 'USA',
#     'population': 150,
#     'gdp': 11983,
#     'corporate_tax_rate': 23},
#    {'name': 'South Korea',
#     'iso2': 'KR',
#     'iso3': 'KOR',
#     'population': 1257,
#     'gdp': 4703,
#     'corporate_tax_rate': 30},
#    {'name': 'Germany',
#     'iso2': 'DE',
#     'iso3': 'DEU',
#     'population': 360,
#     'gdp': 12947,
#     'corporate_tax_rate': 48},
#    {'name': 'Netherlands',
#     'iso2': 'NL',
#     'iso3': 'NLD',
#     'population': 1103,
#     'gdp': 15007,
#     'corporate_tax_rate': 40},
#    {'name': 'United States of America',
#     'iso2': 'US',
#     'iso3': 'USA',
#     'population': 426,
#     'gdp': 1269,
#     'corporate_tax_rate': 14},
#    {'name': 'United States of America',
#     'iso2': 'US',
#     'iso3': 'USA',
#     'population': 291,
#     'gdp': 17181,
#     'corporate_tax_rate': 28},
#    {'source_city': 'Greater China',
#     'name': 'Jamaica',
#     'iso2': 'JM',
#     'iso3': 'JAM',
#     'population': 869,
#     'gdp': 17845,
#     'corporate_tax_rate': 43},
#    {'name': 'Australia',
#     'iso2': 'AU',
#     'iso3': 'AUS',
#     'population': 339,
#     'gdp': 13042,
#     'corporate_tax_rate': 27},
#    {'source_city': 'Americas',
#     'name': 'Dominican Republic',
#     'iso2': 'DO',
#     'iso3': 'DOM',
#     'population': 1194,
#     'gdp': 7624,
#     'corporate_tax_rate': 28},
#    {'name': 'Japan',
#     'iso2': 'JP',
#     'iso3': 'JPN',
#     'population': 306,
#     'gdp': 893,
#     'corporate_tax_rate': 42},
#    {'source_city': 'Cupertino',
#     'name': 'United States',
#     'iso2': 'US',
#     'iso3': 'USA',
#     'population': 936,
#     'gdp': 7456,
#     'corporate_tax_rate': 13},
#    {'source_city': 'North America',
#     'name': 'United States',
#     'iso2': 'US',
#     'iso3': 'USA',
#     'population': 433,
#     'gdp': 3203,
#     'corporate_tax_rate': 14},
#    {'name': 'Belarus',
#     'iso2': 'BY',
#     'iso3': 'BLR',
#     'population': 957,
#     'gdp': 2980,
#     'corporate_tax_rate': 39},
#    {'name': 'Israel',
#     'iso2': 'IL',
#     'iso3': 'ISR',
#     'population': 920,
#     'gdp': 11702,
#     'corporate_tax_rate': 45},
#    {'name': 'Ukraine',
#     'iso2': 'UA',
#     'iso3': 'UKR',
#     'population': 101,
#     'gdp': 6666,
#     'corporate_tax_rate': 13},
#    {'name': 'United States of America',
#     'iso2': 'US',
#     'iso3': 'USA',
#     'population': 378,
#     'gdp': 12471,
#     'corporate_tax_rate': 48},
#    {'name': 'Israel',
#     'iso2': 'IL',
#     'iso3': 'ISR',
#     'population': 941,
#     'gdp': 8776,
#     'corporate_tax_rate': 17},
#    {'name': 'United States of America',
#     'iso2': 'US',
#     'iso3': 'USA',
#     'population': 1360,
#     'gdp': 14490,
#     'corporate_tax_rate': 42},
#    {'source_city': 'Ohio River',
#     'name': 'United States',
#     'iso2': 'US',
#     'iso3': 'USA',
#     'population': 492,
#     'gdp': 14060,
#     'corporate_tax_rate': 40},
#    {'source_city': 'North America',
#     'name': 'United States',
#     'iso2': 'US',
#     'iso3': 'USA',
#     'population': 561,
#     'gdp': 1970,
#     'corporate_tax_rate': 13},
#    {'source_city': 'California',
#     'name': 'United States',
#     'iso2': 'US',
#     'iso3': 'USA',
#     'population': 579,
#     'gdp': 3284,
#     'corporate_tax_rate': 22},
#    {'source_city': 'San Jose',
#     'name': 'Costa Rica',
#     'iso2': 'CR',
#     'iso3': 'CRI',
#     'population': 422,
#     'gdp': 15254,
#     'corporate_tax_rate': 44},
#    {'name': "People's Republic of China",
#     'iso2': 'CN',
#     'iso3': 'CHN',
#     'population': 1371,
#     'gdp': 13981,
#     'corporate_tax_rate': 23},
#    {'name': 'United Kingdom',
#     'iso2': 'GB',
#     'iso3': 'GBR',
#     'population': 604,
#     'gdp': 4876,
#     'corporate_tax_rate': 14},
#    {'name': 'United States of America',
#     'iso2': 'US',
#     'iso3': 'USA',
#     'population': 508,
#     'gdp': 566,
#     'corporate_tax_rate': 46},
#    {'name': 'Italy',
#     'iso2': 'IT',
#     'iso3': 'ITA',
#     'population': 549,
#     'gdp': 296,
#     'corporate_tax_rate': 49},
#    {'source_city': 'Orlando',
#     'name': 'United States',
#     'iso2': 'US',
#     'iso3': 'USA',
#     'population': 241,
#     'gdp': 17886,
#     'corporate_tax_rate': 44},
#    {'name': 'United States of America',
#     'iso2': 'US',
#     'iso3': 'USA',
#     'population': 402,
#     'gdp': 13369,
#     'corporate_tax_rate': 34},
#    {'name': 'United States of America',
#     'iso2': 'US',
#     'iso3': 'USA',
#     'population': 719,
#     'gdp': 12609,
#     'corporate_tax_rate': 45},
#    {'name': 'United Kingdom',
#     'iso2': 'GB',
#     'iso3': 'GBR',
#     'population': 836,
#     'gdp': 17415,
#     'corporate_tax_rate': 28},
#    {'name': 'Korea',
#     'population': 125,
#     'gdp': 15808,
#     'corporate_tax_rate': 44},
#    {'name': 'Australia',
#     'iso2': 'AU',
#     'iso3': 'AUS',
#     'population': 940,
#     'gdp': 17737,
#     'corporate_tax_rate': 31},
#    {'name': 'Canada',
#     'iso2': 'CA',
#     'iso3': 'CAN',
#     'population': 741,
#     'gdp': 19104,
#     'corporate_tax_rate': 35},
#    {'name': 'Japan',
#     'iso2': 'JP',
#     'iso3': 'JPN',
#     'population': 538,
#     'gdp': 13695,
#     'corporate_tax_rate': 45},
#    {'source_city': 'Seattle',
#     'name': 'United States',
#     'iso2': 'US',
#     'iso3': 'USA',
#     'population': 126,
#     'gdp': 6785,
#     'corporate_tax_rate': 32},
#    {'name': 'New Zealand',
#     'iso2': 'NZ',
#     'iso3': 'NZL',
#     'population': 914,
#     'gdp': 15761,
#     'corporate_tax_rate': 20},
#    {'source_city': 'Puerto Rico',
#     'name': 'Puerto Rico',
#     'iso2': 'PR',
#     'iso3': 'PRI',
#     'population': 1235,
#     'gdp': 1658,
#     'corporate_tax_rate': 36},
#    {'name': 'Mexico',
#     'iso2': 'MX',
#     'iso3': 'MEX',
#     'population': 991,
#     'gdp': 9714,
#     'corporate_tax_rate': 12},
#    {'name': 'Spain',
#     'iso2': 'ES',
#     'iso3': 'ESP',
#     'population': 1356,
#     'gdp': 5240,
#     'corporate_tax_rate': 25},
#    {'name': 'Taiwan',
#     'iso2': 'TW',
#     'iso3': 'TWN',
#     'population': 791,
#     'gdp': 13575,
#     'corporate_tax_rate': 37},
#    {'name': 'Sweden',
#     'iso2': 'SE',
#     'iso3': 'SWE',
#     'population': 316,
#     'gdp': 15108,
#     'corporate_tax_rate': 31},
#    {'name': "People's Republic of China",
#     'iso2': 'CN',
#     'iso3': 'CHN',
#     'population': 266,
#     'gdp': 67,
#     'corporate_tax_rate': 16},
#    {'name': 'France',
#     'iso2': 'FR',
#     'iso3': 'FRA',
#     'population': 53,
#     'gdp': 11567,
#     'corporate_tax_rate': 38},
#    {'source_city': 'Washington',
#     'name': 'United States',
#     'iso2': 'US',
#     'iso3': 'USA',
#     'population': 911,
#     'gdp': 15617,
#     'corporate_tax_rate': 42},
#    {'name': 'Iceland',
#     'iso2': 'IS',
#     'iso3': 'ISL',
#     'population': 625,
#     'gdp': 1168,
#     'corporate_tax_rate': 33},
#    {'source_city': 'Foster City',
#     'name': 'United States',
#     'iso2': 'US',
#     'iso3': 'USA',
#     'population': 1138,
#     'gdp': 13944,
#     'corporate_tax_rate': 21},
#    {'source_city': 'Foster City',
#     'name': 'United States',
#     'iso2': 'US',
#     'iso3': 'USA',
#     'population': 902,
#     'gdp': 4879,
#     'corporate_tax_rate': 35},
#    {'name': 'Japan',
#     'iso2': 'JP',
#     'iso3': 'JPN',
#     'population': 459,
#     'gdp': 1798,
#     'corporate_tax_rate': 34},
#    {'source_city': 'Foster City',
#     'name': 'United States',
#     'iso2': 'US',
#     'iso3': 'USA',
#     'population': 1334,
#     'gdp': 17644,
#     'corporate_tax_rate': 21},
#    {'source_city': 'California',
#     'name': 'United States',
#     'iso2': 'US',
#     'iso3': 'USA',
#     'population': 526,
#     'gdp': 6694,
#     'corporate_tax_rate': 37},
#    {'source_city': 'Mountain View',
#     'name': 'United States',
#     'iso2': 'US',
#     'iso3': 'USA',
#     'population': 834,
#     'gdp': 7501,
#     'corporate_tax_rate': 31},
#    {'source_city': 'Delaware',
#     'name': 'United States',
#     'iso2': 'US',
#     'iso3': 'USA',
#     'population': 317,
#     'gdp': 6185,
#     'corporate_tax_rate': 11},
#    {'name': 'Taiwan',
#     'iso2': 'TW',
#     'iso3': 'TWN',
#     'population': 148,
#     'gdp': 947,
#     'corporate_tax_rate': 10},
#    {'name': "People's Republic of China",
#     'iso2': 'CN',
#     'iso3': 'CHN',
#     'population': 89,
#     'gdp': 16868,
#     'corporate_tax_rate': 45},
#    {'name': 'Japan',
#     'iso2': 'JP',
#     'iso3': 'JPN',
#     'population': 71,
#     'gdp': 4032,
#     'corporate_tax_rate': 11},
#    {'name': 'Korea', 'population': 881, 'gdp': 4226, 'corporate_tax_rate': 29},
#    {'name': 'United States of America',
#     'iso2': 'US',
#     'iso3': 'USA',
#     'population': 1005,
#     'gdp': 9541,
#     'corporate_tax_rate': 50},
#    {'name': 'United Kingdom',
#     'iso2': 'GB',
#     'iso3': 'GBR',
#     'population': 1244,
#     'gdp': 10011,
#     'corporate_tax_rate': 29},
#    {'source_city': 'Americas',
#     'name': 'Dominican Republic',
#     'iso2': 'DO',
#     'iso3': 'DOM',
#     'population': 310,
#     'gdp': 11531,
#     'corporate_tax_rate': 48},
#    {'source_city': 'Asia-Pacific',
#     'name': 'Indonesia',
#     'iso2': 'ID',
#     'iso3': 'IDN',
#     'population': 1228,
#     'gdp': 937,
#     'corporate_tax_rate': 37},
#    {'name': 'South Korea',
#     'iso2': 'KR',
#     'iso3': 'KOR',
#     'population': 646,
#     'gdp': 5416,
#     'corporate_tax_rate': 23},
#    {'name': 'United Kingdom',
#     'iso2': 'GB',
#     'iso3': 'GBR',
#     'population': 293,
#     'gdp': 9092,
#     'corporate_tax_rate': 34},
#    {'name': 'Australia',
#     'iso2': 'AU',
#     'iso3': 'AUS',
#     'population': 1247,
#     'gdp': 19831,
#     'corporate_tax_rate': 25},
#    {'source_city': 'United States Germany',
#     'name': 'Isle Of Man',
#     'population': 1072,
#     'gdp': 6008,
#     'corporate_tax_rate': 26},
#    {'source_city': 'Latin America',
#     'name': 'Brazi',
#     'population': 655,
#     'gdp': 4076,
#     'corporate_tax_rate': 35},
#    {'name': 'Argentina',
#     'iso2': 'AR',
#     'iso3': 'ARG',
#     'population': 180,
#     'gdp': 10545,
#     'corporate_tax_rate': 35},
#    {'name': 'Mexico',
#     'iso2': 'MX',
#     'iso3': 'MEX',
#     'population': 1260,
#     'gdp': 2025,
#     'corporate_tax_rate': 26},
#    {'name': 'El Salvador',
#     'iso2': 'SV',
#     'iso3': 'SLV',
#     'population': 617,
#     'gdp': 10631,
#     'corporate_tax_rate': 48},
#    {'name': 'Chile',
#     'iso2': 'CL',
#     'iso3': 'CHL',
#     'population': 837,
#     'gdp': 17408,
#     'corporate_tax_rate': 34},
#    {'name': 'Colombia',
#     'iso2': 'CO',
#     'iso3': 'COL',
#     'population': 52,
#     'gdp': 1256,
#     'corporate_tax_rate': 47},
#    {'name': 'Peru',
#     'iso2': 'PE',
#     'iso3': 'PER',
#     'population': 52,
#     'gdp': 3810,
#     'corporate_tax_rate': 33},
#    {'name': 'Costa Rica',
#     'iso2': 'CR',
#     'iso3': 'CRI',
#     'population': 850,
#     'gdp': 5808,
#     'corporate_tax_rate': 46},
#    {'name': 'Dominican Republic',
#     'iso2': 'DO',
#     'iso3': 'DOM',
#     'population': 299,
#     'gdp': 9500,
#     'corporate_tax_rate': 16},
#    {'name': 'Nicaragua',
#     'iso2': 'NI',
#     'iso3': 'NIC',
#     'population': 403,
#     'gdp': 10985,
#     'corporate_tax_rate': 32},
#    {'name': 'Chile',
#     'iso2': 'CL',
#     'iso3': 'CHL',
#     'population': 947,
#     'gdp': 9291,
#     'corporate_tax_rate': 48},
#    {'name': 'Argentina',
#     'iso2': 'AR',
#     'iso3': 'ARG',
#     'population': 349,
#     'gdp': 18772,
#     'corporate_tax_rate': 17},
#    {'source_city': 'Latin America',
#     'name': 'Brazi',
#     'population': 263,
#     'gdp': 10637,
#     'corporate_tax_rate': 31},
#    {'name': 'Uruguay',
#     'iso2': 'UY',
#     'iso3': 'URY',
#     'population': 1343,
#     'gdp': 2508,
#     'corporate_tax_rate': 33},
#    {'name': 'Colombia',
#     'iso2': 'CO',
#     'iso3': 'COL',
#     'population': 1359,
#     'gdp': 11054,
#     'corporate_tax_rate': 38},
#    {'name': 'Peru',
#     'iso2': 'PE',
#     'iso3': 'PER',
#     'population': 172,
#     'gdp': 19947,
#     'corporate_tax_rate': 36},
#    {'name': 'Mexico',
#     'iso2': 'MX',
#     'iso3': 'MEX',
#     'population': 216,
#     'gdp': 5749,
#     'corporate_tax_rate': 24},
#    {'name': 'El Salvador',
#     'iso2': 'SV',
#     'iso3': 'SLV',
#     'population': 1338,
#     'gdp': 1860,
#     'corporate_tax_rate': 49},
#    {'name': 'Dominican Republic',
#     'iso2': 'DO',
#     'iso3': 'DOM',
#     'population': 318,
#     'gdp': 15881,
#     'corporate_tax_rate': 27},
#    {'name': 'Nicaragua',
#     'iso2': 'NI',
#     'iso3': 'NIC',
#     'population': 1276,
#     'gdp': 19607,
#     'corporate_tax_rate': 23},
#    {'name': 'Paraguay',
#     'iso2': 'PY',
#     'iso3': 'PRY',
#     'population': 1381,
#     'gdp': 13087,
#     'corporate_tax_rate': 46},
#    {'name': 'Brazil',
#     'iso2': 'BR',
#     'iso3': 'BRA',
#     'population': 669,
#     'gdp': 12750,
#     'corporate_tax_rate': 12},
#    {'name': 'Honduras',
#     'iso2': 'HN',
#     'iso3': 'HND',
#     'population': 1239,
#     'gdp': 5959,
#     'corporate_tax_rate': 45},
#    {'name': 'Costa Rica',
#     'iso2': 'CR',
#     'iso3': 'CRI',
#     'population': 120,
#     'gdp': 4518,
#     'corporate_tax_rate': 14},
#    {'name': 'Ecuador',
#     'iso2': 'EC',
#     'iso3': 'ECU',
#     'population': 1095,
#     'gdp': 19565,
#     'corporate_tax_rate': 18},
#    {'name': 'Bolivia',
#     'iso2': 'BO',
#     'iso3': 'BOL',
#     'population': 944,
#     'gdp': 3841,
#     'corporate_tax_rate': 10},
#    {'source_city': 'Utah',
#     'name': 'United States',
#     'iso2': 'US',
#     'iso3': 'USA',
#     'population': 226,
#     'gdp': 17110,
#     'corporate_tax_rate': 27},
#    {'source_city': 'Lehi',
#     'name': 'United States',
#     'iso2': 'US',
#     'iso3': 'USA',
#     'population': 594,
#     'gdp': 8652,
#     'corporate_tax_rate': 32},
#    {'name': 'United States of America',
#     'iso2': 'US',
#     'iso3': 'USA',
#     'population': 562,
#     'gdp': 4216,
#     'corporate_tax_rate': 17},
#    {'source_city': 'Scotts Valley',
#     'name': 'United States',
#     'iso2': 'US',
#     'iso3': 'USA',
#     'population': 1058,
#     'gdp': 881,
#     'corporate_tax_rate': 15},
#    {'source_city': 'Santa Clara',
#     'name': 'Cuba',
#     'iso2': 'CU',
#     'iso3': 'CUB',
#     'population': 715,
#     'gdp': 2599,
#     'corporate_tax_rate': 33},
#    {'source_city': 'California',
#     'name': 'United States',
#     'iso2': 'US',
#     'iso3': 'USA',
#     'population': 552,
#     'gdp': 13266,
#     'corporate_tax_rate': 16},
#    {'source_city': 'California',
#     'name': 'United States',
#     'iso2': 'US',
#     'iso3': 'USA',
#     'population': 455,
#     'gdp': 15893,
#     'corporate_tax_rate': 28},
#    {'source_city': 'Middle East',
#     'name': 'Iran',
#     'iso2': 'IR',
#     'iso3': 'IRN',
#     'population': 1342,
#     'gdp': 16678,
#     'corporate_tax_rate': 46},
#    {'source_city': 'Santa Clara',
#     'name': 'Cuba',
#     'iso2': 'CU',
#     'iso3': 'CUB',
#     'population': 54,
#     'gdp': 5697,
#     'corporate_tax_rate': 14},
#    {'name': "People's Republic of China",
#     'iso2': 'CN',
#     'iso3': 'CHN',
#     'population': 818,
#     'gdp': 16145,
#     'corporate_tax_rate': 17},
#    {'name': 'Saudi Arabia',
#     'iso2': 'SA',
#     'iso3': 'SAU',
#     'population': 465,
#     'gdp': 6591,
#     'corporate_tax_rate': 46},
#    {'name': 'Russia',
#     'iso2': 'RU',
#     'iso3': 'RUS',
#     'population': 50,
#     'gdp': 13899,
#     'corporate_tax_rate': 20},
#    {'name': 'Israel',
#     'iso2': 'IL',
#     'iso3': 'ISR',
#     'population': 260,
#     'gdp': 1410,
#     'corporate_tax_rate': 23},
#    {'source_city': 'Greater China',
#     'name': 'Jamaica',
#     'iso2': 'JM',
#     'iso3': 'JAM',
#     'population': 129,
#     'gdp': 3841,
#     'corporate_tax_rate': 20},
#    {'name': 'Australia',
#     'iso2': 'AU',
#     'iso3': 'AUS',
#     'population': 281,
#     'gdp': 17148,
#     'corporate_tax_rate': 41},
#    {'source_city': 'Americas',
#     'name': 'Dominican Republic',
#     'iso2': 'DO',
#     'iso3': 'DOM',
#     'population': 1066,
#     'gdp': 5935,
#     'corporate_tax_rate': 49},
#    {'name': 'Japan',
#     'iso2': 'JP',
#     'iso3': 'JPN',
#     'population': 777,
#     'gdp': 5707,
#     'corporate_tax_rate': 37},
#    {'source_city': 'Cupertino',
#     'name': 'United States',
#     'iso2': 'US',
#     'iso3': 'USA',
#     'population': 256,
#     'gdp': 10831,
#     'corporate_tax_rate': 29},
#    {'source_city': 'Wilmington',
#     'name': 'United States',
#     'iso2': 'US',
#     'iso3': 'USA',
#     'population': 274,
#     'gdp': 6562,
#     'corporate_tax_rate': 13},
#    {'source_city': 'Massachusetts',
#     'name': 'United States',
#     'iso2': 'US',
#     'iso3': 'USA',
#     'population': 1026,
#     'gdp': 15906,
#     'corporate_tax_rate': 18},
#    {'source_city': 'Boston',
#     'name': 'United States',
#     'iso2': 'US',
#     'iso3': 'USA',
#     'population': 83,
#     'gdp': 5503,
#     'corporate_tax_rate': 13},
#    {'name': 'South Korea',
#     'iso2': 'KR',
#     'iso3': 'KOR',
#     'population': 795,
#     'gdp': 12661,
#     'corporate_tax_rate': 18},
#    {'name': 'Germany',
#     'iso2': 'DE',
#     'iso3': 'DEU',
#     'population': 387,
#     'gdp': 2098,
#     'corporate_tax_rate': 37},
#    {'name': 'Netherlands',
#     'iso2': 'NL',
#     'iso3': 'NLD',
#     'population': 394,
#     'gdp': 4616,
#     'corporate_tax_rate': 43},
#    {'name': 'United States of America',
#     'iso2': 'US',
#     'iso3': 'USA',
#     'population': 37,
#     'gdp': 5369,
#     'corporate_tax_rate': 30},
#    {'name': 'United States of America',
#     'iso2': 'US',
#     'iso3': 'USA',
#     'population': 796,
#     'gdp': 6619,
#     'corporate_tax_rate': 21},
#    {'source_city': 'Santa Clara',
#     'name': 'Cuba',
#     'iso2': 'CU',
#     'iso3': 'CUB',
#     'population': 939,
#     'gdp': 16737,
#     'corporate_tax_rate': 40},
#    {'source_city': 'California',
#     'name': 'United States',
#     'iso2': 'US',
#     'iso3': 'USA',
#     'population': 1081,
#     'gdp': 17738,
#     'corporate_tax_rate': 28},
#    {'name': 'United States of America',
#     'iso2': 'US',
#     'iso3': 'USA',
#     'population': 1029,
#     'gdp': 1698,
#     'corporate_tax_rate': 21},
#    {'source_city': 'Delaware',
#     'name': 'United States',
#     'iso2': 'US',
#     'iso3': 'USA',
#     'population': 128,
#     'gdp': 10874,
#     'corporate_tax_rate': 18},
#    {'source_city': 'Santa Clara',
#     'name': 'Cuba',
#     'iso2': 'CU',
#     'iso3': 'CUB',
#     'population': 1270,
#     'gdp': 17601,
#     'corporate_tax_rate': 33},
#    {'source_city': 'California',
#     'name': 'United States',
#     'iso2': 'US',
#     'iso3': 'USA',
#     'population': 572,
#     'gdp': 14189,
#     'corporate_tax_rate': 42},
#    {'name': 'United States of America',
#     'iso2': 'US',
#     'iso3': 'USA',
#     'population': 1075,
#     'gdp': 2172,
#     'corporate_tax_rate': 16},
#    {'source_city': 'Delaware',
#     'name': 'United States',
#     'iso2': 'US',
#     'iso3': 'USA',
#     'population': 1147,
#     'gdp': 19340,
#     'corporate_tax_rate': 27},
#    {'source_city': 'UltraScale',
#     'name': 'Not Found',
#     'population': 215,
#     'gdp': 11634,
#     'corporate_tax_rate': 41},
#    {'source_city': 'UltraScale',
#     'name': 'Not Found',
#     'population': 1162,
#     'gdp': 7452,
#     'corporate_tax_rate': 40},
#    {'source_city': 'Earth',
#     'name': 'United States',
#     'iso2': 'US',
#     'iso3': 'USA',
#     'population': 470,
#     'gdp': 14450,
#     'corporate_tax_rate': 47},
#    {'source_city': 'Wilmington',
#     'name': 'United States',
#     'iso2': 'US',
#     'iso3': 'USA',
#     'population': 950,
#     'gdp': 11204,
#     'corporate_tax_rate': 18},
#    {'source_city': 'Massachusetts',
#     'name': 'United States',
#     'iso2': 'US',
#     'iso3': 'USA',
#     'population': 1384,
#     'gdp': 17387,
#     'corporate_tax_rate': 27},
#    {'source_city': 'Boston',
#     'name': 'United States',
#     'iso2': 'US',
#     'iso3': 'USA',
#     'population': 150,
#     'gdp': 11983,
#     'corporate_tax_rate': 23},
#    {'name': 'South Korea',
#     'iso2': 'KR',
#     'iso3': 'KOR',
#     'population': 1257,
#     'gdp': 4703,
#     'corporate_tax_rate': 30},
#    {'name': 'Germany',
#     'iso2': 'DE',
#     'iso3': 'DEU',
#     'population': 360,
#     'gdp': 12947,
#     'corporate_tax_rate': 48},
#    {'name': 'Netherlands',
#     'iso2': 'NL',
#     'iso3': 'NLD',
#     'population': 1103,
#     'gdp': 15007,
#     'corporate_tax_rate': 40},
#    {'name': 'United States of America',
#     'iso2': 'US',
#     'iso3': 'USA',
#     'population': 426,
#     'gdp': 1269,
#     'corporate_tax_rate': 14},
#    {'name': 'United States of America',
#     'iso2': 'US',
#     'iso3': 'USA',
#     'population': 291,
#     'gdp': 17181,
#     'corporate_tax_rate': 28},
#    {'source_city': 'Greater China',
#     'name': 'Jamaica',
#     'iso2': 'JM',
#     'iso3': 'JAM',
#     'population': 869,
#     'gdp': 17845,
#     'corporate_tax_rate': 43},
#    {'name': 'Australia',
#     'iso2': 'AU',
#     'iso3': 'AUS',
#     'population': 339,
#     'gdp': 13042,
#     'corporate_tax_rate': 27},
#    {'source_city': 'Americas',
#     'name': 'Dominican Republic',
#     'iso2': 'DO',
#     'iso3': 'DOM',
#     'population': 1194,
#     'gdp': 7624,
#     'corporate_tax_rate': 28},
#    {'name': 'Japan',
#     'iso2': 'JP',
#     'iso3': 'JPN',
#     'population': 306,
#     'gdp': 893,
#     'corporate_tax_rate': 42},
#    {'source_city': 'Cupertino',
#     'name': 'United States',
#     'iso2': 'US',
#     'iso3': 'USA',
#     'population': 936,
#     'gdp': 7456,
#     'corporate_tax_rate': 13},
#    {'source_city': 'North America',
#     'name': 'United States',
#     'iso2': 'US',
#     'iso3': 'USA',
#     'population': 433,
#     'gdp': 3203,
#     'corporate_tax_rate': 14},
#    {'name': 'Belarus',
#     'iso2': 'BY',
#     'iso3': 'BLR',
#     'population': 957,
#     'gdp': 2980,
#     'corporate_tax_rate': 39},
#    {'name': 'Israel',
#     'iso2': 'IL',
#     'iso3': 'ISR',
#     'population': 920,
#     'gdp': 11702,
#     'corporate_tax_rate': 45},
#    {'name': 'Ukraine',
#     'iso2': 'UA',
#     'iso3': 'UKR',
#     'population': 101,
#     'gdp': 6666,
#     'corporate_tax_rate': 13},
#    {'name': 'United States of America',
#     'iso2': 'US',
#     'iso3': 'USA',
#     'population': 378,
#     'gdp': 12471,
#     'corporate_tax_rate': 48},
#    {'name': 'Israel',
#     'iso2': 'IL',
#     'iso3': 'ISR',
#     'population': 941,
#     'gdp': 8776,
#     'corporate_tax_rate': 17},
#    {'name': 'United States of America',
#     'iso2': 'US',
#     'iso3': 'USA',
#     'population': 1360,
#     'gdp': 14490,
#     'corporate_tax_rate': 42},
#    {'source_city': 'Ohio River',
#     'name': 'United States',
#     'iso2': 'US',
#     'iso3': 'USA',
#     'population': 492,
#     'gdp': 14060,
#     'corporate_tax_rate': 40},
#    {'source_city': 'North America',
#     'name': 'United States',
#     'iso2': 'US',
#     'iso3': 'USA',
#     'population': 561,
#     'gdp': 1970,
#     'corporate_tax_rate': 13},
#    {'source_city': 'California',
#     'name': 'United States',
#     'iso2': 'US',
#     'iso3': 'USA',
#     'population': 579,
#     'gdp': 3284,
#     'corporate_tax_rate': 22},
#    {'source_city': 'San Jose',
#     'name': 'Costa Rica',
#     'iso2': 'CR',
#     'iso3': 'CRI',
#     'population': 422,
#     'gdp': 15254,
#     'corporate_tax_rate': 44},
#    {'name': "People's Republic of China",
#     'iso2': 'CN',
#     'iso3': 'CHN',
#     'population': 1371,
#     'gdp': 13981,
#     'corporate_tax_rate': 23},
#    {'name': 'United Kingdom',
#     'iso2': 'GB',
#     'iso3': 'GBR',
#     'population': 604,
#     'gdp': 4876,
#     'corporate_tax_rate': 14},
#    {'name': 'United States of America',
#     'iso2': 'US',
#     'iso3': 'USA',
#     'population': 508,
#     'gdp': 566,
#     'corporate_tax_rate': 46},
#    {'name': 'Italy',
#     'iso2': 'IT',
#     'iso3': 'ITA',
#     'population': 549,
#     'gdp': 296,
#     'corporate_tax_rate': 49},
#    {'source_city': 'Orlando',
#     'name': 'United States',
#     'iso2': 'US',
#     'iso3': 'USA',
#     'population': 241,
#     'gdp': 17886,
#     'corporate_tax_rate': 44},
#    {'name': 'United States of America',
#     'iso2': 'US',
#     'iso3': 'USA',
#     'population': 402,
#     'gdp': 13369,
#     'corporate_tax_rate': 34},
#    {'name': 'United States of America',
#     'iso2': 'US',
#     'iso3': 'USA',
#     'population': 719,
#     'gdp': 12609,
#     'corporate_tax_rate': 45},
#    {'name': 'United Kingdom',
#     'iso2': 'GB',
#     'iso3': 'GBR',
#     'population': 836,
#     'gdp': 17415,
#     'corporate_tax_rate': 28},
#    {'name': 'Korea',
#     'population': 125,
#     'gdp': 15808,
#     'corporate_tax_rate': 44},
#    {'name': 'Australia',
#     'iso2': 'AU',
#     'iso3': 'AUS',
#     'population': 940,
#     'gdp': 17737,
#     'corporate_tax_rate': 31},
#    {'name': 'Canada',
#     'iso2': 'CA',
#     'iso3': 'CAN',
#     'population': 741,
#     'gdp': 19104,
#     'corporate_tax_rate': 35},
#    {'name': 'Japan',
#     'iso2': 'JP',
#     'iso3': 'JPN',
#     'population': 538,
#     'gdp': 13695,
#     'corporate_tax_rate': 45},
#    {'source_city': 'Seattle',
#     'name': 'United States',
#     'iso2': 'US',
#     'iso3': 'USA',
#     'population': 126,
#     'gdp': 6785,
#     'corporate_tax_rate': 32},
#    {'name': 'New Zealand',
#     'iso2': 'NZ',
#     'iso3': 'NZL',
#     'population': 914,
#     'gdp': 15761,
#     'corporate_tax_rate': 20},
#    {'source_city': 'Puerto Rico',
#     'name': 'Puerto Rico',
#     'iso2': 'PR',
#     'iso3': 'PRI',
#     'population': 1235,
#     'gdp': 1658,
#     'corporate_tax_rate': 36},
#    {'name': 'Mexico',
#     'iso2': 'MX',
#     'iso3': 'MEX',
#     'population': 991,
#     'gdp': 9714,
#     'corporate_tax_rate': 12},
#    {'name': 'Spain',
#     'iso2': 'ES',
#     'iso3': 'ESP',
#     'population': 1356,
#     'gdp': 5240,
#     'corporate_tax_rate': 25},
#    {'name': 'Taiwan',
#     'iso2': 'TW',
#     'iso3': 'TWN',
#     'population': 791,
#     'gdp': 13575,
#     'corporate_tax_rate': 37},
#    {'name': 'Sweden',
#     'iso2': 'SE',
#     'iso3': 'SWE',
#     'population': 316,
#     'gdp': 15108,
#     'corporate_tax_rate': 31},
#    {'name': "People's Republic of China",
#     'iso2': 'CN',
#     'iso3': 'CHN',
#     'population': 266,
#     'gdp': 67,
#     'corporate_tax_rate': 16},
#    {'name': 'France',
#     'iso2': 'FR',
#     'iso3': 'FRA',
#     'population': 53,
#     'gdp': 11567,
#     'corporate_tax_rate': 38},
#    {'source_city': 'Washington',
#     'name': 'United States',
#     'iso2': 'US',
#     'iso3': 'USA',
#     'population': 911,
#     'gdp': 15617,
#     'corporate_tax_rate': 42},
#    {'name': 'Iceland',
#     'iso2': 'IS',
#     'iso3': 'ISL',
#     'population': 625,
#     'gdp': 1168,
#     'corporate_tax_rate': 33},
#    {'source_city': 'Foster City',
#     'name': 'United States',
#     'iso2': 'US',
#     'iso3': 'USA',
#     'population': 1138,
#     'gdp': 13944,
#     'corporate_tax_rate': 21},
#    {'source_city': 'Foster City',
#     'name': 'United States',
#     'iso2': 'US',
#     'iso3': 'USA',
#     'population': 902,
#     'gdp': 4879,
#     'corporate_tax_rate': 35},
#    {'name': 'Japan',
#     'iso2': 'JP',
#     'iso3': 'JPN',
#     'population': 459,
#     'gdp': 1798,
#     'corporate_tax_rate': 34},
#    {'source_city': 'Foster City',
#     'name': 'United States',
#     'iso2': 'US',
#     'iso3': 'USA',
#     'population': 1334,
#     'gdp': 17644,
#     'corporate_tax_rate': 21},
#    {'source_city': 'California',
#     'name': 'United States',
#     'iso2': 'US',
#     'iso3': 'USA',
#     'population': 526,
#     'gdp': 6694,
#     'corporate_tax_rate': 37},
#    {'source_city': 'Mountain View',
#     'name': 'United States',
#     'iso2': 'US',
#     'iso3': 'USA',
#     'population': 834,
#     'gdp': 7501,
#     'corporate_tax_rate': 31},
#    {'source_city': 'Delaware',
#     'name': 'United States',
#     'iso2': 'US',
#     'iso3': 'USA',
#     'population': 317,
#     'gdp': 6185,
#     'corporate_tax_rate': 11},
#    {'name': 'Taiwan',
#     'iso2': 'TW',
#     'iso3': 'TWN',
#     'population': 148,
#     'gdp': 947,
#     'corporate_tax_rate': 10},
#    {'name': "People's Republic of China",
#     'iso2': 'CN',
#     'iso3': 'CHN',
#     'population': 89,
#     'gdp': 16868,
#     'corporate_tax_rate': 45},
#    {'name': 'Japan',
#     'iso2': 'JP',
#     'iso3': 'JPN',
#     'population': 71,
#     'gdp': 4032,
#     'corporate_tax_rate': 11},
#    {'name': 'Korea', 'population': 881, 'gdp': 4226, 'corporate_tax_rate': 29},
#    {'name': 'United States of America',
#     'iso2': 'US',
#     'iso3': 'USA',
#     'population': 1005,
#     'gdp': 9541,
#     'corporate_tax_rate': 50},
#    {'name': 'United Kingdom',
#     'iso2': 'GB',
#     'iso3': 'GBR',
#     'population': 1244,
#     'gdp': 10011,
#     'corporate_tax_rate': 29},
#    {'source_city': 'Americas',
#     'name': 'Dominican Republic',
#     'iso2': 'DO',
#     'iso3': 'DOM',
#     'population': 310,
#     'gdp': 11531,
#     'corporate_tax_rate': 48},
#    {'source_city': 'Asia-Pacific',
#     'name': 'Indonesia',
#     'iso2': 'ID',
#     'iso3': 'IDN',
#     'population': 1228,
#     'gdp': 937,
#     'corporate_tax_rate': 37},
#    {'name': 'South Korea',
#     'iso2': 'KR',
#     'iso3': 'KOR',
#     'population': 646,
#     'gdp': 5416,
#     'corporate_tax_rate': 23},
#    {'name': 'United Kingdom',
#     'iso2': 'GB',
#     'iso3': 'GBR',
#     'population': 293,
#     'gdp': 9092,
#     'corporate_tax_rate': 34},
#    {'name': 'Australia',
#     'iso2': 'AU',
#     'iso3': 'AUS',
#     'population': 1247,
#     'gdp': 19831,
#     'corporate_tax_rate': 25},
#    {'source_city': 'United States Germany',
#     'name': 'Isle Of Man',
#     'population': 1072,
#     'gdp': 6008,
#     'corporate_tax_rate': 26},
#    {'source_city': 'Latin America',
#     'name': 'Brazi',
#     'population': 655,
#     'gdp': 4076,
#     'corporate_tax_rate': 35},
#    {'name': 'Argentina',
#     'iso2': 'AR',
#     'iso3': 'ARG',
#     'population': 180,
#     'gdp': 10545,
#     'corporate_tax_rate': 35},
#    {'name': 'Mexico',
#     'iso2': 'MX',
#     'iso3': 'MEX',
#     'population': 1260,
#     'gdp': 2025,
#     'corporate_tax_rate': 26},
#    {'name': 'El Salvador',
#     'iso2': 'SV',
#     'iso3': 'SLV',
#     'population': 617,
#     'gdp': 10631,
#     'corporate_tax_rate': 48},
#    {'name': 'Chile',
#     'iso2': 'CL',
#     'iso3': 'CHL',
#     'population': 837,
#     'gdp': 17408,
#     'corporate_tax_rate': 34},
#    {'name': 'Colombia',
#     'iso2': 'CO',
#     'iso3': 'COL',
#     'population': 52,
#     'gdp': 1256,
#     'corporate_tax_rate': 47},
#    {'name': 'Peru',
#     'iso2': 'PE',
#     'iso3': 'PER',
#     'population': 52,
#     'gdp': 3810,
#     'corporate_tax_rate': 33},
#    {'name': 'Costa Rica',
#     'iso2': 'CR',
#     'iso3': 'CRI',
#     'population': 850,
#     'gdp': 5808,
#     'corporate_tax_rate': 46},
#    {'name': 'Dominican Republic',
#     'iso2': 'DO',
#     'iso3': 'DOM',
#     'population': 299,
#     'gdp': 9500,
#     'corporate_tax_rate': 16},
#    {'name': 'Nicaragua',
#     'iso2': 'NI',
#     'iso3': 'NIC',
#     'population': 403,
#     'gdp': 10985,
#     'corporate_tax_rate': 32},
#    {'name': 'Chile',
#     'iso2': 'CL',
#     'iso3': 'CHL',
#     'population': 947,
#     'gdp': 9291,
#     'corporate_tax_rate': 48},
#    {'name': 'Argentina',
#     'iso2': 'AR',
#     'iso3': 'ARG',
#     'population': 349,
#     'gdp': 18772,
#     'corporate_tax_rate': 17},
#    {'source_city': 'Latin America',
#     'name': 'Brazi',
#     'population': 263,
#     'gdp': 10637,
#     'corporate_tax_rate': 31},
#    {'name': 'Uruguay',
#     'iso2': 'UY',
#     'iso3': 'URY',
#     'population': 1343,
#     'gdp': 2508,
#     'corporate_tax_rate': 33},
#    {'name': 'Colombia',
#     'iso2': 'CO',
#     'iso3': 'COL',
#     'population': 1359,
#     'gdp': 11054,
#     'corporate_tax_rate': 38},
#    {'name': 'Peru',
#     'iso2': 'PE',
#     'iso3': 'PER',
#     'population': 172,
#     'gdp': 19947,
#     'corporate_tax_rate': 36},
#    {'name': 'Mexico',
#     'iso2': 'MX',
#     'iso3': 'MEX',
#     'population': 216,
#     'gdp': 5749,
#     'corporate_tax_rate': 24},
#    {'name': 'El Salvador',
#     'iso2': 'SV',
#     'iso3': 'SLV',
#     'population': 1338,
#     'gdp': 1860,
#     'corporate_tax_rate': 49},
#    {'name': 'Dominican Republic',
#     'iso2': 'DO',
#     'iso3': 'DOM',
#     'population': 318,
#     'gdp': 15881,
#     'corporate_tax_rate': 27},
#    {'name': 'Nicaragua',
#     'iso2': 'NI',
#     'iso3': 'NIC',
#     'population': 1276,
#     'gdp': 19607,
#     'corporate_tax_rate': 23},
#    {'name': 'Paraguay',
#     'iso2': 'PY',
#     'iso3': 'PRY',
#     'population': 1381,
#     'gdp': 13087,
#     'corporate_tax_rate': 46},
#    {'name': 'Brazil',
#     'iso2': 'BR',
#     'iso3': 'BRA',
#     'population': 669,
#     'gdp': 12750,
#     'corporate_tax_rate': 12},
#    {'name': 'Honduras',
#     'iso2': 'HN',
#     'iso3': 'HND',
#     'population': 1239,
#     'gdp': 5959,
#     'corporate_tax_rate': 45},
#    {'name': 'Costa Rica',
#     'iso2': 'CR',
#     'iso3': 'CRI',
#     'population': 120,
#     'gdp': 4518,
#     'corporate_tax_rate': 14},
#    {'name': 'Ecuador',
#     'iso2': 'EC',
#     'iso3': 'ECU',
#     'population': 1095,
#     'gdp': 19565,
#     'corporate_tax_rate': 18},
#    {'name': 'Bolivia',
#     'iso2': 'BO',
#     'iso3': 'BOL',
#     'population': 944,
#     'gdp': 3841,
#     'corporate_tax_rate': 10},
#    {'source_city': 'Utah',
#     'name': 'United States',
#     'iso2': 'US',
#     'iso3': 'USA',
#     'population': 226,
#     'gdp': 17110,
#     'corporate_tax_rate': 27},
#    {'source_city': 'Lehi',
#     'name': 'United States',
#     'iso2': 'US',
#     'iso3': 'USA',
#     'population': 594,
#     'gdp': 8652,
#     'corporate_tax_rate': 32},
#    {'name': 'United States of America',
#     'iso2': 'US',
#     'iso3': 'USA',
#     'population': 562,
#     'gdp': 4216,
#     'corporate_tax_rate': 17},
#    {'source_city': 'Scotts Valley',
#     'name': 'United States',
#     'iso2': 'US',
#     'iso3': 'USA',
#     'population': 1058,
#     'gdp': 881,
#     'corporate_tax_rate': 15},
#    {'source_city': 'Santa Clara',
#     'name': 'Cuba',
#     'iso2': 'CU',
#     'iso3': 'CUB',
#     'population': 715,
#     'gdp': 2599,
#     'corporate_tax_rate': 33},
#    {'source_city': 'California',
#     'name': 'United States',
#     'iso2': 'US',
#     'iso3': 'USA',
#     'population': 552,
#     'gdp': 13266,
#     'corporate_tax_rate': 16},
#    {'source_city': 'California',
#     'name': 'United States',
#     'iso2': 'US',
#     'iso3': 'USA',
#     'population': 455,
#     'gdp': 15893,
#     'corporate_tax_rate': 28},
#    {'source_city': 'Middle East',
#     'name': 'Iran',
#     'iso2': 'IR',
#     'iso3': 'IRN',
#     'population': 1342,
#     'gdp': 16678,
#     'corporate_tax_rate': 46},
#    {'source_city': 'Santa Clara',
#     'name': 'Cuba',
#     'iso2': 'CU',
#     'iso3': 'CUB',
#     'population': 54,
#     'gdp': 5697,
#     'corporate_tax_rate': 14},
#    {'name': "People's Republic of China",
#     'iso2': 'CN',
#     'iso3': 'CHN',
#     'population': 818,
#     'gdp': 16145,
#     'corporate_tax_rate': 17},
#    {'name': 'Saudi Arabia',
#     'iso2': 'SA',
#     'iso3': 'SAU',
#     'population': 465,
#     'gdp': 6591,
#     'corporate_tax_rate': 46},
#    {'name': 'Russia',
#     'iso2': 'RU',
#     'iso3': 'RUS',
#     'population': 50,
#     'gdp': 13899,
#     'corporate_tax_rate': 20},
#    {'name': 'Israel',
#     'iso2': 'IL',
#     'iso3': 'ISR',
#     'population': 260,
#     'gdp': 1410,
#     'corporate_tax_rate': 23}],
#   'Industry': [{'name': 'Apple Card',
#     'SIC_code': None,
#     'industry_group': None,
#     'subindustry_desc': None,
#     'primary_activity': None},
#    {'name': 'iPhone',
#     'SIC_code': None,
#     'industry_group': None,
#     'subindustry_desc': None,
#     'primary_activity': None},
#    {'name': 'artificial intelligence',
#     'SIC_code': None,
#     'industry_group': None,
#     'subindustry_desc': None,
#     'primary_activity': None},
#    {'name': 'accounting',
#     'SIC_code': None,
#     'industry_group': None,
#     'subindustry_desc': None,
#     'primary_activity': None},
#    {'name': 'automotive industry',
#     'SIC_code': None,
#     'industry_group': None,
#     'subindustry_desc': None,
#     'primary_activity': None},
#    {'name': 'etching',
#     'SIC_code': None,
#     'industry_group': None,
#     'subindustry_desc': None,
#     'primary_activity': None},
#    {'name': 'electrochemistry',
#     'SIC_code': None,
#     'industry_group': None,
#     'subindustry_desc': None,
#     'primary_activity': None},
#    {'name': 'AMD Instinct',
#     'SIC_code': None,
#     'industry_group': None,
#     'subindustry_desc': None,
#     'primary_activity': None},
#    {'name': 'artificial intelligence',
#     'SIC_code': None,
#     'industry_group': None,
#     'subindustry_desc': None,
#     'primary_activity': None},
#    {'name': 'accounting',
#     'SIC_code': None,
#     'industry_group': None,
#     'subindustry_desc': None,
#     'primary_activity': None},
#    {'name': 'AMD Instinct',
#     'SIC_code': None,
#     'industry_group': None,
#     'subindustry_desc': None,
#     'primary_activity': None},
#    {'name': 'AMD Instinct',
#     'SIC_code': None,
#     'industry_group': None,
#     'subindustry_desc': None,
#     'primary_activity': None},
#    {'name': 'Ryzen',
#     'SIC_code': None,
#     'industry_group': None,
#     'subindustry_desc': None,
#     'primary_activity': None},
#    {'name': 'AMD EPYC',
#     'SIC_code': None,
#     'industry_group': None,
#     'subindustry_desc': None,
#     'primary_activity': None},
#    {'name': 'artificial intelligence',
#     'SIC_code': None,
#     'industry_group': None,
#     'subindustry_desc': None,
#     'primary_activity': None},
#    {'name': 'automotive industry',
#     'SIC_code': None,
#     'industry_group': None,
#     'subindustry_desc': None,
#     'primary_activity': None},
#    {'name': 'etching',
#     'SIC_code': None,
#     'industry_group': None,
#     'subindustry_desc': None,
#     'primary_activity': None},
#    {'name': 'electrochemistry',
#     'SIC_code': None,
#     'industry_group': None,
#     'subindustry_desc': None,
#     'primary_activity': None},
#    {'name': 'ethics of artificial intelligence',
#     'SIC_code': None,
#     'industry_group': None,
#     'subindustry_desc': None,
#     'primary_activity': None},
#    {'name': 'ethics of artificial intelligence',
#     'SIC_code': None,
#     'industry_group': None,
#     'subindustry_desc': None,
#     'primary_activity': None},
#    {'name': 'Apple Card',
#     'SIC_code': None,
#     'industry_group': None,
#     'subindustry_desc': None,
#     'primary_activity': None},
#    {'name': 'iPhone',
#     'SIC_code': None,
#     'industry_group': None,
#     'subindustry_desc': None,
#     'primary_activity': None},
#    {'name': 'CMOS',
#     'SIC_code': None,
#     'industry_group': None,
#     'subindustry_desc': None,
#     'primary_activity': None},
#    {'name': 'artificial intelligence',
#     'SIC_code': None,
#     'industry_group': None,
#     'subindustry_desc': None,
#     'primary_activity': None},
#    {'name': 'computer security',
#     'SIC_code': None,
#     'industry_group': None,
#     'subindustry_desc': None,
#     'primary_activity': None},
#    {'name': 'wireless communication',
#     'SIC_code': None,
#     'industry_group': None,
#     'subindustry_desc': None,
#     'primary_activity': None},
#    {'name': 'operations management',
#     'SIC_code': None,
#     'industry_group': None,
#     'subindustry_desc': None,
#     'primary_activity': None},
#    {'name': 'analysis',
#     'SIC_code': None,
#     'industry_group': None,
#     'subindustry_desc': None,
#     'primary_activity': None},
#    {'name': 'management',
#     'SIC_code': None,
#     'industry_group': None,
#     'subindustry_desc': None,
#     'primary_activity': None},
#    {'name': 'management',
#     'SIC_code': None,
#     'industry_group': None,
#     'subindustry_desc': None,
#     'primary_activity': None},
#    {'name': 'oncology',
#     'SIC_code': None,
#     'industry_group': None,
#     'subindustry_desc': None,
#     'primary_activity': None},
#    {'name': 'automation',
#     'SIC_code': None,
#     'industry_group': None,
#     'subindustry_desc': None,
#     'primary_activity': None},
#    {'name': 'sensor',
#     'SIC_code': None,
#     'industry_group': None,
#     'subindustry_desc': None,
#     'primary_activity': None},
#    {'name': 'building automation',
#     'SIC_code': None,
#     'industry_group': None,
#     'subindustry_desc': None,
#     'primary_activity': None},
#    {'name': 'management',
#     'SIC_code': None,
#     'industry_group': None,
#     'subindustry_desc': None,
#     'primary_activity': None},
#    {'name': 'finance',
#     'SIC_code': None,
#     'industry_group': None,
#     'subindustry_desc': None,
#     'primary_activity': None},
#    {'name': 'self-employment',
#     'SIC_code': None,
#     'industry_group': None,
#     'subindustry_desc': None,
#     'primary_activity': None},
#    {'name': 'artificial intelligence',
#     'SIC_code': None,
#     'industry_group': None,
#     'subindustry_desc': None,
#     'primary_activity': None},
#    {'name': 'accounting',
#     'SIC_code': None,
#     'industry_group': None,
#     'subindustry_desc': None,
#     'primary_activity': None},
#    {'name': 'self-employment',
#     'SIC_code': None,
#     'industry_group': None,
#     'subindustry_desc': None,
#     'primary_activity': None},
#    {'name': 'management',
#     'SIC_code': None,
#     'industry_group': None,
#     'subindustry_desc': None,
#     'primary_activity': None},
#    {'name': 'dynamic random-access memory',
#     'SIC_code': None,
#     'industry_group': None,
#     'subindustry_desc': None,
#     'primary_activity': None},
#    {'name': 'flash memory',
#     'SIC_code': None,
#     'industry_group': None,
#     'subindustry_desc': None,
#     'primary_activity': None},
#    {'name': 'dynamic random-access memory',
#     'SIC_code': None,
#     'industry_group': None,
#     'subindustry_desc': None,
#     'primary_activity': None},
#    {'name': 'High Bandwidth Memory',
#     'SIC_code': None,
#     'industry_group': None,
#     'subindustry_desc': None,
#     'primary_activity': None},
#    {'name': 'flash memory',
#     'SIC_code': None,
#     'industry_group': None,
#     'subindustry_desc': None,
#     'primary_activity': None},
#    {'name': 'dynamic random-access memory',
# ...
#     'product_name': 'electronic money transfers'},
#    {'company_name': 'Netlist', 'product_name': 'memory'},
#    {'company_name': 'Lexar Media', 'product_name': 'digital media products'},
#    {'company_name': 'Microsoft', 'product_name': 'BASIC interpreters'},
#    {'company_name': 'Netflix', 'product_name': 'DVD'},
#    {'company_name': 'LSI Logic Corporation', 'product_name': 'computer chip'},
#    {'company_name': 'Nvidia', 'product_name': 'AI) hardware'},
#    {'company_name': 'ATI Technologies', 'product_name': 'southbridge parts'},
#    {'company_name': 'Nvidia', 'product_name': 'graphics hardware'},
#    {'company_name': 'Nvidia', 'product_name': 'southbridge parts'},
#    {'company_name': 'ULI Electronics', 'product_name': 'southbridge parts'},
#    {'company_name': 'Nvidia', 'product_name': 'mobile processors'},
#    {'company_name': 'Nvidia',
#     'product_name': 'vehicle navigation and entertainment systems'},
#    {'company_name': 'Nvidia', 'product_name': 'graphics adapters'},
#    {'company_name': 'Pearl Milling Company', 'product_name': 'syrups'},
#    {'company_name': 'Wimm Bill Dann Foods', 'product_name': 'fruit juices'},
#    {'company_name': 'Wimm Bill Dann Foods', 'product_name': 'yogurt'},
#    {'company_name': 'PepsiCo', 'product_name': 'Frito-Lay snacks'},
#    {'company_name': 'PepsiCo', 'product_name': 'Tropicana juices'},
#    {'company_name': 'LOFT', 'product_name': 'candy'},
#    {'company_name': 'Emagic', 'product_name': 'music software'},
#    {'company_name': 'Emagic', 'product_name': 'computer'},
#    {'company_name': 'Apple Energy, LLC', 'product_name': 'solar energy'},
#    {'company_name': 'Apple Inc.', 'product_name': 'solar energy'},
#    {'company_name': 'Apple', 'product_name': 'mobile handset'},
#    {'company_name': 'Analog Devices',
#     'product_name': 'thick film semiconductors'},
#    {'company_name': 'Analog Devices', 'product_name': 'reference circuits'},
#    {'company_name': 'Analog Devices', 'product_name': 'linear, mixed-signal'},
#    {'company_name': 'KLA-Tencor Corporation',
#     'product_name': 'yield management solutions'},
#    {'company_name': 'Semiconductor Products Group',
#     'product_name': 'and associated technologies'},
#    {'company_name': 'Applied Materials',
#     'product_name': 'solar manufacturing equipment'},
#    {'company_name': 'Applied Materials',
#     'product_name': 'laser cleaning technologies'},
#    {'company_name': 'Applied Materials', 'product_name': 'software'},
#    {'company_name': 'Applied Materials', 'product_name': 'services'},
#    {'company_name': 'Applied Materials', 'product_name': 'equipment'},
#    {'company_name': 'Eteris',
#     'product_name': 'semiconductor processing equipment'},
#    {'company_name': 'Applied Materials',
#     'product_name': 'manufacture of semiconductor (integrated circuit) chips'},
#    {'company_name': 'Applied Materials',
#     'product_name': 'flat panel displays'},
#    {'company_name': 'Oramir', 'product_name': 'laser cleaning technologies'},
#    {'company_name': 'Applied Materials',
#     'product_name': 'semiconductor equipment'},
#    {'company_name': 'Tokyo Electron',
#     'product_name': 'semiconductor equipment'},
#    {'company_name': 'NVIDIA Corporation',
#     'product_name': 'integrated graphics processors'},
#    {'company_name': 'Gaming Products',
#     'product_name': 'portable gaming devices'},
#    {'company_name': 'Advanced Micro Devices',
#     'product_name': 'graphics processors'},
#    {'company_name': 'Advanced Micro Devices',
#     'product_name': 'motherboard chipsets'},
#    {'company_name': 'Advanced Micro Devices',
#     'product_name': 'embedded processors'},
#    {'company_name': 'Advanced Micro Devices',
#     'product_name': 'microchip implant'},
#    {'company_name': 'ATI', 'product_name': 'integrated graphics cards'},
#    {'company_name': 'Advanced Micro Devices',
#     'product_name': 'related technologies'},
#    {'company_name': 'Advanced Micro Devices',
#     'product_name': 'computer processors'},
#    {'company_name': 'Advanced Micro Devices', 'product_name': 'semiconductor'},
#    {'company_name': 'Advanced Micro Devices', 'product_name': 'bipolar chips'},
#    {'company_name': 'ATI Technologies Inc.', 'product_name': 'graphics-card'},
#    {'company_name': 'Audible', 'product_name': 'digital audiobooks'},
#    {'company_name': 'Audible', 'product_name': 'programs'},
#    {'company_name': 'Amazon', 'product_name': 'audiobooks'},
#    {'company_name': 'Amazon', 'product_name': 'groceries'},
#    {'company_name': 'Amazon', 'product_name': 'beauty products'},
#    {'company_name': 'Amazon',
#     'product_name': 'health and personal care products'},
#    {'company_name': 'Amazon', 'product_name': 'gourmet food'},
#    {'company_name': 'Amazon', 'product_name': 'product lining'},
#    {'company_name': 'Amazon', 'product_name': 'movies'},
#    {'company_name': 'Amazon', 'product_name': 'baby products'},
#    {'company_name': 'Amazon', 'product_name': 'Kindle e-readers'},
#    {'company_name': 'Amazon', 'product_name': 'Fire tablets'},
#    {'company_name': 'Amazon', 'product_name': 'Echo devices'},
#    {'company_name': 'Amazon', 'product_name': 'Fire TVs'},
#    {'company_name': 'Amazon', 'product_name': 'batteries'},
#    {'company_name': 'Amazon', 'product_name': 'phone chargers'},
#    {'company_name': 'Toys R Us', 'product_name': 'toys'},
#    {'company_name': 'Toys R Us', 'product_name': 'baby products'},
#    {'company_name': 'Amazon', 'product_name': 'diaper wipes'},
#    {'company_name': 'Analog Devices',
#     'product_name': 'thick film semiconductors'},
#    {'company_name': 'Analog Devices', 'product_name': 'reference circuits'},
#    {'company_name': 'Analog Devices', 'product_name': 'linear, mixed-signal'},
#    {'company_name': 'Semiconductor Products Group',
#     'product_name': 'and associated technologies'},
#    {'company_name': 'KLA-Tencor Corporation',
#     'product_name': 'yield management solutions'},
#    {'company_name': 'Applied Materials', 'product_name': 'services'},
#    {'company_name': 'Applied Materials', 'product_name': 'software'},
#    {'company_name': 'Applied Materials', 'product_name': 'equipment'},
#    {'company_name': 'Eteris',
#     'product_name': 'semiconductor processing equipment'},
#    {'company_name': 'Applied Materials',
#     'product_name': 'flat panel displays'},
#    {'company_name': 'Oramir', 'product_name': 'laser cleaning technologies'},
#    {'company_name': 'Applied Materials',
#     'product_name': 'laser cleaning technologies'},
#    {'company_name': 'Applied Materials',
#     'product_name': 'solar manufacturing equipment'},
#    {'company_name': 'Applied Materials',
#     'product_name': 'semiconductor equipment'},
#    {'company_name': 'Tokyo Electron',
#     'product_name': 'semiconductor equipment'},
#    {'company_name': 'Applied Materials',
#     'product_name': 'manufacture of semiconductor (integrated circuit) chips'},
#    {'company_name': 'Apple', 'product_name': 'iPad accessories'},
#    {'company_name': 'Apple', 'product_name': 'mobile handset'},
#    {'company_name': 'Emagic', 'product_name': 'computer'},
#    {'company_name': 'Apple Inc.', 'product_name': 'solar energy'},
#    {'company_name': 'Apple Energy, LLC', 'product_name': 'solar energy'},
#    {'company_name': 'Booking.com',
#     'product_name': 'accommodation reservation services'},
#    {'company_name': 'Booking Holdings',
#     'product_name': 'hotel distribution services'},
#    {'company_name': 'Agoda',
#     'product_name': 'activities reservation services'},
#    {'company_name': 'Agoda', 'product_name': 'ground transportation'},
#    {'company_name': 'Agoda', 'product_name': 'flight'},
#    {'company_name': 'Booking Holdings',
#     'product_name': 'rental car reservation services'},
#    {'company_name': 'Booking.com', 'product_name': 'Connected Trip'},
#    {'company_name': 'Broadcom',
#     'product_name': 'semiconductor and infrastructure software products'},
#    {'company_name': 'Broadcom', 'product_name': 'SSD controller'},
#    {'company_name': 'Broadcom', 'product_name': 'enterprise security'},
#    {'company_name': 'Cintas', 'product_name': 'shop towels'},
#    {'company_name': 'Cintas', 'product_name': 'corporate identity uniforms'},
#    {'company_name': 'Cintas', 'product_name': 'mats'},
#    {'company_name': 'Cintas', 'product_name': 'products and services'},
#    {'company_name': 'Cintas', 'product_name': 'mops'},
#    {'company_name': 'Cintas', 'product_name': 'safety courses'},
#    {'company_name': 'Cintas',
#     'product_name': 'cleaning and restroom supplies'},
#    {'company_name': 'Cintas', 'product_name': 'first aid and safety products'},
#    {'company_name': 'Kamp Fire Equipment',
#     'product_name': 'fire safety products and services'},
#    {'company_name': 'Cintas',
#     'product_name': 'fire safety products and services'},
#    {'company_name': 'Cintas', 'product_name': 'fire protection'},
#    {'company_name': 'Cisco Systems', 'product_name': 'equipment'},
#    {'company_name': 'Cisco Systems',
#     'product_name': 'mobile network management'},
#    {'company_name': 'Cisco', 'product_name': 'IP phones'},
#    {'company_name': 'Cisco Systems',
#     'product_name': 'high-technology services'},
#    {'company_name': 'Cisco Systems', 'product_name': 'networking hardware'},
#    {'company_name': 'Cisco Systems', 'product_name': 'software'},
#    {'company_name': 'Cisco Systems',
#     'product_name': 'telecommunications equipment'},
#    {'company_name': 'Cisco Systems', 'product_name': 'computer boards'},
#    {'company_name': 'Cisco Systems',
#     'product_name': 'IT products and services'},
#    {'company_name': 'Comcast', 'product_name': 'first-party content'},
#    {'company_name': 'Comcast',
#     'product_name': 'television programming content'},
#    {'company_name': 'Comcast', 'product_name': 'cable'},
#    {'company_name': 'Comcast', 'product_name': 'commercial services'},
#    {'company_name': 'Comcast', 'product_name': 'broadband services'},
#    {'company_name': 'Comcast', 'product_name': 'home telephone service'},
#    {'company_name': 'Greater Philadelphia Cablevision',
#     'product_name': 'cable'},
#    {'company_name': 'Comcast', 'product_name': 'wireless devices'},
#    {'company_name': 'Costco Wholesale', 'product_name': 'vacation packages'},
#    {'company_name': 'Costco Wholesale', 'product_name': 'cruises'},
#    {'company_name': 'Costco Wholesale', 'product_name': 'car rentals'},
#    {'company_name': 'Costco Wholesale', 'product_name': 'hot dogs'},
#    {'company_name': 'Costco Home', 'product_name': 'furniture'},
#    {'company_name': 'Pepsi', 'product_name': 'drinks'},
#    {'company_name': 'Gilead Sciences',
#     'product_name': 'intellectual property'},
#    {'company_name': 'Gilead Sciences', 'product_name': 'hepatitis C.'},
#    {'company_name': 'Raylo Chemicals',
#     'product_name': 'pharmaceutical ingredients'},
#    {'company_name': 'Raylo Chemicals',
#     'product_name': 'advanced intermediates'},
#    {'company_name': 'Honeywell', 'product_name': 'deadly and maiming weapons'},
#    {'company_name': 'Honeywell International',
#     'product_name': 'deadly and maiming weapons'},
#    {'company_name': 'Honeywell', 'product_name': 'cluster bombs'},
#    {'company_name': 'Honeywell International',
#     'product_name': 'cluster bombs'},
#    {'company_name': 'Honeywell International',
#     'product_name': 'photographic equipment'},
#    {'company_name': 'Honeywell International',
#     'product_name': 'personal protective equipment'},
#    {'company_name': 'Honeywell International',
#     'product_name': 'Pentax cameras'},
#    {'company_name': 'Pentax', 'product_name': 'photographic equipment'},
#    {'company_name': 'Honeywell International',
#     'product_name': 'electronic guidance systems'},
#    {'company_name': 'Honeywell International',
#     'product_name': 'secondary power turbine engines'},
#    {'company_name': 'Intel', 'product_name': 'computer components'},
#    {'company_name': 'Intel Israel', 'product_name': 'communications products'},
#    {'company_name': 'Intel', 'product_name': 'semiconductor chip'},
#    {'company_name': 'Intel', 'product_name': 'PC microprocessors'},
#    {'company_name': 'Intel', 'product_name': 'hardware'},
#    {'company_name': 'Compaq', 'product_name': 'PC-compatible systems'},
#    {'company_name': 'ProConnect', 'product_name': 'form updates'},
#    {'company_name': 'Intuit', 'product_name': 'e-commerce tools'},
#    {'company_name': 'Intuit', 'product_name': 'credit cards'},
#    {'company_name': 'Intuitive Surgical Devices',
#     'product_name': 'robotic products'},
#    {'company_name': 'Intuitive Surgical', 'product_name': 'spare part'},
#    {'company_name': 'KLA Corporation',
#     'product_name': 'surface inspection system'},
#    {'company_name': 'ADE', 'product_name': 'silicon wafer metrology'},
#    {'company_name': 'ADE', 'product_name': 'related gear'},
#    {'company_name': 'KLA Corporation KLA Corporation',
#     'product_name': 'yield management'},
#    {'company_name': 'KLA Corporation', 'product_name': 'plasma etch products'},
#    {'company_name': 'Lam Research', 'product_name': 'and services'},
#    {'company_name': 'Lam Research',
#     'product_name': 'innovative wafer fabrication equipment'},
#    {'company_name': 'Lam Research', 'product_name': 'chip equipment'},
#    {'company_name': 'Ontrak', 'product_name': 'chip equipment'},
#    {'company_name': 'Lam Research', 'product_name': 'semiconductor wafer'},
#    {'company_name': 'Lam Research', 'product_name': 'related services'},
#    {'company_name': 'The Linde Group',
#     'product_name': 'merchant and cylinder gases'},
#    {'company_name': 'The Linde Group', 'product_name': 'plant components'},
#    {'company_name': 'The Linde Group', 'product_name': 'synthesis gases'},
#    {'company_name': 'The Linde Group', 'product_name': 'argon'},
#    {'company_name': 'Linde plc', 'product_name': 'debt securities'},
#    {'company_name': 'The Linde Group',
#     'product_name': 'industrial gas products'},
#    {'company_name': 'The Linde Group', 'product_name': 'pipeline complexes'},
#    {'company_name': 'The Linde Group', 'product_name': 'delivery vehicles'},
#    {'company_name': 'Lansing Bagnall', 'product_name': 'forklift'},
#    {'company_name': 'Lincare Holdings', 'product_name': 'home care gas'},
#    {'company_name': 'HiQ Tyres & Autocare',
#     'product_name': 'industrial gases'},
#    {'company_name': 'HiQ Tyres & Autocare', 'product_name': 'specialty gases'},
#    {'company_name': 'HiQ Tyres & Autocare', 'product_name': 'medical gases'},
#    {'company_name': 'Mercado Pago Servicios de Procesamiento S.R.L.',
#     'product_name': 'electronic money transfers'},
#    {'company_name': 'Netlist', 'product_name': 'memory'},
#    {'company_name': 'Lexar Media', 'product_name': 'digital media products'},
#    {'company_name': 'Microsoft', 'product_name': 'BASIC interpreters'},
#    {'company_name': 'Netflix', 'product_name': 'DVD'},
#    {'company_name': 'LSI Logic Corporation', 'product_name': 'computer chip'},
#    {'company_name': 'Nvidia', 'product_name': 'AI) hardware'},
#    {'company_name': 'ATI Technologies', 'product_name': 'southbridge parts'},
#    {'company_name': 'Nvidia', 'product_name': 'graphics hardware'},
#    {'company_name': 'Nvidia', 'product_name': 'southbridge parts'},
#    {'company_name': 'ULI Electronics', 'product_name': 'southbridge parts'},
#    {'company_name': 'Nvidia', 'product_name': 'mobile processors'},
#    {'company_name': 'Nvidia',
#     'product_name': 'vehicle navigation and entertainment systems'},
#    {'company_name': 'Nvidia', 'product_name': 'graphics adapters'},
#    {'company_name': 'Pearl Milling Company', 'product_name': 'syrups'},
#    {'company_name': 'Wimm Bill Dann Foods', 'product_name': 'fruit juices'},
#    {'company_name': 'Wimm Bill Dann Foods', 'product_name': 'yogurt'},
#    {'company_name': 'PepsiCo', 'product_name': 'Frito-Lay snacks'},
#    {'company_name': 'PepsiCo', 'product_name': 'Tropicana juices'},
#    {'company_name': 'LOFT', 'product_name': 'candy'}]},
#  {'name': 'NA', 'region_code': '019'},
#  {'name': 'OC', 'region_code': '009'},
#  {'name': 'AS', 'region_code': '142'},
#  {'name': 'EU', 'region_code': '150'},
#  {'name': 'Not Found', 'region_code': ''},
#  {'name': 'SA', 'region_code': '019'}]

# %% [markdown]
# ### Populating Neo4j Nodes{} with Company, Country, Region, Industry, Product from JSON

# %% [markdown]
# * The unique constraint on ticker_code helps maintain data integrity by ensuring that each company is uniquely identifiable by its ticker code and allows for efficient index querying.
# * A ticker code being null has no semantic meaning in the context of companies so we enforce not null constraint such that every company should have a valid ticker for identification purposes in the financial market.

# %%
def create_constraints(tx):
    queries = [
        "CREATE CONSTRAINT IF NOT EXISTS FOR (c:Company) REQUIRE c.ticker_code IS UNIQUE",
        "CREATE CONSTRAINT IF NOT EXISTS FOR (c:Company) REQUIRE c.name IS NOT NULL",

        #"CREATE CONSTRAINT IF NOT EXISTS FOR (i:Industry) REQUIRE i.SIC_code IS UNIQUE", 
        "CREATE CONSTRAINT IF NOT EXISTS FOR (i:Industry) REQUIRE i.name IS UNIQUE",
        #"CREATE CONSTRAINT IF NOT EXISTS FOR (i:Industry) REQUIRE i.SIC_code IS NOT NULL",
        "CREATE CONSTRAINT IF NOT EXISTS FOR (i:Industry) REQUIRE i.name IS UNIQUE",
        #"CREATE CONSTRAINT IF NOT EXISTS FOR (i:Industry) REQUIRE i.industry_group IS NOT NULL",
        
        "CREATE CONSTRAINT IF NOT EXISTS FOR (r:Region) REQUIRE r.region_code IS UNIQUE",
        "CREATE CONSTRAINT IF NOT EXISTS FOR (r:Region) REQUIRE r.region_code IS NOT NULL",
        "CREATE CONSTRAINT IF NOT EXISTS FOR (r:Region) REQUIRE r.name IS NOT NULL",
        
        "CREATE CONSTRAINT IF NOT EXISTS FOR (c:Country) REQUIRE c.iso3 IS UNIQUE",
        "CREATE CONSTRAINT IF NOT EXISTS FOR (c:Country) REQUIRE c.iso3 IS NOT NULL",
        "CREATE CONSTRAINT IF NOT EXISTS FOR (c:Country) REQUIRE c.iso2 IS UNIQUE",
        "CREATE CONSTRAINT IF NOT EXISTS FOR (c:Country) REQUIRE c.name IS UNIQUE",
        "CREATE CONSTRAINT IF NOT EXISTS FOR (c:Country) REQUIRE c.name IS NOT NULL"
    ]

    for query in queries:
        tx.run(query)
        
with GraphDatabase.driver(URI, auth=AUTH) as driver:
    with driver.session(database="neo4j") as session:
        session.execute_write(create_constraints)

# %% [markdown]
# While CREATE CONSTRAINT enforce uniqueness of properties, MERGE helps in avoiding duplicates during node creation and matching.

# %%
def add_company_nodes(tx, json_data):
    query = """
    MERGE (c:Company {name: $company_name, ticker: $ticker_code, founded_year: $founded_year})
    """
    
    companies = json_data['nodes']['Company'] 

    for company in companies:
        founded_year = company['founded_year'] if company['founded_year'] is not None else "" 
        tx.run(query, 
               company_name=company['name'], 
               ticker_code=company['ticker_code'], 
               founded_year=founded_year)

# %%
def add_country_nodes(tx, json_data):
    query = """
    MERGE (c:Country {iso3: $iso3,iso2: $iso2})  // Match by unique iso3 code
    ON CREATE SET 
      c.name = $country_name,
      c.source_city = $source_city,
      c.iso2 = $iso2,
      c.population = $population,
      c.gdp = $gdp,
      c.corporate_tax_rate = $corporate_tax_rate
    ON MATCH SET 
      c.population = $population,  // Optionally update on match
      c.gdp = $gdp,
      c.corporate_tax_rate = $corporate_tax_rate
    """
    
    countries = json_data['nodes']['Country']

    for country in countries:
        iso2 = country.get('iso2', "")
        iso3 = country.get('iso3', "")
        source_city = country.get('source_city', "")
        country_name = "" if country.get('name') == "Not Found" else country.get('name', "")

        
        tx.run(query, 
               source_city=source_city,
               country_name=country_name,
               iso2=iso2,
               iso3=iso3,
               population=country.get('population', 0),
               gdp=country.get('gdp', 0),
               corporate_tax_rate=country.get('corporate_tax_rate', 0)
              )

# %%
def add_region_nodes(tx, json_data):
    # Define the Cypher query using UNWIND to handle multiple regions
    query = """
    UNWIND $regions AS map
    MERGE (n:Region {region_code: map.region_code})
    ON CREATE SET n.name = map.name
    """

    regions = json_data['nodes']['Region']  

    tx.run(query, regions=regions)

# %%
def add_industry_nodes(tx, json_data):
    query = """
        MERGE (i:Industry {name: $industry_name})
        ON CREATE SET 
            i.SIC_code = $SIC_code,
            i.industry_group = $industry_group,
            i.subindustry_desc = $subindustry_desc,
            i.primary_activity = $primary_activity
        ON MATCH SET 
            i.industry_group = $industry_group,
            i.subindustry_desc = $subindustry_desc,
            i.primary_activity = $primary_activity
    """
    
    industries = json_data['nodes']['Industry']
    
    for industry in industries:
        properties = {
            "industry_name": industry["name"],
            "SIC_code": industry['SIC_code'] if industry['SIC_code'] is not None else "",
            "industry_group": industry['industry_group'] if industry['industry_group'] is not None else "",
            "subindustry_desc": industry['subindustry_desc'] if industry['subindustry_desc'] is not None else "",
            "primary_activity": industry['primary_activity'] if industry['primary_activity'] is not None else ""
        }
        
        try:
            tx.run(query, **properties)
        except Exception as e:
            print(f"Error adding industry {industry['name']}: {e}")

# %%
def add_product_nodes(tx, json_data):
    query = """
    MERGE (p:Product {name: $product_name})
    """
    
    products = json_data['nodes']['Product'] 

    for product in products:
        tx.run(query, 
               product_name=product['name'])

# %%
# Create the nodes using the Neo4j connection
with GraphDatabase.driver(URI, auth=AUTH) as driver:
    with driver.session(database="neo4j") as session:
        session.execute_write(add_company_nodes, merged_json)  
        session.execute_write(add_country_nodes, merged_json) 
        session.execute_write(add_region_nodes, merged_json) 
        session.execute_write(add_industry_nodes, merged_json) 
        session.execute_write(add_product_nodes, merged_json)

# %% [markdown]
# #### Sample Creating vector indexes with BERT (will modify to other methods)

# %%
#!pip install -U sentence-transformers
from sentence_transformers import SentenceTransformer

model = SentenceTransformer('all-MiniLM-L6-v2')  # A pre-trained BERT model

def get_text_embedding(text):
    return model.encode(text).tolist()

# Example usage
company_name_embedding = get_text_embedding("Apple Inc.")

# %%
from sklearn.preprocessing import StandardScaler

scaler = StandardScaler()

numerical_data = [[129, 3841, 20]]  # Population, GDP, corporate tax rate
scaled_data = scaler.fit_transform(numerical_data)

# %%
from neo4j import GraphDatabase

URI = os.getenv("NEO4J_URI")
AUTH = (os.getenv("NEO4J_USERNAME"), os.getenv("NEO4J_PASSWORD"))

driver = GraphDatabase.driver(URI, auth=AUTH)

def add_vectors(tx, node_label, name, vector, ticker_code=None):
    if node_label == "Company":
        query = """
        MERGE (n:{label} {{ticker_code: $ticker_code, name: $name}})
        SET n.vector = $vector
        """.format(label=node_label)
        tx.run(query, ticker_code=ticker_code, name=name, vector=vector)
    else:
        query = """
        MERGE (n:{label} {{name: $name}})
        SET n.vector = $vector
        """.format(label=node_label)
        tx.run(query, name=name, vector=vector)

# Example for company and country nodes
with driver.session() as session:
    company_name = "Apple Inc."
    company_vector = get_text_embedding(company_name)
    country_name = "Jamaica"
    country_vector = get_text_embedding(country_name)

    session.execute_write(add_vectors, "Company", company_name, company_vector, "AAPL")
    session.execute_write(add_vectors, "Country", country_name, country_vector)

# %%
def add_index_vector(tx):
    query = """
    CREATE INDEX IF NOT EXISTS FOR (c:Company)
    ON (c.vector);
    """

    tx.run(query)

with driver.session() as session:
    session.execute_write(add_index_vector)

driver.close()

# %% [markdown]
# ### Populating Neo4j with Relationships from JSON
# #### Company-Industry relationship
# One of the key relationships defined in the data is "IS_INVOLVED_IN", which helps in modeling how companies are categorized based on their primary activities and the sectors they contribute to.
#
#
# "IS_INVOLVED_IN": [
#             {
#                 "company_name": "McKinsey &#38; Company",
#                 "industry_name": "management consulting"}]

# %%
def add_company_industry_relationship(tx, json_data):
    query = """
    MERGE (c:Company {name: $company_name})
    MERGE (i:Industry {name: $industry_name})
    MERGE (c)-[:IS_INVOLVED_IN]->(i)
    """
    involved_in = json_data['relationships']['IS_INVOLVED_IN']

    for relationship in involved_in:
        tx.run(query, company_name=relationship['company_name'], industry_name=relationship['industry_name'])

# %%
with driver.session() as session:
    session.execute_write(add_company_industry_relationship, merged_json)

driver.close()
# Out:
# C:\Users\user\AppData\Local\Temp\ipykernel_14544\3008866785.py:1: DeprecationWarning: Using a driver after it has been closed is deprecated. Future versions of the driver will raise an error.
#   with driver.session() as session:

# %% [markdown]
# ### Data Validation Testing

# %% [markdown]
# We also consider cross-referencing with other data sources or using validation rules to ensure data accuracy. (will elaborate more later)

# %%
def smoke_test(data):
    """Check if data is empty."""
    if not data:
        print("Smoke Test Failed: Data is empty.")
        return False
    print("Smoke Test Passed.")
    return True

def range_check_country(data):
    """Check for valid population and GDP values in countries."""
    for country in data['nodes'].get('Country', []):
        if country.get('population', 0) < 0 or country.get('gdp', 0) < 0:
            print(f"Range Check Failed: Invalid population or GDP in Country: {country}")
            return False
    print("Range Check Passed for Country.")
    return True

def anomaly_detection_relationship(data):
    """Identify extreme or outlier net sales in relationships."""
    for relationship in data['relationships'].get('OPERATES_IN_COUNTRY', []):
        if relationship.get('net sales') is not None and relationship['net sales'] < 0:
            print(f"Anomaly Detection Failed: Negative net sales in relationship: {relationship}")
            return False
    print("Anomaly Detection Passed for Relationships.")
    return True

def validate_relationship(data, relationship_type, required_fields):
    """Validate the relationships between companies and industries."""
    for relationship in data['relationships'].get(relationship_type, []):
        for field in required_fields:
            if relationship.get(field) is None:
                print(f"Relationship Validation Failed: Missing '{field}' in {relationship_type}.")
                return False
    print(f"Relationship Validation Passed for {relationship_type}.")
    return True

def run_tests(data):
    """Run all validation tests."""
    # Smoke Test
    if not smoke_test(data):
        return

    # Range Check for country fields
    range_check_country(data)

    # Anomaly Detection for net sales in relationships
    anomaly_detection_relationship(data)

    # Relationship Validation
    validate_relationship(data, 'PARTNERS_WITH', ['company_name_1', 'company_name_2'])
    validate_relationship(data, 'COMPETES_WITH', ['company_name_1', 'company_name_2'])
    validate_relationship(data, 'IS_INVOLVED_IN', ['company_name', 'industry_name'])

    print("All tests executed.")
run_tests(merged_json)
# Out:
# Smoke Test Passed.
# Range Check Passed for Country.
# Anomaly Detection Failed: Negative net sales in relationship: {'company_name': 'Apple', 'country_name': 'Ireland', 'net sales': -24931076, 'headcount': 1665}
# Relationship Validation Passed for PARTNERS_WITH.
# Relationship Validation Passed for COMPETES_WITH.
# Relationship Validation Passed for IS_INVOLVED_IN.
# All tests executed.

# %% [markdown]
# ### Data Validation: Invalid Format Specifier

# %%
def validate_company_data(companies, fields_to_check):
    """ Regular expression to check if the name contains special characters """
    name_pattern = r"^[A-Za-z0-9\s.,&]+$"
    ticker_pattern = r"^[A-Z]{1,5}(\.[A-Z]{1,3})?$"
    invalid_companies = []
    invalid_count = 0 
    
    for company in companies:
        for field in fields_to_check:
            field_value = company.get(field)

            if field_value is None:
                continue

            if field == 'name' and not re.match(name_pattern, field_value):
                invalid_companies.append(company)
                print(f"Invalid name: '{field_value}' in company: {company}")
                invalid_count += 1  

            if field == 'ticker_code' and ('.html' in field_value or not re.match(ticker_pattern, field_value)):
                invalid_companies.append(company)
                print(f"Invalid ticker code: '{field_value}' in company: {company}")
                invalid_count += 1 

    return invalid_companies, invalid_count  


def validate_country_data(countries, fields_to_check):
    """Checking invalid format for iso2 and iso3"""
    iso2_pattern = r"^[A-Z]{2}$"
    iso3_pattern = r"^[A-Z]{3}$"
    invalid_countries = []
    invalid_count = 0  

    for country in countries:
        for field in fields_to_check:
            field_value = country.get(field)

            if field_value is None:
                continue

            if field == 'iso2' and not re.match(iso2_pattern, field_value):
                invalid_countries.append(country)
                print(f"'{field}' is invalid for country: {country}")
                invalid_count += 1  

            if field == 'iso3' and not re.match(iso3_pattern, field_value):
                invalid_countries.append(country)
                print(f"'{field}' is invalid for country: {country}")
                invalid_count += 1 

    return invalid_countries, invalid_count 
fields_to_check_company = list(merged_json["nodes"]["Company"][0].keys())
fields_to_check_country = list(merged_json["nodes"]["Country"][0].keys())

invalid_companies, invalid_company_count = validate_company_data(merged_json['nodes']['Company'], fields_to_check_company)
invalid_countries, invalid_country_count = validate_country_data(merged_json['nodes']['Country'], fields_to_check_country)

print(f"Total invalid companies: {invalid_company_count}")
print(f"Total invalid countries: {invalid_country_count}")
# Out:
# Total invalid companies: 0
# Total invalid countries: 0

# %% [markdown]
# ### Data Validation: Missing Mandatory Fields

# %%
def check_empty_fields(data, node_type):
    node_null_count = 0
    nodes = data['nodes'].get(node_type, [])
    fields_to_check = list(nodes[0].keys()) if nodes else []
    
    for node in nodes:
        for field in fields_to_check:
            if not node.get(field):
                node_null_count += 1
                print(f"'{field}' is empty for {node_type}: {node}") 
    return node_null_count 

individual_null_counts = {}
nodes_to_check = list(merged_json["nodes"].keys())

for node in nodes_to_check:
    null_count = check_empty_fields(merged_json, node)
    individual_null_counts[node] = null_count  

for entity, count in individual_null_counts.items():
    print(f"Total null fields for {entity}: {count}")
# Out:
# 'founded_year' is empty for Company: {'name': 'Apple Inc.', 'ticker_code': 'AAPL', 'founded_year': None}
# 'founded_year' is empty for Company: {'name': 'Major League Soccer Mls', 'ticker_code': 'MLFB', 'founded_year': None}
# 'founded_year' is empty for Company: {'name': 'Adobe Inc.', 'ticker_code': 'ADBE', 'founded_year': None}
# 'founded_year' is empty for Company: {'name': 'Maxim Integrated Products', 'ticker_code': 'MXIM', 'founded_year': None}
# 'founded_year' is empty for Company: {'name': 'Applied Materials Inc De', 'ticker_code': 'AMAT', 'founded_year': None}
# 'founded_year' is empty for Company: {'name': 'Vantage Systems', 'ticker_code': 'VTAGY', 'founded_year': None}
# 'founded_year' is empty for Company: {'name': 'Microsoft', 'ticker_code': 'MSFT', 'founded_year': None}
# 'founded_year' is empty for Company: {'name': 'Coolrunner', 'ticker_code': 'CLCO', 'founded_year': None}
# 'founded_year' is empty for Company: {'name': 'Amazon Com Inc', 'ticker_code': 'AMZN', 'founded_year': None}
# 'founded_year' is empty for Company: {'name': 'Amgen Inc', 'ticker_code': 'AMGN', 'founded_year': None}
# 'founded_year' is empty for Company: {'name': 'Alphabet Inc.', 'ticker_code': 'GOOG', 'founded_year': None}
# 'founded_year' is empty for Company: {'name': 'Audio Magic', 'ticker_code': 'MGIC', 'founded_year': None}
# 'founded_year' is empty for Company: {'name': 'Gemini', 'ticker_code': 'GMNI', 'founded_year': None}
# 'founded_year' is empty for Company: {'name': 'Alphabet Inc.', 'ticker_code': 'GOOGL', 'founded_year': None}
# 'founded_year' is empty for Company: {'name': 'Booking Holdings Inc.', 'ticker_code': 'BKNG', 'founded_year': None}
# 'founded_year' is empty for Company: {'name': 'Broadcom Inc.', 'ticker_code': 'AVGO', 'founded_year': None}
# 'founded_year' is empty for Company: {'name': 'Lsi', 'ticker_code': 'LYTS', 'founded_year': None}
# 'founded_year' is empty for Company: {'name': 'Cintas Corp', 'ticker_code': 'CTAS', 'founded_year': None}
# 'founded_year' is empty for Company: {'name': 'Workday', 'ticker_code': 'WDAY', 'founded_year': None}
# 'founded_year' is empty for Company: {'name': 'Cisco Systems Inc.', 'ticker_code': 'CSCO', 'founded_year': None}
# 'founded_year' is empty for Company: {'name': 'Apjc', 'ticker_code': 'APJCX', 'founded_year': None}
# 'founded_year' is empty for Company: {'name': 'Splunk', 'ticker_code': 'SPLK', 'founded_year': None}
# 'founded_year' is empty for Company: {'name': 'Comcast Corp', 'ticker_code': 'CMCSA', 'founded_year': None}
# 'founded_year' is empty for Company: {'name': 'Costco Wholesale Corp New', 'ticker_code': 'COST', 'founded_year': None}
# 'founded_year' is empty for Company: {'name': 'Gilead Sciences Inc.', 'ticker_code': 'GILD', 'founded_year': None}
# 'founded_year' is empty for Company: {'name': 'Tmunity Therapeutics', 'ticker_code': 'CTNM', 'founded_year': None}
# 'founded_year' is empty for Company: {'name': 'Compugen', 'ticker_code': 'CGEN', 'founded_year': None}
# 'founded_year' is empty for Company: {'name': 'Arcus Biosciences', 'ticker_code': 'RCUS', 'founded_year': None}
# 'founded_year' is empty for Company: {'name': 'Arcellx', 'ticker_code': 'ACLX', 'founded_year': None}
# 'founded_year' is empty for Company: {'name': 'Metabolex', 'ticker_code': 'META', 'founded_year': None}
# 'founded_year' is empty for Company: {'name': 'Assembly Biosciences', 'ticker_code': 'ASMB', 'founded_year': None}
# 'founded_year' is empty for Company: {'name': 'Daiichi Sankyo', 'ticker_code': 'DSNKY', 'founded_year': None}
# 'founded_year' is empty for Company: {'name': 'Nurix', 'ticker_code': 'NRIX', 'founded_year': None}
# 'founded_year' is empty for Company: {'name': 'Butz', 'ticker_code': 'BULZ', 'founded_year': None}
# 'founded_year' is empty for Company: {'name': 'Intel Corp', 'ticker_code': 'INTC', 'founded_year': None}
# 'founded_year' is empty for Company: {'name': 'Intuit Inc.', 'ticker_code': 'INTU', 'founded_year': None}
# 'founded_year' is empty for Company: {'name': 'Intuitive Surgical Inc', 'ticker_code': 'ISRG', 'founded_year': None}
# 'founded_year' is empty for Company: {'name': 'Kla Corp', 'ticker_code': 'KLAC', 'founded_year': None}
# 'founded_year' is empty for Company: {'name': 'Lam Research Corp', 'ticker_code': 'LRCX', 'founded_year': None}
# 'founded_year' is empty for Company: {'name': 'Mercadolibre Inc', 'ticker_code': 'MELI', 'founded_year': None}
# 'founded_year' is empty for Company: {'name': 'Nuance Communications', 'ticker_code': 'NUAN', 'founded_year': None}
# 'founded_year' is empty for Company: {'name': 'Reinvent', 'ticker_code': 'RTPZU', 'founded_year': None}
# 'founded_year' is empty for Company: {'name': 'Mondelez International Inc.', 'ticker_code': 'MDLZ', 'founded_year': None}
# 'founded_year' is empty for Company: {'name': 'Netflix Inc', 'ticker_code': 'NFLX', 'founded_year': None}
# 'founded_year' is empty for Company: {'name': 'Nvidia Corp', 'ticker_code': 'NVDA', 'founded_year': None}
# 'founded_year' is empty for Company: {'name': 'Exluna', 'ticker_code': 'LUNA', 'founded_year': None}
# 'source_city' is empty for Country: {'name': 'Australia', 'iso2': 'AU', 'iso3': 'AUS', 'population': 281, 'gdp': 17148, 'corporate_tax_rate': 41}
# 'source_city' is empty for Country: {'name': 'Japan', 'iso2': 'JP', 'iso3': 'JPN', 'population': 777, 'gdp': 5707, 'corporate_tax_rate': 37}
# 'source_city' is empty for Country: {'name': 'South Korea', 'iso2': 'KR', 'iso3': 'KOR', 'population': 795, 'gdp': 12661, 'corporate_tax_rate': 18}
# 'source_city' is empty for Country: {'name': 'Germany', 'iso2': 'DE', 'iso3': 'DEU', 'population': 387, 'gdp': 2098, 'corporate_tax_rate': 37}
# 'source_city' is empty for Country: {'name': 'Netherlands', 'iso2': 'NL', 'iso3': 'NLD', 'population': 394, 'gdp': 4616, 'corporate_tax_rate': 43}
# 'source_city' is empty for Country: {'name': 'United States of America', 'iso2': 'US', 'iso3': 'USA', 'population': 37, 'gdp': 5369, 'corporate_tax_rate': 30}
# 'source_city' is empty for Country: {'name': 'United States of America', 'iso2': 'US', 'iso3': 'USA', 'population': 796, 'gdp': 6619, 'corporate_tax_rate': 21}
# 'source_city' is empty for Country: {'name': 'United States of America', 'iso2': 'US', 'iso3': 'USA', 'population': 1029, 'gdp': 1698, 'corporate_tax_rate': 21}
# 'source_city' is empty for Country: {'name': 'United States of America', 'iso2': 'US', 'iso3': 'USA', 'population': 1075, 'gdp': 2172, 'corporate_tax_rate': 16}
# 'iso2' is empty for Country: {'source_city': 'UltraScale', 'name': 'Not Found', 'population': 215, 'gdp': 11634, 'corporate_tax_rate': 41}
# 'iso3' is empty for Country: {'source_city': 'UltraScale', 'name': 'Not Found', 'population': 215, 'gdp': 11634, 'corporate_tax_rate': 41}
# 'iso2' is empty for Country: {'source_city': 'UltraScale', 'name': 'Not Found', 'population': 1162, 'gdp': 7452, 'corporate_tax_rate': 40}
# 'iso3' is empty for Country: {'source_city': 'UltraScale', 'name': 'Not Found', 'population': 1162, 'gdp': 7452, 'corporate_tax_rate': 40}
# 'source_city' is empty for Country: {'name': 'South Korea', 'iso2': 'KR', 'iso3': 'KOR', 'population': 1257, 'gdp': 4703, 'corporate_tax_rate': 30}
# 'source_city' is empty for Country: {'name': 'Germany', 'iso2': 'DE', 'iso3': 'DEU', 'population': 360, 'gdp': 12947, 'corporate_tax_rate': 48}
# 'source_city' is empty for Country: {'name': 'Netherlands', 'iso2': 'NL', 'iso3': 'NLD', 'population': 1103, 'gdp': 15007, 'corporate_tax_rate': 40}
# 'source_city' is empty for Country: {'name': 'United States of America', 'iso2': 'US', 'iso3': 'USA', 'population': 426, 'gdp': 1269, 'corporate_tax_rate': 14}
# 'source_city' is empty for Country: {'name': 'United States of America', 'iso2': 'US', 'iso3': 'USA', 'population': 291, 'gdp': 17181, 'corporate_tax_rate': 28}
# 'source_city' is empty for Country: {'name': 'Australia', 'iso2': 'AU', 'iso3': 'AUS', 'population': 339, 'gdp': 13042, 'corporate_tax_rate': 27}
# 'source_city' is empty for Country: {'name': 'Japan', 'iso2': 'JP', 'iso3': 'JPN', 'population': 306, 'gdp': 893, 'corporate_tax_rate': 42}
# 'source_city' is empty for Country: {'name': 'Belarus', 'iso2': 'BY', 'iso3': 'BLR', 'population': 957, 'gdp': 2980, 'corporate_tax_rate': 39}
# 'source_city' is empty for Country: {'name': 'Israel', 'iso2': 'IL', 'iso3': 'ISR', 'population': 920, 'gdp': 11702, 'corporate_tax_rate': 45}
# 'source_city' is empty for Country: {'name': 'Ukraine', 'iso2': 'UA', 'iso3': 'UKR', 'population': 101, 'gdp': 6666, 'corporate_tax_rate': 13}
# 'source_city' is empty for Country: {'name': 'United States of America', 'iso2': 'US', 'iso3': 'USA', 'population': 378, 'gdp': 12471, 'corporate_tax_rate': 48}
# 'source_city' is empty for Country: {'name': 'Israel', 'iso2': 'IL', 'iso3': 'ISR', 'population': 941, 'gdp': 8776, 'corporate_tax_rate': 17}
# 'source_city' is empty for Country: {'name': 'United States of America', 'iso2': 'US', 'iso3': 'USA', 'population': 1360, 'gdp': 14490, 'corporate_tax_rate': 42}
# 'source_city' is empty for Country: {'name': "People's Republic of China", 'iso2': 'CN', 'iso3': 'CHN', 'population': 1371, 'gdp': 13981, 'corporate_tax_rate': 23}
# 'source_city' is empty for Country: {'name': 'United Kingdom', 'iso2': 'GB', 'iso3': 'GBR', 'population': 604, 'gdp': 4876, 'corporate_tax_rate': 14}
# 'source_city' is empty for Country: {'name': 'United States of America', 'iso2': 'US', 'iso3': 'USA', 'population': 508, 'gdp': 566, 'corporate_tax_rate': 46}
# 'source_city' is empty for Country: {'name': 'Italy', 'iso2': 'IT', 'iso3': 'ITA', 'population': 549, 'gdp': 296, 'corporate_tax_rate': 49}
# 'source_city' is empty for Country: {'name': 'United States of America', 'iso2': 'US', 'iso3': 'USA', 'population': 402, 'gdp': 13369, 'corporate_tax_rate': 34}
# 'source_city' is empty for Country: {'name': 'United States of America', 'iso2': 'US', 'iso3': 'USA', 'population': 719, 'gdp': 12609, 'corporate_tax_rate': 45}
# 'source_city' is empty for Country: {'name': 'United Kingdom', 'iso2': 'GB', 'iso3': 'GBR', 'population': 836, 'gdp': 17415, 'corporate_tax_rate': 28}
# 'source_city' is empty for Country: {'name': 'Korea', 'population': 125, 'gdp': 15808, 'corporate_tax_rate': 44}
# 'iso2' is empty for Country: {'name': 'Korea', 'population': 125, 'gdp': 15808, 'corporate_tax_rate': 44}
# 'iso3' is empty for Country: {'name': 'Korea', 'population': 125, 'gdp': 15808, 'corporate_tax_rate': 44}
# 'source_city' is empty for Country: {'name': 'Australia', 'iso2': 'AU', 'iso3': 'AUS', 'population': 940, 'gdp': 17737, 'corporate_tax_rate': 31}
# 'source_city' is empty for Country: {'name': 'Canada', 'iso2': 'CA', 'iso3': 'CAN', 'population': 741, 'gdp': 19104, 'corporate_tax_rate': 35}
# 'source_city' is empty for Country: {'name': 'Japan', 'iso2': 'JP', 'iso3': 'JPN', 'population': 538, 'gdp': 13695, 'corporate_tax_rate': 45}
# 'source_city' is empty for Country: {'name': 'New Zealand', 'iso2': 'NZ', 'iso3': 'NZL', 'population': 914, 'gdp': 15761, 'corporate_tax_rate': 20}
# 'source_city' is empty for Country: {'name': 'Mexico', 'iso2': 'MX', 'iso3': 'MEX', 'population': 991, 'gdp': 9714, 'corporate_tax_rate': 12}
# 'source_city' is empty for Country: {'name': 'Spain', 'iso2': 'ES', 'iso3': 'ESP', 'population': 1356, 'gdp': 5240, 'corporate_tax_rate': 25}
# 'source_city' is empty for Country: {'name': 'Taiwan', 'iso2': 'TW', 'iso3': 'TWN', 'population': 791, 'gdp': 13575, 'corporate_tax_rate': 37}
# 'source_city' is empty for Country: {'name': 'Sweden', 'iso2': 'SE', 'iso3': 'SWE', 'population': 316, 'gdp': 15108, 'corporate_tax_rate': 31}
# 'source_city' is empty for Country: {'name': "People's Republic of China", 'iso2': 'CN', 'iso3': 'CHN', 'population': 266, 'gdp': 67, 'corporate_tax_rate': 16}
# 'source_city' is empty for Country: {'name': 'France', 'iso2': 'FR', 'iso3': 'FRA', 'population': 53, 'gdp': 11567, 'corporate_tax_rate': 38}
# 'source_city' is empty for Country: {'name': 'Iceland', 'iso2': 'IS', 'iso3': 'ISL', 'population': 625, 'gdp': 1168, 'corporate_tax_rate': 33}
# 'source_city' is empty for Country: {'name': 'Japan', 'iso2': 'JP', 'iso3': 'JPN', 'population': 459, 'gdp': 1798, 'corporate_tax_rate': 34}
# 'source_city' is empty for Country: {'name': 'Taiwan', 'iso2': 'TW', 'iso3': 'TWN', 'population': 148, 'gdp': 947, 'corporate_tax_rate': 10}
# 'source_city' is empty for Country: {'name': "People's Republic of China", 'iso2': 'CN', 'iso3': 'CHN', 'population': 89, 'gdp': 16868, 'corporate_tax_rate': 45}
# 'source_city' is empty for Country: {'name': 'Japan', 'iso2': 'JP', 'iso3': 'JPN', 'population': 71, 'gdp': 4032, 'corporate_tax_rate': 11}
# 'source_city' is empty for Country: {'name': 'Korea', 'population': 881, 'gdp': 4226, 'corporate_tax_rate': 29}
# 'iso2' is empty for Country: {'name': 'Korea', 'population': 881, 'gdp': 4226, 'corporate_tax_rate': 29}
# 'iso3' is empty for Country: {'name': 'Korea', 'population': 881, 'gdp': 4226, 'corporate_tax_rate': 29}
# 'source_city' is empty for Country: {'name': 'United States of America', 'iso2': 'US', 'iso3': 'USA', 'population': 1005, 'gdp': 9541, 'corporate_tax_rate': 50}
# 'source_city' is empty for Country: {'name': 'United Kingdom', 'iso2': 'GB', 'iso3': 'GBR', 'population': 1244, 'gdp': 10011, 'corporate_tax_rate': 29}
# 'source_city' is empty for Country: {'name': 'South Korea', 'iso2': 'KR', 'iso3': 'KOR', 'population': 646, 'gdp': 5416, 'corporate_tax_rate': 23}
# 'source_city' is empty for Country: {'name': 'United Kingdom', 'iso2': 'GB', 'iso3': 'GBR', 'population': 293, 'gdp': 9092, 'corporate_tax_rate': 34}
# 'source_city' is empty for Country: {'name': 'Australia', 'iso2': 'AU', 'iso3': 'AUS', 'population': 1247, 'gdp': 19831, 'corporate_tax_rate': 25}
# 'iso2' is empty for Country: {'source_city': 'United States Germany', 'name': 'Isle Of Man', 'population': 1072, 'gdp': 6008, 'corporate_tax_rate': 26}
# 'iso3' is empty for Country: {'source_city': 'United States Germany', 'name': 'Isle Of Man', 'population': 1072, 'gdp': 6008, 'corporate_tax_rate': 26}
# 'iso2' is empty for Country: {'source_city': 'Latin America', 'name': 'Brazi', 'population': 655, 'gdp': 4076, 'corporate_tax_rate': 35}
# 'iso3' is empty for Country: {'source_city': 'Latin America', 'name': 'Brazi', 'population': 655, 'gdp': 4076, 'corporate_tax_rate': 35}
# 'source_city' is empty for Country: {'name': 'Argentina', 'iso2': 'AR', 'iso3': 'ARG', 'population': 180, 'gdp': 10545, 'corporate_tax_rate': 35}
# 'source_city' is empty for Country: {'name': 'Mexico', 'iso2': 'MX', 'iso3': 'MEX', 'population': 1260, 'gdp': 2025, 'corporate_tax_rate': 26}
# 'source_city' is empty for Country: {'name': 'El Salvador', 'iso2': 'SV', 'iso3': 'SLV', 'population': 617, 'gdp': 10631, 'corporate_tax_rate': 48}
# 'source_city' is empty for Country: {'name': 'Chile', 'iso2': 'CL', 'iso3': 'CHL', 'population': 837, 'gdp': 17408, 'corporate_tax_rate': 34}
# 'source_city' is empty for Country: {'name': 'Colombia', 'iso2': 'CO', 'iso3': 'COL', 'population': 52, 'gdp': 1256, 'corporate_tax_rate': 47}
# 'source_city' is empty for Country: {'name': 'Peru', 'iso2': 'PE', 'iso3': 'PER', 'population': 52, 'gdp': 3810, 'corporate_tax_rate': 33}
# 'source_city' is empty for Country: {'name': 'Costa Rica', 'iso2': 'CR', 'iso3': 'CRI', 'population': 850, 'gdp': 5808, 'corporate_tax_rate': 46}
# 'source_city' is empty for Country: {'name': 'Dominican Republic', 'iso2': 'DO', 'iso3': 'DOM', 'population': 299, 'gdp': 9500, 'corporate_tax_rate': 16}
# 'source_city' is empty for Country: {'name': 'Nicaragua', 'iso2': 'NI', 'iso3': 'NIC', 'population': 403, 'gdp': 10985, 'corporate_tax_rate': 32}
# 'source_city' is empty for Country: {'name': 'Chile', 'iso2': 'CL', 'iso3': 'CHL', 'population': 947, 'gdp': 9291, 'corporate_tax_rate': 48}
# 'source_city' is empty for Country: {'name': 'Argentina', 'iso2': 'AR', 'iso3': 'ARG', 'population': 349, 'gdp': 18772, 'corporate_tax_rate': 17}
# 'iso2' is empty for Country: {'source_city': 'Latin America', 'name': 'Brazi', 'population': 263, 'gdp': 10637, 'corporate_tax_rate': 31}
# 'iso3' is empty for Country: {'source_city': 'Latin America', 'name': 'Brazi', 'population': 263, 'gdp': 10637, 'corporate_tax_rate': 31}
# 'source_city' is empty for Country: {'name': 'Uruguay', 'iso2': 'UY', 'iso3': 'URY', 'population': 1343, 'gdp': 2508, 'corporate_tax_rate': 33}
# 'source_city' is empty for Country: {'name': 'Colombia', 'iso2': 'CO', 'iso3': 'COL', 'population': 1359, 'gdp': 11054, 'corporate_tax_rate': 38}
# 'source_city' is empty for Country: {'name': 'Peru', 'iso2': 'PE', 'iso3': 'PER', 'population': 172, 'gdp': 19947, 'corporate_tax_rate': 36}
# 'source_city' is empty for Country: {'name': 'Mexico', 'iso2': 'MX', 'iso3': 'MEX', 'population': 216, 'gdp': 5749, 'corporate_tax_rate': 24}
# 'source_city' is empty for Country: {'name': 'El Salvador', 'iso2': 'SV', 'iso3': 'SLV', 'population': 1338, 'gdp': 1860, 'corporate_tax_rate': 49}
# 'source_city' is empty for Country: {'name': 'Dominican Republic', 'iso2': 'DO', 'iso3': 'DOM', 'population': 318, 'gdp': 15881, 'corporate_tax_rate': 27}
# 'source_city' is empty for Country: {'name': 'Nicaragua', 'iso2': 'NI', 'iso3': 'NIC', 'population': 1276, 'gdp': 19607, 'corporate_tax_rate': 23}
# 'source_city' is empty for Country: {'name': 'Paraguay', 'iso2': 'PY', 'iso3': 'PRY', 'population': 1381, 'gdp': 13087, 'corporate_tax_rate': 46}
# 'source_city' is empty for Country: {'name': 'Brazil', 'iso2': 'BR', 'iso3': 'BRA', 'population': 669, 'gdp': 12750, 'corporate_tax_rate': 12}
# 'source_city' is empty for Country: {'name': 'Honduras', 'iso2': 'HN', 'iso3': 'HND', 'population': 1239, 'gdp': 5959, 'corporate_tax_rate': 45}
# 'source_city' is empty for Country: {'name': 'Costa Rica', 'iso2': 'CR', 'iso3': 'CRI', 'population': 120, 'gdp': 4518, 'corporate_tax_rate': 14}
# 'source_city' is empty for Country: {'name': 'Ecuador', 'iso2': 'EC', 'iso3': 'ECU', 'population': 1095, 'gdp': 19565, 'corporate_tax_rate': 18}
# 'source_city' is empty for Country: {'name': 'Bolivia', 'iso2': 'BO', 'iso3': 'BOL', 'population': 944, 'gdp': 3841, 'corporate_tax_rate': 10}
# 'source_city' is empty for Country: {'name': 'United States of America', 'iso2': 'US', 'iso3': 'USA', 'population': 562, 'gdp': 4216, 'corporate_tax_rate': 17}
# 'source_city' is empty for Country: {'name': "People's Republic of China", 'iso2': 'CN', 'iso3': 'CHN', 'population': 818, 'gdp': 16145, 'corporate_tax_rate': 17}
# 'source_city' is empty for Country: {'name': 'Saudi Arabia', 'iso2': 'SA', 'iso3': 'SAU', 'population': 465, 'gdp': 6591, 'corporate_tax_rate': 46}
# 'source_city' is empty for Country: {'name': 'Russia', 'iso2': 'RU', 'iso3': 'RUS', 'population': 50, 'gdp': 13899, 'corporate_tax_rate': 20}
# 'source_city' is empty for Country: {'name': 'Israel', 'iso2': 'IL', 'iso3': 'ISR', 'population': 260, 'gdp': 1410, 'corporate_tax_rate': 23}
# 'SIC_code' is empty for Industry: {'name': 'Apple Card', 'SIC_code': None, 'industry_group': None, 'subindustry_desc': None, 'primary_activity': None}
# 'industry_group' is empty for Industry: {'name': 'Apple Card', 'SIC_code': None, 'industry_group': None, 'subindustry_desc': None, 'primary_activity': None}
# 'subindustry_desc' is empty for Industry: {'name': 'Apple Card', 'SIC_code': None, 'industry_group': None, 'subindustry_desc': None, 'primary_activity': None}
# 'primary_activity' is empty for Industry: {'name': 'Apple Card', 'SIC_code': None, 'industry_group': None, 'subindustry_desc': None, 'primary_activity': None}
# 'SIC_code' is empty for Industry: {'name': 'iPhone', 'SIC_code': None, 'industry_group': None, 'subindustry_desc': None, 'primary_activity': None}
# 'industry_group' is empty for Industry: {'name': 'iPhone', 'SIC_code': None, 'industry_group': None, 'subindustry_desc': None, 'primary_activity': None}
# 'subindustry_desc' is empty for Industry: {'name': 'iPhone', 'SIC_code': None, 'industry_group': None, 'subindustry_desc': None, 'primary_activity': None}
# 'primary_activity' is empty for Industry: {'name': 'iPhone', 'SIC_code': None, 'industry_group': None, 'subindustry_desc': None, 'primary_activity': None}
# 'SIC_code' is empty for Industry: {'name': 'artificial intelligence', 'SIC_code': None, 'industry_group': None, 'subindustry_desc': None, 'primary_activity': None}
# 'industry_group' is empty for Industry: {'name': 'artificial intelligence', 'SIC_code': None, 'industry_group': None, 'subindustry_desc': None, 'primary_activity': None}
# 'subindustry_desc' is empty for Industry: {'name': 'artificial intelligence', 'SIC_code': None, 'industry_group': None, 'subindustry_desc': None, 'primary_activity': None}
# 'primary_activity' is empty for Industry: {'name': 'artificial intelligence', 'SIC_code': None, 'industry_group': None, 'subindustry_desc': None, 'primary_activity': None}
# 'SIC_code' is empty for Industry: {'name': 'accounting', 'SIC_code': None, 'industry_group': None, 'subindustry_desc': None, 'primary_activity': None}
# 'industry_group' is empty for Industry: {'name': 'accounting', 'SIC_code': None, 'industry_group': None, 'subindustry_desc': None, 'primary_activity': None}
# 'subindustry_desc' is empty for Industry: {'name': 'accounting', 'SIC_code': None, 'industry_group': None, 'subindustry_desc': None, 'primary_activity': None}
# 'primary_activity' is empty for Industry: {'name': 'accounting', 'SIC_code': None, 'industry_group': None, 'subindustry_desc': None, 'primary_activity': None}
# 'SIC_code' is empty for Industry: {'name': 'automotive industry', 'SIC_code': None, 'industry_group': None, 'subindustry_desc': None, 'primary_activity': None}
# 'industry_group' is empty for Industry: {'name': 'automotive industry', 'SIC_code': None, 'industry_group': None, 'subindustry_desc': None, 'primary_activity': None}
# 'subindustry_desc' is empty for Industry: {'name': 'automotive industry', 'SIC_code': None, 'industry_group': None, 'subindustry_desc': None, 'primary_activity': None}
# 'primary_activity' is empty for Industry: {'name': 'automotive industry', 'SIC_code': None, 'industry_group': None, 'subindustry_desc': None, 'primary_activity': None}
# 'SIC_code' is empty for Industry: {'name': 'etching', 'SIC_code': None, 'industry_group': None, 'subindustry_desc': None, 'primary_activity': None}
# 'industry_group' is empty for Industry: {'name': 'etching', 'SIC_code': None, 'industry_group': None, 'subindustry_desc': None, 'primary_activity': None}
# 'subindustry_desc' is empty for Industry: {'name': 'etching', 'SIC_code': None, 'industry_group': None, 'subindustry_desc': None, 'primary_activity': None}
# 'primary_activity' is empty for Industry: {'name': 'etching', 'SIC_code': None, 'industry_group': None, 'subindustry_desc': None, 'primary_activity': None}
# 'SIC_code' is empty for Industry: {'name': 'electrochemistry', 'SIC_code': None, 'industry_group': None, 'subindustry_desc': None, 'primary_activity': None}
# 'industry_group' is empty for Industry: {'name': 'electrochemistry', 'SIC_code': None, 'industry_group': None, 'subindustry_desc': None, 'primary_activity': None}
# 'subindustry_desc' is empty for Industry: {'name': 'electrochemistry', 'SIC_code': None, 'industry_group': None, 'subindustry_desc': None, 'primary_activity': None}
# 'primary_activity' is empty for Industry: {'name': 'electrochemistry', 'SIC_code': None, 'industry_group': None, 'subindustry_desc': None, 'primary_activity': None}
# 'SIC_code' is empty for Industry: {'name': 'AMD Instinct', 'SIC_code': None, 'industry_group': None, 'subindustry_desc': None, 'primary_activity': None}
# 'industry_group' is empty for Industry: {'name': 'AMD Instinct', 'SIC_code': None, 'industry_group': None, 'subindustry_desc': None, 'primary_activity': None}
# 'subindustry_desc' is empty for Industry: {'name': 'AMD Instinct', 'SIC_code': None, 'industry_group': None, 'subindustry_desc': None, 'primary_activity': None}
# 'primary_activity' is empty for Industry: {'name': 'AMD Instinct', 'SIC_code': None, 'industry_group': None, 'subindustry_desc': None, 'primary_activity': None}
# 'SIC_code' is empty for Industry: {'name': 'artificial intelligence', 'SIC_code': None, 'industry_group': None, 'subindustry_desc': None, 'primary_activity': None}
# 'industry_group' is empty for Industry: {'name': 'artificial intelligence', 'SIC_code': None, 'industry_group': None, 'subindustry_desc': None, 'primary_activity': None}
# 'subindustry_desc' is empty for Industry: {'name': 'artificial intelligence', 'SIC_code': None, 'industry_group': None, 'subindustry_desc': None, 'primary_activity': None}
# 'primary_activity' is empty for Industry: {'name': 'artificial intelligence', 'SIC_code': None, 'industry_group': None, 'subindustry_desc': None, 'primary_activity': None}
# 'SIC_code' is empty for Industry: {'name': 'accounting', 'SIC_code': None, 'industry_group': None, 'subindustry_desc': None, 'primary_activity': None}
# 'industry_group' is empty for Industry: {'name': 'accounting', 'SIC_code': None, 'industry_group': None, 'subindustry_desc': None, 'primary_activity': None}
# 'subindustry_desc' is empty for Industry: {'name': 'accounting', 'SIC_code': None, 'industry_group': None, 'subindustry_desc': None, 'primary_activity': None}
# 'primary_activity' is empty for Industry: {'name': 'accounting', 'SIC_code': None, 'industry_group': None, 'subindustry_desc': None, 'primary_activity': None}
# 'SIC_code' is empty for Industry: {'name': 'AMD Instinct', 'SIC_code': None, 'industry_group': None, 'subindustry_desc': None, 'primary_activity': None}
# 'industry_group' is empty for Industry: {'name': 'AMD Instinct', 'SIC_code': None, 'industry_group': None, 'subindustry_desc': None, 'primary_activity': None}
# 'subindustry_desc' is empty for Industry: {'name': 'AMD Instinct', 'SIC_code': None, 'industry_group': None, 'subindustry_desc': None, 'primary_activity': None}
# 'primary_activity' is empty for Industry: {'name': 'AMD Instinct', 'SIC_code': None, 'industry_group': None, 'subindustry_desc': None, 'primary_activity': None}
# 'SIC_code' is empty for Industry: {'name': 'AMD Instinct', 'SIC_code': None, 'industry_group': None, 'subindustry_desc': None, 'primary_activity': None}
# 'industry_group' is empty for Industry: {'name': 'AMD Instinct', 'SIC_code': None, 'industry_group': None, 'subindustry_desc': None, 'primary_activity': None}
# 'subindustry_desc' is empty for Industry: {'name': 'AMD Instinct', 'SIC_code': None, 'industry_group': None, 'subindustry_desc': None, 'primary_activity': None}
# 'primary_activity' is empty for Industry: {'name': 'AMD Instinct', 'SIC_code': None, 'industry_group': None, 'subindustry_desc': None, 'primary_activity': None}
# 'SIC_code' is empty for Industry: {'name': 'Ryzen', 'SIC_code': None, 'industry_group': None, 'subindustry_desc': None, 'primary_activity': None}
# 'industry_group' is empty for Industry: {'name': 'Ryzen', 'SIC_code': None, 'industry_group': None, 'subindustry_desc': None, 'primary_activity': None}
# 'subindustry_desc' is empty for Industry: {'name': 'Ryzen', 'SIC_code': None, 'industry_group': None, 'subindustry_desc': None, 'primary_activity': None}
# 'primary_activity' is empty for Industry: {'name': 'Ryzen', 'SIC_code': None, 'industry_group': None, 'subindustry_desc': None, 'primary_activity': None}
# 'SIC_code' is empty for Industry: {'name': 'AMD EPYC', 'SIC_code': None, 'industry_group': None, 'subindustry_desc': None, 'primary_activity': None}
# 'industry_group' is empty for Industry: {'name': 'AMD EPYC', 'SIC_code': None, 'industry_group': None, 'subindustry_desc': None, 'primary_activity': None}
# 'subindustry_desc' is empty for Industry: {'name': 'AMD EPYC', 'SIC_code': None, 'industry_group': None, 'subindustry_desc': None, 'primary_activity': None}
# 'primary_activity' is empty for Industry: {'name': 'AMD EPYC', 'SIC_code': None, 'industry_group': None, 'subindustry_desc': None, 'primary_activity': None}
# 'SIC_code' is empty for Industry: {'name': 'artificial intelligence', 'SIC_code': None, 'industry_group': None, 'subindustry_desc': None, 'primary_activity': None}
# 'industry_group' is empty for Industry: {'name': 'artificial intelligence', 'SIC_code': None, 'industry_group': None, 'subindustry_desc': None, 'primary_activity': None}
# 'subindustry_desc' is empty for Industry: {'name': 'artificial intelligence', 'SIC_code': None, 'industry_group': None, 'subindustry_desc': None, 'primary_activity': None}
# 'primary_activity' is empty for Industry: {'name': 'artificial intelligence', 'SIC_code': None, 'industry_group': None, 'subindustry_desc': None, 'primary_activity': None}
# 'SIC_code' is empty for Industry: {'name': 'automotive industry', 'SIC_code': None, 'industry_group': None, 'subindustry_desc': None, 'primary_activity': None}
# 'industry_group' is empty for Industry: {'name': 'automotive industry', 'SIC_code': None, 'industry_group': None, 'subindustry_desc': None, 'primary_activity': None}
# 'subindustry_desc' is empty for Industry: {'name': 'automotive industry', 'SIC_code': None, 'industry_group': None, 'subindustry_desc': None, 'primary_activity': None}
# 'primary_activity' is empty for Industry: {'name': 'automotive industry', 'SIC_code': None, 'industry_group': None, 'subindustry_desc': None, 'primary_activity': None}
# 'SIC_code' is empty for Industry: {'name': 'etching', 'SIC_code': None, 'industry_group': None, 'subindustry_desc': None, 'primary_activity': None}
# 'industry_group' is empty for Industry: {'name': 'etching', 'SIC_code': None, 'industry_group': None, 'subindustry_desc': None, 'primary_activity': None}
# 'subindustry_desc' is empty for Industry: {'name': 'etching', 'SIC_code': None, 'industry_group': None, 'subindustry_desc': None, 'primary_activity': None}
# 'primary_activity' is empty for Industry: {'name': 'etching', 'SIC_code': None, 'industry_group': None, 'subindustry_desc': None, 'primary_activity': None}
# 'SIC_code' is empty for Industry: {'name': 'electrochemistry', 'SIC_code': None, 'industry_group': None, 'subindustry_desc': None, 'primary_activity': None}
# 'industry_group' is empty for Industry: {'name': 'electrochemistry', 'SIC_code': None, 'industry_group': None, 'subindustry_desc': None, 'primary_activity': None}
# 'subindustry_desc' is empty for Industry: {'name': 'electrochemistry', 'SIC_code': None, 'industry_group': None, 'subindustry_desc': None, 'primary_activity': None}
# 'primary_activity' is empty for Industry: {'name': 'electrochemistry', 'SIC_code': None, 'industry_group': None, 'subindustry_desc': None, 'primary_activity': None}
# 'SIC_code' is empty for Industry: {'name': 'ethics of artificial intelligence', 'SIC_code': None, 'industry_group': None, 'subindustry_desc': None, 'primary_activity': None}
# 'industry_group' is empty for Industry: {'name': 'ethics of artificial intelligence', 'SIC_code': None, 'industry_group': None, 'subindustry_desc': None, 'primary_activity': None}
# 'subindustry_desc' is empty for Industry: {'name': 'ethics of artificial intelligence', 'SIC_code': None, 'industry_group': None, 'subindustry_desc': None, 'primary_activity': None}
# 'primary_activity' is empty for Industry: {'name': 'ethics of artificial intelligence', 'SIC_code': None, 'industry_group': None, 'subindustry_desc': None, 'primary_activity': None}
# 'SIC_code' is empty for Industry: {'name': 'ethics of artificial intelligence', 'SIC_code': None, 'industry_group': None, 'subindustry_desc': None, 'primary_activity': None}
# 'industry_group' is empty for Industry: {'name': 'ethics of artificial intelligence', 'SIC_code': None, 'industry_group': None, 'subindustry_desc': None, 'primary_activity': None}
# 'subindustry_desc' is empty for Industry: {'name': 'ethics of artificial intelligence', 'SIC_code': None, 'industry_group': None, 'subindustry_desc': None, 'primary_activity': None}
# 'primary_activity' is empty for Industry: {'name': 'ethics of artificial intelligence', 'SIC_code': None, 'industry_group': None, 'subindustry_desc': None, 'primary_activity': None}
# 'SIC_code' is empty for Industry: {'name': 'Apple Card', 'SIC_code': None, 'industry_group': None, 'subindustry_desc': None, 'primary_activity': None}
# 'industry_group' is empty for Industry: {'name': 'Apple Card', 'SIC_code': None, 'industry_group': None, 'subindustry_desc': None, 'primary_activity': None}
# 'subindustry_desc' is empty for Industry: {'name': 'Apple Card', 'SIC_code': None, 'industry_group': None, 'subindustry_desc': None, 'primary_activity': None}
# 'primary_activity' is empty for Industry: {'name': 'Apple Card', 'SIC_code': None, 'industry_group': None, 'subindustry_desc': None, 'primary_activity': None}
# 'SIC_code' is empty for Industry: {'name': 'iPhone', 'SIC_code': None, 'industry_group': None, 'subindustry_desc': None, 'primary_activity': None}
# 'industry_group' is empty for Industry: {'name': 'iPhone', 'SIC_code': None, 'industry_group': None, 'subindustry_desc': None, 'primary_activity': None}
# 'subindustry_desc' is empty for Industry: {'name': 'iPhone', 'SIC_code': None, 'industry_group': None, 'subindustry_desc': None, 'primary_activity': None}
# 'primary_activity' is empty for Industry: {'name': 'iPhone', 'SIC_code': None, 'industry_group': None, 'subindustry_desc': None, 'primary_activity': None}
# 'SIC_code' is empty for Industry: {'name': 'CMOS', 'SIC_code': None, 'industry_group': None, 'subindustry_desc': None, 'primary_activity': None}
# 'industry_group' is empty for Industry: {'name': 'CMOS', 'SIC_code': None, 'industry_group': None, 'subindustry_desc': None, 'primary_activity': None}
# 'subindustry_desc' is empty for Industry: {'name': 'CMOS', 'SIC_code': None, 'industry_group': None, 'subindustry_desc': None, 'primary_activity': None}
# 'primary_activity' is empty for Industry: {'name': 'CMOS', 'SIC_code': None, 'industry_group': None, 'subindustry_desc': None, 'primary_activity': None}
# 'SIC_code' is empty for Industry: {'name': 'artificial intelligence', 'SIC_code': None, 'industry_group': None, 'subindustry_desc': None, 'primary_activity': None}
# 'industry_group' is empty for Industry: {'name': 'artificial intelligence', 'SIC_code': None, 'industry_group': None, 'subindustry_desc': None, 'primary_activity': None}
# 'subindustry_desc' is empty for Industry: {'name': 'artificial intelligence', 'SIC_code': None, 'industry_group': None, 'subindustry_desc': None, 'primary_activity': None}
# 'primary_activity' is empty for Industry: {'name': 'artificial intelligence', 'SIC_code': None, 'industry_group': None, 'subindustry_desc': None, 'primary_activity': None}
# 'SIC_code' is empty for Industry: {'name': 'computer security', 'SIC_code': None, 'industry_group': None, 'subindustry_desc': None, 'primary_activity': None}
# 'industry_group' is empty for Industry: {'name': 'computer security', 'SIC_code': None, 'industry_group': None, 'subindustry_desc': None, 'primary_activity': None}
# 'subindustry_desc' is empty for Industry: {'name': 'computer security', 'SIC_code': None, 'industry_group': None, 'subindustry_desc': None, 'primary_activity': None}
# 'primary_activity' is empty for Industry: {'name': 'computer security', 'SIC_code': None, 'industry_group': None, 'subindustry_desc': None, 'primary_activity': None}
# 'SIC_code' is empty for Industry: {'name': 'wireless communication', 'SIC_code': None, 'industry_group': None, 'subindustry_desc': None, 'primary_activity': None}
# 'industry_group' is empty for Industry: {'name': 'wireless communication', 'SIC_code': None, 'industry_group': None, 'subindustry_desc': None, 'primary_activity': None}
# 'subindustry_desc' is empty for Industry: {'name': 'wireless communication', 'SIC_code': None, 'industry_group': None, 'subindustry_desc': None, 'primary_activity': None}
# 'primary_activity' is empty for Industry: {'name': 'wireless communication', 'SIC_code': None, 'industry_group': None, 'subindustry_desc': None, 'primary_activity': None}
# 'SIC_code' is empty for Industry: {'name': 'operations management', 'SIC_code': None, 'industry_group': None, 'subindustry_desc': None, 'primary_activity': None}
# 'industry_group' is empty for Industry: {'name': 'operations management', 'SIC_code': None, 'industry_group': None, 'subindustry_desc': None, 'primary_activity': None}
# 'subindustry_desc' is empty for Industry: {'name': 'operations management', 'SIC_code': None, 'industry_group': None, 'subindustry_desc': None, 'primary_activity': None}
# 'primary_activity' is empty for Industry: {'name': 'operations management', 'SIC_code': None, 'industry_group': None, 'subindustry_desc': None, 'primary_activity': None}
# 'SIC_code' is empty for Industry: {'name': 'analysis', 'SIC_code': None, 'industry_group': None, 'subindustry_desc': None, 'primary_activity': None}
# 'industry_group' is empty for Industry: {'name': 'analysis', 'SIC_code': None, 'industry_group': None, 'subindustry_desc': None, 'primary_activity': None}
# 'subindustry_desc' is empty for Industry: {'name': 'analysis', 'SIC_code': None, 'industry_group': None, 'subindustry_desc': None, 'primary_activity': None}
# 'primary_activity' is empty for Industry: {'name': 'analysis', 'SIC_code': None, 'industry_group': None, 'subindustry_desc': None, 'primary_activity': None}
# 'SIC_code' is empty for Industry: {'name': 'management', 'SIC_code': None, 'industry_group': None, 'subindustry_desc': None, 'primary_activity': None}
# 'industry_group' is empty for Industry: {'name': 'management', 'SIC_code': None, 'industry_group': None, 'subindustry_desc': None, 'primary_activity': None}
# 'subindustry_desc' is empty for Industry: {'name': 'management', 'SIC_code': None, 'industry_group': None, 'subindustry_desc': None, 'primary_activity': None}
# 'primary_activity' is empty for Industry: {'name': 'management', 'SIC_code': None, 'industry_group': None, 'subindustry_desc': None, 'primary_activity': None}
# 'SIC_code' is empty for Industry: {'name': 'management', 'SIC_code': None, 'industry_group': None, 'subindustry_desc': None, 'primary_activity': None}
# 'industry_group' is empty for Industry: {'name': 'management', 'SIC_code': None, 'industry_group': None, 'subindustry_desc': None, 'primary_activity': None}
# 'subindustry_desc' is empty for Industry: {'name': 'management', 'SIC_code': None, 'industry_group': None, 'subindustry_desc': None, 'primary_activity': None}
# 'primary_activity' is empty for Industry: {'name': 'management', 'SIC_code': None, 'industry_group': None, 'subindustry_desc': None, 'primary_activity': None}
# 'SIC_code' is empty for Industry: {'name': 'oncology', 'SIC_code': None, 'industry_group': None, 'subindustry_desc': None, 'primary_activity': None}
# 'industry_group' is empty for Industry: {'name': 'oncology', 'SIC_code': None, 'industry_group': None, 'subindustry_desc': None, 'primary_activity': None}
# 'subindustry_desc' is empty for Industry: {'name': 'oncology', 'SIC_code': None, 'industry_group': None, 'subindustry_desc': None, 'primary_activity': None}
# 'primary_activity' is empty for Industry: {'name': 'oncology', 'SIC_code': None, 'industry_group': None, 'subindustry_desc': None, 'primary_activity': None}
# 'SIC_code' is empty for Industry: {'name': 'automation', 'SIC_code': None, 'industry_group': None, 'subindustry_desc': None, 'primary_activity': None}
# 'industry_group' is empty for Industry: {'name': 'automation', 'SIC_code': None, 'industry_group': None, 'subindustry_desc': None, 'primary_activity': None}
# 'subindustry_desc' is empty for Industry: {'name': 'automation', 'SIC_code': None, 'industry_group': None, 'subindustry_desc': None, 'primary_activity': None}
# 'primary_activity' is empty for Industry: {'name': 'automation', 'SIC_code': None, 'industry_group': None, 'subindustry_desc': None, 'primary_activity': None}
# 'SIC_code' is empty for Industry: {'name': 'sensor', 'SIC_code': None, 'industry_group': None, 'subindustry_desc': None, 'primary_activity': None}
# 'industry_group' is empty for Industry: {'name': 'sensor', 'SIC_code': None, 'industry_group': None, 'subindustry_desc': None, 'primary_activity': None}
# 'subindustry_desc' is empty for Industry: {'name': 'sensor', 'SIC_code': None, 'industry_group': None, 'subindustry_desc': None, 'primary_activity': None}
# 'primary_activity' is empty for Industry: {'name': 'sensor', 'SIC_code': None, 'industry_group': None, 'subindustry_desc': None, 'primary_activity': None}
# 'SIC_code' is empty for Industry: {'name': 'building automation', 'SIC_code': None, 'industry_group': None, 'subindustry_desc': None, 'primary_activity': None}
# 'industry_group' is empty for Industry: {'name': 'building automation', 'SIC_code': None, 'industry_group': None, 'subindustry_desc': None, 'primary_activity': None}
# 'subindustry_desc' is empty for Industry: {'name': 'building automation', 'SIC_code': None, 'industry_group': None, 'subindustry_desc': None, 'primary_activity': None}
# 'primary_activity' is empty for Industry: {'name': 'building automation', 'SIC_code': None, 'industry_group': None, 'subindustry_desc': None, 'primary_activity': None}
# 'SIC_code' is empty for Industry: {'name': 'management', 'SIC_code': None, 'industry_group': None, 'subindustry_desc': None, 'primary_activity': None}
# 'industry_group' is empty for Industry: {'name': 'management', 'SIC_code': None, 'industry_group': None, 'subindustry_desc': None, 'primary_activity': None}
# 'subindustry_desc' is empty for Industry: {'name': 'management', 'SIC_code': None, 'industry_group': None, 'subindustry_desc': None, 'primary_activity': None}
# 'primary_activity' is empty for Industry: {'name': 'management', 'SIC_code': None, 'industry_group': None, 'subindustry_desc': None, 'primary_activity': None}
# 'SIC_code' is empty for Industry: {'name': 'finance', 'SIC_code': None, 'industry_group': None, 'subindustry_desc': None, 'primary_activity': None}
# 'industry_group' is empty for Industry: {'name': 'finance', 'SIC_code': None, 'industry_group': None, 'subindustry_desc': None, 'primary_activity': None}
# 'subindustry_desc' is empty for Industry: {'name': 'finance', 'SIC_code': None, 'industry_group': None, 'subindustry_desc': None, 'primary_activity': None}
# 'primary_activity' is empty for Industry: {'name': 'finance', 'SIC_code': None, 'industry_group': None, 'subindustry_desc': None, 'primary_activity': None}
# 'SIC_code' is empty for Industry: {'name': 'self-employment', 'SIC_code': None, 'industry_group': None, 'subindustry_desc': None, 'primary_activity': None}
# 'industry_group' is empty for Industry: {'name': 'self-employment', 'SIC_code': None, 'industry_group': None, 'subindustry_desc': None, 'primary_activity': None}
# 'subindustry_desc' is empty for Industry: {'name': 'self-employment', 'SIC_code': None, 'industry_group': None, 'subindustry_desc': None, 'primary_activity': None}
# 'primary_activity' is empty for Industry: {'name': 'self-employment', 'SIC_code': None, 'industry_group': None, 'subindustry_desc': None, 'primary_activity': None}
# 'SIC_code' is empty for Industry: {'name': 'artificial intelligence', 'SIC_code': None, 'industry_group': None, 'subindustry_desc': None, 'primary_activity': None}
# 'industry_group' is empty for Industry: {'name': 'artificial intelligence', 'SIC_code': None, 'industry_group': None, 'subindustry_desc': None, 'primary_activity': None}
# 'subindustry_desc' is empty for Industry: {'name': 'artificial intelligence', 'SIC_code': None, 'industry_group': None, 'subindustry_desc': None, 'primary_activity': None}
# 'primary_activity' is empty for Industry: {'name': 'artificial intelligence', 'SIC_code': None, 'industry_group': None, 'subindustry_desc': None, 'primary_activity': None}
# 'SIC_code' is empty for Industry: {'name': 'accounting', 'SIC_code': None, 'industry_group': None, 'subindustry_desc': None, 'primary_activity': None}
# 'industry_group' is empty for Industry: {'name': 'accounting', 'SIC_code': None, 'industry_group': None, 'subindustry_desc': None, 'primary_activity': None}
# 'subindustry_desc' is empty for Industry: {'name': 'accounting', 'SIC_code': None, 'industry_group': None, 'subindustry_desc': None, 'primary_activity': None}
# 'primary_activity' is empty for Industry: {'name': 'accounting', 'SIC_code': None, 'industry_group': None, 'subindustry_desc': None, 'primary_activity': None}
# 'SIC_code' is empty for Industry: {'name': 'self-employment', 'SIC_code': None, 'industry_group': None, 'subindustry_desc': None, 'primary_activity': None}
# 'industry_group' is empty for Industry: {'name': 'self-employment', 'SIC_code': None, 'industry_group': None, 'subindustry_desc': None, 'primary_activity': None}
# 'subindustry_desc' is empty for Industry: {'name': 'self-employment', 'SIC_code': None, 'industry_group': None, 'subindustry_desc': None, 'primary_activity': None}
# 'primary_activity' is empty for Industry: {'name': 'self-employment', 'SIC_code': None, 'industry_group': None, 'subindustry_desc': None, 'primary_activity': None}
# 'SIC_code' is empty for Industry: {'name': 'management', 'SIC_code': None, 'industry_group': None, 'subindustry_desc': None, 'primary_activity': None}
# 'industry_group' is empty for Industry: {'name': 'management', 'SIC_code': None, 'industry_group': None, 'subindustry_desc': None, 'primary_activity': None}
# 'subindustry_desc' is empty for Industry: {'name': 'management', 'SIC_code': None, 'industry_group': None, 'subindustry_desc': None, 'primary_activity': None}
# 'primary_activity' is empty for Industry: {'name': 'management', 'SIC_code': None, 'industry_group': None, 'subindustry_desc': None, 'primary_activity': None}
# 'SIC_code' is empty for Industry: {'name': 'dynamic random-access memory', 'SIC_code': None, 'industry_group': None, 'subindustry_desc': None, 'primary_activity': None}
# 'industry_group' is empty for Industry: {'name': 'dynamic random-access memory', 'SIC_code': None, 'industry_group': None, 'subindustry_desc': None, 'primary_activity': None}
# 'subindustry_desc' is empty for Industry: {'name': 'dynamic random-access memory', 'SIC_code': None, 'industry_group': None, 'subindustry_desc': None, 'primary_activity': None}
# 'primary_activity' is empty for Industry: {'name': 'dynamic random-access memory', 'SIC_code': None, 'industry_group': None, 'subindustry_desc': None, 'primary_activity': None}
# 'SIC_code' is empty for Industry: {'name': 'flash memory', 'SIC_code': None, 'industry_group': None, 'subindustry_desc': None, 'primary_activity': None}
# 'industry_group' is empty for Industry: {'name': 'flash memory', 'SIC_code': None, 'industry_group': None, 'subindustry_desc': None, 'primary_activity': None}
# 'subindustry_desc' is empty for Industry: {'name': 'flash memory', 'SIC_code': None, 'industry_group': None, 'subindustry_desc': None, 'primary_activity': None}
# 'primary_activity' is empty for Industry: {'name': 'flash memory', 'SIC_code': None, 'industry_group': None, 'subindustry_desc': None, 'primary_activity': None}
# 'SIC_code' is empty for Industry: {'name': 'dynamic random-access memory', 'SIC_code': None, 'industry_group': None, 'subindustry_desc': None, 'primary_activity': None}
# 'industry_group' is empty for Industry: {'name': 'dynamic random-access memory', 'SIC_code': None, 'industry_group': None, 'subindustry_desc': None, 'primary_activity': None}
# 'subindustry_desc' is empty for Industry: {'name': 'dynamic random-access memory', 'SIC_code': None, 'industry_group': None, 'subindustry_desc': None, 'primary_activity': None}
# 'primary_activity' is empty for Industry: {'name': 'dynamic random-access memory', 'SIC_code': None, 'industry_group': None, 'subindustry_desc': None, 'primary_activity': None}
# 'SIC_code' is empty for Industry: {'name': 'High Bandwidth Memory', 'SIC_code': None, 'industry_group': None, 'subindustry_desc': None, 'primary_activity': None}
# 'industry_group' is empty for Industry: {'name': 'High Bandwidth Memory', 'SIC_code': None, 'industry_group': None, 'subindustry_desc': None, 'primary_activity': None}
# 'subindustry_desc' is empty for Industry: {'name': 'High Bandwidth Memory', 'SIC_code': None, 'industry_group': None, 'subindustry_desc': None, 'primary_activity': None}
# 'primary_activity' is empty for Industry: {'name': 'High Bandwidth Memory', 'SIC_code': None, 'industry_group': None, 'subindustry_desc': None, 'primary_activity': None}
# 'SIC_code' is empty for Industry: {'name': 'flash memory', 'SIC_code': None, 'industry_group': None, 'subindustry_desc': None, 'primary_activity': None}
# 'industry_group' is empty for Industry: {'name': 'flash memory', 'SIC_code': None, 'industry_group': None, 'subindustry_desc': None, 'primary_activity': None}
# ...
# 'm49' is empty for Region: {'name': 'SA', 'm49': None}
# 'm49' is empty for Region: {'name': 'NA', 'm49': None}
# 'm49' is empty for Region: {'name': 'NA', 'm49': None}
# 'm49' is empty for Region: {'name': 'SA', 'm49': None}
# 'm49' is empty for Region: {'name': 'SA', 'm49': None}
# 'm49' is empty for Region: {'name': 'NA', 'm49': None}
# 'm49' is empty for Region: {'name': 'NA', 'm49': None}
# 'm49' is empty for Region: {'name': 'NA', 'm49': None}
# 'm49' is empty for Region: {'name': 'NA', 'm49': None}
# 'm49' is empty for Region: {'name': 'NA', 'm49': None}
# 'm49' is empty for Region: {'name': 'EU', 'm49': None}
# 'm49' is empty for Region: {'name': 'AS', 'm49': None}
# 'm49' is empty for Region: {'name': 'EU', 'm49': None}
# 'm49' is empty for Region: {'name': 'NA', 'm49': None}
# 'm49' is empty for Region: {'name': 'AS', 'm49': None}
# 'm49' is empty for Region: {'name': 'NA', 'm49': None}
# 'm49' is empty for Region: {'name': 'NA', 'm49': None}
# 'm49' is empty for Region: {'name': 'NA', 'm49': None}
# 'm49' is empty for Region: {'name': 'NA', 'm49': None}
# 'm49' is empty for Region: {'name': 'NA', 'm49': None}
# 'm49' is empty for Region: {'name': 'AS', 'm49': None}
# 'm49' is empty for Region: {'name': 'EU', 'm49': None}
# 'm49' is empty for Region: {'name': 'NA', 'm49': None}
# 'm49' is empty for Region: {'name': 'EU', 'm49': None}
# 'm49' is empty for Region: {'name': 'NA', 'm49': None}
# 'm49' is empty for Region: {'name': 'NA', 'm49': None}
# 'm49' is empty for Region: {'name': 'NA', 'm49': None}
# 'm49' is empty for Region: {'name': 'EU', 'm49': None}
# 'm49' is empty for Region: {'name': 'Not Found', 'm49': None}
# 'm49' is empty for Region: {'name': 'OC', 'm49': None}
# 'm49' is empty for Region: {'name': 'NA', 'm49': None}
# 'm49' is empty for Region: {'name': 'AS', 'm49': None}
# 'm49' is empty for Region: {'name': 'NA', 'm49': None}
# 'm49' is empty for Region: {'name': 'OC', 'm49': None}
# 'm49' is empty for Region: {'name': 'NA', 'm49': None}
# 'm49' is empty for Region: {'name': 'NA', 'm49': None}
# 'm49' is empty for Region: {'name': 'EU', 'm49': None}
# 'm49' is empty for Region: {'name': 'AS', 'm49': None}
# 'm49' is empty for Region: {'name': 'EU', 'm49': None}
# 'm49' is empty for Region: {'name': 'AS', 'm49': None}
# 'm49' is empty for Region: {'name': 'EU', 'm49': None}
# 'm49' is empty for Region: {'name': 'NA', 'm49': None}
# 'm49' is empty for Region: {'name': 'EU', 'm49': None}
# 'm49' is empty for Region: {'name': 'NA', 'm49': None}
# 'm49' is empty for Region: {'name': 'NA', 'm49': None}
# 'm49' is empty for Region: {'name': 'AS', 'm49': None}
# 'm49' is empty for Region: {'name': 'NA', 'm49': None}
# 'm49' is empty for Region: {'name': 'NA', 'm49': None}
# 'm49' is empty for Region: {'name': 'NA', 'm49': None}
# 'm49' is empty for Region: {'name': 'NA', 'm49': None}
# 'm49' is empty for Region: {'name': 'AS', 'm49': None}
# 'm49' is empty for Region: {'name': 'AS', 'm49': None}
# 'm49' is empty for Region: {'name': 'AS', 'm49': None}
# 'm49' is empty for Region: {'name': 'Not Found', 'm49': None}
# 'm49' is empty for Region: {'name': 'NA', 'm49': None}
# 'm49' is empty for Region: {'name': 'EU', 'm49': None}
# 'm49' is empty for Region: {'name': 'NA', 'm49': None}
# 'm49' is empty for Region: {'name': 'AS', 'm49': None}
# 'm49' is empty for Region: {'name': 'AS', 'm49': None}
# 'm49' is empty for Region: {'name': 'EU', 'm49': None}
# 'm49' is empty for Region: {'name': 'OC', 'm49': None}
# 'm49' is empty for Region: {'name': 'Not Found', 'm49': None}
# 'm49' is empty for Region: {'name': 'Not Found', 'm49': None}
# 'm49' is empty for Region: {'name': 'SA', 'm49': None}
# 'm49' is empty for Region: {'name': 'NA', 'm49': None}
# 'm49' is empty for Region: {'name': 'NA', 'm49': None}
# 'm49' is empty for Region: {'name': 'SA', 'm49': None}
# 'm49' is empty for Region: {'name': 'SA', 'm49': None}
# 'm49' is empty for Region: {'name': 'SA', 'm49': None}
# 'm49' is empty for Region: {'name': 'NA', 'm49': None}
# 'm49' is empty for Region: {'name': 'NA', 'm49': None}
# 'm49' is empty for Region: {'name': 'NA', 'm49': None}
# 'm49' is empty for Region: {'name': 'SA', 'm49': None}
# 'm49' is empty for Region: {'name': 'SA', 'm49': None}
# 'm49' is empty for Region: {'name': 'Not Found', 'm49': None}
# 'm49' is empty for Region: {'name': 'SA', 'm49': None}
# 'm49' is empty for Region: {'name': 'SA', 'm49': None}
# 'm49' is empty for Region: {'name': 'SA', 'm49': None}
# 'm49' is empty for Region: {'name': 'NA', 'm49': None}
# 'm49' is empty for Region: {'name': 'NA', 'm49': None}
# 'm49' is empty for Region: {'name': 'NA', 'm49': None}
# 'm49' is empty for Region: {'name': 'NA', 'm49': None}
# 'm49' is empty for Region: {'name': 'SA', 'm49': None}
# 'm49' is empty for Region: {'name': 'SA', 'm49': None}
# 'm49' is empty for Region: {'name': 'NA', 'm49': None}
# 'm49' is empty for Region: {'name': 'NA', 'm49': None}
# 'm49' is empty for Region: {'name': 'SA', 'm49': None}
# 'm49' is empty for Region: {'name': 'SA', 'm49': None}
# 'm49' is empty for Region: {'name': 'NA', 'm49': None}
# 'm49' is empty for Region: {'name': 'NA', 'm49': None}
# 'm49' is empty for Region: {'name': 'NA', 'm49': None}
# 'm49' is empty for Region: {'name': 'NA', 'm49': None}
# 'm49' is empty for Region: {'name': 'NA', 'm49': None}
# 'm49' is empty for Region: {'name': 'NA', 'm49': None}
# 'm49' is empty for Region: {'name': 'NA', 'm49': None}
# 'm49' is empty for Region: {'name': 'AS', 'm49': None}
# 'm49' is empty for Region: {'name': 'NA', 'm49': None}
# 'm49' is empty for Region: {'name': 'AS', 'm49': None}
# 'm49' is empty for Region: {'name': 'AS', 'm49': None}
# 'm49' is empty for Region: {'name': 'EU', 'm49': None}
# 'm49' is empty for Region: {'name': 'AS', 'm49': None}
# 'm49' is empty for Region: {'name': 'NA', 'm49': None}
# 'm49' is empty for Region: {'name': 'EU', 'm49': None}
# 'm49' is empty for Region: {'name': 'AS', 'm49': None}
# 'm49' is empty for Region: {'name': 'EU', 'm49': None}
# 'm49' is empty for Region: {'name': 'NA', 'm49': None}
# 'm49' is empty for Region: {'name': 'AS', 'm49': None}
# 'm49' is empty for Region: {'name': 'NA', 'm49': None}
# 'm49' is empty for Region: {'name': 'NA', 'm49': None}
# 'm49' is empty for Region: {'name': 'NA', 'm49': None}
# 'm49' is empty for Region: {'name': 'NA', 'm49': None}
# 'm49' is empty for Region: {'name': 'NA', 'm49': None}
# 'm49' is empty for Region: {'name': 'AS', 'm49': None}
# 'm49' is empty for Region: {'name': 'EU', 'm49': None}
# 'm49' is empty for Region: {'name': 'NA', 'm49': None}
# 'm49' is empty for Region: {'name': 'EU', 'm49': None}
# 'm49' is empty for Region: {'name': 'NA', 'm49': None}
# 'm49' is empty for Region: {'name': 'NA', 'm49': None}
# 'm49' is empty for Region: {'name': 'NA', 'm49': None}
# 'm49' is empty for Region: {'name': 'EU', 'm49': None}
# 'm49' is empty for Region: {'name': 'Not Found', 'm49': None}
# 'm49' is empty for Region: {'name': 'OC', 'm49': None}
# 'm49' is empty for Region: {'name': 'NA', 'm49': None}
# 'm49' is empty for Region: {'name': 'AS', 'm49': None}
# 'm49' is empty for Region: {'name': 'NA', 'm49': None}
# 'm49' is empty for Region: {'name': 'OC', 'm49': None}
# 'm49' is empty for Region: {'name': 'NA', 'm49': None}
# 'm49' is empty for Region: {'name': 'NA', 'm49': None}
# 'm49' is empty for Region: {'name': 'EU', 'm49': None}
# 'm49' is empty for Region: {'name': 'AS', 'm49': None}
# 'm49' is empty for Region: {'name': 'EU', 'm49': None}
# 'm49' is empty for Region: {'name': 'AS', 'm49': None}
# 'm49' is empty for Region: {'name': 'EU', 'm49': None}
# 'm49' is empty for Region: {'name': 'NA', 'm49': None}
# 'm49' is empty for Region: {'name': 'EU', 'm49': None}
# 'm49' is empty for Region: {'name': 'NA', 'm49': None}
# 'm49' is empty for Region: {'name': 'NA', 'm49': None}
# 'm49' is empty for Region: {'name': 'AS', 'm49': None}
# 'm49' is empty for Region: {'name': 'NA', 'm49': None}
# 'm49' is empty for Region: {'name': 'NA', 'm49': None}
# 'm49' is empty for Region: {'name': 'NA', 'm49': None}
# 'm49' is empty for Region: {'name': 'NA', 'm49': None}
# 'm49' is empty for Region: {'name': 'AS', 'm49': None}
# 'm49' is empty for Region: {'name': 'AS', 'm49': None}
# 'm49' is empty for Region: {'name': 'AS', 'm49': None}
# 'm49' is empty for Region: {'name': 'Not Found', 'm49': None}
# 'm49' is empty for Region: {'name': 'NA', 'm49': None}
# 'm49' is empty for Region: {'name': 'EU', 'm49': None}
# 'm49' is empty for Region: {'name': 'NA', 'm49': None}
# 'm49' is empty for Region: {'name': 'AS', 'm49': None}
# 'm49' is empty for Region: {'name': 'AS', 'm49': None}
# 'm49' is empty for Region: {'name': 'EU', 'm49': None}
# 'm49' is empty for Region: {'name': 'OC', 'm49': None}
# 'm49' is empty for Region: {'name': 'Not Found', 'm49': None}
# 'm49' is empty for Region: {'name': 'Not Found', 'm49': None}
# 'm49' is empty for Region: {'name': 'SA', 'm49': None}
# 'm49' is empty for Region: {'name': 'NA', 'm49': None}
# 'm49' is empty for Region: {'name': 'NA', 'm49': None}
# 'm49' is empty for Region: {'name': 'SA', 'm49': None}
# 'm49' is empty for Region: {'name': 'SA', 'm49': None}
# 'm49' is empty for Region: {'name': 'SA', 'm49': None}
# 'm49' is empty for Region: {'name': 'NA', 'm49': None}
# 'm49' is empty for Region: {'name': 'NA', 'm49': None}
# 'm49' is empty for Region: {'name': 'NA', 'm49': None}
# 'm49' is empty for Region: {'name': 'SA', 'm49': None}
# 'm49' is empty for Region: {'name': 'SA', 'm49': None}
# 'm49' is empty for Region: {'name': 'Not Found', 'm49': None}
# 'm49' is empty for Region: {'name': 'SA', 'm49': None}
# 'm49' is empty for Region: {'name': 'SA', 'm49': None}
# 'm49' is empty for Region: {'name': 'SA', 'm49': None}
# 'm49' is empty for Region: {'name': 'NA', 'm49': None}
# 'm49' is empty for Region: {'name': 'NA', 'm49': None}
# 'm49' is empty for Region: {'name': 'NA', 'm49': None}
# 'm49' is empty for Region: {'name': 'NA', 'm49': None}
# 'm49' is empty for Region: {'name': 'SA', 'm49': None}
# 'm49' is empty for Region: {'name': 'SA', 'm49': None}
# 'm49' is empty for Region: {'name': 'NA', 'm49': None}
# 'm49' is empty for Region: {'name': 'NA', 'm49': None}
# 'm49' is empty for Region: {'name': 'SA', 'm49': None}
# 'm49' is empty for Region: {'name': 'SA', 'm49': None}
# 'm49' is empty for Region: {'name': 'NA', 'm49': None}
# 'm49' is empty for Region: {'name': 'NA', 'm49': None}
# 'm49' is empty for Region: {'name': 'NA', 'm49': None}
# 'm49' is empty for Region: {'name': 'NA', 'm49': None}
# 'm49' is empty for Region: {'name': 'NA', 'm49': None}
# 'm49' is empty for Region: {'name': 'NA', 'm49': None}
# 'm49' is empty for Region: {'name': 'NA', 'm49': None}
# 'm49' is empty for Region: {'name': 'AS', 'm49': None}
# 'm49' is empty for Region: {'name': 'NA', 'm49': None}
# 'm49' is empty for Region: {'name': 'AS', 'm49': None}
# 'm49' is empty for Region: {'name': 'AS', 'm49': None}
# 'm49' is empty for Region: {'name': 'EU', 'm49': None}
# 'm49' is empty for Region: {'name': 'AS', 'm49': None}
# 'm49' is empty for Region: {'name': 'NA', 'm49': None}
# 'm49' is empty for Region: {'name': 'EU', 'm49': None}
# 'm49' is empty for Region: {'name': 'AS', 'm49': None}
# 'm49' is empty for Region: {'name': 'EU', 'm49': None}
# 'm49' is empty for Region: {'name': 'NA', 'm49': None}
# 'm49' is empty for Region: {'name': 'AS', 'm49': None}
# 'm49' is empty for Region: {'name': 'NA', 'm49': None}
# 'm49' is empty for Region: {'name': 'NA', 'm49': None}
# 'm49' is empty for Region: {'name': 'NA', 'm49': None}
# 'm49' is empty for Region: {'name': 'NA', 'm49': None}
# 'm49' is empty for Region: {'name': 'NA', 'm49': None}
# 'm49' is empty for Region: {'name': 'AS', 'm49': None}
# 'm49' is empty for Region: {'name': 'EU', 'm49': None}
# 'm49' is empty for Region: {'name': 'NA', 'm49': None}
# 'm49' is empty for Region: {'name': 'EU', 'm49': None}
# 'm49' is empty for Region: {'name': 'NA', 'm49': None}
# 'm49' is empty for Region: {'name': 'NA', 'm49': None}
# 'm49' is empty for Region: {'name': 'NA', 'm49': None}
# 'm49' is empty for Region: {'name': 'EU', 'm49': None}
# 'm49' is empty for Region: {'name': 'Not Found', 'm49': None}
# 'm49' is empty for Region: {'name': 'OC', 'm49': None}
# 'm49' is empty for Region: {'name': 'NA', 'm49': None}
# 'm49' is empty for Region: {'name': 'AS', 'm49': None}
# 'm49' is empty for Region: {'name': 'NA', 'm49': None}
# 'm49' is empty for Region: {'name': 'OC', 'm49': None}
# 'm49' is empty for Region: {'name': 'NA', 'm49': None}
# 'm49' is empty for Region: {'name': 'NA', 'm49': None}
# 'm49' is empty for Region: {'name': 'EU', 'm49': None}
# 'm49' is empty for Region: {'name': 'AS', 'm49': None}
# 'm49' is empty for Region: {'name': 'EU', 'm49': None}
# 'm49' is empty for Region: {'name': 'AS', 'm49': None}
# 'm49' is empty for Region: {'name': 'EU', 'm49': None}
# 'm49' is empty for Region: {'name': 'NA', 'm49': None}
# 'm49' is empty for Region: {'name': 'EU', 'm49': None}
# 'm49' is empty for Region: {'name': 'NA', 'm49': None}
# 'm49' is empty for Region: {'name': 'NA', 'm49': None}
# 'm49' is empty for Region: {'name': 'AS', 'm49': None}
# 'm49' is empty for Region: {'name': 'NA', 'm49': None}
# 'm49' is empty for Region: {'name': 'NA', 'm49': None}
# 'm49' is empty for Region: {'name': 'NA', 'm49': None}
# 'm49' is empty for Region: {'name': 'NA', 'm49': None}
# 'm49' is empty for Region: {'name': 'AS', 'm49': None}
# 'm49' is empty for Region: {'name': 'AS', 'm49': None}
# 'm49' is empty for Region: {'name': 'AS', 'm49': None}
# 'm49' is empty for Region: {'name': 'Not Found', 'm49': None}
# 'm49' is empty for Region: {'name': 'NA', 'm49': None}
# 'm49' is empty for Region: {'name': 'EU', 'm49': None}
# 'm49' is empty for Region: {'name': 'NA', 'm49': None}
# 'm49' is empty for Region: {'name': 'AS', 'm49': None}
# 'm49' is empty for Region: {'name': 'AS', 'm49': None}
# 'm49' is empty for Region: {'name': 'EU', 'm49': None}
# 'm49' is empty for Region: {'name': 'OC', 'm49': None}
# 'm49' is empty for Region: {'name': 'Not Found', 'm49': None}
# 'm49' is empty for Region: {'name': 'Not Found', 'm49': None}
# 'm49' is empty for Region: {'name': 'SA', 'm49': None}
# 'm49' is empty for Region: {'name': 'NA', 'm49': None}
# 'm49' is empty for Region: {'name': 'NA', 'm49': None}
# 'm49' is empty for Region: {'name': 'SA', 'm49': None}
# 'm49' is empty for Region: {'name': 'SA', 'm49': None}
# 'm49' is empty for Region: {'name': 'SA', 'm49': None}
# 'm49' is empty for Region: {'name': 'NA', 'm49': None}
# 'm49' is empty for Region: {'name': 'NA', 'm49': None}
# 'm49' is empty for Region: {'name': 'NA', 'm49': None}
# 'm49' is empty for Region: {'name': 'SA', 'm49': None}
# 'm49' is empty for Region: {'name': 'SA', 'm49': None}
# 'm49' is empty for Region: {'name': 'Not Found', 'm49': None}
# 'm49' is empty for Region: {'name': 'SA', 'm49': None}
# 'm49' is empty for Region: {'name': 'SA', 'm49': None}
# 'm49' is empty for Region: {'name': 'SA', 'm49': None}
# 'm49' is empty for Region: {'name': 'NA', 'm49': None}
# 'm49' is empty for Region: {'name': 'NA', 'm49': None}
# 'm49' is empty for Region: {'name': 'NA', 'm49': None}
# 'm49' is empty for Region: {'name': 'NA', 'm49': None}
# 'm49' is empty for Region: {'name': 'SA', 'm49': None}
# 'm49' is empty for Region: {'name': 'SA', 'm49': None}
# 'm49' is empty for Region: {'name': 'NA', 'm49': None}
# 'm49' is empty for Region: {'name': 'NA', 'm49': None}
# 'm49' is empty for Region: {'name': 'SA', 'm49': None}
# 'm49' is empty for Region: {'name': 'SA', 'm49': None}
# 'm49' is empty for Region: {'name': 'NA', 'm49': None}
# 'm49' is empty for Region: {'name': 'NA', 'm49': None}
# 'm49' is empty for Region: {'name': 'NA', 'm49': None}
# 'm49' is empty for Region: {'name': 'NA', 'm49': None}
# 'm49' is empty for Region: {'name': 'NA', 'm49': None}
# 'm49' is empty for Region: {'name': 'NA', 'm49': None}
# 'm49' is empty for Region: {'name': 'NA', 'm49': None}
# 'm49' is empty for Region: {'name': 'AS', 'm49': None}
# 'm49' is empty for Region: {'name': 'NA', 'm49': None}
# 'm49' is empty for Region: {'name': 'AS', 'm49': None}
# 'm49' is empty for Region: {'name': 'AS', 'm49': None}
# 'm49' is empty for Region: {'name': 'EU', 'm49': None}
# 'm49' is empty for Region: {'name': 'AS', 'm49': None}
# Total null fields for Company: 46
# Total null fields for Country: 94
# Total null fields for Industry: 232
# Total null fields for Region: 2152
# Total null fields for Product: 0

# %% [markdown]
# ### Bonus part (Incomplete Data Augmentation)

# %% [markdown]
# In this first part, API call to load data
# The data used in this analysis comes from bautheac/GICS packages the Global Industry Classification Standards (GICS) dataset for consumption in R. The GICS hierarchy begins with 11 sectors and is followed by 24 industry groups, 68 industries, and 157 sub-industries.
#
# Also incorporated the data from `data/ECM_Datasets.csv` and `NASDAQ_10-K_URLs.csv`, in addition to the data extracted from D&B Hoovers database. By integrating new, relevant data from external databases or sources into the existing KG, we aim to enhance existing nodes with more detailed attributes, descriptions, or references.

# %% [markdown]
# (Not yet for incorporating into KG) The field names/properties to the nodes have NOT been properly standardized yet.

# %%
import requests
import pyreadr
import pandas as pd

url = 'https://github.com/bautheac/GICS/raw/0c2b0e4c0ca56a0e520301fd978fc095ed4fc328/data/standards.rda'
response = requests.get(url)

rda_file_path = './data/standards.rda'
with open(rda_file_path, 'wb') as file:
    file.write(response.content)

# Load the .rda file using pyreadr
result = pyreadr.read_r(rda_file_path)

print(result.keys())  

df = result[list(result.keys())[0]]  

# Save the DataFrame as a CSV file and remove the rda file
# df.to_csv('./data/standards.csv', index=False)

os.remove(rda_file_path)

#print("Data has been saved as standards.csv")
# Out:
# odict_keys(['standards'])

# %% [markdown]
# ### Data Wrangling

# %%
# data wrangling for company
df1 = pd.read_csv('data/ECM_Datasets.csv',usecols = ['Company','Ticker','Year of 10-K '],sep=',')

df2 = pd.read_csv('data/NASDAQ_10-K_URLs.csv',usecols = ['Company Name','ticker','Latest Filing Year'],sep=',')


df1 = df1.rename(columns={
            'Company': 'company_name',
            'Ticker': 'ticker',
            'Year of 10-K ': 'year'  
        })
df2 = df2.rename(columns={
            'Company Name': 'company_name',
            'ticker': 'ticker',
            'Latest Filing Year': 'year'
        })
df1['company_name'] = df1['company_name'].str.title().str.strip()
df2['company_name'] = df2['company_name'].str.title().str.strip()

all_df = []
all_df.append(df1)
all_df.append(df2)

merged_df = pd.concat(all_df, ignore_index=True,axis=0)
merged_df["year"] = merged_df["year"].astype('Int64')

merged_df = merged_df.sort_values(by='year', ascending=False)
# duplicates with null value removed first
merged_df = merged_df.drop_duplicates(subset='ticker', keep='first')

# order by company names ASC
merged_df = merged_df.sort_values(by='company_name',ascending=True)

merged_df.reset_index(drop=True, inplace=True)
merged_df.index += 1

merged_df.head(10)
# Out:
#                      company_name ticker  year
# 1                       Adobe Inc   ADBE  2024
# 2      Advanced Micro Devices Inc    AMD  2024
# 3                    Alphabet Inc  GOOGL  2024
# 4                   Alphabet Inc.   GOOG  2024
# 5                  Amazon.Com Inc   AMZN  2024
# 6                       Amgen Inc   AMGN  2024
# 7              Analog Devices Inc    ADI  2023
# 8                       Apple Inc   AAPL  2023
# 9       Applied Materials Inc /De   AMAT  2023
# 10  Automatic Data Processing Inc    ADP  2024

# %%
# data wrangling for industry

def wrangling(csv_path):
    df = pd.read_csv(csv_path)
    
    df = df.dropna()

    df = df.drop_duplicates()
    
    df = df.rename(columns={
        'sector id': 'sector_id',
        'sector name': 'sector_name',
        'industry group id': 'industry_group_id',
        'industry group name': 'industry_group_name',
        'industry id': 'industry_id',
        'industry name': 'industry_name',
        'subindustry id': 'subindustry_id',
        'subindustry name': 'subindustry_name',
        'description': 'primary_activity'
    })

    
    df['sector_id'] = df['sector_id'].astype('Int64')  
    df['industry_group_id'] = df['industry_group_id'].astype('Int64')
    df['industry_id'] = df['industry_id'].astype('Int64')
    df['subindustry_id'] = df['subindustry_id'].astype('Int64')

    df.reset_index(drop=True, inplace=True)
    df.index += 1

    return df

industry = wrangling("./data/standards.csv")
industry.head()
# Out:
#    sector_id sector_name  industry_group_id industry_group_name  industry_id  \
# 1         10      Energy               1010              Energy       101010
# 2         10      Energy               1010              Energy       101010
# 3         10      Energy               1010              Energy       101020
# 4         10      Energy               1010              Energy       101020
# 5         10      Energy               1010              Energy       101020
#
#                  industry_name  subindustry_id  \
# 1  Energy Equipment & Services        10101010
# 2  Energy Equipment & Services        10101020
# 3  Oil, Gas & Consumable Fuels        10102010
# 4  Oil, Gas & Consumable Fuels        10102020
# 5  Oil, Gas & Consumable Fuels        10102030
#
#                      subindustry_name  \
# 1                  Oil & Gas Drilling
# 2      Oil & Gas Equipment & Services
# 3                Integrated Oil & Gas
# 4  Oil & Gas Exploration & Production
# 5      Oil & Gas Refining & Marketing
#
#                                     primary_activity
# 1  Drilling contractors or owners of drilling rig...
# 2  Manufacturers of equipment, including drilling...
# 3  Integrated oil companies engaged in the explor...
# 4  Companies engaged in the exploration and produ...
# 5  Companies engaged in the refining and marketin...

# %% [markdown]
# #### Additional data for Industry Node

# %% [markdown]
# Industry sectors represent large sections of the economy and include multiple companies.

# %%
def add_industry_sector_constraints(tx) -> None:
    tx.run("CREATE INDEX industry_id IF NOT EXISTS FOR (i:Industry) ON (i.industry_id)")
    tx.run("CREATE INDEX industry_name IF NOT EXISTS FOR (i:Industry) ON (i.industry_name)")
    tx.run("CREATE INDEX industry_group IF NOT EXISTS FOR (i:Industry) ON (i.industry_group)")
    tx.run("CREATE INDEX subindustry_name IF NOT EXISTS FOR (i:Industry) ON (i.subindustry_name)")
    tx.run("CREATE INDEX primary_activity IF NOT EXISTS FOR (i:Industry) ON (i.primary_activity)")

# %%
def add_industries(tx, industry: pd.DataFrame) -> None:
    queries = []
    for _, row in industry.iterrows():
        query ="""
        MERGE (:Industry {
            industry_id: $industry_id,
            industry_name: $industry_name,
            industry_group_name: $industry_group_name,
            subindustry_name: $subindustry_name,
            primary_activity: $primary_activity
        })
        """
        queries.append((query, row.to_dict()))
    for query, params in queries:
        tx.run(query, **params)

# %%
with GraphDatabase.driver(URI, auth=AUTH) as driver:
    with driver.session(database="neo4j") as session:
        session.execute_write(add_industry_sector_constraints) 
        session.execute_write(add_industries, industry=industry)

# %% [markdown]
# #### Additional data for industry-company relationship

# %% [markdown]
# This is the partial data table that is extracted from the D&B Hoovers portal
# which can be accessed here: https://app-hoovers-dnb-com.libproxy1.nus.edu.sg/
#
# D&B Hoovers assigns industry classifications based on the Standard Industrial Classification (SIC) system or its internal classifications.

# %%
## only 20 records can be downloaded from, even though 40 of them have the records
import pandas as pd

df = pd.read_csv('data/company_industry.csv')

# List of columns to extract
columns_to_extract = [
    'Company Name', 
    'Ticker', 
    'Country/Region', 
    'Sales (USD)', 
    'D&B Hoovers Industry', 
    'ISIC Rev 4 Code', 
    'ISIC Rev 4 Description'
]
extracted_df = df[columns_to_extract]

extracted_df.reset_index(drop=True, inplace=True)
extracted_df.index += 1

print(extracted_df)
# Out:
#                       Company Name Ticker Country/Region   Sales (USD)  \
# 1                       Apple Inc.   AAPL  United States  3.832850e+11
# 2            Microsoft Corporation   MSFT  United States  2.451220e+11
# 3                 Amazon.com, Inc.   AMZN  United States  5.747850e+11
# 4     Costco Wholesale Corporation   COST  United States  2.422900e+11
# 5                      Tesla, Inc.   TSLA  United States  9.677300e+10
# 6                    Alphabet Inc.  GOOGL  United States  3.073940e+11
# 7                    PepsiCo, Inc.    PEP  United States  8.639200e+10
# 8                T-Mobile US, Inc.   TMUS  United States  7.855800e+10
# 9            QUALCOMM Incorporated   QCOM  United States  3.582000e+10
# 10  Texas Instruments Incorporated    TXN  United States  1.751900e+10
# 11                      Amgen Inc.   AMGN  United States  2.819000e+10
# 12         Applied Materials, Inc.   AMAT  United States  2.651700e+10
# 13    Honeywell International Inc.    HON  United States  3.666200e+10
# 14            Analog Devices, Inc.    ADI  United States  1.230554e+10
# 15           Starbucks Corporation   SBUX  United States  3.597560e+10
# 16         Micron Technology, Inc.     MU  United States  1.554000e+10
# 17        Lam Research Corporation   LRCX  United States  1.490539e+10
# 18           Gilead Sciences, Inc.   GILD  United States  2.711600e+10
# 19    Mondelez International, Inc.   MDLZ  United States  3.601600e+10
# 20               Intel Corporation   INTC  United States  5.422800e+10
#
#                                  D&B Hoovers Industry  ISIC Rev 4 Code  \
# 1              Communications Equipment Manufacturing             2630
# 2                                            Software             5820
# 3                                    Non-store Retail             4791
# 4                                   Department Stores             4719
# 5                         Motor Vehicle Manufacturing             2910
# 6                                Computer Programming             6202
# 7                              Beverage Manufacturing             1104
# 8                Wireless Telecommunications Carriers             6120
# 9              Communications Equipment Manufacturing             2630
# 10  Semiconductor and Other Electronic Component M...             2610
# 11                       Pharmaceutical Manufacturing             2100
# 12              Machinery and Equipment Manufacturing             2819
# 13            Aircraft Engine and Parts Manufacturing             3030
# 14  Semiconductor and Other Electronic Component M...             2610
# 15                               Restaurants and Bars             5610
# 16  Semiconductor and Other Electronic Component M...             2610
# 17  Semiconductor and Other Electronic Component M...             2610
# 18                       Pharmaceutical Manufacturing             2100
# 19                                 Food Manufacturing             1050
# 20  Semiconductor and Other Electronic Component M...             2610
#
#                                ISIC Rev 4 Description
# 1              Manufacture of communication equipment
# 2                                 Software publishing
# 3   Retail sale via mail order houses or via Internet
# 4         Other retail sale in non-specialized stores
# 5                       Manufacture of motor vehicles
# 6   Computer consultancy and computer facilities m...
# 7   Manufacture of soft drinks; production of mine...
# 8              Wireless telecommunications activities
# 9              Manufacture of communication equipment
# 10    Manufacture of electronic components and boards
# 11  Manufacture of pharmaceuticals, medicinal chem...
# 12     Manufacture of other general-purpose machinery
# 13  Manufacture of air and spacecraft and related ...
# 14    Manufacture of electronic components and boards
# 15     Restaurants and mobile food service activities
# 16    Manufacture of electronic components and boards
# 17    Manufacture of electronic components and boards
# 18  Manufacture of pharmaceuticals, medicinal chem...
# 19                      Manufacture of dairy products
# 20    Manufacture of electronic components and boards

# %% [markdown]
# #### Adding Company IS INVOLVED IN Industry Relationship

# %%
def add_company_industry(tx, company_industry: pd.DataFrame) -> None:
    query = """
    MERGE (c:Company {name: $company_name, ticker: $ticker})
    MERGE (i:Industry {isic_rev4_code: $isic_rev4_code, isic_rev4_description: $isic_rev4_description, dnb_hoovers_industry: $dnb_hoovers_industry})
    MERGE (c)-[:INVOLVED_IN]->(i)
    """
    
    for _, row in company_industry.iterrows():
        tx.run(query, 
               company_name=row['Company Name'], 
               ticker=row['Ticker'], 
               isic_rev4_code=row['ISIC Rev 4 Code'], 
               isic_rev4_description=row['ISIC Rev 4 Description'], 
               dnb_hoovers_industry=row['D&B Hoovers Industry'])

# %%
with GraphDatabase.driver(URI, auth=AUTH) as driver:
    with driver.session(database="neo4j") as session:
        session.execute_write(add_company_industry, company_industry=extracted_df)
