# %%
import os
import pandas as pd
import urllib.request
import json 
from operator import itemgetter
import numpy as np
import requests
import pyreadr
import re
from sentence_transformers import SentenceTransformer
from fact_checking import fact_check_and_add
import graph_utils
# Out:
# /Users/wy/Documents/WW-AI-GK/.venv/lib/python3.11/site-packages/sentence_transformers/cross_encoder/CrossEncoder.py:13: TqdmExperimentalWarning: Using `tqdm.autonotebook.tqdm` in notebook mode. Use `tqdm.tqdm` instead to force console mode (e.g. in jupyter console)
#   from tqdm.autonotebook import tqdm, trange
# Connection to graph database established.

# %% [markdown]
# ## Neo4J AuraDB Setup

# %% [markdown]
# ### Resetting database

# %% [markdown]
# We reset the database to start with a blank slate.

# %%
# Removes all nodes and relationships
graph_utils.reset_graph()

# %%
# Removes all indexes and constraints
graph_utils.reset_constraints()

# %% [markdown]
# ## Schema Constraints

# %% [markdown]
# In this section, we define constraints and indexes for the various nodes in our graph.
#
# Key constraints and uniqueness constraints will ensure that nodes can be matched unambiguously.
# We also employ semantic indexes for the purposes of node disambiguiation:
# 1. Full-text indexes allow keywords to be matched (e.g. country name aliases can be used to match to different aliases of a particular country)
# 2. Vector indexes allow similarity based search (e.g. industry description can be used to match to specific industry nodes)

# %% [markdown]
# ### Region Node

# %%
# m49 is key
graph_utils.execute_query('''
CREATE CONSTRAINT region_m49_key IF NOT EXISTS
FOR (r:Region) REQUIRE r.m49 IS NODE KEY''')
# Out:
# EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x125c9d790>, keys=[])

# %%
# name is unique
graph_utils.execute_query('''
CREATE CONSTRAINT region_name_unique IF NOT EXISTS
FOR (r:Region) REQUIRE r.name IS UNIQUE''')
# Out:
# EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x1610677d0>, keys=[])

# %%
# name fulltext index
graph_utils.execute_query('''
CREATE FULLTEXT INDEX region_name_index IF NOT EXISTS
FOR (r:Region) ON EACH [r.name]''')
# Out:
# EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x16109c5d0>, keys=[])

# %% [markdown]
# ### Country Node

# %%
# iso3 is key
graph_utils.execute_query('''
CREATE CONSTRAINT country_iso3_key IF NOT EXISTS
FOR (c:Country) REQUIRE c.iso3 IS NODE KEY''')
# Out:
# EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x161086bd0>, keys=[])

# %%
# iso2 is unique
graph_utils.execute_query('''
CREATE CONSTRAINT country_iso2_unique IF NOT EXISTS
FOR (c:Country) REQUIRE c.iso2 IS UNIQUE''')
# Out:
# EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x16109e650>, keys=[])

# %%
# name is unique
graph_utils.execute_query('''
CREATE CONSTRAINT country_name_unique IF NOT EXISTS
FOR (c:Country) REQUIRE c.name IS UNIQUE''')
# Out:
# EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x1610a1390>, keys=[])

# %%
# aliases fulltext index
graph_utils.execute_query('''
CREATE FULLTEXT INDEX country_aliases_index IF NOT EXISTS
FOR (c:Country) ON EACH [c.aliases]''')
# Out:
# EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x1610a3fd0>, keys=[])

# %% [markdown]
# ### Sector Node

# %%
# gics is key
graph_utils.execute_query('''
CREATE CONSTRAINT sector_gics_key IF NOT EXISTS
FOR (s:Sector) REQUIRE s.gics IS NODE KEY''')
# Out:
# EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x1610a1e90>, keys=[])

# %%
# name is unique
graph_utils.execute_query('''
CREATE CONSTRAINT country_name_unique IF NOT EXISTS
FOR (c:Country) REQUIRE c.name IS UNIQUE''')
# Out:
# EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x1610b9710>, keys=[])

# %% [markdown]
# ### Industry Node

# %%
# gics is key
graph_utils.execute_query('''
CREATE CONSTRAINT industry_gics_key IF NOT EXISTS
FOR (i:Industry) REQUIRE i.gics IS NODE KEY''')
# Out:
# EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x1610b8a90>, keys=[])

# %%
# name is unique
graph_utils.execute_query('''
CREATE CONSTRAINT industry_name_unique IF NOT EXISTS
FOR (i:Industry) REQUIRE i.name IS UNIQUE''')
# Out:
# EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x1610a2590>, keys=[])

# %%
# description vector index
graph_utils.execute_query('''
CREATE VECTOR INDEX industry_description_index IF NOT EXISTS
FOR (i:Industry)
ON i.embedding
OPTIONS { indexConfig: {
 `vector.quantization.enabled`: false
}}''')
# Out:
# EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x16107cfd0>, keys=[])

# %% [markdown]
# ### Company Node

# %%
# ticker is key
graph_utils.execute_query('''CREATE CONSTRAINT company_ticker_key IF NOT EXISTS
FOR (c:Company) REQUIRE c.ticker IS NODE KEY''')
# Out:
# EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x16107ea10>, keys=[])

# %%
# names fulltext index
graph_utils.execute_query('''CREATE FULLTEXT INDEX company_names_index IF NOT EXISTS
FOR (c:Company) ON EACH [c.names]''')
# Out:
# EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x1610b9f50>, keys=[])

# %% [markdown]
# ## Adding Initial Data

# %% [markdown]
# ### Region Nodes

# %% [markdown]
# Our country and region nodes, as well as the IS_IN relationships from countries to regions, are sourced from [UNSD](https://unstats.un.org/unsd/methodology/m49/overview/).

# %%
df_m49 = pd.read_csv('data/UNSD_m49.csv', sep=';')

# %%
continents = df_m49[['Region Code', 'Region Name']]\
                    .dropna()\
                    .drop_duplicates()\
                    .rename(columns={
                        'Region Code': 'm49',
                        'Region Name': 'name'
                    })

# %%
subregions = df_m49[['Sub-region Code', 'Sub-region Name']]\
                    .dropna()\
                    .drop_duplicates()\
                    .rename(columns={
                        'Sub-region Code': 'm49',
                        'Sub-region Name': 'name'
                    })

# %%
itdregions = df_m49[['Intermediate Region Code', 'Intermediate Region Name']]\
                    .dropna()\
                    .drop_duplicates()\
                    .rename(columns={
                        'Intermediate Region Code': 'm49',
                        'Intermediate Region Name': 'name'
                    })

# %%
regions = pd.concat([continents, subregions, itdregions], ignore_index=True)\
            .astype({'m49': int})

# %%
param_dicts = regions.to_dict('records')
param_dicts[:5]
# Out:
# [{'m49': 2, 'name': 'Africa'},
#  {'m49': 19, 'name': 'Americas'},
#  {'m49': 142, 'name': 'Asia'},
#  {'m49': 150, 'name': 'Europe'},
#  {'m49': 9, 'name': 'Oceania'}]

# %%
graph_utils.execute_query_with_params("MERGE (:Region{m49: $m49, name: $name})",
                                      *param_dicts)
# Out:
# [EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x1610ca410>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x1610cac10>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x1610cb550>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x1610cbf90>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x1610d0c10>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x1610d1850>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x1610d2450>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x1610d30d0>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x1610d3dd0>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x1610dc890>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x1610dd4d0>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x1610de110>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x1610ded50>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x1610df990>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x1610e4610>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x1610e5250>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x1610e5e90>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x1610e6ad0>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x1610e7710>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x1610ec390>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x1610ecfd0>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x1610edc10>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x1610ee850>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x1610ef490>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x1610f0110>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x1610f0d50>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x1610f1990>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x1610f2750>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x1610f3390>, keys=[])]

# %% [markdown]
# ### Country Nodes

# %%
countries = df_m49[['ISO-alpha3 Code', 'ISO-alpha2 Code', 'Country or Area']]\
                    .dropna()\
                    .drop_duplicates()\
                    .rename(columns={
                        'ISO-alpha3 Code': 'iso3',
                        'ISO-alpha2 Code': 'iso2',
                        'Country or Area': 'name'
                    })

# %%
param_dicts = countries.to_dict('records')
param_dicts[:5]
# Out:
# [{'iso3': 'DZA', 'iso2': 'DZ', 'name': 'Algeria'},
#  {'iso3': 'EGY', 'iso2': 'EG', 'name': 'Egypt'},
#  {'iso3': 'LBY', 'iso2': 'LY', 'name': 'Libya'},
#  {'iso3': 'MAR', 'iso2': 'MA', 'name': 'Morocco'},
#  {'iso3': 'SDN', 'iso2': 'SD', 'name': 'Sudan'}]

# %%
graph_utils.execute_query_with_params("MERGE (:Country{iso3: $iso3, name: $name, iso2: $iso2})",
                                      *param_dicts)
# Out:
# [EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x1610ff590>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x1610ffe90>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x16170c850>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x16170d2d0>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x16170d990>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x16170e590>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x16170f1d0>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x16170fe10>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x161710a50>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x161711650>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x161712290>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x161712ed0>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x161713b10>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x161718790>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x1617193d0>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x16171a010>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x16171ac50>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x16171b890>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x161724510>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x161725150>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x161725d90>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x1617269d0>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x161727610>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x161728290>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x161729050>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x161729c90>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x16172a8d0>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x16172b510>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x16172c190>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x16172cdd0>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x16172da10>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x16172e650>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x16172f290>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x16172fed0>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x161734b50>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x161735790>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x1617363d0>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x161737010>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x161737c50>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x1617388d0>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x161739510>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x16173a150>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x16173ad90>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x16173bb50>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x1617447d0>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x161745410>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x161746050>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x161746c90>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x1617478d0>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x16174c550>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x16174d190>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x16174ddd0>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x16174ea10>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x16174f650>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x1617542d0>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x161754f10>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x161755b50>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x161756790>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x1617573d0>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x161758050>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x161758c90>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x1617598d0>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x16175a690>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x16175b2d0>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x16175bf10>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x161760b90>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x1617617d0>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x161762410>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x161763050>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x161763c90>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x161768910>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x161769550>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x16176a190>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x16176add0>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x16176ba10>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x161770690>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x1617712d0>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x161771f10>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x161772b50>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x161773790>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x161778410>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x1617791d0>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x161779e10>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x16177aa50>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x16177b690>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x161780310>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x161780f50>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x161781b90>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x1617827d0>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x161783410>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x161784090>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x161784cd0>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x161785910>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x161786550>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x161787190>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x161787dd0>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x16178ca50>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x16178d690>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x16178e2d0>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x16178ef10>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x16178fcd0>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x161790950>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x161791590>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x1617921d0>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x161792e10>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x161793a50>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x1617986d0>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x161799310>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x161799f90>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x16179ac10>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x16179b890>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x1617a0550>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x1617a11d0>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x1617a1e50>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x1617a2ad0>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x1617a3750>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x1617a8410>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x1617a9090>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x1617a9d10>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x1617aab10>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x1617ab750>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x1617b03d0>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x1617b1010>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x1617b1c50>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x1617b2890>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x1617b34d0>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x1617bc190>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x1617bce10>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x1617bda90>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x1617be710>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x1617bf390>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x1617c0050>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x1617c0cd0>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x1617c1950>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x1617c25d0>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x1617c3250>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x1617c3ed0>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x1617c4b90>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x1610f1050>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x1610f04d0>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x1610ee0d0>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x1610ec590>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x1610ecbd0>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x1610e6dd0>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x1610e47d0>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x1610e5310>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x1610de490>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x1610df110>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x1055e5550>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x1610d2690>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x1610d2510>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x1610c8510>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x1610c8e90>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x1610a0690>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x1610875d0>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x161084cd0>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x1617c5a50>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x1617c66d0>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x1617c7350>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x1617d0190>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x1617d0dd0>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x1617d1a10>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x1617d2650>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x1617d3290>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x1617d3ed0>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x1617d8b50>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x1617d97d0>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x1617da450>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x1617db0d0>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x1617dbd50>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x1617dca10>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x1617dd690>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x1617de310>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x1617def90>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x1617dfc10>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x1617e08d0>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x1617e1550>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x1617e21d0>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x1617e2fd0>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x1617e3c10>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x1617ec890>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x1617ed4d0>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x1617ee110>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x1617eed50>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x1617ef990>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x1617f0650>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x1617f12d0>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x1617f1f50>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x1617f2bd0>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x1617f3850>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x1617f8510>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x1617f9190>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x1617f9e10>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x1617faa90>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x1617fb710>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x1618003d0>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x161801050>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x161801e50>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x161802a90>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x1618036d0>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x161804350>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x161804f90>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x161805bd0>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x161806810>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x161807490>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x16180c150>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x16180cdd0>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x16180da50>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x16180e6d0>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x16180f350>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x16180ffd0>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x161818c90>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x161819910>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x16181a590>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x16181b210>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x16181be90>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x16181ccd0>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x16181d910>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x16181e550>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x16181f190>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x16181fdd0>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x161820a50>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x161821690>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x161822310>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x161822f90>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x161823c10>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x1618288d0>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x161829550>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x16182a1d0>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x16182ae50>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x16182bad0>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x16182c790>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x16182d410>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x16182e090>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x16182ed10>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x16182fb10>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x161830790>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x1618313d0>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x161832010>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x161832c50>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x161833890>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x161844510>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x161845190>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x161845e10>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x161846a90>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x161847710>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x1618503d0>, keys=[])]

# %% [markdown]
# ### Country IS_IN Region Relationship

# %%
country_continent = df_m49[['ISO-alpha3 Code', 'Region Code']]\
                            .dropna()\
                            .drop_duplicates()\
                            .rename(columns={
                                'ISO-alpha3 Code': 'iso3',
                                'Region Code': 'm49'
                            })

# %%
country_subregion = df_m49[['ISO-alpha3 Code', 'Sub-region Code']]\
                            .dropna()\
                            .drop_duplicates()\
                            .rename(columns={
                                'ISO-alpha3 Code': 'iso3',
                                'Sub-region Code': 'm49'
                            })

# %%
country_itdregion = df_m49[['ISO-alpha3 Code', 'Intermediate Region Code']]\
                            .dropna()\
                            .drop_duplicates()\
                            .rename(columns={
                                'ISO-alpha3 Code': 'iso3',
                                'Intermediate Region Code': 'm49'
                            })

# %%
country_region = pd.concat([country_continent, country_subregion, country_itdregion], ignore_index=True)

# %%
param_dicts = country_region.to_dict('records')
param_dicts[:5]
# Out:
# [{'iso3': 'DZA', 'm49': 2.0},
#  {'iso3': 'EGY', 'm49': 2.0},
#  {'iso3': 'LBY', 'm49': 2.0},
#  {'iso3': 'MAR', 'm49': 2.0},
#  {'iso3': 'SDN', 'm49': 2.0}]

# %%
graph_utils.execute_query_with_params('''
MATCH
    (c:Country{iso3: $iso3}),
    (r:Region{m49: $m49})
MERGE (c)-[:IS_IN]->(r)''', *param_dicts)
# Out:
# [EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x1610fcbd0>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x1610fd790>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x161853e50>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x161867510>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x161870610>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x1618716d0>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x161872750>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x161873750>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x16187c7d0>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x16187d810>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x16187e890>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x16187f910>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x1618809d0>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x161881a50>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x161882ad0>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x161883b50>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x161890c10>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x161891c90>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x161892d10>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x161893d90>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x161894e50>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x161895ed0>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x161896f50>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x161898190>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x161899250>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x16189a2d0>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x16189b350>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x16189c410>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x16189d490>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x16189e510>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x16189f590>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x1618a4650>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x1618a56d0>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x1618a6750>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x1618a77d0>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x1618b0890>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x1618b1990>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x1618b2a90>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x1618b3b90>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x1618b8e50>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x1618b9ed0>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x1618baed0>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x1618bbf50>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x1618c5090>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x1618c6190>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x1618c7290>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x1618c83d0>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x1618c94d0>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x1618ca5d0>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x1618cb6d0>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x1618d4810>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x1618d5910>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x1618d6a10>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x1618d7b10>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x1618d8c50>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x1618d9ed0>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x1618daf50>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x1618dbfd0>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x1618e9090>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x1618ea190>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x1618eb290>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x1618ec3d0>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x1618ed4d0>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x1618ee5d0>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x1618ef6d0>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x1618f0810>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x1618f1910>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x1618f2a10>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x1618f3b10>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x161900c50>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x161901d50>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x161902fd0>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x16190c090>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x16190d110>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x16190e190>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x16190f290>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x1619143d0>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x1619154d0>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x1619165d0>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x1619176d0>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x16191c810>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x16191d910>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x16191ea10>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x16191fb10>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x161928c50>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x161929d50>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x16192ae50>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x16182d7d0>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x16182d510>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x161829ad0>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x16182b010>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x161823310>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x161823dd0>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x16181e710>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x16181dcd0>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x161819b10>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x161819ad0>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x16180cfd0>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x16180c290>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x161804690>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x161803990>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x161801f90>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x1617fad10>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x1617f9b50>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x1617f2210>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x1617f0250>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x1617eca50>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x1617e3dd0>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x1617e17d0>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x1617def50>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x1617dfd90>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x1617da650>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x1617da190>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x1617d1bd0>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x1617d1b10>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x1617c5090>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x1610843d0>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x1610cb850>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x1610dcc90>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x1610e7ad0>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x1610eec50>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x16192bc50>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x161948d10>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x161949d90>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x16194ae90>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x16194bf90>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x1619510d0>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x1619521d0>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x1619532d0>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x161954410>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x161955510>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x161956610>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x161957710>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x161958850>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x161959950>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x16195aa50>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x16195bcd0>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x161960d90>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x161961e10>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x161962e90>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x161963f90>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x1619650d0>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x1619661d0>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x1619672d0>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x161970410>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x161971510>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x161972610>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x161973710>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x161974850>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x161975950>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x161976a50>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x161977b50>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x16197ce10>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x16197de90>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x16197ef10>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x16197ff90>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x1619890d0>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x16198a1d0>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x16198b2d0>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x16198c410>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x16198d510>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x16198e610>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x16198f710>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x161998850>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x161999950>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x16199aa50>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x16199bb50>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x1619a0c90>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x1619a1f10>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x1619a2f90>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x1619a4050>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x1619a50d0>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x1619a61d0>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x1619a72d0>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x1619ac410>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x1619ad510>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x1619ae610>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x1619af710>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x1619b0850>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x1619b1950>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x1619b2a50>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x1619b3b50>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x1619b4c90>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x1619b5d90>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x1619b7010>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x1619c40d0>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x1619c5150>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x1619c61d0>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x1619c72d0>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x1619cc410>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x1619cd510>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x1619ce610>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x1619cf710>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x1619d4850>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x1619d5950>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x1619d6a50>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x1619d7b50>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x1619d8c90>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x1619d9d90>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x1619dae90>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x1619e4150>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x1619e51d0>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x1619e6250>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x1619e72d0>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x1619ec410>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x1619ed510>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x1619ee610>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x1619ef710>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x1619f4850>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x1619f5950>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x1619f6a50>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x1619f7b50>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x1619fcc90>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x1619fdd90>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x1619fee90>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x1619fff90>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x161a0d250>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x161a0e2d0>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x161a0f350>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x161a14410>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x161a15510>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x161a16610>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x161a17710>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x161a18850>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x161a19950>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x161a1aa50>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x161a1bb50>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x161a20c90>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x161a21d90>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x161a22e90>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x161a23f90>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x161a250d0>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x161a26350>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x161a273d0>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x161a34490>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x161a35510>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x161a36610>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x161a37710>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x161a3c850>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x161a3d950>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x161a3ea50>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x161a3fb50>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x161a44c90>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x161a45d90>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x161a46e90>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x161a47f90>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x161a4d0d0>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x161a4e1d0>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x161a4f450>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x161a54510>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x161a55590>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x161a56610>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x161a57710>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x161a5c850>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x161a5d950>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x161a5ea50>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x161a5fb50>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x161a60c90>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x161a61d90>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x161a62e90>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x161a63f90>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x161a690d0>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x161a6a1d0>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x161a6b2d0>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x161a6c590>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x161a6d610>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x161a6e690>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x161a6f710>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x161a7c850>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x161a7d950>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x161a7ea50>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x161a7fb50>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x161a84c90>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x161a85d90>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x161a86e90>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x161a87f90>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x161a8d0d0>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x161a8e1d0>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x161a8f2d0>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x161a90410>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x161a91690>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x161a92710>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x161a93790>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x161a98850>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x161a99950>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x161a9aa50>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x161a9bb50>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x161aa0c90>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x161aa1d10>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x161aa2e10>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x161aa3f10>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x161aad050>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x161aae150>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x161aaf250>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x161abc390>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x161abd490>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x161abe710>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x161abf790>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x161ab8850>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x161ab98d0>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x161aba9d0>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x161abbad0>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x161ac8c10>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x161ac9d10>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x161acae10>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x161acbf10>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x161ad5050>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x161ad6150>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x161ad7250>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x161ad8390>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x161ad9490>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x161ada590>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x161adb810>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x161ae48d0>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x161ae5950>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x161ae69d0>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x161ae7ad0>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x161ae8c10>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x161ae9d10>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x161aeae10>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x161aebf10>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x161af9050>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x161afa150>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x161afb250>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x161b00390>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x161b01490>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x161b02590>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x161b03690>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x161b04950>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x161b059d0>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x161b06a50>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x161b07ad0>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x161b08c10>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x161b09d10>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x161b0ae10>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x161b0bf10>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x161b15050>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x161b16150>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x161b17250>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x161b18390>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x161b19490>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x161b1a590>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x161b1b690>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x161b1c7d0>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x161b1da50>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x161b1ead0>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x161b1fb50>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x161b28c10>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x161b29d10>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x161b2ae10>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x161b2bf10>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x161b35050>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x161b36150>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x161b37250>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x161b44390>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x161b45490>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x161b46590>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x161b47690>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x161b487d0>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x161b498d0>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x161b4ab50>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x161b4bbd0>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x161b50c90>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x161b51d10>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x161b52e10>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x161b53f10>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x161b59050>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x161b5a150>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x161b5b250>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x161b68390>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x161b69490>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x161b6a590>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x161b6b690>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x161b6c7d0>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x161b6d8d0>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x161b6e9d0>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x161b6fc50>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x161b78d10>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x161b79d90>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x161b7ae10>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x161b7bf10>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x161b81050>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x161b82150>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x161b83250>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x161b84390>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x161b85490>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x161b86590>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x161b87690>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x161b8c7d0>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x161b8d8d0>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x161b8e9d0>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x161b8fad0>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x161b90d90>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x161b91e10>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x161b92e90>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x161b93f10>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x161ba1050>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x161ba2150>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x161ba3250>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x161ba4390>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x161ba5490>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x161ba6590>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x161ba7690>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x161bac7d0>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x161bad8d0>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x161bae9d0>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x161bafad0>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x161bb4c10>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x161bb5e90>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x161bb6f10>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x161bb7f90>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x161bb9050>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x161bba150>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x161bbb250>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x161bbc390>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x161bbd490>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x161bbe590>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x161bbf690>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x161bc87d0>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x161bc98d0>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x161bca9d0>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x161bcbad0>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x161bd4c10>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x161bd5d10>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x161bd6f90>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x161be0050>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x161be10d0>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x161be2150>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x161be3250>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x161be4390>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x161be5490>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x161be6590>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x161be7690>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x161bec7d0>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x161bed8d0>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x161bee9d0>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x161befad0>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x161bf4c10>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x161bf5d10>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x161bf6e10>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x161c080d0>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x161c09150>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x161c0a1d0>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x161c0b250>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x161c0c390>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x161c0d490>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x161c0e590>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x161c0f690>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x161c147d0>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x161c158d0>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x161c169d0>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x161c17ad0>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x161c18c10>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x161c19d10>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x161c1ae10>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x161c1bf10>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x161c211d0>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x161c22250>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x161c232d0>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x161c28390>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x161c29490>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x161c2a590>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x161c2b690>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x161c2c7d0>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x161c2d8d0>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x161c2e9d0>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x161c2fad0>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x161c34c10>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x161c35d10>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x161c36e10>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x161c37f10>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x161c3d050>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x161c3e2d0>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x161c3f350>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x161c48410>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x161c49490>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x161c4a590>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x161c4b690>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x161c4c7d0>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x161c4d8d0>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x161c4e9d0>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x161c4fad0>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x161c54c10>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x161c55d10>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x161c56e10>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x161c57f10>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x161c61050>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x161c62150>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x161c633d0>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x161c68490>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x161c69510>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x161c6a590>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x161c6b690>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x161c747d0>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x161c758d0>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x161c769d0>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x161c77ad0>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x161c80c10>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x161c81d10>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x161c82e10>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x161c83f10>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x161c89050>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x161c8a150>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x161c8b250>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x161c94510>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x161c95590>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x161c96610>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x161c97690>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x161c987d0>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x161c998d0>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x161c9a9d0>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x161c9bad0>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x161c9cc10>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x161c9dd10>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x161c9ee10>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x161c9ff10>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x161ca9050>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x161caa150>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x161cab250>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x161cac390>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x161cad610>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x161cae690>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x161caf710>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x161cb87d0>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x161cb98d0>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x161cba9d0>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x161cbbad0>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x161cc4c10>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x161cc5c90>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x161cc6d90>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x161cc7e90>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x161cc8fd0>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x161cca0d0>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x161ccb1d0>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x161ccc310>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x161ccd410>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x161cce690>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x161ccf710>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x161cd07d0>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x161cd1850>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x161cd2950>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x161cd3a50>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x161cd8b90>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x161cd9c90>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x161cdad90>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x161cdbe90>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x161ce4fd0>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x161ce60d0>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x161ce71d0>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x161ce8310>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x161ce9410>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x161cea510>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x161ceb790>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x161d00850>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x161d018d0>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x161d02950>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x161d03a50>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x161d08b90>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x161d09c90>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x161d0ad90>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x161d0be90>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x161d10fd0>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x161d120d0>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x161d131d0>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x161d14310>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x161d15410>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x161d16510>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x161d17610>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x161d1c8d0>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x161d1d950>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x161d1e9d0>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x161d1fa50>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x161d20b90>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x161d21c90>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x161d22d90>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x161d23e90>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x161d28fd0>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x161d2a0d0>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x161d2b1d0>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x161d30310>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x161d31410>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x161d32510>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x161d33610>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x161d38750>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x161d399d0>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x161d3aa50>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x161d3bad0>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x161d44b90>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x161d45c90>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x161d46d90>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x161d47e90>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x161d48fd0>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x161d4a0d0>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x161d4b190>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x161d54290>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x161d55390>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x161d56490>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x161d57590>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x161d586d0>, keys=[])]

# %% [markdown]
# ### Country Aliases Property

# %% [markdown]
# Alternative names for countries. Source: [Kaggle](https://www.kaggle.com/datasets/wbdill/country-aliaseslist-of-alternative-country-names)/[Wikipedia](https://en.wikipedia.org/wiki/List_of_alternative_country_names)

# %%
df_alias = pd.read_csv('data/country_aliases.csv')

# %%
def split_alias(row):
    '''
    Splits a row if Alias contains multiple aliases seperated by " or "
    '''
    if ' or ' in row['Alias']:
        values = row['Alias'].split(' or ')
        return pd.DataFrame({'iso3': [row['iso3']] * len(values), 'Alias': values})
    return pd.DataFrame({'iso3': [row['iso3']], 'Alias': [row['Alias']]})

# %%
aliases = pd.concat([split_alias(row) for _, row in df_alias.iterrows()],
                  ignore_index=True)\
        .dropna()\
        .drop_duplicates()\
        .rename(columns={'Alias': 'alias'})

# %%
param_dicts = aliases.to_dict('records')
param_dicts[:5]
# Out:
# [{'iso3': 'AFG', 'alias': 'Afghanistan'},
#  {'iso3': 'AFG', 'alias': 'Islamic Republic of Afghanistan'},
#  {'iso3': 'AFG', 'alias': 'Da Afganistan Islami Jumhoryat'},
#  {'iso3': 'AFG', 'alias': 'Jomhuriyyeh Eslamiyyeh Afganestan'},
#  {'iso3': 'ALB', 'alias': 'Albania'}]

# %%
graph_utils.execute_query_with_params('''
MERGE (c:Country {iso3: $iso3})
SET c.aliases = 
    CASE
        WHEN c.aliases IS NULL THEN [$alias]
        WHEN NOT $alias IN c.aliases THEN c.aliases + $alias
        ELSE c.aliases
    END''', *param_dicts)
# Out:
# [EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x125dc1e90>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x161855990>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x161856290>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x161856c90>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x161857890>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x1618644d0>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x161865090>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x161865c50>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x1618667d0>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x161d9cb90>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x161d9df90>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x161d9dc50>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x161d9e2d0>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x161d1f990>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x161d1ea50>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x161d758d0>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x161d75590>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x161d76cd0>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x161d772d0>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x161d77a90>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x161d175d0>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x161d16a50>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x161d13bd0>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x161d133d0>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x161d0be50>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x161f74210>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x161f75150>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x161f75f90>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x161f76e50>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x161f77cd0>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x161d02dd0>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x161d01b90>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x161ce8690>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x161ce8650>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x161ce6410>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x161ce4090>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x161cdbf10>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x161cd2c90>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x161cd1d90>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x161cce5d0>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x161ccca10>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x161cc9290>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x161cc9490>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x161cc6010>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x161cc56d0>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x161cb9150>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x161cbbd10>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x161cac990>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x161cad7d0>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x161cab6d0>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x161ca9250>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x161c9f310>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x161c9afd0>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x161c99d50>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x161c97950>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x161c97b10>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x161c8b6d0>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x161c89590>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x161c831d0>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x161c81110>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x161c75090>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x161c75b10>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x161f80710>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x161f81550>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x161f82410>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x161f83290>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x161c6bf50>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x161c69e90>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x161c63950>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x161c63a50>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x161c57290>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x161c565d0>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x161c4e910>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x161c4ec50>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x161c49390>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x161c48810>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x161c3f7d0>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x161f84650>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x161f85510>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x161f86390>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x161f872d0>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x161df8050>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x161df9090>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x161df87d0>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x161dfab50>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x161dfb450>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x161dfbc50>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x161f8ca10>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x161f8d8d0>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x161f8e950>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x161f8f810>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x161f946d0>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x161f95610>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x161f96450>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x161f97310>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x161f9c190>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x161f9d090>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x161f9ded0>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x161f9ed90>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x161f9fc10>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x161e3cc90>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x161e3d090>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x161e3e4d0>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x161e3dc90>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x161e3f0d0>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x161e44890>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x161e44cd0>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x161e46190>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x161e47010>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x161e47710>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x161fa4350>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x161fa5210>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x161fa6090>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x161fa6fd0>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x161fa7e10>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x161fa8d50>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x161fa9c50>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x161faab50>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x161faba50>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x161fb0990>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x161fb1890>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x161fb2790>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x161fb3690>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x161e946d0>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x161e94810>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x161e96110>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x161e963d0>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x161e96dd0>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x161850b50>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x161e98d10>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x161e99a10>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x161e991d0>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x161e9b4d0>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x161e9bf10>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x161fb8710>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x161fb9610>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x161fba510>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x161fbb410>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x161ea0550>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x161ea1290>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x161ea1b90>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x161ea2990>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x161ea3550>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x161ea3c10>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x161fbcdd0>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x161fbdcd0>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x161fbedd0>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x161fbfc90>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x161fc8b50>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x161fc9a90>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x161fca8d0>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x161fcb790>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x161eec790>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x161eed3d0>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x161eee210>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x161eee150>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x161eef610>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x161fcc210>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x161fcd110>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x161fce010>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x161fcee90>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x161fcfd90>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x161ef0a50>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x161ef1ad0>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x161ef06d0>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x161ef2c10>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x161ef3e10>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x161fd49d0>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x161fd5890>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x161fd6710>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x161fd7650>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x161f4c410>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x161f4d010>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x161f4dc10>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x161f4f350>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x161f48b90>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x161f4a390>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x161f4bb90>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x161f453d0>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x161f46bd0>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x161f50410>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x161f51c10>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x161f53410>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x161f54c50>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x161f56750>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x161f57ed0>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x161f59590>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x161f5ad90>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x161f5d9d0>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x161f5e810>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x161f5f690>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x161f5c8d0>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x1621785d0>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x1621791d0>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x162179dd0>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x16217aad0>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x16217b6d0>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x16109d850>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x161832190>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x161f18110>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x161f180d0>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x161f19050>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x161f1a950>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x161f1a190>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x161066290>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x161fdf910>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x161fdcb90>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x161fddb50>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x161fdec50>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x161fdfd50>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x162144b10>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x162145710>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x162146310>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x162146f10>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x162147b10>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x161f788d0>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x161f797d0>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x161f7a7d0>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x161f7b6d0>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x1620d0410>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x1620d1010>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x1620d1c10>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x1620d2a10>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x1620d3650>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x16216a510>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x16216b090>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x16216bcd0>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x162168890>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x162169450>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x162137790>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x162134ad0>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x1621356d0>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x1621362d0>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x162136ed0>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x16220c710>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x16220d390>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x16220df90>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x16220eb90>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x16220f790>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x161fd83d0>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x161fd8fd0>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x161fd9d50>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x161fda910>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x161fdb4d0>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x161f340d0>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x161f34c90>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x161f35850>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x161f36410>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x161f37010>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x161f37c10>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x161f60850>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x161f61450>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x161f62050>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x161f62c50>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x161f63850>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x161fe0490>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x161fe1090>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x161fe1c90>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x161fe2890>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x161fe3490>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x161fe46d0>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x161fe6a10>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x161fe4750>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x161fe5850>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x161fe6a90>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x161fe7b90>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x161ff8910>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x161ff9510>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x161ffa110>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x161ffad10>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x161ffb910>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x161f7c550>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x161f7d150>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x161f7dd50>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x161f7e950>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x161f7f550>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x161f88190>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x161f88d90>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x161f89990>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x161f8a710>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x161f8b2d0>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x161f8be90>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x161f90a90>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x161f91650>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x161f92210>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x161f92dd0>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x161f939d0>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x161f98610>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x161f99210>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x161f99e10>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x161f9aa10>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x161f9b610>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x161fa0250>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x161fa0e50>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x161fa1a50>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x161fa2650>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x161fa3250>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x161fa3e50>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x161facc10>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x161fad7d0>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x161fae390>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x161faef50>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x161fafb10>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x161f2c710>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x161f2d2d0>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x161f2ded0>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x161f2ead0>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x161f2f6d0>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x161fc0310>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x161fc0f10>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x161fc1b10>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x161fc2710>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x161fc3310>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x161fc3f10>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x161fd0b50>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x161fd1750>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x161fd2350>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x161fd30d0>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x161fd3c90>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x161f00b90>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x161f01b50>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x161f02450>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x161f030d0>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x161f037d0>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x161f083d0>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x161f08fd0>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x161f09bd0>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x161f0a7d0>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x161f0b3d0>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x161f0bfd0>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x161fecc10>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x161fed810>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x161fee410>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x161fef010>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x161fefc10>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x161ff4850>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x161ff55d0>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x161ff6190>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x161ff6d50>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x161ff7910>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x161ef8510>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x161ef90d0>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x161ef9c90>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x161efa890>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x161efb490>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x161e00110>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x161e01050>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x161e01dd0>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x161e01cd0>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x161e035d0>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x161e03f50>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x161e0c910>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x161e0d510>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x161e0e110>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x161e0ed10>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x161e0fa90>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x161e14690>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x161e15250>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x161e15e10>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x161e169d0>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x161e17590>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x161e20190>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x161e21290>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x161e21190>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x161e22a90>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x161e23650>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x161e23d90>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x161e289d0>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x161e295d0>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x161e2a1d0>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x161e2add0>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x161e2b9d0>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x161e30610>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x161e31210>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x161e31f90>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x161e32b50>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x161e33710>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x161e34210>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x161e353d0>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x161e36190>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x161e36a90>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x161e374d0>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x161e37c10>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x161e38a90>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x161e39690>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x161e3a290>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x161e3ae90>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x161e3ba90>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x161e406d0>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x161e412d0>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x161e41ed0>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x161e42ad0>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x161e436d0>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x161e58490>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x161e59050>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x161e59c10>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x161e5a7d0>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x161e5b390>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x161e5bf50>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x161e60e90>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x161e61e50>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x161e62a50>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x161e62f90>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x161e630d0>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x161e68790>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x161e69390>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x161e69f90>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x161e6ab90>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x161e6b790>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x161e6c890>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x161e6d6d0>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x161e6e2d0>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x161e6ee90>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x161e6f5d0>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x161e74110>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x161e74cd0>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x161e75890>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x161e76450>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x161e77010>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x161e77c10>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x161e7cb10>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x161e7db50>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x161e7e090>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x161e7f050>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x161e7fd90>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x161e88150>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x161e89790>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x161e89cd0>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x161e8ac90>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x161e8b9d0>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x161e9c0d0>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x161e9ce50>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x161e9da10>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x161e9e5d0>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x161e9f190>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x161e9fd50>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x161ebc950>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x161ebd510>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x161ebe110>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x161ebed10>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x161ebf910>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x161ec0790>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x161ec13d0>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x161ec1cd0>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x161ec1e50>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x161ec3610>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x161ec4190>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x161ec4d90>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x161ec5990>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x161ec6590>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x161ec7310>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x161ec7ed0>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x161ecc610>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x161eccb90>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x161ecd210>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x161ecf510>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x161ecff50>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x161ed4690>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x161ed5190>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x161ed5310>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x161ed6ad0>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x161ed7a50>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x161ee4390>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x161ee49d0>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x161ee4f50>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x161ee6710>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x161ee7690>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x161ee7890>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x161ef4a90>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x161ef5810>, keys=[]),
# ...
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x1620c1c90>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x1620c2850>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x1620c3410>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x1620c3fd0>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x162034bd0>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x162035790>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x162036350>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x162036f50>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x162037b50>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x16205c810>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x16205d390>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x16205df90>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x16205ec90>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x16205f890>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x16206c450>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x16206d050>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x16206dc50>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x16206e850>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x16206f410>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x162090190>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x162090d50>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x162091910>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x1620924d0>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x162093090>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x162093c50>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x1620ac890>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x1620ad490>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x1620ae090>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x1620aec90>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x1620af890>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x1620bc510>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x1620bd0d0>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x1620bdd50>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x1620be950>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x1620bf550>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x1620e0110>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x1620e0d10>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x1620e1910>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x1620e2690>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x1620e31d0>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x1620e3e10>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x1620e89d0>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x1620e9590>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x1620ea150>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x1620ead90>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x1620eb990>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x1620ec5d0>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x1620ed1d0>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x1620eddd0>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x1620ee9d0>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x1620ef5d0>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x1620f0250>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x1620f0e50>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x1620f1a50>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x1620f2650>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x1620f3250>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x1620f3e50>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x1620f4bd0>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x1620f5790>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x1620f6350>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x1620f6f10>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x1620f7ad0>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x16200c6d0>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x16200d290>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x16200de90>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x16200ea90>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x16200f690>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x1620182d0>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x162018ed0>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x162019ad0>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x16201a6d0>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x16201b2d0>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x16201bed0>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x162024b10>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x162025710>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x162026310>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x162027090>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x162027c50>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x162030850>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x162031410>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x162031fd0>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x162032b90>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x162033750>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x162200390>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x162200f90>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x162201b90>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x162202790>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x162203390>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x162203f90>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x162208bd0>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x1622097d0>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x16220a3d0>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x16220afd0>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x16220bbd0>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x162214810>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x162215590>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x162216150>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x162216d10>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x1622178d0>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x1622204d0>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x162221090>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x162221c50>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x162222850>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x162223450>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x162228090>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x162228c90>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x162229890>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x16222a490>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x16222b090>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x16222bc90>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x16222c8d0>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x16222d4d0>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x16222e0d0>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x16222ecd0>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x16222fa50>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x162238650>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x162239210>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x162239dd0>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x16223a990>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x16223b550>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x16223c150>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x16223cd50>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x16223d950>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x16223e550>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x16223f150>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x16223fd50>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x162244990>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x162245590>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x162246190>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x162246d90>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x162247990>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x1622485d0>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x1622491d0>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x161f65fd0>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x161f6dc10>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x161f75850>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x161f81450>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x161f85090>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x161f8ccd0>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x161f94910>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x161f9c750>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x161fa4390>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x161fa7f90>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x161f7bc50>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x161fb3810>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x161fbb450>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x161fbf090>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x161fcacd0>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x161fcea90>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x161fd66d0>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x161faa2d0>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x161f5e890>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x161f5c890>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x161f5b0d0>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x161f59950>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x161f58150>, keys=[])]

# %% [markdown]
# ### Country Stats

# %% [markdown]
# Yearly stats for each country are sourced from [Worldbank](data.worldbank.org). Corporate Tax Rates sourced from [Tax Foundation](https://taxfoundation.org/data/all/global/corporate-tax-rates-by-country-2023).

# %%
def get_worldbank(indicator: str) -> pd.DataFrame:
    '''
    Get indicator data using worldbank API
    '''
    with urllib.request.urlopen(f"https://api.worldbank.org/v2/country/all/indicator/{indicator}?format=json&per_page=20000") as url:
        data = json.load(url)[1]
    ind = data[0]['indicator']['value']
    iso3 = map(itemgetter('countryiso3code'), data)
    year = map(itemgetter('date'), data)
    value = map(itemgetter('value'), data)
    return pd.DataFrame({
        'iso3': iso3,
        'year': year,
        ind: value
    }).replace('', np.nan)\
      .dropna()\
      .set_index(['iso3', 'year'])

# %%
population = get_worldbank('SP.POP.TOTL')

# %%
gdp = get_worldbank('NY.GDP.MKTP.CD')

# %%
pv = get_worldbank('PV.EST')

# %%
ctr = pd.read_excel('data/corp_tax_rate.xlsx')\
        .melt(id_vars='iso_3',
              value_vars=range(1980, 2024),
              var_name='year',
              value_name='corporate_tax_rate')\
        .rename(columns={'iso_3': 'iso3'})\
        .astype({'year': str})\
        .set_index(['iso3', 'year'])

# %%
stats = pd.concat([population, gdp, pv, ctr], axis=1).sort_index()\
          .reset_index()\
          .rename(columns={
              'Population, total': 'population',
              'GDP (current US$)': 'gdp',
              'Political Stability and Absence of Violence/Terrorism: Estimate': 'pv',
              'corporate_tax_rate': 'corporate_tax_rate'
          })

# %% [markdown]
# We use 2022 stats for now

# %%
param_dicts = stats[stats['year'] == '2022'].to_dict('records')
param_dicts[:3]
# Out:
# [{'iso3': 'ABW',
#   'year': '2022',
#   'population': 106445.0,
#   'gdp': 3544707788.05664,
#   'pv': 1.47468435764313,
#   'corporate_tax_rate': 25.0},
#  {'iso3': 'AFE',
#   'year': '2022',
#   'population': 720859132.0,
#   'gdp': 1183962133998.87,
#   'pv': nan,
#   'corporate_tax_rate': nan},
#  {'iso3': 'AFG',
#   'year': '2022',
#   'population': 41128771.0,
#   'gdp': 14502158192.0904,
#   'pv': -2.5508017539978,
#   'corporate_tax_rate': 20.0}]

# %%
graph_utils.execute_query_with_params('''
MATCH (c:Country {iso3: $iso3})
SET
    c.population = $population,
    c.gdp = $gdp,
    c.pv = $pv,
    c.corporate_tax_rate = $corporate_tax_rate''', *param_dicts)
# Out:
# [EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x161f6c290>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x161f6cc10>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x161f6d750>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x161f6e290>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x161f6f190>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x161d33d10>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x161d329d0>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x161d2ba90>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x161d2b6d0>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x161d2a590>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x161d20e90>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x1626e86d0>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x162747d10>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x162736210>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x1627359d0>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x162734b90>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x162723e50>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x162722fd0>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x162722450>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x162721a10>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x162721090>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x162720210>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x162713810>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x162712e90>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x162711e90>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x162711390>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x162710790>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x1626a7a10>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x1626a6f50>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x1626a6590>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x1626a5910>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x1626a4c10>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x1626f7f90>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x1626f7090>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x1626f6590>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x1626f5910>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x1626f4d50>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x1626f4190>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x16265f410>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x16265ebd0>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x16265e390>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x16265d590>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x16265c9d0>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x1626d7cd0>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x1626d6dd0>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x1626d6250>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x1626d5b10>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x1626d4c10>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x1626d4050>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x1626c7310>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x1626c68d0>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x1626c5bd0>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x1626c5010>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x1626c4690>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x1626b7790>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x1626b6b50>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x1626b5e90>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x1626b52d0>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x1626b4690>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x16266fd10>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x16266f210>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x16266e510>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x16266d990>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x16266cd10>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x16266c110>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x16261f690>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x16261eb90>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x16261df90>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x16261d090>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x16261c490>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x16268f990>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x16268edd0>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x16268ded0>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x16268d690>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x16268c990>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x16267ffd0>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x16267f250>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x16267e6d0>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x16267dc90>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x16267d250>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x16267c650>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x1625b7ad0>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x1625b6c90>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x1625b6050>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x1625b5610>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x1625b4850>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x16264fc90>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x16264f090>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x16264e590>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x16264dbd0>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x16264cf90>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x16264c1d0>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x16263b890>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x16263a790>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x162639c10>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x1626391d0>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x1626385d0>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x1625f3ad0>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x1625f2dd0>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x1625f23d0>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x1625f1650>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x1625f09d0>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x16262bd50>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x16262b410>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x16262a690>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x1626299d0>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x162628d10>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x162628050>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x162593750>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x162592b10>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x162591e10>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x162591210>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x162590610>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x162607810>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x1626070d0>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x162606510>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x162605910>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x162604950>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x162537dd0>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x162537510>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x162536850>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x162535f10>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x1625351d0>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x162534610>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x1625df7d0>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x1625dee10>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x1625de210>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x1625dd610>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x1625dc8d0>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x1625cfb90>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x1625cee90>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x1625ce2d0>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x1625cd750>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x1625ccb50>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x1625bbf90>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x1625bb550>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x1625ba9d0>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x1625b9d10>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x1625b90d0>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x1625b80d0>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x1625a7510>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x1625a6910>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x1625a5d10>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x1625a5290>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x1625a4690>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x162513890>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x162512c90>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x162512090>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x162511610>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x162510a50>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x16257fbd0>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x16257f050>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x16257e5d0>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x16257dad0>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x16257ced0>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x16257c250>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x1624bb990>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x1624baad0>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x1624b9ed0>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x1624b9450>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x1624b8910>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x162573c50>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x162573050>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x162572450>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x1625715d0>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x1625709d0>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x162553c10>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x162552e90>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x1625520d0>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x162551490>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x162550450>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x162543d50>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x162542f90>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x162542410>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x162541810>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x162540b90>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x16249a9d0>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x162498090>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x16249b310>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x126554e90>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x161a8e450>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x161a9a350>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x1610a2ad0>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x161c29810>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x161afa590>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x16240bdd0>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x162340cd0>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x162343f10>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x16239c950>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x16239fad0>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x1623d62d0>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x16244d610>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x16244c090>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x16244ef90>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x16244eb10>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x16244cdd0>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x16236dfd0>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x16236fad0>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x161a45050>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x1624803d0>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x162481cd0>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x162482fd0>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x16237aed0>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x161a5cd50>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x1624dfd90>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x1624dedd0>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x1624ddb50>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x1624dd110>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x1624dc110>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x1623dde10>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x1624ab7d0>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x1624ccf90>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x1624cca10>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x1624cd690>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x1624cef10>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x1624cff50>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x16246e250>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x16246d090>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x16246de10>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x162459ad0>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x16245bd50>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x16245aa50>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x162523ad0>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x162522e10>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x162521650>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x1623c0bd0>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x1623c36d0>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x1623ad310>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x1624ebad0>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x1624eb410>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x1624e8850>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x1624e99d0>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x1624ead10>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x161c20650>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x162485d90>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x162486ed0>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x1624850d0>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x16238bcd0>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x162429a10>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x1625014d0>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x1625012d0>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x162503e90>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x162502490>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x162500310>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x162778cd0>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x162779090>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x162779b50>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x16277a590>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x16277b1d0>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x16277be90>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x162704910>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x162705590>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x162706250>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x162706f10>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x162707b90>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x1627a4790>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x1627a53d0>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x1627a5f10>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x1627a6b10>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x1627a7710>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x162768350>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x162768f50>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x162769b10>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x16276a890>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x16276b490>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x16276be90>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x1627b4a50>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x1627b5690>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x1627b60d0>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x1627b6cd0>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x1627b78d0>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x1627c4550>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x1627c5150>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x1627c5d50>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x1627c6950>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x1627c7550>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x1627544d0>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x1627550d0>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x1627557d0>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x162756450>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x162757050>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x1627e40d0>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x1627e4c50>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x1627e57d0>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x1627e6410>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x1627e70d0>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x1627e7cd0>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x1627f0790>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x1627f1250>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x1627f1e50>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x1627f2a50>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x1627f3750>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x162790350>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x162790f50>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x162791b50>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x162792750>, keys=[])]

# %% [markdown]
# ### Sector Node

# %% [markdown]
# The data used for Sector/Industry nodes comes from [bautheac/GICS](https://github.com/bautheac/GICS) packages the Global Industry Classification Standards (GICS) dataset for consumption in R.  The GICS hierarchy begins with 11 sectors and is followed by 24 industry groups, 68 industries, and 157 sub-industries.

# %%
url = 'https://github.com/bautheac/GICS/raw/0c2b0e4c0ca56a0e520301fd978fc095ed4fc328/data/standards.rda'
response = requests.get(url)

rda_file_path = './data/standards.rda'
with open(rda_file_path, 'wb') as file:
    file.write(response.content)

# Load the .rda file using pyreadr
result = pyreadr.read_r(rda_file_path)

print(result.keys())  

df = result[list(result.keys())[0]]  

# Save the DataFrame as a CSV file and remove the rda file
df.to_csv('./data/standards.csv', index=False)

os.remove(rda_file_path)

print("Data has been saved as standards.csv")
# Out:
# odict_keys(['standards'])
# Data has been saved as standards.csv

# %%
# data wrangling for industry/sector

def wrangling(csv_path):
    df = pd.read_csv(csv_path)
    
    df = df.dropna()

    df = df.drop_duplicates()
    
    df = df.rename(columns={
        'sector id': 'sector_id',
        'sector name': 'sector_name',
        'industry group id': 'industry_group_id',
        'industry group name': 'industry_group_name',
        'industry id': 'industry_id',
        'industry name': 'industry_name',
        'subindustry id': 'subindustry_id',
        'subindustry name': 'subindustry_name',
        'description': 'primary_activity'
    })

    
    df['sector_id'] = df['sector_id'].astype('Int64')  
    df['industry_group_id'] = df['industry_group_id'].astype('Int64')
    df['industry_id'] = df['industry_id'].astype('Int64')
    df['subindustry_id'] = df['subindustry_id'].astype('Int64')

    df.reset_index(drop=True, inplace=True)
    df.index += 1

    return df

df_standards = wrangling("./data/standards.csv")

# %%
sector = df_standards[['sector_id', 'sector_name']] \
        .drop_duplicates() \
        .rename(columns={
            'sector_id': 'gics',
            'sector_name': 'name'
        })

# %%
param_dicts = sector.to_dict('records')
param_dicts[:5]
# Out:
# [{'gics': 10, 'name': 'Energy'},
#  {'gics': 15, 'name': 'Materials'},
#  {'gics': 20, 'name': 'Industrials'},
#  {'gics': 25, 'name': 'Consumer Discretionary'},
#  {'gics': 30, 'name': 'Consumer Staples'}]

# %%
graph_utils.execute_query_with_params("MERGE (:Sector{gics: $gics, name: $name})", *param_dicts)
# Out:
# [EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x162744e10>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x1627441d0>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x162737cd0>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x162737410>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x16285ecd0>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x16285de90>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x16285d0d0>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x16285c350>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x161f64450>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x161a84f90>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x1627921d0>, keys=[])]

# %% [markdown]
# ### Industry Node

# %%
industry = df_standards[['subindustry_id', 'subindustry_name', 'primary_activity']] \
           .drop_duplicates() \
           .rename(columns={
               'subindustry_id': 'gics',
               'subindustry_name': 'name',
               'primary_activity': 'description'
            })

# %% [markdown]
# We use a sentence embeddings model to generate embeddings for the industry description.

# %%
EMBEDDING_MODEL = SentenceTransformer("all-MiniLM-L6-v2")

# %%
industry_desc_embed = EMBEDDING_MODEL.encode(industry['description'].to_numpy())
industry['embedding'] = list(map(list, industry_desc_embed))

# %%
param_dicts = industry.to_dict('records')

# %%
graph_utils.execute_query_with_params("MERGE (:Industry{gics: $gics, name: $name, description: $description, embedding: $embedding})", *param_dicts)
# Out:
# [EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x16da40690>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x16da73b50>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x16da72e90>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x16da724d0>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x16da71a50>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x16da70b90>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x16da70150>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x16da0f3d0>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x16da0e7d0>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x16da0dbd0>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x16da0d010>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x16da0c6d0>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x16da93910>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x16da92cd0>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x16da920d0>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x16da91350>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x16da905d0>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x16da87950>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x16da86cd0>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x16da85f10>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x16da85410>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x16da84790>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x16da63b90>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x16da62d10>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x16da621d0>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x16da61650>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x16da60990>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x16da53dd0>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x16da531d0>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x16da52350>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x16da51950>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x16da50a90>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x16d9dbe90>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x16d9db210>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x16d9da450>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x16d9d9950>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x16d9d8d10>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x16da33f10>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x16da332d0>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x16da32690>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x16da31850>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x16da30d10>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x16da30350>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x16da1f790>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x16da1eb90>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x16da1ddd0>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x16da1cc50>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x16da1c110>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x16d993650>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x16d992a50>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x16d991e50>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x16d991350>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x16d990790>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x16d9fb550>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x16d9fac90>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x16d9f9d90>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x16d9f9290>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x16d9f8350>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x16d9bba50>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x16d9bac10>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x16d9ba490>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x16d9b98d0>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x16d9b8550>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x16d9eba90>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x16d9ead90>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x16d9ea190>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x16d9e9510>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x16d9e8c10>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x16d953c50>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x16d953210>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x16d952490>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x16d951950>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x16d950b50>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x16d9cfe10>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x16d9cf210>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x16d9ce4d0>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x16d9cd990>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x16d9ccc90>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x16d9cc310>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x16d9ab5d0>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x16d9aa690>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x16d9a9b50>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x16d9a9050>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x16d9a82d0>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x16d91f510>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x16d91eb90>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x16d91ddd0>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x16d91d210>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x16d91c3d0>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x16d983950>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x16d9829d0>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x16d982110>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x16d9811d0>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x16d980850>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x16d943ad0>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x16d942e50>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x16d942110>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x16d941510>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x16d940610>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x16d973990>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x16d972d50>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x16d972250>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x16d971650>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x16d970a90>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x16d963e10>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x16d963090>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x16d962490>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x16d961890>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x16d960ad0>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x16d8c3f10>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x16d8c2e50>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x16d8c26d0>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x16d8c1650>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x16d8c0d90>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x16d92fb90>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x16d92f250>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x16d92e190>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x16d92d9d0>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x16d92ce10>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x16d92c110>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x16d89f450>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x16d89e690>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x16d89db10>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x16d89d0d0>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x16d89c050>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x16d907090>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x16d906810>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x16d905cd0>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x16d905010>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x16d904150>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x16d8fb650>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x16d8faad0>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x16d8f9c50>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x16d8f9150>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x16d8f8050>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x16d8eb410>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x16d8ea590>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x16d8e9cd0>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x16d8e9090>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x16d8e84d0>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x16d8d3790>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x16d8d2790>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x16d8d2010>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x16d8d1110>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x16d8d0490>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x16d85b990>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x16d85aa50>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x16d859e90>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x16d8592d0>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x16d858310>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x16d87f650>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x16d87e890>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x16d87e010>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x16d87d310>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x16d87c490>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x16d8af610>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x16d8aed10>, keys=[])]

# %% [markdown]
# ### Industry PART_OF Sector Relationship

# %%
industry_sector = df_standards[['subindustry_id', 'sector_id']] \
                  .drop_duplicates() \
                  .rename(columns={
                      'subindustry_id': 'industry_gics',
                      'sector_id': 'sector_gics'
                  })

# %%
param_dicts = industry_sector.to_dict('records')
param_dicts[:5]
# Out:
# [{'industry_gics': 10101010, 'sector_gics': 10},
#  {'industry_gics': 10101020, 'sector_gics': 10},
#  {'industry_gics': 10102010, 'sector_gics': 10},
#  {'industry_gics': 10102020, 'sector_gics': 10},
#  {'industry_gics': 10102030, 'sector_gics': 10}]

# %%
graph_utils.execute_query_with_params('''
MATCH
    (i:Industry{gics: $industry_gics}),
    (s:Sector{gics: $sector_gics})
MERGE (i)-[:PART_OF]->(s)''', *param_dicts)
# Out:
# [EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x16d8ae190>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x16d81c890>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x16d88f7d0>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x16d88e990>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x16d88d810>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x16d88c750>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x16d87db50>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x16d88c290>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x16d8433d0>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x16d842450>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x16d841450>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x16d840090>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x16d86afd0>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x16d86a010>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x16d869090>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x16d7dbe50>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x16d7dac10>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x16d7d9d90>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x16d7d8ad0>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x16d847890>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x16d846ad0>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x16d845710>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x16d844710>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x16d8334d0>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x16d832490>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x16d831250>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x16d8302d0>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x16d7b7250>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x16d7b6090>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x16d7b5050>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x16d80fdd0>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x16d80eb50>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x16d80dbd0>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x16d80cc90>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x16d7cb7d0>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x16d7ca710>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x16d7c9610>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x16d7c8610>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x16d7f3290>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x16d7f20d0>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x16d7f0f50>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x16d7f0110>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x16d7def10>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x16d7dde90>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x16d7dcdd0>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x16d74fbd0>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x16d74ed10>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x16d74dad0>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x16d74cb10>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x16d787790>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x16d786390>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x16d785410>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x16d784250>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x16d733290>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x16d732150>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x16d730e50>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x16d7a7fd0>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x16d7a6fd0>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x16d7a5a50>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x16d7a4f90>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x16d79b7d0>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x16d79ad10>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x16d7995d0>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x16d7987d0>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x16d773290>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x16d772710>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x16d771150>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x16d7705d0>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x16d762ed0>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x16d762290>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x16d760d90>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x16d6ebad0>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x16d6eaa50>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x16d6e9c10>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x16d6e8b50>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x16d70f810>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x16d70e610>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x16d70d5d0>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x16d70c410>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x16d73f490>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x16d73e2d0>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x16d73cf90>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x16d6b8290>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x16d6babd0>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x16d6b9d50>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x16d6b8cd0>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x16d71f710>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x16d71e9d0>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x16d71d990>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x16d71c710>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x16d6cb390>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x16d6ca450>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x16d6c9210>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x16d6c8290>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x16d6ff250>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x16d6fded0>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x16d6fcd90>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x16d673bd0>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x16d672b50>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x16d6719d0>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x16d670890>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x16d6dbb90>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x16d8582d0>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x16d85b890>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x16d85a990>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x16d8d2190>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x16d8d19d0>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x16d8e9a50>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x16d8ea150>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x16d8f8350>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x16d8fb5d0>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x16d907350>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x16d89c610>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x16d89fd90>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x16d92d150>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x16d92d290>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x16d8c0ad0>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x16d8c2950>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x16d962790>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x16d963ed0>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x16d973850>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x16d940490>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x16d9406d0>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x16d980e10>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x16d981310>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x16d91dc10>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x16d91db90>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x16d9aa2d0>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x16d9ab1d0>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x16d9cc810>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x16d950810>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x16d953a50>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x16d9e9810>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x16d9ea8d0>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x16d9b85d0>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x16d6db1d0>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x16d6d9e90>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x16d6d8cd0>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x16d627f10>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x16d626d90>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x16d625ad0>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x16d624990>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x16d6a3810>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x16d6a2650>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x16d6a1650>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x16d6a0510>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x16d693290>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x16d692010>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x16d690fd0>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x16d64bfd0>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x16d64add0>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x16d649b50>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x16d648ad0>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x16d67ff10>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x16d67e850>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x16d67dad0>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x16d67c5d0>, keys=[])]

# %% [markdown]
# ## Adding Company Data

# %% [markdown]
# ### Import JSON files

# %% [markdown]
# In this part, import all the json files, `nasdaq_kg_schema.json`, `nasdaq_kg_schema_rank_1-10.json` and `nasdaq_kg_schema_rank_11-32.json`.

# %%
json_files = ['nasdaq_kg_schema.json',
              'nasdaq_kg_schema_rank_1-10.json',
              'nasdaq_kg_schema_rank_11-32.json',
              'nasdaq_kg_schema_rank_33-37.json',
              'nasdaq_kg_schema_rank_38-40.json']

def merge_json_files(json_list: list[str]) -> dict:

    merged_json = {
        "nodes": {},
        "relationships": {}
    }

    for file_path in json_list:
        with open(file_path, 'r') as file:
            try:
                data = json.load(file)
                
                if "nodes" in data:
                    for node_type, nodes in data["nodes"].items():
                        if node_type not in merged_json["nodes"]:
                            merged_json["nodes"][node_type] = []
                        merged_json["nodes"][node_type].extend(nodes)

               
                if "relationships" in data:
                    for relationship_type, relationships in data["relationships"].items():
                        if relationship_type not in merged_json["relationships"]:
                            merged_json["relationships"][relationship_type] = []
                        merged_json["relationships"][relationship_type].extend(relationships)

            except json.JSONDecodeError as e:
                print(f"Error decoding {file_path}: {e}")
                
            except FileNotFoundError:
                print("Error: The file was not found.")

    return merged_json

merged_json = merge_json_files(json_files)

# %% [markdown]
# ### Data Validation

# %% [markdown]
# * This part is only for company nodes, where we want to ensure data integrity by checking the primary key ticker_code and ensuring other fields like company name adhere to specific formatting rules and constraints.
# * Validating ticker_code as a valid string consisting of 4 to 5 uppercase letters, is for accurate indexing in financial markets.
# * The process identifies duplicates and keeps the more-info version of an entry over the other duplicates.
# * Standardizing company names into title case and eliminating special symbols maintains consistency in representation and usability.
# * All data entry whose ticker_code and company_name does not meet these criteria will be removed to maintain a clean dataset for the reporting of company information.

# %%
def is_valid_ticker(ticker_code):
    """Helper function to check if the ticker code is valid (str, 4 to 5 letters, all upper case)."""
    return isinstance(ticker_code, str) and 4 <= len(ticker_code) <= 5 and ticker_code.isupper()

def remove_invalid_ticker_companies(data):
    """Remove companies whose ticker_code doesn't meet the 3, 4, or 5 letter criteria."""
    if isinstance(data, str):
        print("Warning: data is a string, attempting to load as JSON.")
        data = json.loads(data)  
    
    if "nodes" in data and "Company" in data["nodes"]:
        companies = data["nodes"]["Company"]
        filtered_companies = [company for company in companies if is_valid_ticker(company.get("ticker_code"))]
        data["nodes"]["Company"] = filtered_companies
    else:
        print("Warning: The expected structure is not found in the data.")

    return data

def is_more_comprehensive(entry1, entry2):
    """Helper function to determine which duplicate has more comprehensive details."""
    return sum(1 for v in entry1.values() if v) > sum(1 for v in entry2.values() if v)

def remove_duplicates(data):
    seen_tickers = {}
    for company in data["nodes"]["Company"]:   
        ticker = company.get("ticker_code", "")
        if ticker in seen_tickers:
            if is_more_comprehensive(company, seen_tickers[ticker]):
                seen_tickers[ticker] = company
        else:
            seen_tickers[ticker] = company 
    data["nodes"]["Company"] = list(seen_tickers.values())
    return data

def clean_names(name):
    name = name.title()
    name = re.sub(r'[^\w\s]', '', name)
    return name

def standarize_case(data):
    """function to standardize title case and no other special."""
    for company in data["nodes"]["Company"]:
        company["name"] = clean_names(company["name"])
    return data

# %%
def company_validate(data): 
    data = remove_invalid_ticker_companies(data)
    # data = remove_duplicates(data)
    data = standarize_case(data)
    print("Completed.")
    return data

validated_data = company_validate(merged_json)
# Out:
# Completed.

# %% [markdown]
# ### Adding Company Nodes

# %%
companies = validated_data['nodes']['Company']
for company in companies:
    company['founded_year'] = company['founded_year'] or ""
companies[:5]
# Out:
# [{'name': 'Apple Inc', 'ticker_code': 'AAPL', 'founded_year': ''},
#  {'name': 'Apple', 'ticker_code': 'AAPL', 'founded_year': ''},
#  {'name': 'Airpods', 'ticker_code': 'AAPL', 'founded_year': ''},
#  {'name': 'Apple', 'ticker_code': 'AAPL', 'founded_year': ''},
#  {'name': 'Major League Soccer Mls',
#   'ticker_code': 'MLFB',
#   'founded_year': ''}]

# %%
graph_utils.execute_query_with_params('''
MERGE (c:Company {ticker: $ticker_code})
SET c.names = 
    CASE
        WHEN c.names IS NULL THEN [$name]
        WHEN NOT $name IN c.names THEN c.names + $name
        ELSE c.names
    END,
    c.founded_year = $founded_year''', *companies)
# Out:
# [EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x16d60b810>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x16d60aad0>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x16d609c90>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x16d6085d0>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x16d5cc910>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x16db910d0>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x16db92850>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x16d5a1950>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x16d5a07d0>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x16d547e90>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x16d6589d0>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x16d6588d0>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x16d67f350>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x16dadd490>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x16dc1f950>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x16dbec810>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x16dbed7d0>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x16dbee190>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x16dbeee90>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x16dbef550>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x16dbb0690>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x16dbb11d0>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x16dbb1dd0>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x16dbb2c90>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x16dbb36d0>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x16dc54390>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x16dc54c10>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x16dc55810>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x16dc56850>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x16dc56f90>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x16dc57e10>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x16dc68c90>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x16dc69890>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x16dc6a610>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x16dc6b050>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x16dc6b710>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x16dc2c410>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x16dc2d450>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x16dc2df10>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x16dc2ec50>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x16dc2f7d0>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x16dc74490>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x16dc74fd0>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x16dc75910>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x16dc76390>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x16dc770d0>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x16dc77b90>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x16dc08910>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x16dc09550>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x16dc0a150>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x16dc0ae10>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x16dc0bdd0>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x16dc93fd0>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x16dc90a10>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x16dc91950>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x16dc923d0>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x16dc93510>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x161f485d0>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x161f4fc90>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x161f4ef10>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x161850550>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x161f56a10>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x16dc3cad0>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x16dc3d850>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x16dc3e190>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x16dc3edd0>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x16dc3fc90>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x1618d6d90>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x1618d5e50>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x161846410>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x161d48250>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x16dc99810>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x16dc99790>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x16dc98c90>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x16dc9ae10>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x16dc9bb10>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x1627b0690>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x1627b1210>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x1627b2190>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x1627b2d50>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x1627b3950>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x16dc84190>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x16dc84ed0>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x16dc859d0>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x16dc86710>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x16dc87290>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x16dc87e50>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x1627d0c10>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x1627d16d0>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x1627d2290>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x1627d30d0>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x1627d3b50>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x1627e07d0>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x1627e1490>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x1627e2050>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x1627e2bd0>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x1627e3a90>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x1627f8710>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x1627f8f50>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x1627f9d10>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x1627fa750>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x1627fb1d0>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x1617b3c50>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x1617b1e50>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x1617b10d0>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x1628345d0>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x162835590>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x162836190>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x162836e10>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x162837710>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x16284c490>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x16284cf90>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x16284dc50>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x16284e950>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x16284f710>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x1628101d0>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x162810f90>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x1628118d0>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x162812450>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x162813050>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x162813fd0>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x162868d10>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x162869990>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x16286a550>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x16286afd0>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x16286bed0>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x16287ca50>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x16287da10>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x16287e5d0>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x16287eed0>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x16287fdd0>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x162898a50>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x162899690>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x16289a190>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x16289ab50>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x16289b750>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x162824590>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x162825150>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x162825d50>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x162826890>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x162827490>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x1628bc390>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x1628bd110>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x1628bdc90>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x1628be890>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x1628bf550>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x1628d8310>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x1628d8f90>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x1628d99d0>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x1628da690>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x1628db4d0>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x1628dbdd0>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x1628f08d0>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x1628f14d0>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x1628f23d0>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x1628f2fd0>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x1628f3bd0>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x16d31c890>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x16d31d490>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x16d31e090>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x16d31ed50>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x16d31f950>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x16d330610>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x16d331210>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x16d331e10>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x16d332990>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x16d333150>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x16d3440d0>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x16d344b10>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x16d345a10>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x16d346310>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x16d346f10>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x16d347b10>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x16d300790>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x16d301350>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x16d302490>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x16d302f50>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x16d303b50>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x1628a8750>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x1628a94d0>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x1628aa0d0>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x1628aa9d0>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x1628ab5d0>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x16d3741d0>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x16d374f50>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x16d375cd0>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x16d376990>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x16d377650>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x16d3781d0>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x16d378e50>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x16d379a10>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x16d37a710>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x16d37b250>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x16d37bf90>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x16d394c50>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x16d395810>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x16d396410>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x16d397010>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x16d397b50>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x16d3a8a10>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x16d3a9610>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x16d3aa210>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x16d3aab90>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x1628f90d0>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x1628fa910>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x16db835d0>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x16d648b90>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x16d67c310>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x16d5e0490>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x16d5e1310>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x16d5e2310>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x16d5e3510>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x16dc1d6d0>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x16dc1c910>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x16d659290>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x16d65a290>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x16d65b3d0>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x16d325ad0>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x16d671510>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x16d672150>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x16d6fe7d0>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x16d6fedd0>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x16d6cafd0>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x16d71c250>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x16d71f6d0>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x16d6b8d90>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x16d6b8510>, keys=[]),
#  EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x16d73cb10>, keys=[])]

# %% [markdown]
# ### Adding Company relationships

# %% [markdown]
# For the purposes of consistency checking later on, we prepare the company relationship data and store the edges in a list. We use the fulltext and vector indexes we created to match the data to the correct nodes.

# %%
all_edges = []

# %% [markdown]
# ### Company-Industry relationship

# %% [markdown]
# One of the key relationships defined in the data is "IS_INVOLVED_IN", which helps in modeling how companies are categorized based on their primary activities and the sectors they contribute to.
#
#
# "IS_INVOLVED_IN": [
#             {
#                 "company_name": "McKinsey &#38; Company",
#                 "industry_name": "management consulting"}]

# %%
company_industries = validated_data['relationships']['IS_INVOLVED_IN']
company_industries[:5]
# Out:
# [{'company_name': 'Apple', 'industry_name': 'accounting'},
#  {'company_name': 'Apple', 'industry_name': 'technology'},
#  {'company_name': 'Apple', 'industry_name': 'information technology'},
#  {'company_name': 'Brightstar Corporation',
#   'industry_name': 'wireless device services'},
#  {'company_name': 'Applied Materials, Inc.',
#   'industry_name': 'semiconductor equipment'}]

# %%
for company_industry in company_industries:
    industry_name = company_industry['industry_name']
    company_industry['company_name'] = clean_names(company_industry['company_name'])
    company_industry['embedding'] = EMBEDDING_MODEL.encode(industry_name).tolist()

# %%
is_involved_in_edges = graph_utils.execute_query_with_params("""
CALL db.index.fulltext.queryNodes('company_names_index', $company_name)
    YIELD node AS c, score AS company_score
CALL db.index.vector.queryNodes('industry_description_index', 10, $embedding)
    YIELD node AS i, score AS industry_score
WHERE company_score > 1
AND industry_score > 0.7
RETURN
    c.ticker AS ticker,
    i.gics AS gics""", *company_industries)

for records, _, _ in is_involved_in_edges:
    for ticker, gics in records:
        all_edges.append((ticker, gics, "Company", "Industry", "IS_INVOLVED_IN", {}))

# %% [markdown]
# ### Company-Country relationships

# %% [markdown]
# One of the key relationships defined in the data is "HEADQUARTERS_IN" and "OPERATES_IN", which helps in modeling how companies are categorized based on their countries.
# * "HEADQUARTERS_IN" relationship signifies that a company has its headquarters located in a specific country. It helps in understanding the geographical base of the company and can have implications for regulatory compliance, market strategy, and more.
# * "OPERATES_IN" relationship indicates that a company conducts its business operations in a specific country, which can include selling products, providing services, or having a physical presence (like branches or subsidiaries).

# %%
headquarters_data = validated_data['relationships']['HEADQUARTERS_IN']
for entry in headquarters_data:
    entry['company_name'] = clean_names(entry['company_name'])
headquarters_data[:5]
# Out:
# [{'company_name': 'Emea', 'country_name': 'Ireland'},
#  {'company_name': 'Apple', 'country_name': 'United States'},
#  {'company_name': 'Apple', 'country_name': 'United States'},
#  {'company_name': 'Zhengzhou Technology Park', 'country_name': 'China'},
#  {'company_name': 'Adobe', 'country_name': 'United States'}]

# %%
headquarters_edges = graph_utils.execute_query_with_params("""
CALL db.index.fulltext.queryNodes('company_names_index', $company_name)
    YIELD node AS company
CALL db.index.fulltext.queryNodes('country_aliases_index', $country_name)
    YIELD node AS country   
RETURN company.ticker AS ticker, country.iso3 AS iso3""", *headquarters_data)

for records, _, _ in headquarters_edges:
    for ticker, iso3 in records:
        all_edges.append((ticker, iso3, "Company", "Country", "HEADQUARTERS_IN", {}))

# %%
operates_data = validated_data['relationships']['OPERATES_IN_COUNTRY']
for entry in operates_data:
    entry['company_name'] = clean_names(entry['company_name'])
    entry['net_sales'] = entry.pop('net sales')
operates_data[:5]
# Out:
# [{'company_name': 'Apple',
#   'country_name': 'Ireland',
#   'headcount': 7343,
#   'net_sales': 29831428},
#  {'company_name': 'Apple',
#   'country_name': 'Ireland',
#   'headcount': 1665,
#   'net_sales': -24931076},
#  {'company_name': 'Apple',
#   'country_name': 'United States',
#   'headcount': 1585,
#   'net_sales': -12538324},
#  {'company_name': 'Apple',
#   'country_name': 'United States',
#   'headcount': 9447,
#   'net_sales': -20940672},
#  {'company_name': 'Emea',
#   'country_name': 'Ireland',
#   'headcount': 5825,
#   'net_sales': -21823981}]

# %%
operates_edges = graph_utils.execute_query_with_params("""
CALL db.index.fulltext.queryNodes('company_names_index', $company_name)
    YIELD node AS company
CALL db.index.fulltext.queryNodes('country_aliases_index', $country_name)
    YIELD node AS country   
RETURN
    company.ticker AS ticker,
    country.iso3 AS iso3,
    $headcount AS headcount,
    $net_sales AS net_sales""", *operates_data)

for records, _, _ in operates_edges:
    for ticker, iso3, headcount, net_sales in records:
        all_edges.append((ticker, iso3, "Company", "Country", "OPERATES_IN",
                          {'headcount': headcount, 'net_sales': net_sales}))

# %% [markdown]
# ### Company-Company relationships

# %% [markdown]
# The key relationships are "COMPETES_WITH" and "SUBSIDIARY_OF".
# * "COMPETES_WITH" relationship is used to represent the competitive dynamics between companies. When two companies operate in the same industry or market and offer similar products or services, they are considered competitors.
# * "SUBSIDIARY_OF" relationship indicates that one company is a subsidiary of another, meaning it is controlled or owned by a parent company. This is a common structure in corporate hierarchies.

# %%
company_competes = validated_data['relationships']['COMPETES_WITH']
for entry in company_competes:
    entry['company_name_1'] = clean_names(entry['company_name_1'])
    entry['company_name_2'] = clean_names(entry['company_name_2'])
company_competes[:5]
# Out:
# [{'company_name_1': 'Be Inc', 'company_name_2': 'Gassée', 'type': None},
#  {'company_name_1': 'Gassée', 'company_name_2': 'Be Inc', 'type': None},
#  {'company_name_1': 'Microsoft', 'company_name_2': 'Apple', 'type': None},
#  {'company_name_1': 'Apple', 'company_name_2': 'Microsoft', 'type': None},
#  {'company_name_1': 'Adobe', 'company_name_2': 'Shopify', 'type': None}]

# %%
competes_edges = graph_utils.execute_query_with_params("""
CALL db.index.fulltext.queryNodes('company_names_index', $company_name_1)
    YIELD node AS company1
CALL db.index.fulltext.queryNodes('company_names_index', $company_name_2)
    YIELD node AS company2
RETURN company1.ticker AS ticker1, company2.ticker AS ticker2""", *company_competes)

for records, _, _ in competes_edges:
    for ticker1, ticker2 in records:
        all_edges.append((ticker1, ticker2, "Company", "Company", "COMPETES_WITH", {}))

# %%
company_subsidiary = validated_data['relationships']['SUBSIDIARY_OF']
for entry in company_subsidiary:
    entry['company_name_1'] = clean_names(entry['company_name_1'])
    entry['company_name_2'] = clean_names(entry['company_name_2'])
company_subsidiary[:5]
# Out:
# [{'company_name_1': 'Flurry Analytics',
#   'company_name_2': 'Verizon',
#   'type': 'subsidiary'},
#  {'company_name_1': 'Apple Energy Llc',
#   'company_name_2': 'Apple Inc',
#   'type': 'subsidiary'},
#  {'company_name_1': 'Ace American Insurance Company',
#   'company_name_2': 'Chubb Limited',
#   'type': 'subsidiary'},
#  {'company_name_1': 'Adp Indemnity',
#   'company_name_2': 'Chubb Limited',
#   'type': 'subsidiary'},
#  {'company_name_1': 'Arm',
#   'company_name_2': 'Arm Holdings',
#   'type': 'subsidiary'}]

# %%
subsidiary_edges = graph_utils.execute_query_with_params("""
CALL db.index.fulltext.queryNodes('company_names_index', $company_name_1)
    YIELD node AS company1
CALL db.index.fulltext.queryNodes('company_names_index', $company_name_2)
    YIELD node AS company2
RETURN company1.ticker AS ticker1, company2.ticker AS ticker2""", *company_subsidiary)

for records, _, _ in subsidiary_edges:
    for ticker1, ticker2 in records:
        all_edges.append((ticker1, ticker2, "Company", "Company", "SUBSIDIARY_OF", {}))

# %%
company_supplies = validated_data['relationships']['PARTNERS_WITH']
for entry in company_supplies:
    entry['company_name_1'] = clean_names(entry['company_name_1'])
    entry['company_name_2'] = clean_names(entry['company_name_2'])
company_supplies[:5]
# Out:
# [{'company_name_1': 'Apple',
#   'company_name_2': 'Nextstep',
#   'type': 'suppliers'},
#  {'company_name_1': 'Apple',
#   'company_name_2': 'Lens Technology',
#   'type': 'suppliers'},
#  {'company_name_1': 'Apple',
#   'company_name_2': 'Lens Technology',
#   'type': 'suppliers'},
#  {'company_name_1': 'Chubb Limited',
#   'company_name_2': 'Adp Indemnity',
#   'type': 'suppliers'},
#  {'company_name_1': 'Chubb Limited',
#   'company_name_2': 'Adp Indemnity',
#   'type': 'suppliers'}]

# %%
subsidiary_edges = graph_utils.execute_query_with_params("""
CALL db.index.fulltext.queryNodes('company_names_index', $company_name_1)
    YIELD node AS company1
CALL db.index.fulltext.queryNodes('company_names_index', $company_name_2)
    YIELD node AS company2
RETURN company1.ticker AS ticker1, company2.ticker AS ticker2""", *company_supplies)

for records, _, _ in subsidiary_edges:
    for ticker1, ticker2 in records:
        all_edges.append((ticker1, ticker2, "Company", "Company", "SUPPLIES_TO", {}))

# %% [markdown]
# ### Consistency Checking

# %% [markdown]
# In this section, we perform consistency checking of the edges we have gathered before adding them to the graph. We define that an edge is consistent with the current graph, if there is a positive evidence (pattern) in the graph that supports the edge.
#
# We make use of the Graph Fact Checking rules (GFCs) mining algorithm introduced by this [paper](https://github.com/001waiyan/GDRB/blob/master/2018-DASFAA-GFC-paper.pdf). We created a [fork](https://github.com/001waiyan/GDRB) of the paper's repository for the purposes of integration with the project. In this fork, we set up the FactChecker API, which performs the following:
# 1. Generate patterns (GFCs) for the given relation and input graph.
# 2. Checks each input edge against each found pattern.
#
# The GFC mining algorithm relies on Principal Closed World Assumption (PCWA) of the input graph, i.e. if the graph has at least one edge (V1)-[:R]->(V2), we assume that we have complete information of all (V1)-[:R]->(Vx). For example if the graph has two competitors of Apple, (Apple)-[:COMPETES_WITH]->(Google) and (Apple)-[:Competes_With]->(Samsung), anything not in the graph (e.g. (Apple)-[:COMPETES_WITH]->(Meta)) is considered false.
#
# In this section, we systematically fact check and add to the Neo4j database the list of edges, while maintaining PCWA of the graph. The edges to add are grouped by same source node and relation type (e.g. all COMPETES_WITH edges for the Apple node). Each group is fact checked using the FactChecker API and added one at a time to maintain PCWA.
#
# Algorithm used:
# 1. Group the edges by the same source node and relation type.
# 2. Add all groups that contain duplicate edges to the graph, without fact checking. (Assuming that these edges are more likely to be consistent)
# 3. For the remaining groups, run the FactChecker API on each of them.
# 4. If an edge was matched by at least one found pattern, add that edge to the graph.
# 5. If no patterns were found for the group, add all its edges to the graph.

# %%
patterns = fact_check_and_add(all_edges, min_supp=0.5, min_conf=0.1, top_k=50, max_size=2)
# Out:
# ====================Adding groups with duplicates====================
# Processing group: ('AAPL', 'Company', 'Industry', 'IS_INVOLVED_IN')
# 10 edges found in group.
# Adding 5 unique edges.
#
# Processing group: ('KLAC', 'Company', 'Industry', 'IS_INVOLVED_IN')
# 144 edges found in group.
# Adding 57 unique edges.
#
# Processing group: ('CMCSA', 'Company', 'Industry', 'IS_INVOLVED_IN')
# 126 edges found in group.
# Adding 49 unique edges.
#
# Processing group: ('AMAT', 'Company', 'Industry', 'IS_INVOLVED_IN')
# 109 edges found in group.
# Adding 31 unique edges.
#
# Processing group: ('ADBE', 'Company', 'Industry', 'IS_INVOLVED_IN')
# 8 edges found in group.
# Adding 4 unique edges.
#
# Processing group: ('AMZN', 'Company', 'Industry', 'IS_INVOLVED_IN')
# 105 edges found in group.
# Adding 37 unique edges.
#
# Processing group: ('NVDA', 'Company', 'Industry', 'IS_INVOLVED_IN')
# 62 edges found in group.
# Adding 21 unique edges.
#
# Processing group: ('AMGN', 'Company', 'Industry', 'IS_INVOLVED_IN')
# 5 edges found in group.
# Adding 3 unique edges.
#
# Processing group: ('GOOG', 'Company', 'Industry', 'IS_INVOLVED_IN')
# 10 edges found in group.
# Adding 5 unique edges.
#
# Processing group: ('GOOGL', 'Company', 'Industry', 'IS_INVOLVED_IN')
# 4 edges found in group.
# Adding 2 unique edges.
#
# Processing group: ('BKNG', 'Company', 'Industry', 'IS_INVOLVED_IN')
# 19 edges found in group.
# Adding 14 unique edges.
#
# Processing group: ('AVGO', 'Company', 'Industry', 'IS_INVOLVED_IN')
# 11 edges found in group.
# Adding 10 unique edges.
#
# Processing group: ('CSCO', 'Company', 'Industry', 'IS_INVOLVED_IN')
# 7 edges found in group.
# Adding 5 unique edges.
#
# Processing group: ('VTAGY', 'Company', 'Industry', 'IS_INVOLVED_IN')
# 7 edges found in group.
# Adding 5 unique edges.
#
# Processing group: ('SFTBY', 'Company', 'Industry', 'IS_INVOLVED_IN')
# 152 edges found in group.
# Adding 49 unique edges.
#
# Processing group: ('NUAN', 'Company', 'Industry', 'IS_INVOLVED_IN')
# 12 edges found in group.
# Adding 8 unique edges.
#
# Processing group: ('UAVS', 'Company', 'Industry', 'IS_INVOLVED_IN')
# 12 edges found in group.
# Adding 8 unique edges.
#
# Processing group: ('GILD', 'Company', 'Industry', 'IS_INVOLVED_IN')
# 22 edges found in group.
# Adding 14 unique edges.
#
# Processing group: ('MDLZ', 'Company', 'Industry', 'IS_INVOLVED_IN')
# 9 edges found in group.
# Adding 8 unique edges.
#
# Processing group: ('INTC', 'Company', 'Industry', 'IS_INVOLVED_IN')
# 12 edges found in group.
# Adding 10 unique edges.
#
# Processing group: ('INTU', 'Company', 'Industry', 'IS_INVOLVED_IN')
# 18 edges found in group.
# Adding 15 unique edges.
#
# Processing group: ('LRCX', 'Company', 'Industry', 'IS_INVOLVED_IN')
# 39 edges found in group.
# Adding 19 unique edges.
#
# Processing group: ('MELI', 'Company', 'Industry', 'IS_INVOLVED_IN')
# 27 edges found in group.
# Adding 23 unique edges.
#
# Processing group: ('PANW', 'Company', 'Industry', 'IS_INVOLVED_IN')
# 2 edges found in group.
# Adding 1 unique edges.
#
# Processing group: ('REGN', 'Company', 'Industry', 'IS_INVOLVED_IN')
# 8 edges found in group.
# Adding 3 unique edges.
#
# Processing group: ('VRTX', 'Company', 'Industry', 'IS_INVOLVED_IN')
# 8 edges found in group.
# Adding 3 unique edges.
#
# Processing group: ('TMUS', 'Company', 'Industry', 'IS_INVOLVED_IN')
# 16 edges found in group.
# Adding 15 unique edges.
#
# Processing group: ('TGSGY', 'Company', 'Industry', 'IS_INVOLVED_IN')
# 36 edges found in group.
# Adding 28 unique edges.
#
# Processing group: ('AAPL', 'Company', 'Country', 'HEADQUARTERS_IN')
# 44 edges found in group.
# Adding 11 unique edges.
#
# Processing group: ('ADBE', 'Company', 'Country', 'HEADQUARTERS_IN')
# 24 edges found in group.
# Adding 12 unique edges.
#
# Processing group: ('AMZN', 'Company', 'Country', 'HEADQUARTERS_IN')
# 100 edges found in group.
# Adding 12 unique edges.
#
# Processing group: ('AMAT', 'Company', 'Country', 'HEADQUARTERS_IN')
# 101 edges found in group.
# Adding 16 unique edges.
#
# Processing group: ('NVDA', 'Company', 'Country', 'HEADQUARTERS_IN')
# 114 edges found in group.
# Adding 13 unique edges.
#
# Processing group: ('AMGN', 'Company', 'Country', 'HEADQUARTERS_IN')
# 22 edges found in group.
# Adding 11 unique edges.
#
# Processing group: ('GOOGL', 'Company', 'Country', 'HEADQUARTERS_IN')
# 44 edges found in group.
# Adding 11 unique edges.
#
# Processing group: ('GOOG', 'Company', 'Country', 'HEADQUARTERS_IN')
# 44 edges found in group.
# Adding 11 unique edges.
#
# Processing group: ('BKNG', 'Company', 'Country', 'HEADQUARTERS_IN')
# 22 edges found in group.
# Adding 11 unique edges.
#
# Processing group: ('CTAS', 'Company', 'Country', 'HEADQUARTERS_IN')
# 22 edges found in group.
# Adding 11 unique edges.
#
# Processing group: ('KLAC', 'Company', 'Country', 'HEADQUARTERS_IN')
# 144 edges found in group.
# Adding 12 unique edges.
#
# Processing group: ('CMCSA', 'Company', 'Country', 'HEADQUARTERS_IN')
# 144 edges found in group.
# Adding 12 unique edges.
#
# Processing group: ('COST', 'Company', 'Country', 'HEADQUARTERS_IN')
# 67 edges found in group.
# Adding 12 unique edges.
#
# Processing group: ('GILD', 'Company', 'Country', 'HEADQUARTERS_IN')
# 66 edges found in group.
# Adding 11 unique edges.
#
# Processing group: ('REGN', 'Company', 'Country', 'HEADQUARTERS_IN')
# 110 edges found in group.
# Adding 11 unique edges.
#
# Processing group: ('VRTX', 'Company', 'Country', 'HEADQUARTERS_IN')
# 110 edges found in group.
# Adding 11 unique edges.
#
# Processing group: ('MDLZ', 'Company', 'Country', 'HEADQUARTERS_IN')
# 27 edges found in group.
# Adding 16 unique edges.
#
# Processing group: ('TMUS', 'Company', 'Country', 'HEADQUARTERS_IN')
# 62 edges found in group.
# Adding 16 unique edges.
#
# Processing group: ('INTC', 'Company', 'Country', 'HEADQUARTERS_IN')
# 46 edges found in group.
# Adding 12 unique edges.
#
# Processing group: ('INTU', 'Company', 'Country', 'HEADQUARTERS_IN')
# 23 edges found in group.
# Adding 12 unique edges.
#
# Processing group: ('LRCX', 'Company', 'Country', 'HEADQUARTERS_IN')
# 45 edges found in group.
# Adding 12 unique edges.
#
# Processing group: ('SFTBY', 'Company', 'Country', 'HEADQUARTERS_IN')
# 32 edges found in group.
# Adding 18 unique edges.
#
# Processing group: ('MELI', 'Company', 'Country', 'HEADQUARTERS_IN')
# 25 edges found in group.
# Adding 12 unique edges.
#
# Processing group: ('MSFT', 'Company', 'Country', 'HEADQUARTERS_IN')
# 38 edges found in group.
# Adding 16 unique edges.
#
# Processing group: ('META', 'Company', 'Country', 'HEADQUARTERS_IN')
# 34 edges found in group.
# Adding 12 unique edges.
#
# Processing group: ('NFLX', 'Company', 'Country', 'HEADQUARTERS_IN')
# 56 edges found in group.
# Adding 12 unique edges.
#
# Processing group: ('PANW', 'Company', 'Country', 'HEADQUARTERS_IN')
# 13 edges found in group.
# Adding 12 unique edges.
#
# Processing group: ('QCOM', 'Company', 'Country', 'HEADQUARTERS_IN')
# 55 edges found in group.
# Adding 11 unique edges.
#
# Processing group: ('SBUX', 'Company', 'Country', 'HEADQUARTERS_IN')
# 48 edges found in group.
# Adding 15 unique edges.
#
# Processing group: ('AAPL', 'Company', 'Country', 'OPERATES_IN')
# 144 edges found in group.
# Adding 12 unique edges.
#
# Processing group: ('ADBE', 'Company', 'Country', 'OPERATES_IN')
# 140 edges found in group.
# Adding 13 unique edges.
#
# Processing group: ('AMZN', 'Company', 'Country', 'OPERATES_IN')
# 169 edges found in group.
# Adding 14 unique edges.
#
# Processing group: ('AMAT', 'Company', 'Country', 'OPERATES_IN')
# 159 edges found in group.
# Adding 18 unique edges.
#
# Processing group: ('NVDA', 'Company', 'Country', 'OPERATES_IN')
# 266 edges found in group.
# Adding 27 unique edges.
#
# Processing group: ('TMUS', 'Company', 'Country', 'OPERATES_IN')
# 197 edges found in group.
# Adding 17 unique edges.
#
# Processing group: ('AMGN', 'Company', 'Country', 'OPERATES_IN')
# 80 edges found in group.
# Adding 14 unique edges.
#
# Processing group: ('GOOGL', 'Company', 'Country', 'OPERATES_IN')
# 90 edges found in group.
# Adding 12 unique edges.
#
# Processing group: ('GOOG', 'Company', 'Country', 'OPERATES_IN')
# 90 edges found in group.
# Adding 12 unique edges.
#
# Processing group: ('BKNG', 'Company', 'Country', 'OPERATES_IN')
# 113 edges found in group.
# Adding 41 unique edges.
#
# Processing group: ('AVGO', 'Company', 'Country', 'OPERATES_IN')
# 57 edges found in group.
# Adding 13 unique edges.
#
# Processing group: ('CTAS', 'Company', 'Country', 'OPERATES_IN')
# 44 edges found in group.
# Adding 11 unique edges.
#
# Processing group: ('CSCO', 'Company', 'Country', 'OPERATES_IN')
# 74 edges found in group.
# Adding 16 unique edges.
#
# Processing group: ('VTAGY', 'Company', 'Country', 'OPERATES_IN')
# 27 edges found in group.
# Adding 16 unique edges.
#
# Processing group: ('KLAC', 'Company', 'Country', 'OPERATES_IN')
# 200 edges found in group.
# Adding 13 unique edges.
#
# Processing group: ('CMCSA', 'Company', 'Country', 'OPERATES_IN')
# 364 edges found in group.
# Adding 31 unique edges.
#
# Processing group: ('COST', 'Company', 'Country', 'OPERATES_IN')
# 155 edges found in group.
# Adding 25 unique edges.
#
# Processing group: ('GILD', 'Company', 'Country', 'OPERATES_IN')
# 167 edges found in group.
# Adding 13 unique edges.
#
# Processing group: ('MELI', 'Company', 'Country', 'OPERATES_IN')
# 97 edges found in group.
# Adding 26 unique edges.
#
# Processing group: ('REGN', 'Company', 'Country', 'OPERATES_IN')
# 176 edges found in group.
# Adding 11 unique edges.
#
# Processing group: ('VRTX', 'Company', 'Country', 'OPERATES_IN')
# 176 edges found in group.
# Adding 11 unique edges.
#
# Processing group: ('MDLZ', 'Company', 'Country', 'OPERATES_IN')
# 72 edges found in group.
# Adding 17 unique edges.
#
# Processing group: ('INTC', 'Company', 'Country', 'OPERATES_IN')
# 46 edges found in group.
# Adding 12 unique edges.
#
# Processing group: ('INTU', 'Company', 'Country', 'OPERATES_IN')
# 71 edges found in group.
# Adding 12 unique edges.
#
# Processing group: ('NFLX', 'Company', 'Country', 'OPERATES_IN')
# 114 edges found in group.
# Adding 13 unique edges.
#
# Processing group: ('TSLA', 'Company', 'Country', 'OPERATES_IN')
# 110 edges found in group.
# Adding 11 unique edges.
#
# Processing group: ('ISRG', 'Company', 'Country', 'OPERATES_IN')
# 44 edges found in group.
# Adding 11 unique edges.
#
# Processing group: ('META', 'Company', 'Country', 'OPERATES_IN')
# 103 edges found in group.
# Adding 14 unique edges.
#
# Processing group: ('PANW', 'Company', 'Country', 'OPERATES_IN')
# 68 edges found in group.
# Adding 12 unique edges.
#
# Processing group: ('QCOM', 'Company', 'Country', 'OPERATES_IN')
# 90 edges found in group.
# Adding 13 unique edges.
#
# Processing group: ('LRCX', 'Company', 'Country', 'OPERATES_IN')
# 56 edges found in group.
# Adding 12 unique edges.
#
# Processing group: ('SFTBY', 'Company', 'Country', 'OPERATES_IN')
# 77 edges found in group.
# Adding 18 unique edges.
#
# Processing group: ('MXIM', 'Company', 'Country', 'OPERATES_IN')
# 33 edges found in group.
# Adding 11 unique edges.
#
# Processing group: ('MSFT', 'Company', 'Country', 'OPERATES_IN')
# 38 edges found in group.
# Adding 16 unique edges.
#
# Processing group: ('SBUX', 'Company', 'Country', 'OPERATES_IN')
# 51 edges found in group.
# Adding 16 unique edges.
#
# Processing group: ('MSFT', 'Company', 'Company', 'COMPETES_WITH')
# 5 edges found in group.
# Adding 2 unique edges.
#
# Processing group: ('AAPL', 'Company', 'Company', 'COMPETES_WITH')
# 48 edges found in group.
# Adding 24 unique edges.
#
# Processing group: ('ADBE', 'Company', 'Company', 'COMPETES_WITH')
# 49 edges found in group.
# Adding 22 unique edges.
#
# Processing group: ('QCOM', 'Company', 'Company', 'COMPETES_WITH')
# 9 edges found in group.
# Adding 5 unique edges.
#
# Processing group: ('KLAC', 'Company', 'Company', 'COMPETES_WITH')
# 3 edges found in group.
# Adding 1 unique edges.
#
# Processing group: ('AMZN', 'Company', 'Company', 'COMPETES_WITH')
# 48 edges found in group.
# Adding 23 unique edges.
#
# Processing group: ('GOOG', 'Company', 'Company', 'COMPETES_WITH')
# 47 edges found in group.
# Adding 23 unique edges.
#
# Processing group: ('PANW', 'Company', 'Company', 'COMPETES_WITH')
# 49 edges found in group.
# Adding 23 unique edges.
#
# Processing group: ('BKNG', 'Company', 'Company', 'COMPETES_WITH')
# 47 edges found in group.
# Adding 23 unique edges.
#
# Processing group: ('CSCO', 'Company', 'Company', 'COMPETES_WITH')
# 47 edges found in group.
# Adding 23 unique edges.
#
# Processing group: ('VTAGY', 'Company', 'Company', 'COMPETES_WITH')
# 3 edges found in group.
# Adding 2 unique edges.
#
# Processing group: ('COST', 'Company', 'Company', 'COMPETES_WITH')
# 3 edges found in group.
# Adding 2 unique edges.
#
# Processing group: ('AMAT', 'Company', 'Company', 'COMPETES_WITH')
# 45 edges found in group.
# Adding 23 unique edges.
#
# Processing group: ('INTC', 'Company', 'Company', 'COMPETES_WITH')
# 14 edges found in group.
# Adding 9 unique edges.
#
# Processing group: ('GOOGL', 'Company', 'Company', 'COMPETES_WITH')
# 44 edges found in group.
# Adding 22 unique edges.
#
# Processing group: ('AVGO', 'Company', 'Company', 'COMPETES_WITH')
# 45 edges found in group.
# Adding 23 unique edges.
#
# Processing group: ('NFLX', 'Company', 'Company', 'COMPETES_WITH')
# 46 edges found in group.
# Adding 23 unique edges.
#
# Processing group: ('AMGN', 'Company', 'Company', 'COMPETES_WITH')
# 44 edges found in group.
# Adding 22 unique edges.
#
# Processing group: ('MDLZ', 'Company', 'Company', 'COMPETES_WITH')
# 44 edges found in group.
# Adding 22 unique edges.
#
# Processing group: ('TSLA', 'Company', 'Company', 'COMPETES_WITH')
# 44 edges found in group.
# Adding 22 unique edges.
#
# Processing group: ('INTU', 'Company', 'Company', 'COMPETES_WITH')
# 44 edges found in group.
# Adding 22 unique edges.
#
# Processing group: ('REGN', 'Company', 'Company', 'COMPETES_WITH')
# 44 edges found in group.
# Adding 22 unique edges.
#
# Processing group: ('ISRG', 'Company', 'Company', 'COMPETES_WITH')
# 44 edges found in group.
# Adding 22 unique edges.
#
# Processing group: ('META', 'Company', 'Company', 'COMPETES_WITH')
# 44 edges found in group.
# Adding 22 unique edges.
#
# Processing group: ('VRTX', 'Company', 'Company', 'COMPETES_WITH')
# 44 edges found in group.
# Adding 22 unique edges.
#
# Processing group: ('MELI', 'Company', 'Company', 'COMPETES_WITH')
# 44 edges found in group.
# Adding 22 unique edges.
#
# Processing group: ('TMUS', 'Company', 'Company', 'COMPETES_WITH')
# 44 edges found in group.
# Adding 22 unique edges.
#
# Processing group: ('GILD', 'Company', 'Company', 'COMPETES_WITH')
# 44 edges found in group.
# Adding 22 unique edges.
#
# Processing group: ('CMCSA', 'Company', 'Company', 'COMPETES_WITH')
# 2 edges found in group.
# Adding 1 unique edges.
#
# Processing group: ('AAPL', 'Company', 'Company', 'SUBSIDIARY_OF')
# 49 edges found in group.
# Adding 23 unique edges.
#
# Processing group: ('AMZN', 'Company', 'Company', 'SUBSIDIARY_OF')
# 6 edges found in group.
# Adding 3 unique edges.
#
# Processing group: ('AMAT', 'Company', 'Company', 'SUBSIDIARY_OF')
# 5 edges found in group.
# Adding 3 unique edges.
#
# Processing group: ('META', 'Company', 'Company', 'SUBSIDIARY_OF')
# 6 edges found in group.
# Adding 4 unique edges.
#
# Processing group: ('BKNG', 'Company', 'Company', 'SUBSIDIARY_OF')
# 7 edges found in group.
# Adding 3 unique edges.
#
# Processing group: ('GOOG', 'Company', 'Company', 'SUBSIDIARY_OF')
# 7 edges found in group.
# Adding 3 unique edges.
#
# Processing group: ('COST', 'Company', 'Company', 'SUBSIDIARY_OF')
# 2 edges found in group.
# Adding 1 unique edges.
#
# Processing group: ('GILD', 'Company', 'Company', 'SUBSIDIARY_OF')
# 7 edges found in group.
# Adding 5 unique edges.
#
# Processing group: ('CSCO', 'Company', 'Company', 'SUBSIDIARY_OF')
# 4 edges found in group.
# Adding 2 unique edges.
#
# Processing group: ('INTU', 'Company', 'Company', 'SUBSIDIARY_OF')
# 4 edges found in group.
# Adding 2 unique edges.
#
# Processing group: ('QCOM', 'Company', 'Company', 'SUBSIDIARY_OF')
# 3 edges found in group.
# Adding 1 unique edges.
#
# Processing group: ('GOOGL', 'Company', 'Company', 'SUBSIDIARY_OF')
# 3 edges found in group.
# Adding 1 unique edges.
#
# Processing group: ('NFLX', 'Company', 'Company', 'SUBSIDIARY_OF')
# 3 edges found in group.
# Adding 1 unique edges.
#
# Processing group: ('AVGO', 'Company', 'Company', 'SUBSIDIARY_OF')
# 3 edges found in group.
# Adding 1 unique edges.
#
# Processing group: ('AMGN', 'Company', 'Company', 'SUBSIDIARY_OF')
# 3 edges found in group.
# Adding 1 unique edges.
#
# Processing group: ('MDLZ', 'Company', 'Company', 'SUBSIDIARY_OF')
# 3 edges found in group.
# Adding 1 unique edges.
#
# Processing group: ('TSLA', 'Company', 'Company', 'SUBSIDIARY_OF')
# 3 edges found in group.
# Adding 1 unique edges.
#
# Processing group: ('REGN', 'Company', 'Company', 'SUBSIDIARY_OF')
# 3 edges found in group.
# Adding 1 unique edges.
#
# Processing group: ('ISRG', 'Company', 'Company', 'SUBSIDIARY_OF')
# 3 edges found in group.
# Adding 1 unique edges.
#
# Processing group: ('VRTX', 'Company', 'Company', 'SUBSIDIARY_OF')
# 3 edges found in group.
# Adding 1 unique edges.
#
# Processing group: ('MELI', 'Company', 'Company', 'SUBSIDIARY_OF')
# 3 edges found in group.
# Adding 1 unique edges.
#
# Processing group: ('ADBE', 'Company', 'Company', 'SUBSIDIARY_OF')
# 3 edges found in group.
# Adding 1 unique edges.
#
# Processing group: ('PANW', 'Company', 'Company', 'SUBSIDIARY_OF')
# 3 edges found in group.
# Adding 1 unique edges.
#
# Processing group: ('TMUS', 'Company', 'Company', 'SUBSIDIARY_OF')
# 3 edges found in group.
# Adding 1 unique edges.
#
# Processing group: ('AAPL', 'Company', 'Company', 'SUPPLIES_TO')
# 8 edges found in group.
# Adding 2 unique edges.
#
# ====================Adding groups without duplicates====================
# Processing group: ('CTNM', 'Company', 'Industry', 'IS_INVOLVED_IN')
# 2 edges found in group.
# 0 patterns found for group.
# Adding 2 filtered edges.
#
# Processing group: ('QCOM', 'Company', 'Industry', 'IS_INVOLVED_IN')
# 16 edges found in group.
# 0 patterns found for group.
# Adding 16 filtered edges.
#
# Processing group: ('ISRG', 'Company', 'Industry', 'IS_INVOLVED_IN')
# 3 edges found in group.
# 0 patterns found for group.
# Adding 3 filtered edges.
#
# Processing group: ('MSFT', 'Company', 'Industry', 'IS_INVOLVED_IN')
# 11 edges found in group.
# 0 patterns found for group.
# Adding 11 filtered edges.
#
# Processing group: ('META', 'Company', 'Industry', 'IS_INVOLVED_IN')
# 5 edges found in group.
# 0 patterns found for group.
# Adding 5 filtered edges.
#
# Processing group: ('NFLX', 'Company', 'Industry', 'IS_INVOLVED_IN')
# 1 edges found in group.
# 0 patterns found for group.
# Adding 1 filtered edges.
#
# Processing group: ('TSLA', 'Company', 'Industry', 'IS_INVOLVED_IN')
# 2 edges found in group.
# 0 patterns found for group.
# Adding 2 filtered edges.
#
# Processing group: ('AVGO', 'Company', 'Country', 'HEADQUARTERS_IN')
# 1 edges found in group.
# 0 patterns found for group.
# Adding 1 filtered edges.
#
# Processing group: ('CSCO', 'Company', 'Country', 'HEADQUARTERS_IN')
# 13 edges found in group.
# 0 patterns found for group.
# Adding 13 filtered edges.
#
# Processing group: ('VTAGY', 'Company', 'Country', 'HEADQUARTERS_IN')
# 13 edges found in group.
# 0 patterns found for group.
# Adding 13 filtered edges.
#
# Processing group: ('MXIM', 'Company', 'Country', 'HEADQUARTERS_IN')
# 11 edges found in group.
# 0 patterns found for group.
# Adding 11 filtered edges.
#
# Processing group: ('TSLA', 'Company', 'Country', 'HEADQUARTERS_IN')
# 11 edges found in group.
# 0 patterns found for group.
# Adding 11 filtered edges.
#
# Processing group: ('NUAN', 'Company', 'Country', 'OPERATES_IN')
# 11 edges found in group.
# 0 patterns found for group.
# Adding 11 filtered edges.
#
# Processing group: ('UAVS', 'Company', 'Country', 'OPERATES_IN')
# 11 edges found in group.
# 0 patterns found for group.
# Adding 11 filtered edges.
#
# Processing group: ('DDRX', 'Company', 'Country', 'OPERATES_IN')
# 1 edges found in group.
# 0 patterns found for group.
# Adding 1 filtered edges.
#
# Processing group: ('MXIM', 'Company', 'Company', 'COMPETES_WITH')
# 1 edges found in group.
# 8 patterns found for group.
# Adding 0 filtered edges.
#
# Processing group: ('SFTBY', 'Company', 'Company', 'COMPETES_WITH')
# 1 edges found in group.
# 8 patterns found for group.
# Adding 0 filtered edges.
#
# Processing group: ('NVDA', 'Company', 'Company', 'COMPETES_WITH')
# 2 edges found in group.
# 8 patterns found for group.
# Adding 0 filtered edges.
#
# Processing group: ('DDRX', 'Company', 'Company', 'COMPETES_WITH')
# 1 edges found in group.
# 8 patterns found for group.
# Adding 0 filtered edges.
#
# Processing group: ('SBUX', 'Company', 'Company', 'COMPETES_WITH')
# 1 edges found in group.
# 8 patterns found for group.
# Adding 0 filtered edges.
#
# Processing group: ('CTAS', 'Company', 'Company', 'SUBSIDIARY_OF')
# 1 edges found in group.
# 8 patterns found for group.
# Adding 0 filtered edges.
#
# Processing group: ('KLAC', 'Company', 'Company', 'SUBSIDIARY_OF')
# 2 edges found in group.
# 8 patterns found for group.
# Adding 0 filtered edges.
#
# Processing group: ('CMCSA', 'Company', 'Company', 'SUBSIDIARY_OF')
# 1 edges found in group.
# 8 patterns found for group.
# Adding 0 filtered edges.
#
# Processing group: ('VTAGY', 'Company', 'Company', 'SUBSIDIARY_OF')
# 1 edges found in group.
# 8 patterns found for group.
# Adding 0 filtered edges.
#
# Processing group: ('SFTBY', 'Company', 'Company', 'SUBSIDIARY_OF')
# 1 edges found in group.
# 8 patterns found for group.
# Adding 0 filtered edges.
#
# Processing group: ('MSFT', 'Company', 'Company', 'SUBSIDIARY_OF')
# 1 edges found in group.
# 8 patterns found for group.
# Adding 0 filtered edges.
#
# Processing group: ('DDRX', 'Company', 'Company', 'SUBSIDIARY_OF')
# 1 edges found in group.
# 8 patterns found for group.
# Adding 0 filtered edges.
#
# Processing group: ('TGSGY', 'Company', 'Company', 'SUBSIDIARY_OF')
# 1 edges found in group.
# 8 patterns found for group.
# Adding 0 filtered edges.
#
# Processing group: ('LRCX', 'Company', 'Company', 'SUPPLIES_TO')
# 2 edges found in group.
# 0 patterns found for group.
# Adding 2 filtered edges.

# %% [markdown]
# #### Interpretation of Mined Patterns

# %% [markdown]
# The statement "Company A COMPETES_WITH Company B" is considered consistent if at least one of the following is true:
# 1. Company A and B headquarter and operate in the same country
# 2. Company A headquarters and operates in a country that company B is operating in
# 3. Company A and B are involved in the same industry
# 4. Company A operates in a country that company B is headquartering and operating in
# 5. Company A and B operate in the same country

# %%
patterns[('Company', 'Company', 'COMPETES_WITH')]
# Out:
# {Pattern((Company1)-[:HEADQUARTERS_IN]->(Country3),
#  (Company1)-[:OPERATES_IN]->(Country3),
#  (Company2)-[:HEADQUARTERS_IN]->(Country3),
#  (Company2)-[:OPERATES_IN]->(Country3)),
#  Pattern((Company1)-[:HEADQUARTERS_IN]->(Country3),
#  (Company1)-[:OPERATES_IN]->(Country3),
#  (Company2)-[:OPERATES_IN]->(Country3)),
#  Pattern((Company1)-[:IS_INVOLVED_IN]->(Industry3),
#  (Company2)-[:IS_INVOLVED_IN]->(Industry3)),
#  Pattern((Company1)-[:OPERATES_IN]->(Country3),
#  (Company2)-[:HEADQUARTERS_IN]->(Country3),
#  (Company2)-[:OPERATES_IN]->(Country3)),
#  Pattern((Company1)-[:OPERATES_IN]->(Country3),
#  (Company2)-[:OPERATES_IN]->(Country3))}

# %% [markdown]
# The statement "Company A SUBSIDIARY_OF Company B" is considered consistent if at least one of the following is true:
# 1. Company A and B headquarter and operate in the same country
# 2. Company A headquarters and operates in a country that company B is operating in
# 3. Company A and B are involved in the same industry
# 4. Company A operates in a country that company B is headquartering and operating in
# 5. Company A and B operate in the same country

# %%
patterns[('Company', 'Company', 'SUBSIDIARY_OF')]
# Out:
# {Pattern((Company1)-[:HEADQUARTERS_IN]->(Country3),
#  (Company1)-[:OPERATES_IN]->(Country3),
#  (Company2)-[:HEADQUARTERS_IN]->(Country3),
#  (Company2)-[:OPERATES_IN]->(Country3)),
#  Pattern((Company1)-[:HEADQUARTERS_IN]->(Country3),
#  (Company1)-[:OPERATES_IN]->(Country3),
#  (Company2)-[:OPERATES_IN]->(Country3)),
#  Pattern((Company1)-[:IS_INVOLVED_IN]->(Industry3),
#  (Company2)-[:IS_INVOLVED_IN]->(Industry3)),
#  Pattern((Company1)-[:OPERATES_IN]->(Country3),
#  (Company2)-[:HEADQUARTERS_IN]->(Country3),
#  (Company2)-[:OPERATES_IN]->(Country3)),
#  Pattern((Company1)-[:OPERATES_IN]->(Country3),
#  (Company2)-[:OPERATES_IN]->(Country3))}
